# %%
pip install kagglehub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.4/63.4 kB 2.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from itertools import combinations
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings("ignore")

# %%
path = kagglehub.dataset_download("osmi/mental-health-in-tech-survey")
# Out:
# ...
# 100%|██████████| 48.8k/48.8k [00:00<00:00, 614kB/s]
# Extracting files...

# %%
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/sara-arranz/.cache/kagglehub/datasets/osmi/mental-health-in-tech-survey/versions/3

# %%
df_mh = pd.read_csv("../files/raw/survey.csv")
df_mh.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees remote_work  \
# 0             No       Yes          Often            6-25          No
# 1             No        No         Rarely  More than 1000          No
# 2             No        No         Rarely            6-25          No
# 3            Yes       Yes          Often          26-100          No
# 4             No        No          Never         100-500         Yes
#
#   tech_company    benefits care_options wellness_program   seek_help  \
# ...

# %%
df_mh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %%
df_mh_ca= df_mh[df_mh["state"]== "CA"]

df_mh_ca
# Out:
#                 Timestamp  Age  Gender        Country state self_employed  \
# 12    2014-08-27 11:33:23   42  female  United States    CA           NaN
# 24    2014-08-27 11:36:48   33    male  United States    CA            No
# 27    2014-08-27 11:37:59   35  Female  United States    CA            No
# 65    2014-08-27 11:51:07   40    Male  United States    CA            No
# 74    2014-08-27 11:56:29   33    Male  United States    CA            No
# ...                   ...  ...     ...            ...   ...           ...
# 1220  2015-02-21 10:00:50   46    Male  United States    CA            No
# 1236  2015-02-24 10:32:32   60    Male  United States    CA            No
# 1249  2015-07-22 18:57:54   30       M  United States    CA            No
# 1250  2015-07-27 23:25:34   30    Male  United States    CA           Yes
# 1256  2015-11-07 12:36:58   34    male  United States    CA            No
#
#      family_history treatment work_interfere    no_employees remote_work  \
# ...

# %%
for c in df_mh_ca.columns:
    print(f"Valores únicos {c}:\n", df_mh_ca[f"{c}"].unique())
# Out:
# Valores únicos Timestamp:
#  ['2014-08-27 11:33:23' '2014-08-27 11:36:48' '2014-08-27 11:37:59'
#  '2014-08-27 11:51:07' '2014-08-27 11:56:29' '2014-08-27 12:05:13'
#  '2014-08-27 12:31:02' '2014-08-27 12:35:23' '2014-08-27 12:40:53'
#  '2014-08-27 12:42:52' '2014-08-27 12:44:51' '2014-08-27 12:48:29'
#  '2014-08-27 12:51:25' '2014-08-27 12:51:55' '2014-08-27 12:53:13'
#  '2014-08-27 12:54:11' '2014-08-27 12:55:38' '2014-08-27 13:32:48'
#  '2014-08-27 13:42:38' '2014-08-27 13:55:16' '2014-08-27 14:14:52'
#  '2014-08-27 14:15:21' '2014-08-27 14:16:00' '2014-08-27 14:18:41'
#  '2014-08-27 14:18:44' '2014-08-27 14:20:08' '2014-08-27 14:21:42'
#  '2014-08-27 14:25:54' '2014-08-27 14:26:32' '2014-08-27 14:28:43'
#  '2014-08-27 14:28:51' '2014-08-27 14:29:19' '2014-08-27 14:30:33'
#  '2014-08-27 14:31:28' '2014-08-27 14:38:13' '2014-08-27 14:39:20'
#  '2014-08-27 14:45:45' '2014-08-27 14:47:10' '2014-08-27 14:47:28'
#  '2014-08-27 14:52:44' '2014-08-27 14:53:11' '2014-08-27 15:11:30'
# ...

# %%
df_mh_ca = df_mh_ca.drop("Timestamp", axis = 1)
df_mh_ca = df_mh_ca.drop("tech_company", axis = 1)

# %%
df_mh_ca.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'state', 'self_employed', 'family_history',
#        'treatment', 'work_interfere', 'no_employees', 'remote_work',
#        'benefits', 'care_options', 'wellness_program', 'seek_help',
#        'anonymity', 'leave', 'mental_health_consequence',
#        'phys_health_consequence', 'coworkers', 'supervisor',
#        'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %%
df_mh_ca.columns = df_mh_ca.columns.str.lower()

# %%
def map_gender(g):
    g = str(g).strip().lower()
    
    if g in ['male', 'm', 'man', 'Make', "Male", "M"]:
        return 'male'
    elif g in ['female', 'f', 'Woman', 'female (trans)', 'Female (cis)', "Female", "F"]:
        return 'female'
    else:
        return 'other'

# Aplicar a la columna 'gender' (ajusta el nombre si es distinto)
df_mh_ca['gender'] = df_mh_ca['gender'].apply(map_gender)
df_mh_ca['gender'].value_counts()
# Out:
# gender
# male      93
# female    40
# other      5
# Name: count, dtype: int64

# %%
df_mh_ca.describe(include="O").T
# Out:
#                           count unique                                  top  \
# gender                      138      3                                 male
# country                     138      1                        United States
# state                       138      1                                   CA
# self_employed               137      2                                   No
# family_history              138      2                                   No
# treatment                   138      2                                  Yes
# work_interfere              117      4                            Sometimes
# no_employees                138      6                       More than 1000
# remote_work                 138      2                                   No
# benefits                    138      3                                  Yes
# care_options                138      3                                  Yes
# ...

# %%
porcentaje_nulos = round(df_mh_ca.isnull().mean() * 100, 2)

porcentaje_nulos
# Out:
# age                           0.00
# gender                        0.00
# country                       0.00
# state                         0.00
# self_employed                 0.72
# family_history                0.00
# treatment                     0.00
# work_interfere               15.22
# no_employees                  0.00
# remote_work                   0.00
# benefits                      0.00
# care_options                  0.00
# wellness_program              0.00
# seek_help                     0.00
# anonymity                     0.00
# leave                         0.00
# mental_health_consequence     0.00
# phys_health_consequence       0.00
# coworkers                     0.00
# supervisor                    0.00
# mental_health_interview       0.00
# phys_health_interview         0.00
# mental_vs_physical            0.00
# obs_consequence               0.00
# comments                     88.41
# dtype: float64

# %%
df_mh_ca["comments"].unique()
# Out:
# array([nan, 'Relatively new job. Ask again later',
#        'In small startups it is very hard to keep mental health issues truly private no matter what management does.',
#        "Don't know because I haven't checked not because it's difficult to find out. If you didn't have the don't know option I would've looked up the answer.",
#        "Regardless of a stated lack of negative consequences for discussing mental health issues with coworkers/superiors unconscious bias is a very real thing - as long as I don't *need* to inform my co-workers my mental health issues do not need to be public knowledge.",
#        "I'm troubled by the way that our hiring process tends to filter out non-neurotypicals of all stripes. Competent people who act a little funny can be hard to hire.",
# ...

# %%
nulls = df_mh_ca.isna()
nulls
# Out:
#         age  gender  country  state  self_employed  family_history  treatment  \
# 12    False   False    False  False           True           False      False
# 24    False   False    False  False          False           False      False
# 27    False   False    False  False          False           False      False
# 65    False   False    False  False          False           False      False
# 74    False   False    False  False          False           False      False
# ...     ...     ...      ...    ...            ...             ...        ...
# 1220  False   False    False  False          False           False      False
# 1236  False   False    False  False          False           False      False
# 1249  False   False    False  False          False           False      False
# 1250  False   False    False  False          False           False      False
# 1256  False   False    False  False          False           False      False
#
# ...

# %%
df_null_wi = df_mh_ca[df_mh_ca["work_interfere"].isna()]

df_null_wi
# Out:
#       age  gender        country state self_employed family_history treatment  \
# 167    42    male  United States    CA            No             No        No
# 295    24  female  United States    CA            No             No        No
# 297    60    male  United States    CA            No             No        No
# 314    27    male  United States    CA            No            Yes        No
# 325    25    male  United States    CA            No             No        No
# 366    35    male  United States    CA            No            Yes        No
# 402    23    male  United States    CA            No             No        No
# 405    26    male  United States    CA            No            Yes        No
# 407    33    male  United States    CA            No             No        No
# 490    31    male  United States    CA            No             No        No
# 509    22    male  United States    CA            No             No        No
# ...

# %%
df_mh_ca["work_interfere"] =df_mh_ca["work_interfere"].fillna("Unknown")

# %%
df_mh_ca
# Out:
#       age  gender        country state self_employed family_history treatment  \
# 12     42  female  United States    CA           NaN            Yes       Yes
# 24     33    male  United States    CA            No            Yes       Yes
# 27     35  female  United States    CA            No            Yes       Yes
# 65     40    male  United States    CA            No            Yes        No
# 74     33    male  United States    CA            No             No        No
# ...   ...     ...            ...   ...           ...            ...       ...
# 1220   46    male  United States    CA            No            Yes       Yes
# 1236   60    male  United States    CA            No             No       Yes
# 1249   30    male  United States    CA            No            Yes       Yes
# 1250   30    male  United States    CA           Yes            Yes       Yes
# 1256   34    male  United States    CA            No            Yes       Yes
#
# ...

# %%
df_mh_ca.groupby("work_interfere")[["leave", "mental_health_consequence"]].value_counts().sort_values(ascending=False).reset_index()
# Out:
#    work_interfere               leave mental_health_consequence  count
# 0       Sometimes          Don't know                     Maybe     13
# 1           Never          Don't know                     Maybe      9
# 2         Unknown          Don't know                        No      8
# 3       Sometimes          Don't know                       Yes      7
# 4       Sometimes  Somewhat difficult                       Yes      7
# 5          Rarely          Don't know                        No      6
# 6       Sometimes          Don't know                        No      6
# 7       Sometimes       Somewhat easy                        No      5
# 8         Unknown           Very easy                        No      5
# 9         Unknown          Don't know                     Maybe      5
# 10          Often          Don't know                       Yes      5
# 11          Often          Don't know                     Maybe      5
# ...

# %% [markdown]
# ## Perfil salud mental de los encuestados

# %%
df_mh_ca.columns
# Out:
# Index(['age', 'gender', 'country', 'state', 'self_employed', 'family_history',
#        'treatment', 'work_interfere', 'no_employees', 'remote_work',
#        'benefits', 'care_options', 'wellness_program', 'seek_help',
#        'anonymity', 'leave', 'mental_health_consequence',
#        'phys_health_consequence', 'coworkers', 'supervisor',
#        'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %%
df_mh_ca_profile = df_mh_ca[['age', 'gender', 'self_employed', 'family_history','treatment', 'remote_work']]

# %%
df_mh_ca_profile
# Out:
#       age  gender self_employed family_history treatment remote_work
# 12     42  female           NaN            Yes       Yes          No
# 24     33    male            No            Yes       Yes          No
# 27     35  female            No            Yes       Yes         Yes
# 65     40    male            No            Yes        No         Yes
# 74     33    male            No             No        No          No
# ...   ...     ...           ...            ...       ...         ...
# 1220   46    male            No            Yes       Yes          No
# 1236   60    male            No             No       Yes         Yes
# 1249   30    male            No            Yes       Yes          No
# 1250   30    male           Yes            Yes       Yes          No
# 1256   34    male            No            Yes       Yes          No
#
# [138 rows x 6 columns]

# %%
df_mh_ca_profile.describe(include=object).T
# Out:
#                count unique   top freq
# gender           138      3  male   93
# self_employed    137      2    No  127
# family_history   138      2    No   70
# treatment        138      2   Yes   86
# remote_work      138      2    No  118

# %%
sns.countplot(
    data = df_mh_ca_profile,
    x='self_employed',
    hue="gender",
    palette = "viridis"
)

plt.title('Empleados por cuenta propia por género')
plt.ylabel('Count')
plt.xlabel('Trabajador por cuenta ajena')
plt.xticks(rotation=0)
plt.errorbar= None,
plt.tight_layout()
plt.show()

# %%
df_pie_gend = df_mh_ca_profile['gender'].value_counts()


plt.pie(
    df_pie_gend.values,
    labels=df_pie_gend.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=plt.cm.Pastel1.colors
)

plt.title('Género')
plt.axis('equal')  
plt.show()

# %%
df_pie_trat = df_mh_ca_profile['treatment'].value_counts()


plt.pie(
    df_pie_trat.values,
    labels=df_pie_trat.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=plt.cm.Pastel1.colors
)

plt.title('Personas en tratamiento')
plt.axis('equal')  
plt.show()

# %%
sns.countplot(
    data = df_mh_ca_profile,
    x='treatment',
    hue="gender",
    palette = "viridis"
)

plt.title('Personas en tratamiento por género')
plt.ylabel('Count')
plt.xlabel('Personas en tratamiento')
plt.xticks(rotation=0)
plt.errorbar= None,
plt.tight_layout()
plt.show()

# %%
df_pie_fam = df_mh_ca_profile['family_history'].value_counts()


plt.pie(
    df_pie_fam.values,
    labels=df_pie_fam.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=plt.cm.Pastel1.colors
)

plt.title('Historial familiar de enfermedades mentales')
plt.axis('equal')  
plt.show()

# %%
sns.countplot(
    data = df_mh_ca_profile,
    x='family_history',
    hue="gender",
    palette = "viridis"
)

plt.title('Personas con historial familiar de enfermedades mentales por género')
plt.ylabel('Count')
plt.xlabel('Historial familiar')
plt.xticks(rotation=0)
plt.errorbar= None,
plt.tight_layout()
plt.show()

# %%
sns.countplot(
    data = df_mh_ca_profile,
    x='remote_work',
    hue="treatment",
    palette = "viridis"
)

plt.title('Personas con trabajo en remoto en tratamiento')
plt.ylabel('Count')
plt.xlabel('Trabajo remoto')
plt.xticks(rotation=0)
plt.errorbar= None,
plt.tight_layout()
plt.show()

# %%
sns.barplot(
    data = df_mh_ca_profile,
    y='age',
    x="treatment",
    palette = "viridis",
    errorbar= None
)

plt.title('Personas en tratamiento por edad')
plt.ylabel('Edad')
plt.xlabel('Tratamiento')
plt.xticks(rotation=0),
plt.tight_layout()
plt.show()

# %%
sns.countplot(
    data = df_mh_ca_profile,
    x='self_employed',
    hue="treatment",
    palette = "viridis"
)

plt.title('Empleados por cuenta propia en tratamiento')
plt.ylabel('Count')
plt.xlabel('Trabajador por cuenta propia')
plt.xticks(rotation=0),
plt.tight_layout()
plt.show()

# %% [markdown]
# Tablas de percepción de la comunicación en el entorno laboral

# %%
import matplotlib.ticker as mtick
new_cols = [
    "seek_help", "leave", "mental_health_consequence", "phys_health_consequence",
    "coworkers", "supervisor", "mental_health_interview", "phys_health_interview",
    "mental_vs_physical", "obs_consequence"
]

for c in new_cols:
    ax = sns.countplot(
        data=df_mh_ca,
        x=c,
        palette="viridis"
    )
    
    total = len(df_mh_ca[c].dropna())  # Total válido (sin NaN)

    for p in ax.patches:
        height = p.get_height()
        percentage = 100 * height / total
        ax.text(
            p.get_x() + p.get_width() / 2,
            height + 0.5,
            f'{percentage:.1f}%',  # Mostrar porcentaje con 1 decimal
            ha='center',
            fontsize=9
        )
    ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=total))
    plt.ylabel('Porcentaje')
    plt.xlabel(c)
    plt.xticks(rotation=0)
    plt.title(f'Distribución de {c}')
    plt.tight_layout()
    plt.show()

# %%
new_cols = [
    "seek_help", "leave", "mental_health_consequence", "phys_health_consequence",
    "coworkers", "supervisor", "mental_health_interview", "phys_health_interview",
    "mental_vs_physical", "obs_consequence"]


fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(20, 8))
axes = axes.flatten()  

for i, c in enumerate(new_cols):
    ax = axes[i]
    total = len(df_mh_ca[c].dropna())

    sns.countplot(data=df_mh_ca, x=c, palette="viridis", ax=ax)

    for p in ax.patches:
        height = p.get_height()
        percentage = 100 * height / total
        ax.text(
            p.get_x() + p.get_width() / 2,
            height + total * 0.01,
            f'{percentage:.1f}%',
            ha='center',
            fontsize=8
        )

    # Convertir el eje Y a porcentaje
    ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=total))

    ax.set_title(c.replace('_', ' ').title(), fontsize=10)
    ax.set_xlabel('')
    ax.set_ylabel('Porcentaje')
    ax.tick_params(axis='x', rotation=45)

# Ajustar layout para que no se sobrepongan
plt.tight_layout()
plt.show()

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Data set con el filtro de las empresas +1000 empleados

# %%
df_mh_ca["no_employees"].unique()
# Out:
# array(['26-100', '6-25', 'More than 1000', '1-5', '100-500', '500-1000'],
#       dtype=object)

# %%
df_mh_ca_emp = df_mh_ca[df_mh_ca["no_employees"]== "More than 1000"]

# %% [markdown]
# ## Perfil salud mental de los encuestados (empresas +1000)

# %%
df_mh_ca_emp.columns
# Out:
# Index(['age', 'gender', 'country', 'state', 'self_employed', 'family_history',
#        'treatment', 'work_interfere', 'no_employees', 'remote_work',
#        'benefits', 'care_options', 'wellness_program', 'seek_help',
#        'anonymity', 'leave', 'mental_health_consequence',
#        'phys_health_consequence', 'coworkers', 'supervisor',
#        'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %%
df_mh_ca_emp = df_mh_ca_emp.drop(['country', 'state', 'no_employees', 'comments'], axis=1)

# %%
df_mh_ca_emp.to_csv("../files/processed/saludmental_cal.csv")

# %%
df_mh_ca_profile_v2 = df_mh_ca_emp[['age', 'gender', 'self_employed', 'family_history','treatment', 'remote_work']]

# %%
df_mh_ca_profile_v2
# Out:
#       age gender self_employed family_history treatment remote_work
# 65     40   male            No            Yes        No         Yes
# 74     33   male            No             No        No          No
# 84     33   male            No            Yes        No          No
# 156    27   male            No            Yes       Yes          No
# 162    31   male            No             No        No          No
# ...   ...    ...           ...            ...       ...         ...
# 1150   32   male            No             No       Yes          No
# 1165   32   male            No            Yes        No          No
# 1181   38   male            No            Yes       Yes          No
# 1236   60   male            No             No       Yes         Yes
# 1256   34   male            No            Yes       Yes          No
#
# [68 rows x 6 columns]

# %%
df_mh_ca_profile_v2.describe(include= object).T
# Out:
#                count unique   top freq
# gender            68      3  male   56
# self_employed     68      2    No   67
# family_history    68      2    No   39
# treatment         68      2   Yes   37
# remote_work       68      2    No   64

# %%
sns.countplot(
    data = df_mh_ca_profile_v2,
    x='self_employed',
    hue="gender",
    palette = "viridis"
)

plt.title('Empleados por cuenta propia por género')
plt.ylabel('Count')
plt.xlabel('Trabajador por cuenta ajena')
plt.xticks(rotation=0)
plt.errorbar= None,
plt.tight_layout()
plt.show()

# %%
df_pie_gend_v2 = df_mh_ca_profile_v2['gender'].value_counts()


plt.pie(
    df_pie_gend_v2.values,
    labels=df_pie_gend_v2.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=plt.cm.Pastel1.colors
)

plt.title('Género')
plt.axis('equal')  
plt.show()

# %%
df_pie_trat_v2 = df_mh_ca_profile_v2['treatment'].value_counts()


plt.pie(
    df_pie_trat_v2.values,
    labels=df_pie_trat_v2.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=plt.cm.Pastel1.colors
)

plt.title('Personas en tratamiento')
plt.axis('equal')  
plt.show()

# %%
sns.countplot(
    data = df_mh_ca_profile_v2,
    x='treatment',
    hue="gender",
    palette = "viridis"
)

plt.title('Personas en tratamiento por género')
plt.ylabel('Count')
plt.xlabel('Personas en tratamiento')
plt.xticks(rotation=0)
plt.errorbar= None,
plt.tight_layout()
plt.show()

# %%
df_pie_fam_v2 = df_mh_ca_profile_v2['family_history'].value_counts()


plt.pie(
    df_pie_fam_v2.values,
    labels=df_pie_fam_v2.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=plt.cm.Pastel1.colors
)

plt.title('Historial familiar de enfermedades mentales')
plt.axis('equal')  
plt.show()

# %%
sns.countplot(
    data = df_mh_ca_profile_v2,
    x='family_history',
    hue="gender",
    palette = "viridis"
)

plt.title('Personas con historial familiar de enfermedades mentales por género')
plt.ylabel('Count')
plt.xlabel('Historial familiar')
plt.xticks(rotation=0)
plt.errorbar= None,
plt.tight_layout()
plt.show()

# %%
sns.countplot(
    data = df_mh_ca_profile_v2,
    x='remote_work',
    hue="treatment",
    palette = "viridis"
)

plt.title('Personas con trabajo en remoto en tratamiento')
plt.ylabel('Count')
plt.xlabel('Trabajo remoto')
plt.xticks(rotation=0)
plt.errorbar= None,
plt.tight_layout()
plt.show()

# %%
sns.barplot(
    data = df_mh_ca_profile_v2,
    y='age',
    x="treatment",
    palette = "viridis",
    errorbar= None
)

plt.title('Personas en tratamiento por edad')
plt.ylabel('Edad')
plt.xlabel('Tratamiento')
plt.xticks(rotation=0),
plt.tight_layout()
plt.show()

# %%
sns.countplot(
    data = df_mh_ca_profile_v2,
    x='self_employed',
    hue="treatment",
    palette = "viridis"
)

plt.title('Empleados por cuenta propia en tratamiento')
plt.ylabel('Count')
plt.xlabel('Trabajador por cuenta propia')
plt.xticks(rotation=0),
plt.tight_layout()
plt.show()

# %% [markdown]
# Tablas de percepción de la comunicación en el entorno laboral

# %%
import matplotlib.ticker as mtick
new_cols = [
    "seek_help", "leave", "mental_health_consequence", "phys_health_consequence",
    "coworkers", "supervisor", "mental_health_interview", "phys_health_interview",
    "mental_vs_physical", "obs_consequence"
]

for c in new_cols:
    ax = sns.countplot(
        data=df_mh_ca_emp,
        x=c,
        palette="viridis"
    )
    
    total = len(df_mh_ca[c].dropna())  # Total válido (sin NaN)

    for p in ax.patches:
        height = p.get_height()
        percentage = 100 * height / total
        ax.text(
            p.get_x() + p.get_width() / 2,
            height + 0.5,
            f'{percentage:.1f}%',  # Mostrar porcentaje con 1 decimal
            ha='center',
            fontsize=9
        )
    ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=total))
    plt.ylabel('Porcentaje')
    plt.xlabel(c)
    plt.xticks(rotation=0)
    plt.title(f'Distribución de {c}')
    plt.tight_layout()
    plt.show()

# %%
new_cols = [
    "seek_help", "leave", "mental_health_consequence", "phys_health_consequence",
    "coworkers", "supervisor", "mental_health_interview", "phys_health_interview",
    "mental_vs_physical", "obs_consequence"]


fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(20, 8))
axes = axes.flatten()  

for i, c in enumerate(new_cols):
    ax = axes[i]
    total = len(df_mh_ca_emp[c].dropna())

    sns.countplot(data=df_mh_ca_emp, x=c, palette="viridis", ax=ax)

    for p in ax.patches:
        height = p.get_height()
        percentage = 100 * height / total
        ax.text(
            p.get_x() + p.get_width() / 2,
            height + total * 0.01,
            f'{percentage:.1f}%',
            ha='center',
            fontsize=8
        )

    # Convertir el eje Y a porcentaje
    ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=total))

    ax.set_title(c.replace('_', ' ').title(), fontsize=10)
    ax.set_xlabel('')
    ax.set_ylabel('Porcentaje')
    ax.tick_params(axis='x', rotation=45)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

fig.suptitle('En empresas con más de 1000 empleados', fontsize=16, fontweight='bold')


# Ajustar layout para que no se sobrepongan
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# ## Relación de variables

# %%
# Crear tabla cruzada
cross_tab = pd.crosstab(df_mh_ca_emp['seek_help'], df_mh_ca_emp['mental_health_consequence'], normalize='index') * 100

# Crear gráfico de barras agrupadas
cross_tab.plot(kind='bar', stacked=False, colormap='viridis')
plt.title('Relación entre la Disposición a Buscar Ayuda y la Percepción de Consecuencias Negativas')
plt.xlabel('¿Buscarías ayuda?')
plt.ylabel('Porcentaje')
plt.xticks(rotation=0)
plt.legend(title='Consecuencias Negativas')
plt.tight_layout()
plt.show();

# %%
# Crear tabla cruzada
cross_tab = pd.crosstab(df_mh_ca_emp['treatment'], df_mh_ca_emp['mental_health_interview'], normalize='index') * 100

# Crear gráfico de barras agrupadas
cross_tab.plot(kind='bar', stacked=False, colormap='viridis')
plt.title('Relación entre estar en tratamiento y la intención de mencionar un problema de salud mental en una entrevista')
plt.xlabel('Está en tratamiento')
plt.ylabel('Porcentaje')
plt.xticks(rotation=0)
plt.legend(title='Mancionaría su diagnóstico')
plt.tight_layout()
plt.show();

# %%
cross_tab = pd.crosstab(df_mh_ca_emp['wellness_program'], df_mh_ca_emp['seek_help'], normalize='index') * 100

# Crear gráfico de barras agrupadas
cross_tab.plot(kind='bar', stacked=False, colormap='viridis')
plt.title('Relación entre los programas de bienestar y la búsqueda de ayuda')
plt.xlabel('Programas de bienestar')
plt.ylabel('Porcentaje')
plt.xticks(rotation=0)
plt.legend(title='Búsqueda de ayuda')
plt.tight_layout()
plt.show();

# %%
cross_tab = pd.crosstab(df_mh_ca_emp['leave'], df_mh_ca_emp['supervisor'], normalize='index') * 100

# Crear gráfico de barras agrupadas
cross_tab.plot(kind='bar', stacked=False, colormap='viridis')
plt.title('Relación entre facilidad para coger una baja y poder hablar con los supervisores')
plt.xlabel('Poder coger una baja')
plt.ylabel('Porcentaje')
plt.xticks(rotation=90)
plt.legend(title='Hablar con supervisores')
plt.tight_layout()
plt.show();

# %%
# Agrupar edades en rangos
bins = [0, 25, 35, 45, 60, 100]
labels = ['<25', '25-34', '35-44', '45-59', '60+']
df_mh_ca_emp['age_group'] = pd.cut(df_mh_ca_emp['age'], bins=bins, labels=labels, right=False)

# Filtrar valores válidos
df_plot = df_mh_ca_emp[df_mh_ca_emp['treatment'].notna() & df_mh_ca_emp['gender'].notna() & df_mh_ca_emp['age_group'].notna()]

# Hacer el barplot
plt.figure(figsize=(10, 6))
sns.countplot(
    data=df_plot,
    x='age_group',
    hue='gender',
    palette='viridis',
    order=labels
)

plt.title('Uso del tratamiento según género y rango de edad')
plt.xlabel('Rango de edad')
plt.ylabel('Cantidad de personas en tratamiento')
plt.legend(title='Género', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Agrupar edades
bins = [0, 25, 35, 45, 60, 100]
labels = ['<25', '25-34', '35-44', '45-59', '60+']
df_mh_ca['age_group'] = pd.cut(df_mh_ca['age'], bins=bins, labels=labels, right=False)

# Limpiar datos
df_plot = df_mh_ca[
    df_mh_ca['treatment'].notna() &
    df_mh_ca['gender'].notna() &
    df_mh_ca['age_group'].notna()
]

# Agrupar y calcular porcentaje
grouped = (
    df_plot
    .groupby(['age_group', 'gender'])['treatment']
    .value_counts(normalize=True)
    .rename('percentage')
    .reset_index()
)

# Filtrar solo quienes dijeron "Yes" (o cambia a "No" si prefieres analizar eso)
grouped_yes = grouped[grouped['treatment'] == 'Yes']

# Graficar
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=grouped_yes,
    x='age_group',
    y='percentage',
    hue='gender',
    palette='viridis',
    order=labels
)


for p in ax.patches:
    height = p.get_height()
    if not pd.isna(height):
        ax.text(
            p.get_x() + p.get_width() / 2,
            height + 0.01,
            f'{height:.1%}',
            ha='center',
            va='bottom',
            fontsize=9
        )

plt.title('Porcentaje de personas que buscaron tratamiento\nsegún género y rango de edad')
plt.ylabel('Porcentaje')
plt.xlabel('Rango de edad')
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y:.0%}'))
plt.legend(title='Género', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
