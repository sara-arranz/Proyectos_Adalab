# %%
import requests
import re
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Coloca tus credenciales aquí
CLIENT_ID = "90527396d8f84493aae641a416e24f17"
CLIENT_SECRET = "0d68e0bcec03408890499dcb774bd3f6"

# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
def rastreo_global(year, limit=50, market='ES', max_results=500):
    """rastreo_global:Realiza una búsqueda global de canciones de un género en Spotify y con un año determinado.

    Arguments:
        año (int o str) -- Año específico para filtrar 

    Keyword Arguments:
        limit {int} -- Número de canciones por solicitud (máx. 50). (default: {50})
        market {str} -- Mercado donde se puede escuchar cada canción (default: {'ES'})
        max_results {int} -- Número total de resultados deseados (default: {500})

    Returns:
        datos {dict} -- lista de dicionarios de canciones con información relevante 
    """
    
    generos = ['reggaeton', 'pop', 'rap', 'indie']
    resultados_por_genero = {}

    # Iterar sobre los géneros
    for genero in generos:
        print(f"Buscando canciones del género {genero}...")

        datos = []  # Lista donde almacenaremos los resultados
        offset = 0  # Para la paginación
        
        while len(datos) < max_results:
            # Realizar la búsqueda en Spotify por género y año
            query = f"genre:{genero} year:{year}"
            busqueda = sp.search(q=query, limit=limit, offset=offset, type='track', market=market)
            
            # Obtener los resultados
            items = busqueda['tracks']['items']
            
            # Si no hay más resultados, salir del bucle
            if not items:
                break

            # Procesar los resultados
            for item in items:
                track_info = {
                    'track_name': item['name'],
                    'artist_name': ', '.join([artist['name'] for artist in item['artists']]),  # Todos los artistas
                    'release_date': item['album']['release_date'],
                    'id_track': item['id'],
                    'popularity': item['popularity'],
                    'genero': genero  # Añadimos el género
                }
                datos.append(track_info)

                # Si alcanzamos el máximo de resultados, detenemos la búsqueda
                if len(datos) >= max_results:
                    break

            # Aumentamos el offset para la siguiente paginación
            offset += limit
        
        # Almacenamos los resultados de este género en el diccionario
        resultados_por_genero[genero] = datos

    return resultados_por_genero

# %%
resultados = rastreo_global (year = 2021)
# Out:
# Buscando canciones del género reggaeton...
# Buscando canciones del género pop...
# Buscando canciones del género rap...
# Buscando canciones del género indie...

# %%
resultados
# Out:
# {'reggaeton': [{'track_name': 'Ley Seca',
#    'artist_name': 'JHAYCO, Anuel AA',
#    'release_date': '2021-09-03',
#    'id_track': '3JCaq3KDSROg3TXhdiDa9n',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Old Skul',
#    'artist_name': 'Rauw Alejandro',
#    'release_date': '2021-12-10',
#    'id_track': '4Z8HZSApeddaRM2ovivUj4',
#    'popularity': 75,
#    'genero': 'reggaeton'},
#   {'track_name': 'ALMAS GEMELAS',
#    'artist_name': 'Myke Towers',
#    'release_date': '2021-07-22',
#    'id_track': '2KcNrONbZ0hvBPjvrDO2tx',
#    'popularity': 67,
#    'genero': 'reggaeton'},
#   {'track_name': 'Desesperados',
#    'artist_name': 'Rauw Alejandro, Chencho Corleone',
#    'release_date': '2021-12-10',
#    'id_track': '6mmPpaltUZK7xjNlBPQQ0p',
#    'popularity': 74,
#    'genero': 'reggaeton'},
#   {'track_name': 'Todo De Ti',
#    'artist_name': 'Rauw Alejandro',
#    'release_date': '2021-12-10',
#    'id_track': '3rdAz1fbUfZxYgaCviYhRo',
#    'popularity': 76,
#    'genero': 'reggaeton'},
#   {'track_name': 'Cúrame',
#    'artist_name': 'Rauw Alejandro',
#    'release_date': '2021-12-10',
#    'id_track': '1FlL8ycld6uVDDyhV7P5FA',
#    'popularity': 70,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tokyo',
#    'artist_name': 'JHAYCO',
#    'release_date': '2021-09-03',
#    'id_track': '1gYipuSzUpI6BENbGrgeid',
#    'popularity': 67,
#    'genero': 'reggaeton'},
#   {'track_name': 'Dile (Homenaje)',
#    'artist_name': 'JHAYCO',
#    'release_date': '2021-09-03',
#    'id_track': '073yIM7v2j6XadD4Nkn0Fh',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'Yonaguni',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2021-06-04',
#    'id_track': '2JPLbjOn0wPCngEot2STUS',
#    'popularity': 73,
#    'genero': 'reggaeton'},
#   {'track_name': 'EL BARCO',
#    'artist_name': 'KAROL G',
#    'release_date': '2021-03-26',
#    'id_track': '0MT6qJd7wKlWjH7tP7oWHi',
#    'popularity': 71,
#    'genero': 'reggaeton'},
#   {'track_name': 'CONTIGO VOY A MUERTE',
#    'artist_name': 'KAROL G, Camilo',
#    'release_date': '2021-03-26',
#    'id_track': '615XWyY2RPfk3iuYcU6qvi',
#    'popularity': 70,
#    'genero': 'reggaeton'},
#   {'track_name': 'Air Drop',
#    'artist_name': 'Bryant Myers',
#    'release_date': '2021-07-30',
#    'id_track': '1oP4qehV9MBDaA89mfb1HR',
#    'popularity': 61,
#    'genero': 'reggaeton'},
#   {'track_name': '23 Preguntas',
#    'artist_name': 'Anuel AA',
#    'release_date': '2021-08-23',
#    'id_track': '5ANkjNH7elrxzggidjnH9v',
#    'popularity': 67,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tacones Rojos',
#    'artist_name': 'Sebastian Yatra',
#    'release_date': '2021-10-22',
#    'id_track': '0Be7sopyKMv8Y8npsUkax2',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': 'EXPERIMENTO',
#    'artist_name': 'Myke Towers',
#    'release_date': '2021-09-23',
#    'id_track': '6c32C8T3KlXrbvWSoD5aON',
#    'popularity': 62,
#    'genero': 'reggaeton'},
#   {'track_name': 'Quiéreme Mientras Se Pueda',
#    'artist_name': 'Manuel Turizo',
#    'release_date': '2021-04-09',
#    'id_track': '1WH3iquIQXnSPwUzlROT8R',
#    'popularity': 70,
#    'genero': 'reggaeton'},
#   {'track_name': 'Todo De Ti',
#    'artist_name': 'Rauw Alejandro',
#    'release_date': '2021-05-20',
#    'id_track': '4fSIb4hdOQ151TILNsSEaF',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'Esa Cruz',
#    'artist_name': 'Anuel AA',
#    'release_date': '2021-11-26',
#    'id_track': '7dlFn4xJYAg8hdp9mdz9Zr',
#    'popularity': 64,
#    'genero': 'reggaeton'},
#   {'track_name': 'Vida de Rico',
#    'artist_name': 'Camilo',
#    'release_date': '2021-03-04',
#    'id_track': '4nTduFjaTmGysc9WKNuCcs',
#    'popularity': 67,
#    'genero': 'reggaeton'},
#   {'track_name': 'MÍRENME AHORA',
#    'artist_name': 'Myke Towers',
#    'release_date': '2021-04-23',
#    'id_track': '1QigNNcv8c5X2iL294bZev',
#    'popularity': 61,
#    'genero': 'reggaeton'},
#   {'track_name': 'BEBÉ',
#    'artist_name': 'Camilo, El Alfa',
#    'release_date': '2021-03-04',
#    'id_track': '3Zf4GutWZ7Hv3wsVQsSQPs',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'Pareja Del Año',
#    'artist_name': 'Sebastian Yatra, Myke Towers',
#    'release_date': '2021-04-16',
#    'id_track': '2rCbl9naJYhaxjLsfx88uM',
#    'popularity': 65,
#    'genero': 'reggaeton'},
#   {'track_name': '911 (Remix)',
#    'artist_name': 'Sech, JHAYCO',
#    'release_date': '2021-07-09',
#    'id_track': '27RSJHEA99Y0Vsow7nA37A',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'Cosa Guapa',
#    'artist_name': 'Rauw Alejandro',
#    'release_date': '2021-12-10',
#    'id_track': '7aWiJeMyxxPEyjwvZyauAF',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'FRIKI',
#    'artist_name': 'Feid, KAROL G',
#    'release_date': '2021-12-17',
#    'id_track': '2WrqTrNIHqfcMCgmEo0A7E',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'Millones',
#    'artist_name': 'Camilo',
#    'release_date': '2021-03-04',
#    'id_track': '3YAnNBdk0uHyakXXzMbNJq',
#    'popularity': 65,
#    'genero': 'reggaeton'},
#   {'track_name': 'Pepas',
#    'artist_name': 'Farruko',
#    'release_date': '2021-06-24',
#    'id_track': '5fwSHlTEWpluwOM0Sxnh5k',
#    'popularity': 74,
#    'genero': 'reggaeton'},
#   {'track_name': 'Aloha',
#    'artist_name': 'Maluma, Beéle, Rauw Alejandro, Mambo Kingz, DJ Luian, Darell',
#    'release_date': '2021-03-05',
#    'id_track': '5RAIMjdrCEjpjaR5tBATXU',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': "Desenfocao'",
#    'artist_name': 'Rauw Alejandro',
#    'release_date': '2021-12-10',
#    'id_track': '2CEf2gU5ZJamLXa3NrgAvA',
#    'popularity': 72,
#    'genero': 'reggaeton'},
#   {'track_name': 'Qué Más Pues?',
#    'artist_name': 'J Balvin, Maria Becerra',
#    'release_date': '2021-09-10',
#    'id_track': '6D2TCm4nf5nxAcdGJ7w3QP',
#    'popularity': 67,
#    'genero': 'reggaeton'},
#   {'track_name': 'Nostálgico',
#    'artist_name': 'Rvssian, Rauw Alejandro, Chris Brown',
#    'release_date': '2021-09-08',
#    'id_track': '2BEcap3xJtmiPaHKyfQi4e',
#    'popularity': 67,
#    'genero': 'reggaeton'},
#   {'track_name': 'Sexo Virtual',
#    'artist_name': 'Rauw Alejandro',
#    'release_date': '2021-12-10',
#    'id_track': '1lV3QHHMAQt0Kc1ioZq2MP',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': 'North Carolina',
#    'artist_name': 'Anuel AA, Eladio Carrion',
#    'release_date': '2021-11-26',
#    'id_track': '0B1J4Mm4oRVMqoy6RM9vIM',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Promesa',
#    'artist_name': 'Alex Gargolas, Eladio Carrion',
#    'release_date': '2021-08-27',
#    'id_track': '7bwufLkhYm0zA6YOBEUTt7',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'EL MAKINON',
#    'artist_name': 'KAROL G, Mariah Angeliq',
#    'release_date': '2021-03-26',
#    'id_track': '2FSGUA0gFgGeQdprjtGM2M',
#    'popularity': 67,
#    'genero': 'reggaeton'},
#   {'track_name': 'SI TÚ SUPIERAS - Bonus Track',
#    'artist_name': 'Feid',
#    'release_date': '2021-08-20',
#    'id_track': '1SCYfmGM5ueb6YiiQbLXVn',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tusa',
#    'artist_name': 'KAROL G, Nicki Minaj',
#    'release_date': '2021-03-26',
#    'id_track': '0dKg2vGC1hFqcK5LGTaKzX',
#    'popularity': 67,
#    'genero': 'reggaeton'},
#   {'track_name': 'Persia - Remix',
#    'artist_name': 'Jossef, Jamby El Favo, Eix',
#    'release_date': '2021-01-22',
#    'id_track': '3SgybTfx3GWHAcjhK9iPmz',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'Loco',
#    'artist_name': 'Justin Quiles, Chimbala, Zion & Lennox',
#    'release_date': '2021-08-19',
#    'id_track': '6b2HYgqcK9mvktt4GxAu72',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Happy Birthday',
#    'artist_name': 'Tempo, El Alfa',
#    'release_date': '2021-12-09',
#    'id_track': '0XkGuccSfq43beHberZYKz',
#    'popularity': 61,
#    'genero': 'reggaeton'},
#   {'track_name': 'Loco',
#    'artist_name': 'Justin Quiles, Chimbala, Zion & Lennox',
#    'release_date': '2021-05-13',
#    'id_track': '6PDlkWmrq2ZKiUuFt2aQsH',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'BICHOTA',
#    'artist_name': 'KAROL G',
#    'release_date': '2021-03-26',
#    'id_track': '1WvrDdouh6C51In1SdATbq',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ay, DiOs Mío!',
#    'artist_name': 'KAROL G',
#    'release_date': '2021-03-26',
#    'id_track': '1beTDCe7sT7fzm8WIKXicz',
#    'popularity': 65,
#    'genero': 'reggaeton'},
#   {'track_name': 'Desesperados',
#    'artist_name': 'Rauw Alejandro, Chencho Corleone',
#    'release_date': '2021-12-11',
#    'id_track': '6ZOcbKub95XSDESsKKuH41',
#    'popularity': 65,
#    'genero': 'reggaeton'},
#   {'track_name': 'Fiel - Remix',
#    'artist_name': 'Wisin, JHAYCO, Anuel AA, Los Legendarios, Myke Towers',
#    'release_date': '2021-06-15',
#    'id_track': '43qcs9NpJhDxtG91zxFkj7',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': '2/Catorce',
#    'artist_name': 'Rauw Alejandro, Mr. Naisgai',
#    'release_date': '2021-12-10',
#    'id_track': '78QcVmzxS0wIwuC2rpAauI',
#    'popularity': 65,
#    'genero': 'reggaeton'},
#   {'track_name': 'Si Te Interesa',
#    'artist_name': 'Beéle',
#    'release_date': '2021-11-10',
#    'id_track': '3cuxPiF5W1ID8R5Mmr36gS',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'AM Remix',
#    'artist_name': 'Nio Garcia, J Balvin, Bad Bunny',
#    'release_date': '2021-06-24',
#    'id_track': '05bfbizlM5AX6Mf1RRyMho',
#    'popularity': 64,
#    'genero': 'reggaeton'},
#   {'track_name': 'Los Bo',
#    'artist_name': 'JHAYCO, Myke Towers',
#    'release_date': '2021-01-07',
#    'id_track': '71CIZGbBZR71GfQFB8c2xU',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Medallo',
#    'artist_name': 'Blessd, Justin Quiles, Lenny Tavárez',
#    'release_date': '2021-10-27',
#    'id_track': '6lX6l7OuA3qrnIRfdsr0dw',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': 'Travesuras - Remix',
#    'artist_name': 'Nio Garcia, Casper Magico, Ozuna, Wisin & Yandel, Myke Towers, Flow La Movie',
#    'release_date': '2021-03-11',
#    'id_track': '0VWLId2RwPCno9s1cJm2Vy',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'Sobrio',
#    'artist_name': 'Maluma',
#    'release_date': '2021-07-08',
#    'id_track': '4HzqWEdAbzcVFDv0pvxV4w',
#    'popularity': 64,
#    'genero': 'reggaeton'},
#   {'track_name': '1942',
#    'artist_name': 'Anuel AA',
#    'release_date': '2021-11-26',
#    'id_track': '1GeDO38NIKUFT7dzjifCbA',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Índigo',
#    'artist_name': 'Camilo, Evaluna Montaner',
#    'release_date': '2021-10-13',
#    'id_track': '4knc1Fp3kbuq8bH2byOvLu',
#    'popularity': 62,
#    'genero': 'reggaeton'},
#   {'track_name': 'SEJODIOTO',
#    'artist_name': 'KAROL G',
#    'release_date': '2021-09-21',
#    'id_track': '704LUEih663hiE3CnyUrFW',
#    'popularity': 64,
#    'genero': 'reggaeton'},
#   {'track_name': 'Colorín Colorado',
#    'artist_name': 'Justin Quiles',
#    'release_date': '2021-08-19',
#    'id_track': '2YZDh5CecWx0qlFiTvqVQ9',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Los Bo',
#    'artist_name': 'JHAYCO, Myke Towers',
#    'release_date': '2021-09-03',
#    'id_track': '0AXTYqxygPlNS6E4arLO1g',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mujeriego',
#    'artist_name': 'Ryan Castro',
#    'release_date': '2021-12-17',
#    'id_track': '78kygHp1dvW1kncYjBgbe1',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'FUMETEO - Remix',
#    'artist_name': 'Feid, Mora, Eladio Carrion',
#    'release_date': '2021-12-17',
#    'id_track': '5SXG3VyqqWkzr4a3sUnupK',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'KESI - Remix',
#    'artist_name': 'Camilo, Shawn Mendes',
#    'release_date': '2021-07-14',
#    'id_track': '0IqCoZ168iRc9LqfrYgpZy',
#    'popularity': 62,
#    'genero': 'reggaeton'},
#   {'track_name': 'No Contesta',
#    'artist_name': 'Ele A El Dominio',
#    'release_date': '2021-11-12',
#    'id_track': '7IycmKrikhnpa0aX4ZWHfY',
#    'popularity': 61,
#    'genero': 'reggaeton'},
#   {'track_name': 'Lo Siento BB:/ (with Bad Bunny & Julieta Venegas)',
#    'artist_name': 'Tainy, Bad Bunny, Julieta Venegas',
#    'release_date': '2021-10-05',
#    'id_track': '4gzsuuZypVbxs0Af1LSZyB',
#    'popularity': 67,
#    'genero': 'reggaeton'},
#   {'track_name': 'KESI',
#    'artist_name': 'Camilo',
#    'release_date': '2021-03-04',
#    'id_track': '42lpuSQmnLUM1ZXJVzIVOi',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'Machu Picchu',
#    'artist_name': 'Camilo, Evaluna Montaner',
#    'release_date': '2021-03-04',
#    'id_track': '6RV9pRLIQiXm3qTGeyQluf',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'Qué Más Pues?',
#    'artist_name': 'J Balvin, Maria Becerra',
#    'release_date': '2021-05-28',
#    'id_track': '6hf0RpxTbOprT5nnwzkk8e',
#    'popularity': 61,
#    'genero': 'reggaeton'},
#   {'track_name': 'FUMETEO - Remix',
#    'artist_name': 'Feid, Mora, Eladio Carrion',
#    'release_date': '2021-11-26',
#    'id_track': '4sIVl8rmGPDemhnod4JID3',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Súbelo',
#    'artist_name': 'Anuel AA, Myke Towers, JHAYCO',
#    'release_date': '2021-11-26',
#    'id_track': '3xv8JksRyqHa1lwkM9xvJf',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'En Mi Cuarto',
#    'artist_name': 'JHAYCO, Skrillex',
#    'release_date': '2021-07-30',
#    'id_track': '6Ee34qCOE6FBzEPRAGwSrn',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Me Fije',
#    'artist_name': 'Alex Rose, Rauw Alejandro',
#    'release_date': '2021-03-18',
#    'id_track': '6Et5KimMg3IXwD6lJPGmQw',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'Súbelo',
#    'artist_name': 'Anuel AA, Myke Towers, JHAYCO',
#    'release_date': '2021-11-18',
#    'id_track': '3fHEwAssCgM4wJYdjT5Ch0',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'AMOR DE MI VIDA',
#    'artist_name': 'Feid',
#    'release_date': '2021-12-17',
#    'id_track': '2C6eINAA8cO6e5a8PjnWsK',
#    'popularity': 62,
#    'genero': 'reggaeton'},
#   {'track_name': '911',
#    'artist_name': 'Sech',
#    'release_date': '2021-04-15',
#    'id_track': '2p2Q23iaaPSEa1tI6TsCVX',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'UN DIA (ONE DAY)',
#    'artist_name': 'J Balvin, Dua Lipa, Bad Bunny, Tainy',
#    'release_date': '2021-09-10',
#    'id_track': '66x45Yh9x397PWpxMX0ZDT',
#    'popularity': 64,
#    'genero': 'reggaeton'},
#   {'track_name': 'En Mi Cuarto',
#    'artist_name': 'JHAYCO, Skrillex',
#    'release_date': '2021-09-03',
#    'id_track': '2Doh4izLZGrUD3yOSs9y9G',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ella - Remix',
#    'artist_name': 'Boza, Lunay, Lenny Tavárez, Juhn, Beéle',
#    'release_date': '2021-10-29',
#    'id_track': '7iHHlCbsFou5DZSW5HCPfs',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Sal y Perrea',
#    'artist_name': 'Sech',
#    'release_date': '2021-04-15',
#    'id_track': '5u7twkeask1VIyDeNTElSU',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'Exit',
#    'artist_name': 'Anuel AA',
#    'release_date': '2021-11-26',
#    'id_track': '66jvPrhrBjUeaz7hvg20vE',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mcgregor',
#    'artist_name': 'Anuel AA',
#    'release_date': '2021-11-26',
#    'id_track': '5zaIVQv1oPnTa86BUmmbjz',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': '911',
#    'artist_name': 'Sech',
#    'release_date': '2021-02-05',
#    'id_track': '2TksvaRivgAEj780DgRB73',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'SR DE LOS CIELOS',
#    'artist_name': 'Myke Towers',
#    'release_date': '2021-04-23',
#    'id_track': '3iug2F7ByIBMVkmLGgt3ir',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Monastery',
#    'artist_name': 'Ryan Castro, Feid',
#    'release_date': '2021-11-12',
#    'id_track': '1JpzJfxjHGFUyTHXLZidok',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tan Bonita',
#    'artist_name': 'Piso 21',
#    'release_date': '2021-03-18',
#    'id_track': '6mm3K0yWp6uzfOMuipM9Zh',
#    'popularity': 61,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Nota',
#    'artist_name': 'Manuel Turizo, Rauw Alejandro, Myke Towers',
#    'release_date': '2021-04-09',
#    'id_track': '5VzNsUnLmYcRfRfxpQsusa',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Esta Dejá',
#    'artist_name': 'JHAYCO',
#    'release_date': '2021-09-03',
#    'id_track': '3rP4fbwWIAxRqay8ozCvhu',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Machu Picchu',
#    'artist_name': 'Camilo, Evaluna Montaner',
#    'release_date': '2021-03-01',
#    'id_track': '1LXb70u8SLsvBAPWHMCTMe',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'Poblado - Remix',
#    'artist_name': 'J Balvin, KAROL G, Nicky Jam, Crissin, Totoy El Frio, Natan & Shander',
#    'release_date': '2021-06-18',
#    'id_track': '1WedZeiezCmCEOzLwhx0hV',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'FULANITO',
#    'artist_name': 'Becky G, El Alfa',
#    'release_date': '2021-06-03',
#    'id_track': '59L8x0xy8njj75vzVCPMqg',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Fragancia',
#    'artist_name': 'Juhn, Jay Wheeler',
#    'release_date': '2021-05-13',
#    'id_track': '5URNvRGY4fqoaWTkBJpOiH',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Dos Problemas (feat. Big Soto) - Remix',
#    'artist_name': 'Blessd, Javiielo, Neutro Shorty, Big Soto',
#    'release_date': '2021-08-06',
#    'id_track': '7bx66Je824Iak8c1CfsMrE',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Christian Dior',
#    'artist_name': 'JHAYCO',
#    'release_date': '2021-09-03',
#    'id_track': '11hBaUK4uHt1KPkwfPoTwN',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Nanae',
#    'artist_name': 'Jay Menez, Beéle',
#    'release_date': '2021-10-28',
#    'id_track': '5aVHwG3dLQVOGEt77hm27c',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Antes',
#    'artist_name': 'Anuel AA, Ozuna',
#    'release_date': '2021-01-22',
#    'id_track': '73O30uMI7n6DuzBmbtO7kC',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'La MVP',
#    'artist_name': 'Miky Woodz',
#    'release_date': '2021-11-12',
#    'id_track': '74WOZ17ERaFrHXYtSid13p',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'RD',
#    'artist_name': 'Anuel AA, Ozuna',
#    'release_date': '2021-01-22',
#    'id_track': '3F5OoUJSVVC1f5PwOxcx0N',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'BURBERRY',
#    'artist_name': 'Myke Towers, Ñengo Flow',
#    'release_date': '2021-04-23',
#    'id_track': '1cH9JMgvzkOXGKPiegrBjw',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mini Mini',
#    'artist_name': 'El Punto40, Marcianeke',
#    'release_date': '2021-05-26',
#    'id_track': '3KI4rfS7kRC58Dd4ToY7P3',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Pin',
#    'artist_name': 'Anuel AA',
#    'release_date': '2021-11-26',
#    'id_track': '5L1GX9GFIHYm1AMAlNgoHw',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'JOVEN LEYENDA',
#    'artist_name': 'Myke Towers',
#    'release_date': '2021-04-23',
#    'id_track': '6uD3PAU7twkPP4o13w49R4',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'De Museo',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2021-07-06',
#    'id_track': '267NGliXM8YLVZiKAD9Otm',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'Nubes',
#    'artist_name': 'Rauw Alejandro',
#    'release_date': '2021-12-10',
#    'id_track': '2nU1vaARHQ8FoaxFfe4ZN7',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': '100 MILLONES',
#    'artist_name': 'Bad Bunny, Luar La L',
#    'release_date': '2021-05-28',
#    'id_track': '4Ixc50wY5pbUvNEogTQ2wL',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'JUGADOR FRANQUICIA',
#    'artist_name': 'Myke Towers',
#    'release_date': '2021-04-23',
#    'id_track': '4kNpoVStauSMwm0mF0qShU',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Pepas',
#    'artist_name': 'Farruko',
#    'release_date': '2021-10-01',
#    'id_track': '2B4GHvToeLTOBB4QLzW3Ni',
#    'popularity': 64,
#    'genero': 'reggaeton'},
#   {'track_name': 'PIN PIN',
#    'artist_name': 'Myke Towers',
#    'release_date': '2021-04-23',
#    'id_track': '51tMYALx6Lkrte41DoWIPq',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': '¿Y Eso?',
#    'artist_name': 'Rauw Alejandro',
#    'release_date': '2021-12-10',
#    'id_track': '4b9rqLPiePJzzd5hW9I6f6',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Los Tragos',
#    'artist_name': 'Reik, Maria Becerra',
#    'release_date': '2021-11-25',
#    'id_track': '7iXJg4IUyrWont5YSQrbKP',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'Leyenda',
#    'artist_name': 'Anuel AA',
#    'release_date': '2021-11-26',
#    'id_track': '3BIOxohEjTEcRRg0VVlNI6',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'AM',
#    'artist_name': 'Nio Garcia, Flow La Movie',
#    'release_date': '2021-01-28',
#    'id_track': '2dNhNlpZAtV4lwAFW45LIv',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'TODO O NADA',
#    'artist_name': 'Lunay, Anitta',
#    'release_date': '2021-05-21',
#    'id_track': '59rjsHYxdxeUG6gd43Emzs',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'VUDÚ',
#    'artist_name': 'Lunay, Chris Jedi, Chencho Corleone',
#    'release_date': '2021-05-21',
#    'id_track': '24YLHalbl2ePQbEXiKqKcP',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Agua (with J Balvin)',
#    'artist_name': 'Tainy, J Balvin',
#    'release_date': '2021-03-05',
#    'id_track': '7CtbxAGq2P0jtYh6SH9DMR',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'CHIMBITA',
#    'artist_name': 'Feid, Sky Rompiendo',
#    'release_date': '2021-08-20',
#    'id_track': '35xvhWIZMpsDcJxr14Ukbx',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'EL BARCO',
#    'artist_name': 'KAROL G',
#    'release_date': '2021-03-25',
#    'id_track': '2IViAyalheAvrT9ErMCABT',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'Monastery',
#    'artist_name': 'Ryan Castro, Feid',
#    'release_date': '2021-11-12',
#    'id_track': '0hwPOmpTn71SMU5wMSlXvL',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'El Incomprendido',
#    'artist_name': 'Farruko, Victor Cardenas, Dj Adoni',
#    'release_date': '2021-09-30',
#    'id_track': '493Rk3iS7rs8uPfpnfm95u',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'VACAXIONES',
#    'artist_name': 'Feid',
#    'release_date': '2021-12-17',
#    'id_track': '5QLs1kIWkkxcdUBfTkqWBX',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Santa Diabla',
#    'artist_name': 'Amarion, Luar La L, Lyanno',
#    'release_date': '2021-05-21',
#    'id_track': '4WtRBfne50DKGeIgetFzJB',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Guaro (Remix)',
#    'artist_name': 'Pipe Bueno, Jessi Uribe, Yeison Jimenez, Carin Leon, Alzate, Darío Gómez, Luis Alberto Posada, El Charrito Negro, Jhonny Rivera, Jhon Alex Castaño',
#    'release_date': '2021-09-16',
#    'id_track': '5sMHuOIvtsSuFZafTcF19Q',
#    'popularity': 62,
#    'genero': 'reggaeton'},
#   {'track_name': 'TENGO FE',
#    'artist_name': 'Feid',
#    'release_date': '2021-08-20',
#    'id_track': '57pkksnRS4NOOphTmoRlK2',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'GATO MALO',
#    'artist_name': 'KAROL G, NATHY PELUSO',
#    'release_date': '2021-03-26',
#    'id_track': '7wy5kv4fYAsR9qFxKKZC5E',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Desnudarte',
#    'artist_name': 'Brytiago, Jay Wheeler',
#    'release_date': '2021-01-29',
#    'id_track': '3wrBFPDRyIGyGXxGSc970M',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'In Da Getto',
#    'artist_name': 'J Balvin, Skrillex',
#    'release_date': '2021-09-10',
#    'id_track': '1q0PYXTbDsirp2l74ng6pn',
#    'popularity': 62,
#    'genero': 'reggaeton'},
#   {'track_name': 'OTRA NO',
#    'artist_name': 'Lunay, Bryant Myers, Zion',
#    'release_date': '2021-05-21',
#    'id_track': '3f2K8tmTI3mHzojNYqae4h',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Una Vida Para Recordar',
#    'artist_name': 'Piso 21, Myke Towers',
#    'release_date': '2021-03-18',
#    'id_track': '6n8CqMxK4RqmUrX6gsJseD',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'SI TÚ SUPIERAS',
#    'artist_name': 'Feid',
#    'release_date': '2021-12-17',
#    'id_track': '6qtDKAKZhJfVziibsoGBBj',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Angelito',
#    'artist_name': 'Ovy On The Drums, Beéle, Bad Milk',
#    'release_date': '2021-03-31',
#    'id_track': '5zm5Ra1DVCmujK882R7QSP',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Rapido',
#    'artist_name': 'Amenazzy, Farruko, Myke Towers, Rochy RD',
#    'release_date': '2021-06-18',
#    'id_track': '4OMeEpkakI4Vb77gulgTDw',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Piropo',
#    'artist_name': 'Noriel',
#    'release_date': '2021-12-03',
#    'id_track': '3ltZpTagx93zE54eTG5NBh',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Malory',
#    'artist_name': 'Ryan Castro',
#    'release_date': '2021-09-21',
#    'id_track': '3ppbP8uBOpIWU1mq9zXu3i',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Me Extraña',
#    'artist_name': 'JHAYCO',
#    'release_date': '2021-09-03',
#    'id_track': '2EYy5e5yDpF8yaxq8rNopo',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Señor Juez',
#    'artist_name': 'Ozuna, Anthony Santos',
#    'release_date': '2021-11-04',
#    'id_track': '2PH533J1xudlfZ5GaHAdVX',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Nos Matamos',
#    'artist_name': 'JHAYCO',
#    'release_date': '2021-09-03',
#    'id_track': '0kekARy9zsWohICrBUjyIn',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mala Costumbre',
#    'artist_name': 'Manuel Turizo, Wisin & Yandel',
#    'release_date': '2021-01-07',
#    'id_track': '70uX4beGHc1nQikXveOknp',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ram Pam Pam',
#    'artist_name': 'NATTI NATASHA, Becky G',
#    'release_date': '2021-04-20',
#    'id_track': '4DHDIdeayp8xvlyg22wREO',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'BURBERRY',
#    'artist_name': 'Myke Towers, Nengo Flow',
#    'release_date': '2021-04-07',
#    'id_track': '4kdMfObhCkNZ47gsl63uXP',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Dividimos (Bachata Version)',
#    'artist_name': 'Nio Garcia, Flow La Movie',
#    'release_date': '2021-06-10',
#    'id_track': '1RYuxP3H45CoeYZAYWDtBf',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Botella',
#    'artist_name': 'Justin Quiles, Maluma',
#    'release_date': '2021-08-19',
#    'id_track': '6GPBXtnSepHovJi1uD1Ggj',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'In Da Getto',
#    'artist_name': 'J Balvin, Skrillex',
#    'release_date': '2021-07-02',
#    'id_track': '63aj87TQG6F3RVO5nbG2VQ',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': "Pa' Olvidarme De Ella",
#    'artist_name': 'Piso 21, Christian Nodal',
#    'release_date': '2021-03-18',
#    'id_track': '3lR4O0vtkhCAvVEUEWUL0S',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': 'CUANDO ME VEN',
#    'artist_name': 'Myke Towers',
#    'release_date': '2021-04-23',
#    'id_track': '0UlinN0HQMMvezbjG8Ff6U',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Fan de Tus Fotos',
#    'artist_name': 'Nicky Jam, Romeo Santos',
#    'release_date': '2021-02-08',
#    'id_track': '1mauYRwbpoGQX6itP2FAJC',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'A Un Paso De La Luna - Remix',
#    'artist_name': 'Reik, Rocco Hunt, Ana Mena',
#    'release_date': '2021-03-23',
#    'id_track': '6EQR7Y5vVZFiPD0RUECIDv',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Última Canción',
#    'artist_name': 'Anuel AA',
#    'release_date': '2021-11-26',
#    'id_track': '5EyOJqMNxI1B6F8aFGpal4',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'Los Dioses',
#    'artist_name': 'Anuel AA, Ozuna',
#    'release_date': '2021-01-22',
#    'id_track': '7oHsIIDKbEJlFULg1HF0pP',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Se Le Ve',
#    'artist_name': 'Dímelo Flow, Dalex, Sech, Justin Quiles, Arcángel, De La Ghetto, Lenny Tavárez',
#    'release_date': '2021-08-12',
#    'id_track': '5W1qmxHrMlQGGAiFA3ZQqP',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Perfecta',
#    'artist_name': 'Reik, Maluma',
#    'release_date': '2021-05-27',
#    'id_track': '6VOb0Kkrd45Bp5RHYSla2J',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Babymama - Remix',
#    'artist_name': 'Joyce Santana, Farruko, Luar La L, Eladio Carrion, Myke Towers, Ñengo Flow',
#    'release_date': '2021-12-17',
#    'id_track': '1d3mQY9cJeyx0EMxBkXORn',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Quedate Sola',
#    'artist_name': 'Jon Z, Myke Towers, Eladio Carrion',
#    'release_date': '2021-02-12',
#    'id_track': '0UT1rpFwDw5GLM7jDVs9pN',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'No Te Enamores - Remix',
#    'artist_name': 'Milly, Farruko, Nio Garcia, Jay Wheeler, Amenazzy',
#    'release_date': '2021-11-12',
#    'id_track': '6ZtHV4d8demcEeNnqdfar2',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'UNA MÁS',
#    'artist_name': 'Tainy, Yandel, Rauw Alejandro',
#    'release_date': '2021-07-15',
#    'id_track': '7Hzh5oY6cIitvcK6oJDwTb',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'Llorando en un Ferrari',
#    'artist_name': 'Anuel AA',
#    'release_date': '2021-11-26',
#    'id_track': '0x4Kmsd1YLB9emO8thJ62U',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Date Tu Guille',
#    'artist_name': 'Milly, Farruko, Myke Towers, Lary Over, Rauw Alejandro, Sharo Towers',
#    'release_date': '2021-11-12',
#    'id_track': '7iAS64n4wSFgfPkVATWENl',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'Nena Buena',
#    'artist_name': 'Anuel AA, Ozuna',
#    'release_date': '2021-01-22',
#    'id_track': '7m6aTkKrrPHAZ4fGnksoda',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': "Ponte Pa' Mi",
#    'artist_name': 'Justin Quiles',
#    'release_date': '2021-08-19',
#    'id_track': '3duhGpIBMgDwTtnicFWNH5',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mi Vicio',
#    'artist_name': 'JHAYCO',
#    'release_date': '2021-09-03',
#    'id_track': '6eDImMU0RbxxTWqlEzpcom',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Una Palabra',
#    'artist_name': 'Anuel AA',
#    'release_date': '2021-11-26',
#    'id_track': '0RP5vC6fzwr15mSAotXJEo',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Jeans',
#    'artist_name': 'Justin Quiles',
#    'release_date': '2021-08-19',
#    'id_track': '78dzBjk47wuaraNVpVJ9QB',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'DE NOVELA',
#    'artist_name': 'Myke Towers, Sahir',
#    'release_date': '2021-04-23',
#    'id_track': '7m6oknLLj0b6HnfB757DaQ',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': '14 De Febrero',
#    'artist_name': 'Feid',
#    'release_date': '2021-08-20',
#    'id_track': '2GZmcIwvFeu3NgKu1HJL4u',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'PAKATA',
#    'artist_name': 'Darell, El Alfa',
#    'release_date': '2021-08-20',
#    'id_track': '59rRvUjxSrKnimSsg678f9',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Wao',
#    'artist_name': 'Sech',
#    'release_date': '2021-04-15',
#    'id_track': '2B4nQ6yvVVBMqfgOrYtubb',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Dictadura',
#    'artist_name': 'Anuel AA',
#    'release_date': '2021-11-26',
#    'id_track': '16RRpUyUDjkIept8AymRiL',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Poblado - Remix',
#    'artist_name': 'J Balvin, KAROL G, Nicky Jam, Crissin, Totoy El Frio, Natan & Shander',
#    'release_date': '2021-09-10',
#    'id_track': '2K1CQMoG2Dy5nmeOYnhoi8',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Las Gargolas',
#    'artist_name': 'Alex Gargolas, Mora, Luar La L, Arcángel, Brray, Darell',
#    'release_date': '2021-08-26',
#    'id_track': '0AhrguZp4czhW89ZmYVvWS',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Bebe',
#    'artist_name': 'Yng Lvcas',
#    'release_date': '2021-12-24',
#    'id_track': '6odrHMSLjP3aOXC4ipKUC6',
#    'popularity': 61,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ella',
#    'artist_name': 'Boza',
#    'release_date': '2021-04-16',
#    'id_track': '66S2z95FN3nUAr9S1gUIsp',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': '100',
#    'artist_name': 'Anuel AA, Ozuna',
#    'release_date': '2021-01-22',
#    'id_track': '2sqgNScWya6T8PwKMELYW8',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Real Hasta la Muerte',
#    'artist_name': 'Anuel AA',
#    'release_date': '2021-11-26',
#    'id_track': '06HLRbv3Vzkvd5bjQVL12c',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'PFA',
#    'artist_name': 'Myke Towers',
#    'release_date': '2021-04-23',
#    'id_track': '1Gxz2YOLLaDrfwZ6yTKcw2',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'CORONE',
#    'artist_name': 'Feid',
#    'release_date': '2021-08-20',
#    'id_track': '1A7rUacip28yYERtzuQZ55',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'Polvo',
#    'artist_name': 'Nicky Jam, Myke Towers',
#    'release_date': '2021-08-27',
#    'id_track': '0T5VcGJw3qFfeVlabdwQfE',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'PRIMER MELÓN',
#    'artist_name': 'Myke Towers',
#    'release_date': '2021-04-23',
#    'id_track': '3GivOBvN7vkeNXoCteX4LS',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mi Voz Cuesta un Billón',
#    'artist_name': 'Anuel AA, Mora',
#    'release_date': '2021-11-26',
#    'id_track': '4JHjB2AekXGX7sCx6NLrJU',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'FRIKI',
#    'artist_name': 'Feid, KAROL G',
#    'release_date': '2021-12-10',
#    'id_track': '3No3zHVwKadKDR00kZdmAB',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ropa Interior',
#    'artist_name': 'JHAYCO, Kendo Kaponi',
#    'release_date': '2021-09-03',
#    'id_track': '6VbBXLHYIriwKQUKbI8dwE',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Lejos Conmigo',
#    'artist_name': 'Greeicy, Alejandro Sanz',
#    'release_date': '2021-08-20',
#    'id_track': '6bEyu7fMzsnP5COEg3RkWn',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Rick Flair',
#    'artist_name': 'Anuel AA',
#    'release_date': '2021-11-26',
#    'id_track': '2PkRgnDUP0ED3xHjCNMJk4',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Pepas - Tiësto Remix',
#    'artist_name': 'Farruko, Tiësto',
#    'release_date': '2021-09-29',
#    'id_track': '1bFgMkoazsyZGSflpCzYm6',
#    'popularity': 62,
#    'genero': 'reggaeton'},
#   {'track_name': 'ALTO RIESGO',
#    'artist_name': 'Myke Towers',
#    'release_date': '2021-04-23',
#    'id_track': '0Yh503ljN7vBHj2hi67TuI',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tú No Eras Así',
#    'artist_name': 'Pacho El Antifeka, Rauw Alejandro',
#    'release_date': '2021-12-08',
#    'id_track': '6h1UftIKsK3dn9RJXhx4G9',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': '300',
#    'artist_name': 'Anuel AA',
#    'release_date': '2021-11-26',
#    'id_track': '38qm9QOThz4R650p5WPKrN',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'El Incomprendido',
#    'artist_name': 'Farruko, Victor Cardenas, Dj Adoni',
#    'release_date': '2021-10-01',
#    'id_track': '2mL37yB3f3Lfy4iiXV02Qf',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mal Acostumbrao - con Maria Becerra',
#    'artist_name': 'Mau y Ricky, Maria Becerra',
#    'release_date': '2021-09-02',
#    'id_track': '1wcE84DVQUF16xudVFzezL',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'PROBLEMA',
#    'artist_name': 'Daddy Yankee',
#    'release_date': '2021-02-26',
#    'id_track': '2dl5K2ScW7jYhAhuem06cm',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'SOLA ES MEJOR',
#    'artist_name': 'KAROL G, Yandar & Yostin',
#    'release_date': '2021-03-26',
#    'id_track': '6b5LFS96QBt4qJ5Yd3tfqm',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Polvo Perfecto',
#    'artist_name': 'Marconi Impara, Luar La L',
#    'release_date': '2021-05-14',
#    'id_track': '2aNC0Rbq7O2pUDDaPZ8rhj',
#    'popularity': 39,
#    'genero': 'reggaeton'},
#   {'track_name': 'NIVELES',
#    'artist_name': 'Myke Towers',
#    'release_date': '2021-04-23',
#    'id_track': '2Hx2NbD3aAlDn5ZLyQNFWK',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Wasa Wasa',
#    'artist_name': 'Ryan Castro',
#    'release_date': '2021-08-06',
#    'id_track': '62oa0bcvFTpbbWUkBdXXMM',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'LEYENDAS',
#    'artist_name': 'KAROL G, Wisin & Yandel, Nicky Jam, Ivy Queen, Zion, Alberto Stylee',
#    'release_date': '2021-03-26',
#    'id_track': '5vQy9fwVJTeLsaX9IOpCcp',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Bebé Que Bien Te Ves',
#    'artist_name': 'J Balvin, Feid',
#    'release_date': '2021-09-10',
#    'id_track': '6Se3CKRvYOyuzHGdHAooem',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'MOOD - Remix',
#    'artist_name': 'Omy de Oro, Jay Wheeler, Nio Garcia',
#    'release_date': '2021-12-17',
#    'id_track': '65wccjJxugGBsPKZcsHG49',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Municiones',
#    'artist_name': 'Anuel AA, Ozuna',
#    'release_date': '2021-01-22',
#    'id_track': '2nVOSrxGjCqblT9CKqEMHi',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'LOCATION',
#    'artist_name': 'KAROL G, Anuel AA, J Balvin',
#    'release_date': '2021-02-12',
#    'id_track': '5Km4r87BoX2qqtoprYS1gh',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'Una Nota',
#    'artist_name': 'J Balvin, Sech',
#    'release_date': '2021-09-10',
#    'id_track': '7iqOIHHEmu6Vhw25GgQ2eA',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'JORDAN IV',
#    'artist_name': 'Feid',
#    'release_date': '2021-08-20',
#    'id_track': '5ZyNCQmxZlYZfAHeJXTkI2',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tuyo y Mío',
#    'artist_name': 'Camilo, Los Dos Carnales',
#    'release_date': '2021-03-04',
#    'id_track': '4msyEItsAavVb5pZYCuz4n',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'COMMENT',
#    'artist_name': 'Feid',
#    'release_date': '2021-12-17',
#    'id_track': '4cjmzyooA8MkQAKrfESAoo',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Guilla de Crema',
#    'artist_name': 'Chencho Corleone, Juhn',
#    'release_date': '2021-02-19',
#    'id_track': '36nowPBgzfeb3BPa9sFuNg',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'OTRO FILI',
#    'artist_name': 'J Balvin, Jay Wheeler',
#    'release_date': '2021-09-10',
#    'id_track': '0nZjipkI0piCeaAp7Tt2KN',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Dime Tú',
#    'artist_name': 'Anuel AA, Ozuna',
#    'release_date': '2021-01-22',
#    'id_track': '1U8Ta5gcm2xhma1FQS2bKV',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Perra',
#    'artist_name': 'J Balvin, Tokischa',
#    'release_date': '2021-09-10',
#    'id_track': '04JVwAItboGpDhDgC4fNta',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mala Costumbre',
#    'artist_name': 'Manuel Turizo, Wisin & Yandel',
#    'release_date': '2021-04-09',
#    'id_track': '09WuqcTbf8iMRn8W4N8xBX',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'LO INVERTÍ',
#    'artist_name': 'Myke Towers, Miky Woodz',
#    'release_date': '2021-04-23',
#    'id_track': '1zgzf9LXZxLIY1cXC7pEfE',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'LOCATION',
#    'artist_name': 'KAROL G, Anuel AA, J Balvin',
#    'release_date': '2021-03-26',
#    'id_track': '478g4LSkyMB1PMkVOVmIaE',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Maria',
#    'artist_name': 'Anuel AA, Ozuna',
#    'release_date': '2021-01-22',
#    'id_track': '1tu5h5BU2WWrGH407kU0pe',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'RONCARME',
#    'artist_name': 'Myke Towers',
#    'release_date': '2021-04-23',
#    'id_track': '05Nsfa5ClXR0IdypylxfOT',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'Amor en Coma',
#    'artist_name': 'Manuel Turizo, Maluma',
#    'release_date': '2021-04-08',
#    'id_track': '3RasiWohReHWYM1FJ9d1ZD',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'Perfecto',
#    'artist_name': 'Anuel AA, Ozuna',
#    'release_date': '2021-01-22',
#    'id_track': '6UlIGL6Nv5KKTNH2c6vYTP',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Emojis de Corazones (feat. Los Legendarios)',
#    'artist_name': 'Wisin, JHAYCO, Ozuna, Los Legendarios',
#    'release_date': '2021-09-24',
#    'id_track': '5Mw46yRtdiOdjqSG0eDItr',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'SÚBELE EL VOLUMEN',
#    'artist_name': 'Daddy Yankee, Myke Towers, JHAYCO',
#    'release_date': '2021-07-16',
#    'id_track': '343HgC6SVFtTAgMPlGoNjn',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Llamada',
#    'artist_name': 'Pusho, Myke Towers',
#    'release_date': '2021-11-11',
#    'id_track': '4VlVJff7viYXRb7TbmXGGP',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'EL PADRINO',
#    'artist_name': 'Feid',
#    'release_date': '2021-08-20',
#    'id_track': '0zWkVCi9eFjcVAM839IkCZ',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'AJEDRÉZ',
#    'artist_name': 'Myke Towers',
#    'release_date': '2021-04-23',
#    'id_track': '5CExCI5k3t3Bhws8sgs8Hl',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Otra Noche Sin Ti',
#    'artist_name': 'J Balvin, Khalid',
#    'release_date': '2021-04-09',
#    'id_track': '2CdTLdDjwZdVcm0bresVWx',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'Primera Carta',
#    'artist_name': 'Cali Y El Dandee, Beret',
#    'release_date': '2021-01-21',
#    'id_track': '3VdyHA9vN9CiL9OPizGd0H',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'Nunca',
#    'artist_name': 'Anuel AA, Ozuna',
#    'release_date': '2021-01-22',
#    'id_track': '14Ub5CX67F4si1R5UJxM43',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'CUENTA',
#    'artist_name': 'Myke Towers',
#    'release_date': '2021-04-23',
#    'id_track': '2J19dDdM6nmKDbN4AVJ1R4',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'PURRITO APA',
#    'artist_name': 'Feid, ICON',
#    'release_date': '2021-08-20',
#    'id_track': '4s3clr8iaefWqqPxHGKZj1',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'Los Rompediskoteca',
#    'artist_name': 'JHAYCO',
#    'release_date': '2021-09-03',
#    'id_track': '5c7jyyEdD8jze2O60UImvb',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ram Pam Pam',
#    'artist_name': 'NATTI NATASHA, Becky G',
#    'release_date': '2021-09-24',
#    'id_track': '730gfBUwEpyruhbSvDuytR',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Dictadura',
#    'artist_name': 'Anuel AA',
#    'release_date': '2021-10-28',
#    'id_track': '4yoc5cUWk4OFvqOcvFvw0o',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Oh Mama - Premium',
#    'artist_name': 'Farruko, Myke Towers',
#    'release_date': '2021-02-25',
#    'id_track': '1En6OzqLa2XWiY1We4jHms',
#    'popularity': 41,
#    'genero': 'reggaeton'},
#   {'track_name': 'Hunter',
#    'artist_name': 'Rauw Alejandro',
#    'release_date': '2021-12-23',
#    'id_track': '2CBUVYOUUvBLOQDz9ML8SB',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Más De La Una',
#    'artist_name': 'Piso 21, Maluma',
#    'release_date': '2021-03-18',
#    'id_track': '00szcRmgqJGtqrfIUYkM1h',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': '8 DIAX',
#    'artist_name': 'Feid',
#    'release_date': '2021-12-17',
#    'id_track': '52ZI5nsIiC5Zh6z5ufTYAK',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Los De Siempre',
#    'artist_name': 'Anuel AA, Chris Jedi',
#    'release_date': '2021-08-06',
#    'id_track': '5IsTVBbwSjU38VqJbZNokS',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'TE MATA',
#    'artist_name': 'Feid',
#    'release_date': '2021-08-20',
#    'id_track': '3eFL5cxO22TpyjK3wNb27q',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Coldplay',
#    'artist_name': 'Cali Y El Dandee, Aitana',
#    'release_date': '2021-10-28',
#    'id_track': '1aaACV8X5g9coHgXLlEfIX',
#    'popularity': 39,
#    'genero': 'reggaeton'},
#   {'track_name': 'PSL',
#    'artist_name': 'Sech',
#    'release_date': '2021-04-15',
#    'id_track': '6o4Gciys1ZIOQ2kDGnvKdm',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'PAPA JOHNS',
#    'artist_name': 'Myke Towers',
#    'release_date': '2021-04-23',
#    'id_track': '78priJC6WYdAjjH9CoaXMA',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'Las Nenas (feat. La Duraca)',
#    'artist_name': 'NATTI NATASHA, Cazzu, FARIANA, La Duraca',
#    'release_date': '2021-03-04',
#    'id_track': '2KTCXvWUbqfiinbFe7PJKP',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Fantasia Sexual',
#    'artist_name': 'Lunay, Brytiago, Revol, Myke Towers, Rauw Alejandro',
#    'release_date': '2021-01-13',
#    'id_track': '2Gbdc2PNfE5tXu9ujCxEiQ',
#    'popularity': 40,
#    'genero': 'reggaeton'},
#   {'track_name': 'Gucci En Mis Pies',
#    'artist_name': 'Ele A El Dominio',
#    'release_date': '2021-07-16',
#    'id_track': '4RhKIBupRs3ID7Svb8kiwX',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ganas - Remix',
#    'artist_name': 'El Clooy, Blessd',
#    'release_date': '2021-11-27',
#    'id_track': '2gozgdGrgeKxV5ssjzokPo',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Si Te Veo',
#    'artist_name': 'Arcángel, Jay Wheeler, Miky Woodz',
#    'release_date': '2021-05-07',
#    'id_track': '2TmT3wSwRf0CYJFGGaIXNB',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Te Va Bien (feat. Darell)',
#    'artist_name': 'KEVVO, Arcángel, Becky G, Darell',
#    'release_date': '2021-12-02',
#    'id_track': '6Fm1HlUcIPN1ZZoVN5rTOa',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'Brazilera',
#    'artist_name': 'Rauw Alejandro, Anitta',
#    'release_date': '2021-12-10',
#    'id_track': '6jPFaBQGvDFrcyf5kQAJ6G',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Bff <3',
#    'artist_name': 'DEKKO',
#    'release_date': '2021-11-25',
#    'id_track': '0XQsWXjHkSjLuSHnHB1qLL',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Duvibes',
#    'artist_name': 'Sech',
#    'release_date': '2021-04-15',
#    'id_track': '5CiWKzBkTveHezqY3TQmCW',
#    'popularity': 39,
#    'genero': 'reggaeton'},
#   {'track_name': 'MIONCA AL BLOQUE',
#    'artist_name': 'Feid, Sael',
#    'release_date': '2021-12-17',
#    'id_track': '0mIFOa5E7widNaQ76voSN1',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Tóxica',
#    'artist_name': 'Farruko',
#    'release_date': '2021-10-01',
#    'id_track': '7Crx42VpbY4h4qrz2q9DuH',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Loquita',
#    'artist_name': 'Reik, Rauw Alejandro',
#    'release_date': '2021-08-12',
#    'id_track': '2OTULPNeQUkwQ0tNzcG7tj',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'CONFIAR',
#    'artist_name': 'Myke Towers',
#    'release_date': '2021-04-23',
#    'id_track': '6vYQaurynY7NoHd6Iw85QM',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'IMPOSIBLE - REMIX',
#    'artist_name': 'Blessd, Maluma',
#    'release_date': '2021-05-13',
#    'id_track': '5eaLGyPrVG7FbZ5vVnBm93',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'PAM',
#    'artist_name': 'Justin Quiles, Daddy Yankee, El Alfa',
#    'release_date': '2021-08-19',
#    'id_track': '7uF2XRp2srFB1mvTMEChoh',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'Playa',
# ...
#    'artist_name': 'Bo Burnham',
#    'release_date': '2021-06-10',
#    'id_track': '2Q6RiCAKOrxRYtvl9pcpjY',
#    'popularity': 56,
#    'genero': 'indie'},
#   {'track_name': 'Attrape-rêve',
#    'artist_name': 'Polo & Pan',
#    'release_date': '2021-06-25',
#    'id_track': '6ro7bmnTuOhGoKeYFRPN3G',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'Cookie Chips',
#    'artist_name': "Rejjie Snow, MF DOOM, Cam O'bi",
#    'release_date': '2021-07-09',
#    'id_track': '6z8DOqs0yHWQkXRezHEx63',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Seasons',
#    'artist_name': 'Jon and Roy',
#    'release_date': '2021-05-07',
#    'id_track': '6nm6GDxFjTkBHLIO9nFzz9',
#    'popularity': 43,
#    'genero': 'indie'},
#   {'track_name': 'On My Knees',
#    'artist_name': 'RÜFÜS DU SOL',
#    'release_date': '2021-09-23',
#    'id_track': '7ABUiQBM8cjktnp6QLTTaT',
#    'popularity': 56,
#    'genero': 'indie'},
#   {'track_name': 'Infinite Amethyst',
#    'artist_name': 'Lena Raine, Minecraft',
#    'release_date': '2021-10-20',
#    'id_track': '3Vkyy6CB4UDEvFncUBc53z',
#    'popularity': 50,
#    'genero': 'indie'},
#   {'track_name': 'Motorbike',
#    'artist_name': 'Leon Bridges',
#    'release_date': '2021-07-23',
#    'id_track': '3mMduiD8yb4IaS5tZKqSZy',
#    'popularity': 48,
#    'genero': 'indie'},
#   {'track_name': 'Way Less Sad',
#    'artist_name': 'AJR',
#    'release_date': '2021-03-26',
#    'id_track': '6YIivt0G3ZUuNrM62jp9pL',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Magic',
#    'artist_name': 'Polo & Pan',
#    'release_date': '2021-06-25',
#    'id_track': '3QEYYJTIEd6Tv0HCrgHvri',
#    'popularity': 43,
#    'genero': 'indie'},
#   {'track_name': 'Frankenstein',
#    'artist_name': 'Claire Rosinkranz',
#    'release_date': '2021-05-14',
#    'id_track': '1xSmjB0t19q4CSJ0X0ymGB',
#    'popularity': 54,
#    'genero': 'indie'},
#   {'track_name': 'Rain (from The Suicide Squad)',
#    'artist_name': 'grandson, Jessie Reyez',
#    'release_date': '2021-06-22',
#    'id_track': '6gi7qsHSH2JWZsTRHndxqm',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'Tattica',
#    'artist_name': 'Fulminacci',
#    'release_date': '2021-03-12',
#    'id_track': '3rAvsg2npEEGeaGckpqmW9',
#    'popularity': 48,
#    'genero': 'indie'},
#   {'track_name': 'Asatoma',
#    'artist_name': 'Sam Garrett, Mollie Mendoza',
#    'release_date': '2021-12-21',
#    'id_track': '5cWhrasStIDbhlEP231OGB',
#    'popularity': 41,
#    'genero': 'indie'},
#   {'track_name': 'Seize the Power',
#    'artist_name': 'YONAKA',
#    'release_date': '2021-07-15',
#    'id_track': '794IGyga5qnhlzOUimLOMw',
#    'popularity': 51,
#    'genero': 'indie'},
#   {'track_name': 'No Need - Edit',
#    'artist_name': 'Oscar Jerome, Ben Hauke',
#    'release_date': '2021-07-21',
#    'id_track': '1XLPk9vj45rK2pbnurZ0Wi',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'Fiamme negli occhi',
#    'artist_name': 'Coma_Cose',
#    'release_date': '2021-04-16',
#    'id_track': '60nw7bwqYjVsrccNjF6TMO',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'TAKE ALL THE LOVE',
#    'artist_name': 'Arthur Nery',
#    'release_date': '2021-04-23',
#    'id_track': '2v6jmF6VQWS96x6tSg05IC',
#    'popularity': 73,
#    'genero': 'indie'},
#   {'track_name': 'La isla del sol',
#    'artist_name': 'un muerto mas',
#    'release_date': '2021-06-11',
#    'id_track': '0HBn23L8dzvkSnyeLhlsCD',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'Greek Tragedy - Oliver Nelson TikTok Remix',
#    'artist_name': 'The Wombats, Oliver Nelson',
#    'release_date': '2021-01-15',
#    'id_track': '64rqvMhAPLLEag310IG3z9',
#    'popularity': 56,
#    'genero': 'indie'},
#   {'track_name': 'Pasadena',
#    'artist_name': 'La Femme',
#    'release_date': '2021-04-02',
#    'id_track': '2dALvck73iimdQBrGAuaNo',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Like 1999',
#    'artist_name': 'Valley',
#    'release_date': '2021-10-01',
#    'id_track': '25gacl0dFF9HTclx7Ug7xC',
#    'popularity': 56,
#    'genero': 'indie'},
#   {'track_name': 'Eyes Fall',
#    'artist_name': 'Ocie Elliott',
#    'release_date': '2021-08-27',
#    'id_track': '1i7xvrUa72MKMhnQcYSZxx',
#    'popularity': 43,
#    'genero': 'indie'},
#   {'track_name': 'People Eater',
#    'artist_name': 'Sodikken',
#    'release_date': '2021-02-17',
#    'id_track': '1Sv71cSqfQLuzdPZlzb6QH',
#    'popularity': 55,
#    'genero': 'indie'},
#   {'track_name': 'La Poesia Intermitente',
#    'artist_name': 'El Chacal & Los Alpes Floreados, Goyo Degano',
#    'release_date': '2021-12-17',
#    'id_track': '26ERj5NYGRfdM1ZVfh2UZx',
#    'popularity': 42,
#    'genero': 'indie'},
#   {'track_name': 'Ferma A Guardare (feat. Pinguini Tattici Nucleari)',
#    'artist_name': 'Ernia, Pinguini Tattici Nucleari',
#    'release_date': '2021-01-19',
#    'id_track': '1eDC4NiUYgQSKpKDIvXxi4',
#    'popularity': 57,
#    'genero': 'indie'},
#   {'track_name': 'And We Go Gentle',
#    'artist_name': 'Hiatus Kaiyote',
#    'release_date': '2021-06-25',
#    'id_track': '3PHgxKy3nKy0v9KvUtHl8g',
#    'popularity': 51,
#    'genero': 'indie'},
#   {'track_name': 'Black Sheep',
#    'artist_name': 'Metric',
#    'release_date': '2021-07-09',
#    'id_track': '0fx2BkX6CYYDteR8HiLf1Y',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'Fight On',
#    'artist_name': 'The Lathums',
#    'release_date': '2021-09-24',
#    'id_track': '66duVGNVSFRDg4rcTH561l',
#    'popularity': 50,
#    'genero': 'indie'},
#   {'track_name': 'Bitchboy',
#    'artist_name': 'The Oozes',
#    'release_date': '2021-05-21',
#    'id_track': '1QQ0bhZ39lG5LVjWIGiryS',
#    'popularity': 53,
#    'genero': 'indie'},
#   {'track_name': 'Lo Hice, Te Dejé',
#    'artist_name': 'Daniel, Me Estás Matando',
#    'release_date': '2021-04-16',
#    'id_track': '5HT7sdhkOCFVegIoMOL7yj',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'Coltellata (feat. thasup)',
#    'artist_name': 'Gazzelle, thasup',
#    'release_date': '2021-02-12',
#    'id_track': '6RDCUnAj3V4s37b0BBBXTa',
#    'popularity': 56,
#    'genero': 'indie'},
#   {'track_name': 'AURORA',
#    'artist_name': 'HUMBE',
#    'release_date': '2021-11-11',
#    'id_track': '0NHsOitbhh1DJy1b6otZHf',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'Painforever',
#    'artist_name': 'Rebzyyx',
#    'release_date': '2021-01-12',
#    'id_track': '6EIA1MCAyKN67izGFL8ato',
#    'popularity': 54,
#    'genero': 'indie'},
#   {'track_name': 'Seize the Power',
#    'artist_name': 'YONAKA',
#    'release_date': '2021-01-27',
#    'id_track': '4wD6EgZCok8Qb5Fs8jszYc',
#    'popularity': 48,
#    'genero': 'indie'},
#   {'track_name': 'Get High',
#    'artist_name': 'Chet Faker',
#    'release_date': '2021-07-16',
#    'id_track': '3q8bVATKAOwjc8C0jY3DRd',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'That Funny Feeling',
#    'artist_name': 'Bo Burnham',
#    'release_date': '2021-06-10',
#    'id_track': '5CU5CRWy6PjUJsHCVbkYI2',
#    'popularity': 54,
#    'genero': 'indie'},
#   {'track_name': 'Lemonhaze',
#    'artist_name': 'PawPaw Rod',
#    'release_date': '2021-09-15',
#    'id_track': '2bydO0jZES9rBvSnPvYN5L',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'FREESTYLE - Live Set',
#    'artist_name': 'WOS',
#    'release_date': '2021-03-11',
#    'id_track': '0WYcVMr4ekWawPKIL2JDZd',
#    'popularity': 40,
#    'genero': 'indie'},
#   {'track_name': 'Level of Concern',
#    'artist_name': 'Twenty One Pilots',
#    'release_date': '2021-11-19',
#    'id_track': '1OpJNP2QNZ78TnewxSVybt',
#    'popularity': 51,
#    'genero': 'indie'},
#   {'track_name': 'Je suis au jardin',
#    'artist_name': 'Okvsho',
#    'release_date': '2021-09-24',
#    'id_track': '5x9t1giM2ts8zZbcFqvsVk',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Dark Rain',
#    'artist_name': 'DRAMA',
#    'release_date': '2021-10-21',
#    'id_track': '6nFeqs4DACn0ldbumEshsg',
#    'popularity': 51,
#    'genero': 'indie'},
#   {'track_name': 'You and Me On The Rock (feat. Lucius)',
#    'artist_name': 'Brandi Carlile, Lucius',
#    'release_date': '2021-10-01',
#    'id_track': '61X73CJcpwGIxgQgKEXbw0',
#    'popularity': 50,
#    'genero': 'indie'},
#   {'track_name': 'Hush - Still Woozy Remix',
#    'artist_name': 'The Marías, Still Woozy',
#    'release_date': '2021-09-16',
#    'id_track': '4dGuRldChjvboZktprNJFM',
#    'popularity': 55,
#    'genero': 'indie'},
#   {'track_name': 'Crust',
#    'artist_name': 'Flying Lotus',
#    'release_date': '2021-04-30',
#    'id_track': '6ri6ZQWxqIZgYd2RfsnKNa',
#    'popularity': 51,
#    'genero': 'indie'},
#   {'track_name': 'INTRODUCCIÓN AL ÉXTASIS',
#    'artist_name': 'WOS',
#    'release_date': '2021-11-18',
#    'id_track': '74KCrwYaoHssps1bXnh1mR',
#    'popularity': 40,
#    'genero': 'indie'},
#   {'track_name': "Lord It's A Feeling",
#    'artist_name': 'London Grammar',
#    'release_date': '2021-04-16',
#    'id_track': '3ETbxVJMIJHm68APazPq90',
#    'popularity': 39,
#    'genero': 'indie'},
#   {'track_name': "Ain't Nice",
#    'artist_name': 'Viagra Boys',
#    'release_date': '2021-01-08',
#    'id_track': '3hxUQ6HX7p4dY8qQVInVoY',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'MANIFIESTO',
#    'artist_name': 'HUMBE',
#    'release_date': '2021-11-11',
#    'id_track': '3dCaq6gk0XBCSfnlupKJ5r',
#    'popularity': 50,
#    'genero': 'indie'},
#   {'track_name': "Baby It's You",
#    'artist_name': 'London Grammar',
#    'release_date': '2021-04-16',
#    'id_track': '1Yb6awhvnYL8W0PGk2sIbl',
#    'popularity': 42,
#    'genero': 'indie'},
#   {'track_name': 'Love is Pain',
#    'artist_name': 'FINNEAS',
#    'release_date': '2021-10-15',
#    'id_track': '2tJUcBxiQEYSCzC3BdIOk8',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'La Sentada',
#    'artist_name': 'La Muchacha',
#    'release_date': '2021-03-19',
#    'id_track': '6iql0jmyrOmtI58SGMI3IJ',
#    'popularity': 37,
#    'genero': 'indie'},
#   {'track_name': 'Smile',
#    'artist_name': 'Wolf Alice',
#    'release_date': '2021-06-04',
#    'id_track': '0mjOx4zUlL5t4rF1xnrfvi',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'Muzzle',
#    'artist_name': 'Destroy Boys',
#    'release_date': '2021-10-08',
#    'id_track': '5SQX4pwdAOTsoAmLO6RqZY',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'Pagsamo',
#    'artist_name': 'Arthur Nery',
#    'release_date': '2021-10-01',
#    'id_track': '0WZqHCoOBXqgCCIsUZLC2a',
#    'popularity': 71,
#    'genero': 'indie'},
#   {'track_name': 'Hypotheticals',
#    'artist_name': 'Lake Street Dive',
#    'release_date': '2021-03-12',
#    'id_track': '5lE2EFXt4muvLFMGQg4hZN',
#    'popularity': 58,
#    'genero': 'indie'},
#   {'track_name': 'La Mirada',
#    'artist_name': 'El Kuelgue, Julieta Venegas',
#    'release_date': '2021-09-30',
#    'id_track': '10eEsR3v9cX7KiuANy6qjd',
#    'popularity': 45,
#    'genero': 'indie'},
#   {'track_name': 'Always',
#    'artist_name': 'The Snuts',
#    'release_date': '2021-04-02',
#    'id_track': '77eb7DGxwuA3ID69HQeDsE',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 't r a n s p a r e n t s o u l feat. Travis Barker',
#    'artist_name': 'WILLOW, Travis Barker',
#    'release_date': '2021-04-27',
#    'id_track': '1QL7nSDZCwZMnbisV4KOXt',
#    'popularity': 57,
#    'genero': 'indie'},
#   {'track_name': 'Blouse',
#    'artist_name': 'Clairo',
#    'release_date': '2021-07-16',
#    'id_track': '7brBeAX3RT0CMh3qbTBrIP',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'How Can I Make It OK?',
#    'artist_name': 'Wolf Alice',
#    'release_date': '2021-06-04',
#    'id_track': '2vy48b6ad55AzooT8Mg2nY',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Switch',
#    'artist_name': 'Paco Amoroso, Adrian Dargelos',
#    'release_date': '2021-11-25',
#    'id_track': '6eQ22lLj0aDBvwBQvRsQfe',
#    'popularity': 41,
#    'genero': 'indie'},
#   {'track_name': 'Calling U Back',
#    'artist_name': 'The Marías',
#    'release_date': '2021-06-25',
#    'id_track': '5WVWQQpBJqljbZtxo19CxS',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': "don't miss me",
#    'artist_name': 'Claire Rosinkranz',
#    'release_date': '2021-11-22',
#    'id_track': '5MG69A9XyXDbBbeOxdR3Tl',
#    'popularity': 53,
#    'genero': 'indie'},
#   {'track_name': "I Don't Wanna Leave",
#    'artist_name': 'RÜFÜS DU SOL',
#    'release_date': '2021-10-21',
#    'id_track': '0mWXMQ8hrrAJfxN7LG2Wsk',
#    'popularity': 50,
#    'genero': 'indie'},
#   {'track_name': 'Walk Above the City',
#    'artist_name': 'The Paper Kites, MARO',
#    'release_date': '2021-02-05',
#    'id_track': '3rk9HrCzwejynrzxfxTKaW',
#    'popularity': 35,
#    'genero': 'indie'},
#   {'track_name': "3 O'Clock Things",
#    'artist_name': 'AJR',
#    'release_date': '2021-03-26',
#    'id_track': '0hxRyDVC61KlZGS6m2Min4',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'Casita',
#    'artist_name': 'Goth Babe',
#    'release_date': '2021-09-10',
#    'id_track': '3HjAGIYYXG7PS7OegQa0xM',
#    'popularity': 55,
#    'genero': 'indie'},
#   {'track_name': "Le temps de l'amour",
#    'artist_name': 'Bon Entendeur, Françoise Hardy',
#    'release_date': '2021-06-25',
#    'id_track': '5shtZ4h7uNYO1KrBjVcDml',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'mantra II,',
#    'artist_name': 'Ed Maverick',
#    'release_date': '2021-04-30',
#    'id_track': '2XcWZWstxIKrpjrpPLCw5m',
#    'popularity': 51,
#    'genero': 'indie'},
#   {'track_name': 'I Love To Love',
#    'artist_name': 'Bon Entendeur, Tina Charles',
#    'release_date': '2021-06-25',
#    'id_track': '26MwBGP2wbNUDZhSS43wAn',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'Love Me Like You Used To',
#    'artist_name': 'Lord Huron',
#    'release_date': '2021-05-21',
#    'id_track': '0JfpIwZfcRwDzD6GRYzfKN',
#    'popularity': 54,
#    'genero': 'indie'},
#   {'track_name': 'Blesse-moi',
#    'artist_name': 'Therapie TAXI',
#    'release_date': '2021-01-08',
#    'id_track': '6nRSyu4oOed8HgcVxV1cWl',
#    'popularity': 53,
#    'genero': 'indie'},
#   {'track_name': 'You Want Love',
#    'artist_name': 'Freyr',
#    'release_date': '2021-05-28',
#    'id_track': '2qNp94LDtM0vors2eziLEI',
#    'popularity': 43,
#    'genero': 'indie'},
#   {'track_name': '.intoodeep.',
#    'artist_name': 'Dead Poet Society',
#    'release_date': '2021-12-03',
#    'id_track': '54jvLVojOWiQRubRfKmZ2k',
#    'popularity': 50,
#    'genero': 'indie'},
#   {'track_name': 'Bambi',
#    'artist_name': 'Clairo',
#    'release_date': '2021-07-16',
#    'id_track': '6wQXjA6KWbwPT3ydQCsJ4P',
#    'popularity': 53,
#    'genero': 'indie'},
#   {'track_name': 'Harbor',
#    'artist_name': 'Clairo',
#    'release_date': '2021-07-16',
#    'id_track': '57VAuR1WgKFzcpO3ujQx9A',
#    'popularity': 53,
#    'genero': 'indie'},
#   {'track_name': 'Suéltame, Bogotá',
#    'artist_name': 'Diamante Eléctrico',
#    'release_date': '2021-02-11',
#    'id_track': '7qhunqQrA4o3Hk4c6ohRTg',
#    'popularity': 42,
#    'genero': 'indie'},
#   {'track_name': 'Vivo',
#    'artist_name': 'Andrea Laszlo De Simone',
#    'release_date': '2021-01-15',
#    'id_track': '37yGDW6a3PVlhv0EJLfjx6',
#    'popularity': 41,
#    'genero': 'indie'},
#   {'track_name': 'Sapling',
#    'artist_name': 'Foy Vance',
#    'release_date': '2021-05-27',
#    'id_track': '3pMbjkN5k9z6kZ2bcEZH1s',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'A Dream With a Baseball Player',
#    'artist_name': 'Faye Webster',
#    'release_date': '2021-06-25',
#    'id_track': '7hNPcyHhNYLCtTFa5bxvX1',
#    'popularity': 63,
#    'genero': 'indie'},
#   {'track_name': 'Cheer Up Baby',
#    'artist_name': 'Inhaler',
#    'release_date': '2021-07-09',
#    'id_track': '4jwrBNhvazRacmab5ArWSZ',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'DRUGS',
#    'artist_name': 'Tai Verdes',
#    'release_date': '2021-05-20',
#    'id_track': '4tVASOccgcigdCfwUamZCh',
#    'popularity': 54,
#    'genero': 'indie'},
#   {'track_name': 'Ritchie Sacramento',
#    'artist_name': 'Mogwai',
#    'release_date': '2021-02-19',
#    'id_track': '7yBwhVl7W0YT5cCMw8MOjW',
#    'popularity': 40,
#    'genero': 'indie'},
#   {'track_name': 'Square One',
#    'artist_name': 'Caamp',
#    'release_date': '2021-02-26',
#    'id_track': '5taOnvtHJUxuaqaLdMNqFd',
#    'popularity': 48,
#    'genero': 'indie'},
#   {'track_name': 'REVIVED',
#    'artist_name': 'Derivakat',
#    'release_date': '2021-08-18',
#    'id_track': '36dKqk62FGNRPq7iguVGjf',
#    'popularity': 54,
#    'genero': 'indie'}]}

# %%
len (resultados)
# Out:
# 4

# %%
type (resultados)
# Out:
# dict

# %%
resultados.keys ()
# Out:
# dict_keys(['reggaeton', 'pop', 'rap', 'indie'])

# %%
resultados ['pop']
# Out:
# [{'track_name': 'Tiroteo - Remix',
#   'artist_name': 'Marc Seguí, Rauw Alejandro, Pol Granch',
#   'release_date': '2021-04-01',
#   'id_track': '4OwhwvKESFtuu06dTgct7i',
#   'popularity': 78,
#   'genero': 'pop'},
#  {'track_name': 'Mon Amour - Remix',
#   'artist_name': 'zzoilo, Aitana',
#   'release_date': '2021-08-18',
#   'id_track': '5TMLavqGRKNxgzMBrVpC9R',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'La Old Skul',
#   'artist_name': 'Rauw Alejandro',
#   'release_date': '2021-12-10',
#   'id_track': '4Z8HZSApeddaRM2ovivUj4',
#   'popularity': 75,
#   'genero': 'pop'},
#  {'track_name': 'Desesperados',
#   'artist_name': 'Rauw Alejandro, Chencho Corleone',
#   'release_date': '2021-12-10',
#   'id_track': '6mmPpaltUZK7xjNlBPQQ0p',
#   'popularity': 74,
#   'genero': 'pop'},
#  {'track_name': 'Todo De Ti',
#   'artist_name': 'Rauw Alejandro',
#   'release_date': '2021-12-10',
#   'id_track': '3rdAz1fbUfZxYgaCviYhRo',
#   'popularity': 76,
#   'genero': 'pop'},
#  {'track_name': 'Cúrame',
#   'artist_name': 'Rauw Alejandro',
#   'release_date': '2021-12-10',
#   'id_track': '1FlL8ycld6uVDDyhV7P5FA',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'Exoplaneta',
#   'artist_name': 'Arde Bogotá',
#   'release_date': '2021-05-07',
#   'id_track': '68PEuXNjodWFts3Ph4BPVv',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Una Foto en Blanco y Negro',
#   'artist_name': 'David Otero, Taburete',
#   'release_date': '2021-03-05',
#   'id_track': '1iBZ1b5ULbGnyhq5Xhpqql',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Libertad',
#   'artist_name': 'Nil Moliner',
#   'release_date': '2021-10-22',
#   'id_track': '1kG7gfH4HDUlDht0VZYkiP',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'La Magia',
#   'artist_name': 'Galvan Real, Raul Camacho',
#   'release_date': '2021-02-21',
#   'id_track': '1uw6eHdMtRlX6MtiZVJYB9',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Flamenco y Bachata',
#   'artist_name': 'Daviles de Novelda',
#   'release_date': '2021-02-14',
#   'id_track': '6ynErSDSlxqsxg0D3LJ8sK',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'En Sueños',
#   'artist_name': 'Luis Cortés, Zaira',
#   'release_date': '2021-06-18',
#   'id_track': '3YFfdub6AUsrzdcBTeWIQL',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Gitana',
#   'artist_name': 'MARLENA',
#   'release_date': '2021-07-22',
#   'id_track': '1voueLCs7g2cD8NLHg1Iz7',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Tiago PZK: Bzrp Music Sessions, Vol. 48',
#   'artist_name': 'Bizarrap, Tiago PZK',
#   'release_date': '2021-12-29',
#   'id_track': '6VAS7m73rDopQe7BdrFMpD',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'La Niña de la Escuela',
#   'artist_name': 'Lola Indigo, TINI, Belinda',
#   'release_date': '2021-07-01',
#   'id_track': '1g4cZvi0nLeeIycd0Rkljj',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': 'Tacones Rojos',
#   'artist_name': 'Sebastian Yatra',
#   'release_date': '2021-10-22',
#   'id_track': '0Be7sopyKMv8Y8npsUkax2',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'drivers license',
#   'artist_name': 'Olivia Rodrigo',
#   'release_date': '2021-05-21',
#   'id_track': '5wANPM4fQCJwkGd4rN57mH',
#   'popularity': 80,
#   'genero': 'pop'},
#  {'track_name': 'Eladio Carrion: Bzrp Music Sessions, Vol. 40',
#   'artist_name': 'Bizarrap, Eladio Carrion',
#   'release_date': '2021-06-09',
#   'id_track': '1VauUM5CBX7nkLcgafQL2B',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Cariño',
#   'artist_name': 'Arde Bogotá',
#   'release_date': '2021-05-07',
#   'id_track': '7uWmMWEBGlBAm5B0oMpcs8',
#   'popularity': 54,
#   'genero': 'pop'},
#  {'track_name': 'Easy On Me',
#   'artist_name': 'Adele',
#   'release_date': '2021-11-19',
#   'id_track': '46IZ0fSY2mpAiktS3KOqds',
#   'popularity': 79,
#   'genero': 'pop'},
#  {'track_name': 'Quiéreme Mientras Se Pueda',
#   'artist_name': 'Manuel Turizo',
#   'release_date': '2021-04-09',
#   'id_track': '1WH3iquIQXnSPwUzlROT8R',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'Shivers',
#   'artist_name': 'Ed Sheeran',
#   'release_date': '2021-10-25',
#   'id_track': '50nfwKoDiSYg8zOCREWAm5',
#   'popularity': 79,
#   'genero': 'pop'},
#  {'track_name': 'A Dónde Vamos',
#   'artist_name': 'Morat',
#   'release_date': '2021-07-16',
#   'id_track': '21t07fSxEHAjazqclabTEJ',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Formentera',
#   'artist_name': 'Aitana, Nicki Nicole',
#   'release_date': '2021-12-02',
#   'id_track': '3nfICwo20uiFdEGzgNUSrG',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Mala Vida',
#   'artist_name': 'Luis Cortés',
#   'release_date': '2021-02-19',
#   'id_track': '3IT1XT70SguZjuUiKiUu89',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Todo De Ti',
#   'artist_name': 'Rauw Alejandro',
#   'release_date': '2021-05-20',
#   'id_track': '4fSIb4hdOQ151TILNsSEaF',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Morad: Bzrp Music Sessions, Vol. 47',
#   'artist_name': 'Bizarrap, Morad',
#   'release_date': '2021-12-08',
#   'id_track': '39yyHtQ4tkjZzd8TfIBKQw',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'Vida de Rico',
#   'artist_name': 'Camilo',
#   'release_date': '2021-03-04',
#   'id_track': '4nTduFjaTmGysc9WKNuCcs',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'BEBÉ',
#   'artist_name': 'Camilo, El Alfa',
#   'release_date': '2021-03-04',
#   'id_track': '3Zf4GutWZ7Hv3wsVQsSQPs',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Pareja Del Año',
#   'artist_name': 'Sebastian Yatra, Myke Towers',
#   'release_date': '2021-04-16',
#   'id_track': '2rCbl9naJYhaxjLsfx88uM',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Volví',
#   'artist_name': 'Aventura, Bad Bunny',
#   'release_date': '2021-08-03',
#   'id_track': '2vmfvSoZBFAt9hhRoEByLi',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': '911 (Remix)',
#   'artist_name': 'Sech, JHAYCO',
#   'release_date': '2021-07-09',
#   'id_track': '27RSJHEA99Y0Vsow7nA37A',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'Cosa Guapa',
#   'artist_name': 'Rauw Alejandro',
#   'release_date': '2021-12-10',
#   'id_track': '7aWiJeMyxxPEyjwvZyauAF',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Te debo una canción',
#   'artist_name': 'Shinova',
#   'release_date': '2021-02-26',
#   'id_track': '6E4Z9YuZz9VA7NxXxshXQx',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'La sonrisa intacta',
#   'artist_name': 'Shinova',
#   'release_date': '2021-02-26',
#   'id_track': '52Pxn490S6sTjhXgyfeSbk',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'FRIKI',
#   'artist_name': 'Feid, KAROL G',
#   'release_date': '2021-12-17',
#   'id_track': '2WrqTrNIHqfcMCgmEo0A7E',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Abajo',
#   'artist_name': 'Arde Bogotá',
#   'release_date': '2021-05-07',
#   'id_track': '45ucex4am8ru040h5mhxuo',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'A ver qué pasa - Estrella Damm 2021',
#   'artist_name': 'Rigoberta Bandini',
#   'release_date': '2021-06-16',
#   'id_track': '2F76kzOWgd3n6GwoKpRSTX',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'El Beso',
#   'artist_name': 'Arde Bogotá',
#   'release_date': '2021-05-07',
#   'id_track': '325R4okpFnhCZ8guXOH0Ah',
#   'popularity': 51,
#   'genero': 'pop'},
#  {'track_name': 'Millones',
#   'artist_name': 'Camilo',
#   'release_date': '2021-03-04',
#   'id_track': '3YAnNBdk0uHyakXXzMbNJq',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Miénteme',
#   'artist_name': 'TINI, Maria Becerra',
#   'release_date': '2021-04-29',
#   'id_track': '0cOa970mzTWAxKtltpkpLc',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Aloha',
#   'artist_name': 'Maluma, Beéle, Rauw Alejandro, Mambo Kingz, DJ Luian, Darell',
#   'release_date': '2021-03-05',
#   'id_track': '5RAIMjdrCEjpjaR5tBATXU',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': "Desenfocao'",
#   'artist_name': 'Rauw Alejandro',
#   'release_date': '2021-12-10',
#   'id_track': '2CEf2gU5ZJamLXa3NrgAvA',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'good 4 u',
#   'artist_name': 'Olivia Rodrigo',
#   'release_date': '2021-05-21',
#   'id_track': '4ZtFanR9U6ndgddUvNcjcG',
#   'popularity': 78,
#   'genero': 'pop'},
#  {'track_name': 'I WANNA BE YOUR SLAVE',
#   'artist_name': 'Måneskin',
#   'release_date': '2021-03-19',
#   'id_track': '4pt5fDVTg5GhEvEtlz9dKk',
#   'popularity': 77,
#   'genero': 'pop'},
#  {'track_name': 'you broke me first',
#   'artist_name': 'Tate McRae',
#   'release_date': '2021-03-26',
#   'id_track': '4l0RmWt52FxpVxMNni6i63',
#   'popularity': 80,
#   'genero': 'pop'},
#  {'track_name': 'deja vu',
#   'artist_name': 'Olivia Rodrigo',
#   'release_date': '2021-05-21',
#   'id_track': '6HU7h9RYOaPRFeh0R3UeAr',
#   'popularity': 80,
#   'genero': 'pop'},
#  {'track_name': 'Aquel Nap ZzZz',
#   'artist_name': 'Rauw Alejandro',
#   'release_date': '2021-12-10',
#   'id_track': '5bQLsyTrUaMQRfr6whwGe5',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Happier Than Ever',
#   'artist_name': 'Billie Eilish',
#   'release_date': '2021-07-30',
#   'id_track': '4RVwu0g32PAqgUiJoXsdF8',
#   'popularity': 80,
#   'genero': 'pop'},
#  {'track_name': 'Sexo Virtual',
#   'artist_name': 'Rauw Alejandro',
#   'release_date': '2021-12-10',
#   'id_track': '1lV3QHHMAQt0Kc1ioZq2MP',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Easy On Me',
#   'artist_name': 'Adele',
#   'release_date': '2021-10-14',
#   'id_track': '0gplL1WMoJ6iYaPgMCL0gX',
#   'popularity': 75,
#   'genero': 'pop'},
#  {'track_name': 'Bad Habits',
#   'artist_name': 'Ed Sheeran',
#   'release_date': '2021-10-25',
#   'id_track': '3rmo8F54jFF8OgYsqTxm5d',
#   'popularity': 75,
#   'genero': 'pop'},
#  {'track_name': 'Do It To It',
#   'artist_name': 'ACRAZE, Cherish',
#   'release_date': '2021-08-20',
#   'id_track': '20on25jryn53hWghthWWW3',
#   'popularity': 73,
#   'genero': 'pop'},
#  {'track_name': 'Woman',
#   'artist_name': 'Doja Cat',
#   'release_date': '2021-06-25',
#   'id_track': '6Uj1ctrBOjOas8xZXGqKk4',
#   'popularity': 79,
#   'genero': 'pop'},
#  {'track_name': 'Kiss Me More (feat. SZA)',
#   'artist_name': 'Doja Cat, SZA',
#   'release_date': '2021-06-25',
#   'id_track': '3DarAbFujv6eYNliUTyqtz',
#   'popularity': 79,
#   'genero': 'pop'},
#  {'track_name': 'Enamórate De Alguien Más',
#   'artist_name': 'Morat',
#   'release_date': '2021-07-16',
#   'id_track': '1pDgS6HDNrrIawdhYEvI0s',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'SI TÚ SUPIERAS - Bonus Track',
#   'artist_name': 'Feid',
#   'release_date': '2021-08-20',
#   'id_track': '1SCYfmGM5ueb6YiiQbLXVn',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'happier',
#   'artist_name': 'Olivia Rodrigo',
#   'release_date': '2021-05-21',
#   'id_track': '2tGvwE8GcFKwNdAXMnlbfl',
#   'popularity': 78,
#   'genero': 'pop'},
#  {'track_name': 'Friday (feat. Mufasa & Hypeman) - Dopamine Re-Edit',
#   'artist_name': 'Riton, Nightcrawlers, Mufasa & Hypeman, Mufasa, Dopamine',
#   'release_date': '2021-01-15',
#   'id_track': '4cG7HUWYHBV6R6tHn1gxrl',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'Leave Before You Love Me (with Jonas Brothers)',
#   'artist_name': 'Marshmello, Jonas Brothers',
#   'release_date': '2021-05-21',
#   'id_track': '4qu63nuBpdn0qHUHuObEj1',
#   'popularity': 75,
#   'genero': 'pop'},
#  {'track_name': 'Ghost',
#   'artist_name': 'Justin Bieber',
#   'release_date': '2021-03-19',
#   'id_track': '6I3mqTwhRpn34SLVafSH7G',
#   'popularity': 79,
#   'genero': 'pop'},
#  {'track_name': "Don't Be Shy",
#   'artist_name': 'Tiësto, KAROL G',
#   'release_date': '2021-08-12',
#   'id_track': '0bI7K9Becu2dtXK1Q3cZNB',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'jealousy, jealousy',
#   'artist_name': 'Olivia Rodrigo',
#   'release_date': '2021-05-21',
#   'id_track': '0MMyJUC3WNnFS1lit5pTjk',
#   'popularity': 77,
#   'genero': 'pop'},
#  {'track_name': 'Enemy (with JID) - from the series Arcane League of Legends',
#   'artist_name': 'Imagine Dragons, JID, Arcane, League of Legends',
#   'release_date': '2021-10-28',
#   'id_track': '1r9xUipOqoNwggBpENDsvJ',
#   'popularity': 73,
#   'genero': 'pop'},
#  {'track_name': 'Idiota',
#   'artist_name': 'Morat, Danna Paola',
#   'release_date': '2021-07-16',
#   'id_track': '0cS0bJ0oBylj3TFtz6x9pC',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': '2/Catorce',
#   'artist_name': 'Rauw Alejandro, Mr. Naisgai',
#   'release_date': '2021-12-10',
#   'id_track': '78QcVmzxS0wIwuC2rpAauI',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'You Belong With Me (Taylor’s Version)',
#   'artist_name': 'Taylor Swift',
#   'release_date': '2021-04-09',
#   'id_track': '1qrpoAMXodY6895hGKoUpA',
#   'popularity': 76,
#   'genero': 'pop'},
#  {'track_name': 'Manos de Tijera',
#   'artist_name': 'Camilo',
#   'release_date': '2021-03-04',
#   'id_track': '2f8sB9lQ6Uh1lKKWJNR9rW',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Where Are You Now',
#   'artist_name': 'Lost Frequencies, Calum Scott',
#   'release_date': '2021-07-30',
#   'id_track': '3uUuGVFu1V7jTQL60S1r8z',
#   'popularity': 73,
#   'genero': 'pop'},
#  {'track_name': 'YaMeFui',
#   'artist_name': 'Bizarrap, Duki, Nicki Nicole',
#   'release_date': '2021-07-28',
#   'id_track': '42ahuAFlYGjIGBpVdHcLij',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'Fair Trade (with Travis Scott)',
#   'artist_name': 'Drake, Travis Scott',
#   'release_date': '2021-09-03',
#   'id_track': '40iJIUlhi6renaREYGeIDS',
#   'popularity': 75,
#   'genero': 'pop'},
#  {'track_name': 'Peaches (feat. Daniel Caesar & Giveon)',
#   'artist_name': 'Justin Bieber, Daniel Caesar, GIVĒON',
#   'release_date': '2021-03-19',
#   'id_track': '4iJyoBOLtHqaGxP12qzhQI',
#   'popularity': 75,
#   'genero': 'pop'},
#  {'track_name': 'My Universe',
#   'artist_name': 'Coldplay, BTS',
#   'release_date': '2021-09-24',
#   'id_track': '3FeVmId7tL5YN8B7R3imoM',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'como si no importara',
#   'artist_name': 'Emilia, Duki',
#   'release_date': '2021-07-13',
#   'id_track': '1GYJpuLq41vEVKXiHGEY9j',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'Save Your Tears (with Ariana Grande) (Remix)',
#   'artist_name': 'The Weeknd, Ariana Grande',
#   'release_date': '2021-04-23',
#   'id_track': '37BZB0z9T8Xu7U3e65qxFy',
#   'popularity': 73,
#   'genero': 'pop'},
#  {'track_name': 'La street',
#   'artist_name': 'Jul, Morad',
#   'release_date': '2021-12-10',
#   'id_track': '29n9av2AJlYDHtqfuv0X04',
#   'popularity': 59,
#   'genero': 'pop'},
#  {'track_name': 'My Universe',
#   'artist_name': 'Coldplay, BTS',
#   'release_date': '2021-10-15',
#   'id_track': '46HNZY1i7O6jwTA7Slo2PI',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'Sobrio',
#   'artist_name': 'Maluma',
#   'release_date': '2021-07-08',
#   'id_track': '4HzqWEdAbzcVFDv0pvxV4w',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Chemtrails Over The Country Club',
#   'artist_name': 'Lana Del Rey',
#   'release_date': '2021-03-19',
#   'id_track': '7bPWdJgx8vek7S5i5yAtvG',
#   'popularity': 76,
#   'genero': 'pop'},
#  {'track_name': 'Leave The Door Open',
#   'artist_name': 'Bruno Mars, Anderson .Paak, Silk Sonic',
#   'release_date': '2021-11-11',
#   'id_track': '02VBYrHfVwfEWXk5DXyf0T',
#   'popularity': 74,
#   'genero': 'pop'},
#  {'track_name': 'Índigo',
#   'artist_name': 'Camilo, Evaluna Montaner',
#   'release_date': '2021-10-13',
#   'id_track': '4knc1Fp3kbuq8bH2byOvLu',
#   'popularity': 62,
#   'genero': 'pop'},
#  {'track_name': 'Mood (feat. iann dior)',
#   'artist_name': '24kGoldn, iann dior',
#   'release_date': '2021-03-26',
#   'id_track': '4jPy3l0RUwlUI9T5XHBW2m',
#   'popularity': 74,
#   'genero': 'pop'},
#  {'track_name': 'L-Gante: Bzrp Music Sessions, Vol.38',
#   'artist_name': 'Bizarrap, L-Gante',
#   'release_date': '2021-03-10',
#   'id_track': '1Crj1zkRMpsEjb9NOR6Zof',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': 'Billie Bossa Nova',
#   'artist_name': 'Billie Eilish',
#   'release_date': '2021-07-30',
#   'id_track': '2KnuaZYoGzDoHiBTNYOTXG',
#   'popularity': 74,
#   'genero': 'pop'},
#  {'track_name': 'No Hay Más Que Hablar',
#   'artist_name': 'Morat',
#   'release_date': '2021-07-16',
#   'id_track': '0PrD2VArqOuweEzhnpdM89',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Earned It (Fifty Shades Of Grey)',
#   'artist_name': 'The Weeknd',
#   'release_date': '2021-02-05',
#   'id_track': '1cQ3LIkZE68pMSnPhZWXLu',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'KESI - Remix',
#   'artist_name': 'Camilo, Shawn Mendes',
#   'release_date': '2021-07-14',
#   'id_track': '0IqCoZ168iRc9LqfrYgpZy',
#   'popularity': 62,
#   'genero': 'pop'},
#  {'track_name': 'The Color Violet',
#   'artist_name': 'Tory Lanez',
#   'release_date': '2021-12-10',
#   'id_track': '3azJifCSqg9fRij2yKIbWz',
#   'popularity': 81,
#   'genero': 'pop'},
#  {'track_name': 'ZITTI E BUONI',
#   'artist_name': 'Måneskin',
#   'release_date': '2021-03-19',
#   'id_track': '776AftMmFFAWUIEAb3lHhw',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Something About You',
#   'artist_name': 'Eyedress, Dent May',
#   'release_date': '2021-08-27',
#   'id_track': '6RiiSy9GzSwiyDEJDiMuKe',
#   'popularity': 78,
#   'genero': 'pop'},
#  {'track_name': 'Tiroteo',
#   'artist_name': 'Marc Seguí, Pol Granch',
#   'release_date': '2021-01-15',
#   'id_track': '05HpBFLrHBjWpgV0DSPUAv',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': "All Too Well (10 Minute Version) (Taylor's Version) (From The Vault)",
#   'artist_name': 'Taylor Swift',
#   'release_date': '2021-11-12',
#   'id_track': '5enxwA8aAbwZbf5qCHORXi',
#   'popularity': 75,
#   'genero': 'pop'},
#  {'track_name': 'Lo Siento BB:/ (with Bad Bunny & Julieta Venegas)',
#   'artist_name': 'Tainy, Bad Bunny, Julieta Venegas',
#   'release_date': '2021-10-05',
#   'id_track': '4gzsuuZypVbxs0Af1LSZyB',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Machu Picchu',
#   'artist_name': 'Camilo, Evaluna Montaner',
#   'release_date': '2021-03-04',
#   'id_track': '6RV9pRLIQiXm3qTGeyQluf',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'The Motto',
#   'artist_name': 'Tiësto, Ava Max',
#   'release_date': '2021-11-04',
#   'id_track': '18asYwWugKjjsihZ0YvRxO',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'OUT OUT (feat. Charli XCX & Saweetie)',
#   'artist_name': 'Joel Corry, Jax Jones, Charli xcx, Saweetie',
#   'release_date': '2021-08-13',
#   'id_track': '6Dy1jexKYriXAVG6evyUTJ',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Pray For Me',
#   'artist_name': 'The Weeknd, Kendrick Lamar',
#   'release_date': '2021-02-05',
#   'id_track': '6huNf4dutXRjJyGn7f5BPS',
#   'popularity': 74,
#   'genero': 'pop'},
#  {'track_name': 'CORALINE',
#   'artist_name': 'Måneskin',
#   'release_date': '2021-03-19',
#   'id_track': '7HMz8o0m7ASQ3ImFPfhWTY',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'AMOR DE MI VIDA',
#   'artist_name': 'Feid',
#   'release_date': '2021-12-17',
#   'id_track': '2C6eINAA8cO6e5a8PjnWsK',
#   'popularity': 62,
#   'genero': 'pop'},
#  {'track_name': 'brutal',
#   'artist_name': 'Olivia Rodrigo',
#   'release_date': '2021-05-21',
#   'id_track': '6SRsiMl7w1USE4mFqrOhHC',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'brutal',
#   'artist_name': 'Olivia Rodrigo',
#   'release_date': '2021-05-21',
#   'id_track': '6SRsiMl7w1USE4mFqrOhHC',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': "Halley's Comet",
#   'artist_name': 'Billie Eilish',
#   'release_date': '2021-07-30',
#   'id_track': '5XsAal7ZcWg1I5T4NcRjkv',
#   'popularity': 73,
#   'genero': 'pop'},
#  {'track_name': 'Love Story (Taylor’s Version)',
#   'artist_name': 'Taylor Swift',
#   'release_date': '2021-04-09',
#   'id_track': '6YvqWjhGD8mB5QXcbcUKtx',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'Ella - Remix',
#   'artist_name': 'Boza, Lunay, Lenny Tavárez, Juhn, Beéle',
#   'release_date': '2021-10-29',
#   'id_track': '7iHHlCbsFou5DZSW5HCPfs',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'Your Power',
#   'artist_name': 'Billie Eilish',
#   'release_date': '2021-07-30',
#   'id_track': '042Sl6Mn83JHyLEqdK7uI0',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'Dance Monkey',
#   'artist_name': 'Tones And I',
#   'release_date': '2021-07-16',
#   'id_track': '2N8m6CYs74qQO4mjVcXO30',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'I Follow Rivers - The Magician Remix',
#   'artist_name': 'Lykke Li, The Magician',
#   'release_date': '2021-07-16',
#   'id_track': '3zNNXjjjeLrzIXSJZKalDi',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Higher Power',
#   'artist_name': 'Coldplay',
#   'release_date': '2021-05-07',
#   'id_track': '0939D7aT18uBDS2MTjWzct',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Papel',
#   'artist_name': "Rim'K, Morad",
#   'release_date': '2021-08-27',
#   'id_track': '2OqfQTMNm4NC4ZsyhectJ1',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Pain',
#   'artist_name': 'PinkPantheress',
#   'release_date': '2021-10-15',
#   'id_track': '4S4QJfBGGrC8jRIjJHf1Ka',
#   'popularity': 78,
#   'genero': 'pop'},
#  {'track_name': 'Machu Picchu',
#   'artist_name': 'Camilo, Evaluna Montaner',
#   'release_date': '2021-03-01',
#   'id_track': '1LXb70u8SLsvBAPWHMCTMe',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'No Wahala',
#   'artist_name': '1da Banton',
#   'release_date': '2021-07-23',
#   'id_track': '4vHy2IHzf3EabEa7oMpUZB',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': "We Are Never Ever Getting Back Together (Taylor's Version)",
#   'artist_name': 'Taylor Swift',
#   'release_date': '2021-11-12',
#   'id_track': '5YqltLsjdqFtvqE7Nrysvs',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Love Story (Taylor’s Version)',
#   'artist_name': 'Taylor Swift',
#   'release_date': '2021-02-12',
#   'id_track': '3CeCwYWvdfXbZLXFhBrbnf',
#   'popularity': 73,
#   'genero': 'pop'},
#  {'track_name': 'Mónaco',
#   'artist_name': 'LAGOS, Danny Ocean',
#   'release_date': '2021-05-28',
#   'id_track': '3HgvO4B5LLmdPOT2d8cSZd',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'Run',
#   'artist_name': 'OneRepublic',
#   'release_date': '2021-08-27',
#   'id_track': '6KL88T4Ma4ABXqzgUoEwkd',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'Yebba’s Heartbreak',
#   'artist_name': 'Drake, Yebba',
#   'release_date': '2021-09-03',
#   'id_track': '1PDP7mLiAMwhfmgIwzhOm2',
#   'popularity': 74,
#   'genero': 'pop'},
#  {'track_name': 'MONEY',
#   'artist_name': 'LISA',
#   'release_date': '2021-09-10',
#   'id_track': '7hU3IHwjX150XLoTVmjD0q',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'DUELE EL CORAZON',
#   'artist_name': 'Enrique Iglesias, Wisin',
#   'release_date': '2021-09-17',
#   'id_track': '5adqS3stLaSPAEOszOnpXG',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'Enemy - From the series Arcane League of Legends',
#   'artist_name': 'Imagine Dragons, Arcane, League of Legends',
#   'release_date': '2021-10-27',
#   'id_track': '5UlnuulVAVmmesw4VzqHdG',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Kiss Me More (feat. SZA)',
#   'artist_name': 'Doja Cat, SZA',
#   'release_date': '2021-04-09',
#   'id_track': '3DarAbFujv6eYNliUTyqtz',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'SUBEME LA RADIO',
#   'artist_name': 'Enrique Iglesias, Descemer Bueno, Zion & Lennox',
#   'release_date': '2021-09-17',
#   'id_track': '0mnAmQX1pciMncT2qFCNmK',
#   'popularity': 62,
#   'genero': 'pop'},
#  {'track_name': 'The Way I Loved You (Taylor’s Version)',
#   'artist_name': 'Taylor Swift',
#   'release_date': '2021-04-09',
#   'id_track': '22bPsP2jCgbLUvh82U0Z3M',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'abcdefu',
#   'artist_name': 'GAYLE',
#   'release_date': '2021-08-13',
#   'id_track': '4fouWK6XVHhzl78KzQ1UjL',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'NDA',
#   'artist_name': 'Billie Eilish',
#   'release_date': '2021-07-30',
#   'id_track': '38GBNKZUhfBkk3oNlWzRYd',
#   'popularity': 73,
#   'genero': 'pop'},
#  {'track_name': 'Playground (from the series Arcane League of Legends)',
#   'artist_name': 'Bea Miller, Arcane, League of Legends',
#   'release_date': '2021-11-05',
#   'id_track': '0eSKFjwdh7uOJZ7me6YbaN',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Need to Know',
#   'artist_name': 'Doja Cat',
#   'release_date': '2021-06-25',
#   'id_track': '3Vi5XqYrmQgOYBajMWSvCi',
#   'popularity': 74,
#   'genero': 'pop'},
#  {'track_name': 'Envolver',
#   'artist_name': 'Anitta',
#   'release_date': '2021-11-11',
#   'id_track': '3IAfUEeaXRX9s9UdKOJrFI',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Oh My God',
#   'artist_name': 'Adele',
#   'release_date': '2021-11-19',
#   'id_track': '3Kkjo3cT83cw09VJyrLNwX',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Heavy',
#   'artist_name': 'The Marías',
#   'release_date': '2021-06-25',
#   'id_track': '1ShRHPAiiIrh0arZbSFmx1',
#   'popularity': 78,
#   'genero': 'pop'},
#  {'track_name': 'Let Somebody Go',
#   'artist_name': 'Coldplay, Selena Gomez',
#   'release_date': '2021-10-15',
#   'id_track': '4cGqn0E8JCSY9gQllQj4Mf',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Amour plastique',
#   'artist_name': 'Videoclub, Adèle Castillon, Mattyeux',
#   'release_date': '2021-01-29',
#   'id_track': '269XSeQhDrWEotMALJaACW',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Remember',
#   'artist_name': 'Becky Hill, David Guetta',
#   'release_date': '2021-06-18',
#   'id_track': '4laAKIq9ZxBCwf99rauPYb',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Summer of Love (Shawn Mendes & Tainy)',
#   'artist_name': 'Shawn Mendes, Tainy',
#   'release_date': '2021-08-20',
#   'id_track': '0z8hI3OPS8ADPWtoCjjLl6',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Heartbreak Anthem (with David Guetta & Little Mix)',
#   'artist_name': 'Galantis, David Guetta, Little Mix',
#   'release_date': '2021-05-20',
#   'id_track': '5K6Ssv4Z3zRvxt0P6EKUAP',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'What Could Have Been (from the series Arcane League of Legends)',
#   'artist_name': 'Sting, Ray Chen',
#   'release_date': '2021-11-20',
#   'id_track': '6YB9jhzVEzw8CKeXD7Vx8j',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'I Drink Wine',
#   'artist_name': 'Adele',
#   'release_date': '2021-11-19',
#   'id_track': '6v0UJD4a2FtleHeSYVX02A',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'BED',
#   'artist_name': 'Joel Corry, RAYE, David Guetta',
#   'release_date': '2021-02-26',
#   'id_track': '0siYMEsGrzzzlWLXK5zJfS',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'SAD GIRLZ LUV MONEY Remix (feat. Kali Uchis and Moliy)',
#   'artist_name': 'Amaarae, Kali Uchis, MOLIY',
#   'release_date': '2021-09-16',
#   'id_track': '09gysnJpfQ3ublBmJDfcEC',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'Roi',
#   'artist_name': 'Videoclub, Adèle Castillon, Mattyeux',
#   'release_date': '2021-01-29',
#   'id_track': '7LPGJhkRDEW6KopWhD8DbX',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'You Right',
#   'artist_name': 'Doja Cat, The Weeknd',
#   'release_date': '2021-06-25',
#   'id_track': '0k4d5YPDr1r7FX77VdqWez',
#   'popularity': 73,
#   'genero': 'pop'},
#  {'track_name': 'Lonely (with benny blanco)',
#   'artist_name': 'Justin Bieber, benny blanco',
#   'release_date': '2021-03-19',
#   'id_track': '3S8jK1mGzQi24ilFb45DAZ',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'hope ur ok',
#   'artist_name': 'Olivia Rodrigo',
#   'release_date': '2021-05-21',
#   'id_track': '1zejeOnykpCoyVSit6Bwp3',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Getting Older',
#   'artist_name': 'Billie Eilish',
#   'release_date': '2021-07-30',
#   'id_track': '4HOryCnbme0zBnF8LWij3f',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Los Tragos',
#   'artist_name': 'Reik, Maria Becerra',
#   'release_date': '2021-11-25',
#   'id_track': '7iXJg4IUyrWont5YSQrbKP',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': 'Memories (feat. Kid Cudi) - 2021 Remix',
#   'artist_name': 'David Guetta, Kid Cudi',
#   'release_date': '2021-01-08',
#   'id_track': '59o6ojGNGJOYiVJSzC6Lsa',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'La Distancia',
#   'artist_name': 'Manuel Medrano',
#   'release_date': '2021-10-01',
#   'id_track': '0LpEr3qpmDQ1gEabnsQlGC',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Higher Power',
#   'artist_name': 'Coldplay',
#   'release_date': '2021-10-15',
#   'id_track': '65OR4ywy8Cgs3FDHK82Idl',
#   'popularity': 62,
#   'genero': 'pop'},
#  {'track_name': 'right where you left me - bonus track',
#   'artist_name': 'Taylor Swift',
#   'release_date': '2021-01-07',
#   'id_track': '3zwMVvkBe2qIKDObWgXw4N',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': "I Knew You Were Trouble (Taylor's Version)",
#   'artist_name': 'Taylor Swift',
#   'release_date': '2021-11-12',
#   'id_track': '6AtZLIzUINvExIUy4QhdjP',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Therefore I Am',
#   'artist_name': 'Billie Eilish',
#   'release_date': '2021-07-30',
#   'id_track': '20R4HfKloPKgXDqU7UKk3x',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'CHIMBITA',
#   'artist_name': 'Feid, Sky Rompiendo',
#   'release_date': '2021-08-20',
#   'id_track': '35xvhWIZMpsDcJxr14Ukbx',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': 'Fearless (Taylor’s Version)',
#   'artist_name': 'Taylor Swift',
#   'release_date': '2021-04-09',
#   'id_track': '77sMIMlNaSURUAXq5coCxE',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'Overwhelmed (Ryan Mack Remix)',
#   'artist_name': 'Ryan Mack',
#   'release_date': '2021-07-14',
#   'id_track': '03eyNjBM2mpx28H6kdaufN',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': "It'll Be Okay",
#   'artist_name': 'Shawn Mendes',
#   'release_date': '2021-12-01',
#   'id_track': '2KnLkZ3z7PO3kgVGHGqDpD',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'VACAXIONES',
#   'artist_name': 'Feid',
#   'release_date': '2021-12-17',
#   'id_track': '5QLs1kIWkkxcdUBfTkqWBX',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Guaro (Remix)',
#   'artist_name': 'Pipe Bueno, Jessi Uribe, Yeison Jimenez, Carin Leon, Alzate, Darío Gómez, Luis Alberto Posada, El Charrito Negro, Jhonny Rivera, Jhon Alex Castaño',
#   'release_date': '2021-09-16',
#   'id_track': '5sMHuOIvtsSuFZafTcF19Q',
#   'popularity': 62,
#   'genero': 'pop'},
#  {'track_name': 'TENGO FE',
#   'artist_name': 'Feid',
#   'release_date': '2021-08-20',
#   'id_track': '57pkksnRS4NOOphTmoRlK2',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': "I Didn't Change My Number",
#   'artist_name': 'Billie Eilish',
#   'release_date': '2021-07-30',
#   'id_track': '7bcy34fBT2ap1L4bfPsl9q',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'Beautiful Mistakes (feat. Megan Thee Stallion)',
#   'artist_name': 'Maroon 5, Megan Thee Stallion',
#   'release_date': '2021-06-11',
#   'id_track': '5zFglKYiknIxks8geR8rcL',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'Goodbye (from the series Arcane League of Legends)',
#   'artist_name': 'Ramsey, Arcane, League of Legends',
#   'release_date': '2021-11-05',
#   'id_track': '50qY6EQTt33QAUQnDgbYOS',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Girls Want Girls (with Lil Baby)',
#   'artist_name': 'Drake, Lil Baby',
#   'release_date': '2021-09-03',
#   'id_track': '37Nqx7iavZpotJSDXZWbJ3',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'Guns for Hire (from the series Arcane League of Legends)',
#   'artist_name': 'Woodkid, Arcane, League of Legends',
#   'release_date': '2021-11-13',
#   'id_track': '38x5NsjgoLaYCnhAghHdyo',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Sunshine',
#   'artist_name': 'OneRepublic',
#   'release_date': '2021-11-10',
#   'id_track': '5r43qanLhUCdBj8HN3fa6B',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'SI TÚ SUPIERAS',
#   'artist_name': 'Feid',
#   'release_date': '2021-12-17',
#   'id_track': '6qtDKAKZhJfVziibsoGBBj',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': "Red (Taylor's Version)",
#   'artist_name': 'Taylor Swift',
#   'release_date': '2021-11-12',
#   'id_track': '4OAuvHryIVv4kMDNSLuPt6',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': "22 (Taylor's Version)",
#   'artist_name': 'Taylor Swift',
#   'release_date': '2021-11-12',
#   'id_track': '3yII7UwgLF6K5zW3xad3MP',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Acapulco',
#   'artist_name': 'Jason Derulo',
#   'release_date': '2021-09-03',
#   'id_track': '3eJH2nAjvNXdmPfBkALiPZ',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Confession',
#   'artist_name': 'Babyboy AV',
#   'release_date': '2021-10-22',
#   'id_track': '7IAzRTQQz6Aoywj0R1Qce5',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Drunk-Dazed',
#   'artist_name': 'ENHYPEN',
#   'release_date': '2021-04-26',
#   'id_track': '1wcr8DjnN59Awev8nnKpQ4',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Living Legend',
#   'artist_name': 'Lana Del Rey',
#   'release_date': '2021-10-22',
#   'id_track': '6pZ9Nj3vzj1RW4ZkR9GcQ9',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': "Pa' Olvidarme De Ella",
#   'artist_name': 'Piso 21, Christian Nodal',
#   'release_date': '2021-03-18',
#   'id_track': '3lR4O0vtkhCAvVEUEWUL0S',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Male Fantasy',
#   'artist_name': 'Billie Eilish',
#   'release_date': '2021-07-30',
#   'id_track': '4ak9GGe6afmi2HbxEjvhIC',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Permission to Dance',
#   'artist_name': 'BTS',
#   'release_date': '2021-07-23',
#   'id_track': '3XYRV7ZSHqIRDG87DKTtry',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Si No Te Tengo / Ángel / Aquello Que Pasó',
#   'artist_name': 'Ke Personajes',
#   'release_date': '2021-08-17',
#   'id_track': '1fKFxmSByZfjwVSbq0PHye',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': "Ain't Shit",
#   'artist_name': 'Doja Cat',
#   'release_date': '2021-06-25',
#   'id_track': '5lAnYvAIkSDNXqfo7DyFUm',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'Wants and Needs (feat. Lil Baby)',
#   'artist_name': 'Drake, Lil Baby',
#   'release_date': '2021-03-05',
#   'id_track': '65OVbaJR5O1RmwOQx0875b',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'You',
#   'artist_name': 'Regard, Troye Sivan, Tate McRae',
#   'release_date': '2021-04-16',
#   'id_track': '2cc8Sw1OnCuA5bV8nqWqpE',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Lost Cause',
#   'artist_name': 'Billie Eilish',
#   'release_date': '2021-07-30',
#   'id_track': '4191RXFPa7Ge9XkA4cWlna',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Run',
#   'artist_name': 'OneRepublic',
#   'release_date': '2021-05-05',
#   'id_track': '2UbVnbE5FH6008mAm6Mmgw',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Rescue Me',
#   'artist_name': 'OneRepublic',
#   'release_date': '2021-08-27',
#   'id_track': '37LNNQNbL1YLyutBG6aWRx',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Replay',
#   'artist_name': 'Tems',
#   'release_date': '2021-09-14',
#   'id_track': '2dFqK2ZkYB9Xc47gr3xXWl',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Hold On',
#   'artist_name': 'Justin Bieber',
#   'release_date': '2021-03-19',
#   'id_track': '1nahzW3kfMuwReTka28tH5',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Off My Face',
#   'artist_name': 'Justin Bieber',
#   'release_date': '2021-03-19',
#   'id_track': '3T03rPwlL8NVk1yIaxeD8U',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Leave The Door Open',
#   'artist_name': 'Bruno Mars, Anderson .Paak, Silk Sonic',
#   'release_date': '2021-11-12',
#   'id_track': '4pryE6cN2gFL1FVF5fYINl',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Habibi - Albanian Remix',
#   'artist_name': 'Ricky Rich, Dardan, DJ Gimi-O',
#   'release_date': '2021-11-19',
#   'id_track': '2sHYMLUd4nVLxHPKY05Ein',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Oxytocin',
#   'artist_name': 'Billie Eilish',
#   'release_date': '2021-07-30',
#   'id_track': '4t2OeILB07eMGTXSUbMPEu',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'my future',
#   'artist_name': 'Billie Eilish',
#   'release_date': '2021-07-30',
#   'id_track': '3YUMWmx8EJq0DurfuIwoGh',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'YSY A: Bzrp Music Sessions, Vol. 37',
#   'artist_name': 'Bizarrap, YSY A',
#   'release_date': '2021-01-27',
#   'id_track': '1xXQCSt0xkfeGhe18ey2p8',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Red Lights (Bang Chan, Hyunjin)',
#   'artist_name': 'Stray Kids',
#   'release_date': '2021-08-23',
#   'id_track': '0LatE4S9UtCDwIdGQsFFKL',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Nothing New (feat. Phoebe Bridgers) (Taylor’s Version) (From The Vault)',
#   'artist_name': 'Taylor Swift, Phoebe Bridgers',
#   'release_date': '2021-11-12',
#   'id_track': '01K4zKU104LyJ8gMb7227B',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Ghost Town',
#   'artist_name': 'Benson Boone',
#   'release_date': '2021-10-15',
#   'id_track': '135Lf4Q0CzlMNfOxbEUsLH',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'FEVER',
#   'artist_name': 'ENHYPEN',
#   'release_date': '2021-04-26',
#   'id_track': '0UzymivvUH5s8z4PeWZJaK',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Lavender Sunflower',
#   'artist_name': 'Tory Lanez',
#   'release_date': '2021-12-10',
#   'id_track': '1au2UduxcvHfa0fZS3Szci',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'Anyone',
#   'artist_name': 'Justin Bieber',
#   'release_date': '2021-03-19',
#   'id_track': '2WnAKZefdRHxtBEkRjFOHC',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Otro Día Más',
#   'artist_name': 'Ke Personajes, La Contra',
#   'release_date': '2021-06-10',
#   'id_track': '0ccUrj1mliFnR8R8VxCmKO',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'D O D O',
#   'artist_name': 'Tayc',
#   'release_date': '2021-11-19',
#   'id_track': '2dJMDzMF5jMvVFKLTci81H',
#   'popularity': 62,
#   'genero': 'pop'},
#  {'track_name': '3:15 (Breathe)',
#   'artist_name': 'Russ',
#   'release_date': '2021-05-21',
#   'id_track': '0dGqP4VickYjtIaB5VOt4H',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'Better in the Dark',
#   'artist_name': 'Jordana, TV Girl',
#   'release_date': '2021-10-13',
#   'id_track': '3SeDS5sSoWnwAZvVgkdKzf',
#   'popularity': 74,
#   'genero': 'pop'},
#  {'track_name': 'CORONE',
#   'artist_name': 'Feid',
#   'release_date': '2021-08-20',
#   'id_track': '1A7rUacip28yYERtzuQZ55',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Matador - Remasterizado 2008',
#   'artist_name': 'Los Fabulosos Cadillacs',
#   'release_date': '2021-03-05',
#   'id_track': '4bMZ60QNM6OEehI6b8RtS4',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'Angel Baby',
#   'artist_name': 'Troye Sivan',
#   'release_date': '2021-09-09',
#   'id_track': '2m6Ko3CY1qXNNja8AlugNc',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Could Have Been Me',
#   'artist_name': 'Halsey',
#   'release_date': '2021-12-17',
#   'id_track': '16nCYYc1lCxCyvaR1lgo0i',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Not My Responsibility',
#   'artist_name': 'Billie Eilish',
#   'release_date': '2021-07-30',
#   'id_track': '4T2zre0jqstNJ5Gt0WG9lz',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Cover Me In Sunshine',
#   'artist_name': 'P!nk, Willow Sage Hart',
#   'release_date': '2021-02-12',
#   'id_track': '6Tio0ZoDeSQnI7EBAqWer2',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Killshot - Slowed + Reverb',
#   'artist_name': 'Magdalena Bay',
#   'release_date': '2021-02-05',
#   'id_track': '6pdyvJQkPkwo2WoDH7tFHO',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Fountains (with Tems)',
#   'artist_name': 'Drake, Tems',
#   'release_date': '2021-09-03',
#   'id_track': '08XWh5c0BMyD1nKVxxl91z',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'INVISIBLE',
#   'artist_name': 'Duran Duran',
#   'release_date': '2021-10-22',
#   'id_track': '51EpFns3CG9taCMQz6XDom',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Line of Fire',
#   'artist_name': 'José González',
#   'release_date': '2021-09-17',
#   'id_track': '1I6LFohPBMnEu9CXamGCwY',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Dealer',
#   'artist_name': 'Lana Del Rey',
#   'release_date': '2021-10-22',
#   'id_track': '7iqQz931tn59mK6IZ3knRx',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': '夜に駆ける',
#   'artist_name': 'YOASOBI',
#   'release_date': '2021-01-06',
#   'id_track': '6MCjmGYlw6mQVWRFVgBRvB',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'After Last Night (with Thundercat & Bootsy Collins)',
#   'artist_name': 'Bruno Mars, Anderson .Paak, Silk Sonic, Thundercat, Bootsy Collins',
#   'release_date': '2021-11-11',
#   'id_track': '3jiKUMXqwEodB7gVv1RMZU',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Mal Acostumbrao - con Maria Becerra',
#   'artist_name': 'Mau y Ricky, Maria Becerra',
#   'release_date': '2021-09-02',
#   'id_track': '1wcE84DVQUF16xudVFzezL',
#   'popularity': 54,
#   'genero': 'pop'},
#  {'track_name': '0X1=LOVESONG (I Know I Love You) feat. Seori',
#   'artist_name': 'TOMORROW X TOGETHER, Seori',
#   'release_date': '2021-05-31',
#   'id_track': '1Z8TPHiKeCUyClxV6WTTIf',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'I Must Apologise',
#   'artist_name': 'PinkPantheress',
#   'release_date': '2021-10-15',
#   'id_track': '2rrq3SGYxk90xLx5fMmPhZ',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'The Feels',
#   'artist_name': 'TWICE',
#   'release_date': '2021-11-12',
#   'id_track': '308Ir17KlNdlrbVLHWhlLe',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': "Don't Start Now",
#   'artist_name': 'Dua Lipa',
#   'release_date': '2021-02-11',
#   'id_track': '2FlcxnvybdwpaMmMhaRtSN',
#   'popularity': 59,
#   'genero': 'pop'},
#  {'track_name': 'I Bet You Think About Me (feat. Chris Stapleton) (Taylor’s Version) (From The Vault)',
#   'artist_name': 'Taylor Swift, Chris Stapleton',
#   'release_date': '2021-11-12',
#   'id_track': '4CkgMiMqZ5JzW9iYXSTMTL',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Moonlight Shadow',
#   'artist_name': 'W&W, Groove Coverage',
#   'release_date': '2021-11-26',
#   'id_track': '0R2KmlsyojxoYG8wxcd5XX',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Otra Baby',
#   'artist_name': 'Akim, Dalex, Beéle, Boza',
#   'release_date': '2021-01-29',
#   'id_track': '4f2nbpKWfnj7tNyL2Ihj9n',
#   'popularity': 49,
#   'genero': 'pop'},
#  {'track_name': '怪物',
#   'artist_name': 'YOASOBI',
#   'release_date': '2021-12-01',
#   'id_track': '2vjY3jGKElvqXoaGNEuYef',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'U Are My High (with Future)',
#   'artist_name': 'DJ Snake, Future',
#   'release_date': '2021-12-03',
#   'id_track': '0ITaSRuI0L1RNL7ZNYTTi7',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'GOLDWING',
#   'artist_name': 'Billie Eilish',
#   'release_date': '2021-07-30',
#   'id_track': '0FfqyjhB6Kspvit1oOo7ax',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Speechless (feat. Erika Sirola)',
#   'artist_name': 'Robin Schulz, Erika Sirola',
#   'release_date': '2021-02-26',
#   'id_track': '7wDTDI7giGtVFqgNipVcAR',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'JORDAN IV',
#   'artist_name': 'Feid',
#   'release_date': '2021-08-20',
#   'id_track': '5ZyNCQmxZlYZfAHeJXTkI2',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'COMMENT',
#   'artist_name': 'Feid',
#   'release_date': '2021-12-17',
#   'id_track': '4cjmzyooA8MkQAKrfESAoo',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Knife Talk (with 21 Savage ft. Project Pat)',
#   'artist_name': 'Drake, 21 Savage, Project Pat',
#   'release_date': '2021-09-03',
#   'id_track': '2BcMwX1MPV6ZHP4tUT9uq6',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'Le temps',
#   'artist_name': 'Tayc',
#   'release_date': '2021-02-26',
#   'id_track': '6yIh43XrY4Mc5xOxeagVhp',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': "Message In A Bottle (Taylor's Version) (From The Vault)",
#   'artist_name': 'Taylor Swift',
#   'release_date': '2021-11-12',
#   'id_track': '3z6XUommYDWPHeFhmhhT6j',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Dragostea Din Tei (W&W Remix)',
#   'artist_name': 'O-Zone, W&W',
#   'release_date': '2021-01-22',
#   'id_track': '6ljpxxjn7TNc2BijuKtPSo',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Still Sleepless',
#   'artist_name': 'D.O.D, Carla Monroe',
#   'release_date': '2021-09-17',
#   'id_track': '4vyG9ZhHT8MKJE5mTICMFC',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Levitating (feat. DaBaby)',
#   'artist_name': 'Dua Lipa, DaBaby',
#   'release_date': '2021-02-11',
#   'id_track': '0v2boHmWtxMTD2REGN8MbK',
#   'popularity': 59,
#   'genero': 'pop'},
#  {'track_name': 'Sometimes (Backwood)',
#   'artist_name': 'Gigi Perez',
#   'release_date': '2021-02-05',
#   'id_track': '1ElGmhauttS9p7LwmHG9uM',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Way 2 Sexy (with Future & Young Thug)',
#   'artist_name': 'Drake, Future, Young Thug',
#   'release_date': '2021-09-03',
#   'id_track': '0k1WUmIRnG3xU6fvvDVfRG',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Champagne Poetry',
#   'artist_name': 'Drake',
#   'release_date': '2021-09-03',
#   'id_track': '2HSmyk2qMN8WQjuGhaQgCk',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Need It (feat. YoungBoy Never Broke Again)',
#   'artist_name': 'Migos, YoungBoy Never Broke Again',
#   'release_date': '2021-06-11',
#   'id_track': '1cMMVJ4FDqhCci9efd1BU6',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Santa, Can’t You Hear Me',
#   'artist_name': 'Kelly Clarkson, Ariana Grande',
#   'release_date': '2021-10-15',
#   'id_track': '2O3MQ6H3gjrIWDcpeTrikT',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'EL PADRINO',
#   'artist_name': 'Feid',
#   'release_date': '2021-08-20',
#   'id_track': '0zWkVCi9eFjcVAM839IkCZ',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'Resultó Muy Perra (Me Dejó Solito)',
#   'artist_name': 'Jessi Uribe, Carin Leon',
#   'release_date': '2021-06-18',
#   'id_track': '0JfDDmD5vuNYpwQj4FCxdj',
#   'popularity': 59,
#   'genero': 'pop'},
#  {'track_name': 'LO$ER=LO♡ER',
#   'artist_name': 'TOMORROW X TOGETHER',
#   'release_date': '2021-08-17',
#   'id_track': '21aOLk12MksET8AsbU0SI6',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Amoeba',
#   'artist_name': 'Clairo',
#   'release_date': '2021-07-16',
#   'id_track': '0HAqq2GcQKyi3s87GuN7jU',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': '残響散歌',
#   'artist_name': 'Aimer',
#   'release_date': '2021-12-06',
#   'id_track': '7v8wKvNQQIxkugCFFjrkaO',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'Remember (with David Guetta)',
#   'artist_name': 'Becky Hill, David Guetta',
#   'release_date': '2021-08-27',
#   'id_track': '6feiJqgHqeSvkGUzf11AYs',
#   'popularity': 62,
#   'genero': 'pop'},
#  {'track_name': "Stevie Doesn't Wonder",
#   'artist_name': 'Hotel Ugly',
#   'release_date': '2021-12-07',
#   'id_track': '7BgyWwbbybJr2IbQoI1gzH',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Hot Air Balloon',
#   'artist_name': 'Don Diablo, AR/CO',
#   'release_date': '2021-11-05',
#   'id_track': '67p96tIoC4ESrod9kW331R',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'Someday',
#   'artist_name': 'OneRepublic',
#   'release_date': '2021-08-27',
#   'id_track': '6aDsgHPZsMztSbZernzlF8',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'That Go! (feat. T-Shyne)',
#   'artist_name': 'Young Stoner Life, Young Thug, Meek Mill, T-Shyne',
#   'release_date': '2021-04-16',
#   'id_track': '6rUmUJ2drFemHTH73bFAKQ',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'TSU',
#   'artist_name': 'Drake',
#   'release_date': '2021-09-03',
#   'id_track': '4s7QLoImIwmPi9L6dq1nVW',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'la di die (feat. Jaden Hossler)',
#   'artist_name': 'Nessa Barrett, jxdn',
#   'release_date': '2021-02-19',
#   'id_track': '3RLshk3cDQOqWhSIRCVaXL',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'Merry Christmas',
#   'artist_name': 'Ed Sheeran, Elton John',
#   'release_date': '2021-12-03',
#   'id_track': '3bH2Eu9A9ymI4UnGHRmoXg',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Break It Off - Bonus',
#   'artist_name': 'PinkPantheress',
#   'release_date': '2021-10-15',
#   'id_track': '78ul3D77noQsYjSwvwiPU1',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'TE MATA',
#   'artist_name': 'Feid',
#   'release_date': '2021-08-20',
#   'id_track': '3eFL5cxO22TpyjK3wNb27q',
#   'popularity': 54,
#   'genero': 'pop'},
#  {'track_name': 'Lady Of Namek',
#   'artist_name': 'Tory Lanez',
#   'release_date': '2021-12-10',
#   'id_track': '6ieWL5CLN9WdC875guWtMe',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Si Me Ven Llorando',
#   'artist_name': 'Jessi Uribe',
#   'release_date': '2021-09-24',
#   'id_track': '5v6eE5Wn65VSoBiJnOUyTm',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Attracted to You',
#   'artist_name': 'PinkPantheress',
#   'release_date': '2021-07-09',
# ...
#   'popularity': 50,
#   'genero': 'pop'},
#  {'track_name': '清空',
#   'artist_name': '苏星婕, 王忻辰',
#   'release_date': '2021-01-28',
#   'id_track': '5HGvMmgabU7ZkF94klVhdm',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'A un Milímetro de Ti',
#   'artist_name': 'El Blachy',
#   'release_date': '2021-06-18',
#   'id_track': '2SS9HhYPgHnHXlkgmr8B5i',
#   'popularity': 42,
#   'genero': 'pop'},
#  {'track_name': 'Dernier métro',
#   'artist_name': 'Kendji Girac, GIMS',
#   'release_date': '2021-11-11',
#   'id_track': '7J8XJt5KveebN0DzWXrbgQ',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'Démons',
#   'artist_name': 'Angèle, Damso',
#   'release_date': '2021-12-02',
#   'id_track': '3gAEAmxdP1GIjgQ3Zud2mE',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Abeg',
#   'artist_name': 'DJ Neptune, Joeboy, Omah Lay',
#   'release_date': '2021-11-26',
#   'id_track': '62cC7k1opRIS9sdviJnVj5',
#   'popularity': 51,
#   'genero': 'pop'},
#  {'track_name': 'Scarface',
#   'artist_name': 'Werenoi',
#   'release_date': '2021-08-18',
#   'id_track': '2RSpOGQtcNgmbx5ejgho5X',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Passat',
#   'artist_name': 'SDM, Maes',
#   'release_date': '2021-12-09',
#   'id_track': '5yHoANSze7sGzhn9MUarH3',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': '∞ LOVE (feat. Guè)',
#   'artist_name': 'Marracash, Guè',
#   'release_date': '2021-11-19',
#   'id_track': '0HhSB4nAJpI5expWnZL199',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'Pour Me Water',
#   'artist_name': 'Kizz Daniel',
#   'release_date': '2021-11-18',
#   'id_track': '1DrfpnLvbwndPScRLwbUE0',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'KASSAV (feat. Tiakola)',
#   'artist_name': 'Gazo, Tiakola',
#   'release_date': '2021-02-26',
#   'id_track': '25PVU9aowaP69bSYRBe3sj',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Mode Akimbo (feat. Jul)',
#   'artist_name': 'SCH, Jul',
#   'release_date': '2021-03-19',
#   'id_track': '7qezIDRM0E3WTW1lWxItug',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Better Days',
#   'artist_name': 'Dermot Kennedy',
#   'release_date': '2021-10-22',
#   'id_track': '48USW4aYqrylYWJmFPbC8A',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'MODO TURBO',
#   'artist_name': 'Luísa Sonza, Pabllo Vittar, Anitta',
#   'release_date': '2021-07-18',
#   'id_track': '2ip4hxYupn3CSsHjn4l2a8',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': "Mais je t'aime",
#   'artist_name': 'Grand Corps Malade, Camille Lellouche',
#   'release_date': '2021-09-10',
#   'id_track': '17NQyo1HsqDX7mbzsTWMuX',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Cruel',
#   'artist_name': 'OBOY',
#   'release_date': '2021-09-10',
#   'id_track': '1q3UKwsvTPfF44xQJYC0sg',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'Dans le Réseau',
#   'artist_name': 'Djadja & Dinaz',
#   'release_date': '2021-03-20',
#   'id_track': '0X5zETsfr8nGAVABRcD4o4',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': '7am On Bridle Path',
#   'artist_name': 'Drake',
#   'release_date': '2021-09-03',
#   'id_track': '42m3eP1JJhtzffal9B136J',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': '逆夢',
#   'artist_name': 'King Gnu',
#   'release_date': '2021-12-24',
#   'id_track': '6ZiEWet0uFRwWBCEKCQ8rY',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'Early In The Morning',
#   'artist_name': 'Kris Kross Amsterdam, Shaggy, Conor Maynard',
#   'release_date': '2021-04-30',
#   'id_track': '2R9nfayl1NXhuAdEpwG2Qa',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'Son Of A Sinner',
#   'artist_name': 'Jelly Roll',
#   'release_date': '2021-09-17',
#   'id_track': '6ngGiVX91DRmGDH4G5EgeO',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Sagacité',
#   'artist_name': 'MHD',
#   'release_date': '2021-07-15',
#   'id_track': '6UgODeTkEfRQBWcJ4nWUl5',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Running (To You)',
#   'artist_name': 'Chike, Simi',
#   'release_date': '2021-02-12',
#   'id_track': '5rTC3tKShDyYK0wk0rq96X',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'TAKE ALL THE LOVE',
#   'artist_name': 'Arthur Nery',
#   'release_date': '2021-04-23',
#   'id_track': '2v6jmF6VQWS96x6tSg05IC',
#   'popularity': 73,
#   'genero': 'pop'},
#  {'track_name': 'Volver a Vernos',
#   'artist_name': 'Matías Valdez',
#   'release_date': '2021-11-17',
#   'id_track': '6FzRjE65s7jGPVnLbx5FSr',
#   'popularity': 51,
#   'genero': 'pop'},
#  {'track_name': 'Having Our Way (feat. Drake)',
#   'artist_name': 'Migos, Drake',
#   'release_date': '2021-06-11',
#   'id_track': '2NM0qHzx4Ohy8iXHEEgwlO',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Контракт',
#   'artist_name': 'Poshlaya Molly',
#   'release_date': '2021-03-12',
#   'id_track': '2bqS0QtnXGjOYs3z6VtSyW',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'Crush',
#   'artist_name': 'SEVENTEEN',
#   'release_date': '2021-10-22',
#   'id_track': '68kHuoBxtNcWZWxBu1V007',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'Ferma A Guardare (feat. Pinguini Tattici Nucleari)',
#   'artist_name': 'Ernia, Pinguini Tattici Nucleari',
#   'release_date': '2021-01-19',
#   'id_track': '1eDC4NiUYgQSKpKDIvXxi4',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Coltellata (feat. thasup)',
#   'artist_name': 'Gazzelle, thasup',
#   'release_date': '2021-02-12',
#   'id_track': '6RDCUnAj3V4s37b0BBBXTa',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Timidez / A Mi Lado (Acústico)',
#   'artist_name': 'El Rodri',
#   'release_date': '2021-03-19',
#   'id_track': '3xti89QanGWwBQKcYTVmsC',
#   'popularity': 49,
#   'genero': 'pop'},
#  {'track_name': "Que tout s'danse",
#   'artist_name': 'Noé Preszow',
#   'release_date': '2021-04-02',
#   'id_track': '5btPpAAwVyA8bRc3Ol8gqQ',
#   'popularity': 51,
#   'genero': 'pop'},
#  {'track_name': 'Август - это ты',
#   'artist_name': 'МОТ',
#   'release_date': '2021-08-27',
#   'id_track': '4jkq9bTWSn4phpLK9B5DhO',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'Derrière le brouillard',
#   'artist_name': 'Grand Corps Malade, Louane',
#   'release_date': '2021-09-10',
#   'id_track': '6r6nk82xSKVf9SoJTY1w2p',
#   'popularity': 54,
#   'genero': 'pop'},
#  {'track_name': 'Oshe (feat. The Cavemen.)',
#   'artist_name': 'Kizz Daniel, The Cavemen.',
#   'release_date': '2021-11-18',
#   'id_track': '4upQnh3K5k1xbVOr97fdG7',
#   'popularity': 51,
#   'genero': 'pop'},
#  {'track_name': 'Doudou',
#   'artist_name': 'Koba LaD, Naps',
#   'release_date': '2021-12-09',
#   'id_track': '1cgRpYVOkYnxomkDpYLyba',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'зима',
#   'artist_name': 'ooes',
#   'release_date': '2021-06-25',
#   'id_track': '0cOftxEWGyu4XAqEsqmdWS',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Pagsamo',
#   'artist_name': 'Arthur Nery',
#   'release_date': '2021-10-01',
#   'id_track': '0WZqHCoOBXqgCCIsUZLC2a',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'Osama',
#   'artist_name': 'Zakes Bantwini, Kasango',
#   'release_date': '2021-12-03',
#   'id_track': '0T0FIfA0AI3ELwNVBSZNS3',
#   'popularity': 45,
#   'genero': 'pop'},
#  {'track_name': 'Te Mentiría',
#   'artist_name': 'The La Planta',
#   'release_date': '2021-06-24',
#   'id_track': '1GtBrm91qZLzAZ0OR8uSCk',
#   'popularity': 45,
#   'genero': 'pop'},
#  {'track_name': 'Blesse-moi',
#   'artist_name': 'Therapie TAXI',
#   'release_date': '2021-01-08',
#   'id_track': '6nRSyu4oOed8HgcVxV1cWl',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': '白月光与朱砂痣 - 中英文版',
#   'artist_name': '大籽, 嘿人李逵Noisemakers',
#   'release_date': '2021-01-01',
#   'id_track': '4ZC1k5x3nAJi9E3esl5yLb',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Crazy Tings',
#   'artist_name': 'Tems',
#   'release_date': '2021-09-10',
#   'id_track': '5VQagemEOLpJJikcLzDNYR',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'Cold Outside',
#   'artist_name': 'Timaya, Bnxn',
#   'release_date': '2021-10-14',
#   'id_track': '2jZ2MrAk8iNZk1dsI0Vr5z',
#   'popularity': 54,
#   'genero': 'pop'},
#  {'track_name': 'Para Siempre',
#   'artist_name': 'Benjamín Amadeo',
#   'release_date': '2021-09-02',
#   'id_track': '5ILu4zdXzG4WCbX9GtMNJX',
#   'popularity': 49,
#   'genero': 'pop'},
#  {'track_name': 'TERE TE',
#   'artist_name': 'AP Dhillon, Gurinder Gill',
#   'release_date': '2021-11-21',
#   'id_track': '0ptqV9ySE8HVbWblGdv3Eb',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Allegro Ventigo',
#   'artist_name': 'Dan Balan, Matteo',
#   'release_date': '2021-04-20',
#   'id_track': '16DIrIswfV76PWOg54XS0F',
#   'popularity': 45,
#   'genero': 'pop'},
#  {'track_name': 'Кайфую',
#   'artist_name': 'VESNA305',
#   'release_date': '2021-11-30',
#   'id_track': '4ltlMh1fmktbnPXZJrdwwz',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': '孤勇者 - 《英雄聯盟：雙城之戰》動畫劇集中文主題曲',
#   'artist_name': 'Eason Chan',
#   'release_date': '2021-12-07',
#   'id_track': '6akVETVeqqPVvuBS5e0EB1',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Dulce Simfonie',
#   'artist_name': 'AMI',
#   'release_date': '2021-12-02',
#   'id_track': '4QnkbnGZ44ItEEZZdN223b',
#   'popularity': 39,
#   'genero': 'pop'},
#  {'track_name': 'Run Away to Mars',
#   'artist_name': 'TALK',
#   'release_date': '2021-06-23',
#   'id_track': '6G1Mz5yMgn0ydOlIvTrZ65',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': '半生雪',
#   'artist_name': 'Silk Ye',
#   'release_date': '2021-03-09',
#   'id_track': '78bqfALvRPcASKzAYOpo7z',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'Dimension (feat. Skepta & Rema)',
#   'artist_name': 'JAE5, Skepta, Rema',
#   'release_date': '2021-03-18',
#   'id_track': '2Jy4EdqIZswDZvVDh5dx3A',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'FUM22 NOCIVE',
#   'artist_name': 'Green Montana',
#   'release_date': '2021-06-10',
#   'id_track': '3v9eCrcYmTjYjy68TWHj5b',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Dans mes bras',
#   'artist_name': 'Kendji Girac, Dadju',
#   'release_date': '2021-11-11',
#   'id_track': '67uINkj49Zoh1fhIZvA4fk',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Dirty Looks',
#   'artist_name': 'Lainey Wilson',
#   'release_date': '2021-02-19',
#   'id_track': '45EwtYrnqJH3AH2bFpEOC6',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Vérité',
#   'artist_name': 'Ninho',
#   'release_date': '2021-12-03',
#   'id_track': '1O1EqgvgRyj1ejZPUxI0UX',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Yakalelo',
#   'artist_name': 'SDM',
#   'release_date': '2021-04-08',
#   'id_track': '1IeB4ax90dBPu7aM1aqEVA',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': '从前说',
#   'artist_name': '小阿七',
#   'release_date': '2021-12-29',
#   'id_track': '3t5edAHbyFEW67wFApp7EO',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'ночь',
#   'artist_name': 'ooes',
#   'release_date': '2021-06-25',
#   'id_track': '0Mfjy6p9vZsfzbQReWdooZ',
#   'popularity': 54,
#   'genero': 'pop'},
#  {'track_name': 'R.A.F',
#   'artist_name': 'PLK',
#   'release_date': '2021-11-12',
#   'id_track': '0Bo36dconUdOrPoFgVZM5p',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Enigma',
#   'artist_name': 'AMI, Tata Vlad',
#   'release_date': '2021-04-28',
#   'id_track': '2f8MHyPig4TgiKlhIqH8wh',
#   'popularity': 40,
#   'genero': 'pop'},
#  {'track_name': '12 Bande',
#   'artist_name': 'Varinder Brar',
#   'release_date': '2021-10-11',
#   'id_track': '6dgYHmc5yBnQFI4FSCbp6y',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Птичка',
#   'artist_name': 'HammAli & Navai',
#   'release_date': '2021-05-17',
#   'id_track': '6Abmb1Nh7Bc5U6o4iEgSDH',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'Un homme',
#   'artist_name': 'Jérémy Frerot',
#   'release_date': '2021-02-19',
#   'id_track': '7fu7J4k1mdnmpfVXFuEShk',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Petrouchka (feat. PLK)',
#   'artist_name': 'Soso Maness, PLK',
#   'release_date': '2021-06-04',
#   'id_track': '03y045SZqaC94yfXl1cU4E',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'Mesdames',
#   'artist_name': 'Grand Corps Malade',
#   'release_date': '2021-09-10',
#   'id_track': '53rHB42qfLOqmbbePg4aKx',
#   'popularity': 54,
#   'genero': 'pop'},
#  {'track_name': 'Best life',
#   'artist_name': 'Naps, GIMS',
#   'release_date': '2021-09-29',
#   'id_track': '2kUKeN9ZpYHqfBjB8Gphb2',
#   'popularity': 50,
#   'genero': 'pop'},
#  {'track_name': '295',
#   'artist_name': 'Sidhu Moose Wala',
#   'release_date': '2021-05-15',
#   'id_track': '5W7DOVGQLTigu09afW7QMT',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'No Choice',
#   'artist_name': 'Fly By Midnight',
#   'release_date': '2021-11-19',
#   'id_track': '74G0T9Zo5TAJQabpW4gIs3',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Hello',
#   'artist_name': 'JOY',
#   'release_date': '2021-05-31',
#   'id_track': '3cGp1jXxLReLKz7QgVbWZR',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': '飞鸟和蝉',
#   'artist_name': 'Ren Ran',
#   'release_date': '2021-07-27',
#   'id_track': '4lhbajK3dvUcJ0UNEeCdMn',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'Не Бруклин',
#   'artist_name': 'МОТ, LYRIQ',
#   'release_date': '2021-05-27',
#   'id_track': '0UNq8Fqmv81cnbq0OqPPVV',
#   'popularity': 50,
#   'genero': 'pop'},
#  {'track_name': 'No Vacancy',
#   'artist_name': 'Treaty Oak Revival',
#   'release_date': '2021-01-29',
#   'id_track': '3pVs5Zehts89WLyBPiYfxG',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'County Line',
#   'artist_name': 'Chase Matthew',
#   'release_date': '2021-07-02',
#   'id_track': '1V8LJmUEAleAHmBUaD0ZFI',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'My love (feat. Tayc)',
#   'artist_name': 'Josman, Tayc',
#   'release_date': '2021-06-20',
#   'id_track': '1QtUnWsxvPKHmNgoaksOBv',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'EUPHON',
#   'artist_name': 'Gazo',
#   'release_date': '2021-02-26',
#   'id_track': '26xheWSJ6cJf1oF5ooC4ZC',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Habit',
#   'artist_name': 'Laurell',
#   'release_date': '2021-04-09',
#   'id_track': '4bnutybG1itDcpyoQo2Uoc',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'Mona Lisa',
#   'artist_name': 'Booba, JSX',
#   'release_date': '2021-03-04',
#   'id_track': '5LYRIyhmlrDAQsYdHEvP0f',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Home',
#   'artist_name': 'Klangkarussell',
#   'release_date': '2021-05-27',
#   'id_track': '2S5Ddttb7db90WNDde1UJx',
#   'popularity': 50,
#   'genero': 'pop'},
#  {'track_name': '突破口',
#   'artist_name': 'SUPER BEAVER',
#   'release_date': '2021-02-03',
#   'id_track': '2JNl3zf7dLaK3ceN12RTOW',
#   'popularity': 50,
#   'genero': 'pop'},
#  {'track_name': 'Заманчивая',
#   'artist_name': 'MATRANG',
#   'release_date': '2021-08-13',
#   'id_track': '5kbOFqQ15vDh2FODZ3l1IF',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'Limitless',
#   'artist_name': 'Jul',
#   'release_date': '2021-06-25',
#   'id_track': '2M7460TZk22Lvh6LbNi1lS',
#   'popularity': 49,
#   'genero': 'pop'},
#  {'track_name': 'Broadway Girls (feat. Morgan Wallen)',
#   'artist_name': 'Lil Durk, Morgan Wallen',
#   'release_date': '2021-12-17',
#   'id_track': '3DZ8dbKg4OTSSqGARvecYd',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': '陪你看星星',
#   'artist_name': '陈子晴',
#   'release_date': '2021-06-12',
#   'id_track': '5cqjXHVSyVz2LP9r6K304N',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': '好きだから。',
#   'artist_name': '『ユイカ』',
#   'release_date': '2021-06-27',
#   'id_track': '02xwA3Ej9NPetftp9V7VZ3',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'Rihanna',
#   'artist_name': 'SDM',
#   'release_date': '2021-04-08',
#   'id_track': '73RQVlMExXaeOi6mnlz3Bb',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': '还是会想你',
#   'artist_name': '林達浪, H3R3',
#   'release_date': '2021-03-14',
#   'id_track': '011rlesOl5PD27bKaqPYrO',
#   'popularity': 49,
#   'genero': 'pop'},
#  {'track_name': 'СОЛНЦЕ МОНАКО',
#   'artist_name': 'Lusia Chebotina',
#   'release_date': '2021-10-29',
#   'id_track': '01D9gZCXYrAKVIYSgzOGrs',
#   'popularity': 51,
#   'genero': 'pop'},
#  {'track_name': 'волна',
#   'artist_name': 'тима ищет свет',
#   'release_date': '2021-04-09',
#   'id_track': '74UTzZAyhs0ZJhB2BRKOKZ',
#   'popularity': 50,
#   'genero': 'pop'},
#  {'track_name': 'PIB',
#   'artist_name': 'Niaks',
#   'release_date': '2021-07-16',
#   'id_track': '78253BuWHumjypJTGCdE5u',
#   'popularity': 51,
#   'genero': 'pop'}]

# %%
df_resultados_pop = pd.DataFrame (resultados ['pop'])
df_resultados_pop.to_csv("pop2021.csv")

# %%
df_resultados_indie = pd.DataFrame (resultados ['indie'])
df_resultados_indie
# Out:
#               track_name                artist_name release_date  \
# 0             Exoplaneta                Arde Bogotá   2021-05-07
# 1     La Gent Que Estimo  Oques Grasses, Rita Payés   2021-05-28
# 2                 Cariño                Arde Bogotá   2021-05-07
# 3               Elefants              Oques Grasses   2021-05-28
# 4    Te debo una canción                    Shinova   2021-02-26
# ..                   ...                        ...          ...
# 495        Cheer Up Baby                    Inhaler   2021-07-09
# 496                DRUGS                 Tai Verdes   2021-05-20
# 497   Ritchie Sacramento                     Mogwai   2021-02-19
# 498           Square One                      Caamp   2021-02-26
# 499              REVIVED                  Derivakat   2021-08-18
#
#                    id_track  popularity genero
# 0    68PEuXNjodWFts3Ph4BPVv          56  indie
# 1    2aTvlIMGoo2L9x5YzJNjj5          57  indie
# 2    7uWmMWEBGlBAm5B0oMpcs8          54  indie
# 3    7aMxgxCCbkmtRpNNB5OWgY          54  indie
# 4    6E4Z9YuZz9VA7NxXxshXQx          52  indie
# ..                      ...         ...    ...
# 495  4jwrBNhvazRacmab5ArWSZ          49  indie
# 496  4tVASOccgcigdCfwUamZCh          54  indie
# 497  7yBwhVl7W0YT5cCMw8MOjW          40  indie
# 498  5taOnvtHJUxuaqaLdMNqFd          48  indie
# 499  36dKqk62FGNRPq7iguVGjf          54  indie
#
# [500 rows x 6 columns]

# %%
df_resultados_indie.to_csv("indie2021.csv")

# %%
df_resultados_rap = pd.DataFrame (resultados ['rap'])
df_resultados_rap
# Out:
#                                         track_name  \
# 0                                  Piel de Cordero
# 1                                  Ahora y Siempre
# 2                                        Otra cama
# 3                  Tu Y Yo (feat. Los del Control)
# 4                                        Blin Blin
# ..                                             ...
# 495                                  Street Runner
# 496                                   Yeah - bonus
# 497                                     Boombarrio
# 498  Sharing Locations (feat. Lil Baby & Lil Durk)
# 499                                      F*ck Love
#
#                        artist_name release_date                id_track  \
# 0              Quevedo, La Pantera   2021-08-07  04d4GpLedinwpfctvgOIhY
# 1                  Quevedo, Linton   2021-12-11  4iaNmAvcZ6sPGvgZ6vQQdx
# 2                   Hard GZ, Dualy   2021-04-30  5HKnmHBpjIXnSSXlJmrLAQ
# 3            Cano, Los del Control   2021-10-29  5pVEORKrVAtcWOEMJlZCFB
# 4                 Bad Gyal, Juanka   2021-03-18  4OWPAMZcoRwAmMA971KBTh
# ..                             ...          ...                     ...
# 495                       Rod Wave   2021-03-26  5iMRhOHzze2CujxHiJ6cRL
# 496                     Mac Miller   2021-10-15  7b8aKAUn1BB2k1clevj4aB
# 497             Chystemc, Macrodee   2021-02-26  0san1KUetFkSctwivThY7z
# 498  Meek Mill, Lil Durk, Lil Baby   2021-08-27  3J4VKkUpLvomXJbn9ZAypO
# 499                           Lund   2021-06-04  2kHrlDvECzPyjcbmSQNusl
#
#      popularity genero
# 0            63    rap
# 1            64    rap
# 2            56    rap
# 3            54    rap
# 4            59    rap
# ..          ...    ...
# 495          67    rap
# 496          53    rap
# 497          47    rap
# 498          53    rap
# 499          54    rap
#
# [500 rows x 6 columns]

# %%
df_resultados_rap.to_csv("rap2021.csv")

# %%
df_resultados_reggaeton = pd.DataFrame (resultados ['reggaeton'])
df_resultados_reggaeton
# Out:
#            track_name                       artist_name release_date  \
# 0            Ley Seca                  JHAYCO, Anuel AA   2021-09-03
# 1         La Old Skul                    Rauw Alejandro   2021-12-10
# 2       ALMAS GEMELAS                       Myke Towers   2021-07-22
# 3        Desesperados  Rauw Alejandro, Chencho Corleone   2021-12-10
# 4          Todo De Ti                    Rauw Alejandro   2021-12-10
# ..                ...                               ...          ...
# 495  Batman en Can Am                          Arcángel   2021-09-17
# 496      Pa' Guayarte                   J Balvin, Ozuna   2021-09-10
# 497         Peligrosa                            Maluma   2021-01-28
# 498         Tu Veneno                          J Balvin   2021-12-10
# 499       Ocean Drive    Ñengo Flow, Onyx Toca El Piano   2021-07-22
#
#                    id_track  popularity     genero
# 0    3JCaq3KDSROg3TXhdiDa9n          68  reggaeton
# 1    4Z8HZSApeddaRM2ovivUj4          75  reggaeton
# 2    2KcNrONbZ0hvBPjvrDO2tx          67  reggaeton
# 3    6mmPpaltUZK7xjNlBPQQ0p          74  reggaeton
# 4    3rdAz1fbUfZxYgaCviYhRo          76  reggaeton
# ..                      ...         ...        ...
# 495  06xqvKWGYnt3XpCgTpEhCC          35  reggaeton
# 496  77J8t2pFJYI8k4tZgJ3ybY          37  reggaeton
# 497  0iZiKRyiDMhdo7dxDhRuRL          37  reggaeton
# 498  591Jlv0BcckG5YwEH4yAY2          38  reggaeton
# 499  2OTjjwuQnYeDFnlULe7JYK          29  reggaeton
#
# [500 rows x 6 columns]

# %%
df_resultados_reggaeton.to_csv("reggaeton2021.csv")
