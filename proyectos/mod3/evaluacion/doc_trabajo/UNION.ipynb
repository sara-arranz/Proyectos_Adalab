# %%
import pandas as pd
import numpy as np

# %%
df_clientes = pd.read_csv('../files/clientes_limpio.csv', index_col = 0)

# %%
df_clientes.head()
# Out:
#    Loyalty_Number          Province       City Postal_Code  Gender Education  \
# 0          480934           Ontario    Toronto     M2Z_4K1  Female  Bachelor
# 1          549612           Alberta   Edmonton     T3G_6Y6    Male   College
# 2          429460  British_Columbia  Vancouver     V6E_3D9    Male   College
# 3          608370           Ontario    Toronto     P1W_1K4    Male   College
# 4          530508            Quebec       Hull     J8Y_3Z5    Male  Bachelor
#
#    Salary_$ Marital_Status Loyalty_Card      CLV Enrollment_Type  \
# 0     83236        Married         Star  3839.14        Standard
# 1     79359       Divorced         Star  3839.61        Standard
# 2     79359         Single         Star  3839.75        Standard
# 3     79359         Single         Star  3839.75        Standard
# 4    103495        Married         Star  3842.79        Standard
#
#   Enrollment_Date
# 0         2016-02
# 1         2016-03
# 2         2014-07
# 3         2013-02
# ...

# %%
df_clientes.duplicated().sum()
# Out:
# 0

# %%
df_clientes.isnull().sum()
# Out:
# Loyalty_Number     0
# Province           0
# City               0
# Postal_Code        0
# Gender             0
# Education          0
# Salary_$           0
# Marital_Status     0
# Loyalty_Card       0
# CLV                0
# Enrollment_Type    0
# Enrollment_Date    0
# dtype: int64

# %%
df_clientes.shape
# Out:
# (16737, 12)

# %%
df_vuelos = pd.read_csv('../files/vuelos_limpio.csv', index_col = 0)

# %%
df_vuelos.head()
# Out:
#    Loyalty_Number  Flights_Booked  Flights_with_Companions  Total_Flights  \
# 0          100018               3                        0              3
# 1          100102              10                        4             14
# 2          100140               6                        0              6
# 3          100214               0                        0              0
# 4          100272               0                        0              0
#
#    Distance  Points_Accumulated  Points_Redeemed  Dollar_Cost_Points_Redeemed  \
# 0      1521                 152                0                            0
# 1      2030                 203                0                            0
# 2      1200                 120                0                            0
# 3         0                   0                0                            0
# 4         0                   0                0                            0
#
#       Date
# 0  2017-01
# 1  2017-01
# 2  2017-01
# ...

# %%
df_vuelos.shape
# Out:
# (405624, 9)

# %%
df_vuelos.duplicated().sum()
# Out:
# 1864

# %%
df_vuelos.isnull().sum()
# Out:
# Loyalty_Number                 0
# Flights_Booked                 0
# Flights_with_Companions        0
# Total_Flights                  0
# Distance                       0
# Points_Accumulated             0
# Points_Redeemed                0
# Dollar_Cost_Points_Redeemed    0
# Date                           0
# dtype: int64

# %% [markdown]
# ### Dado que tenemos una columna coincidente vamos a utilizar el método merge para unificar ambos data_frame

# %%
df_aerolinea = pd.merge(df_clientes,df_vuelos,on='Loyalty_Number', how='left')

# %%
df_aerolinea.head()
# Out:
#    Loyalty_Number Province     City Postal_Code  Gender Education  Salary_$  \
# 0          480934  Ontario  Toronto     M2Z_4K1  Female  Bachelor     83236
# 1          480934  Ontario  Toronto     M2Z_4K1  Female  Bachelor     83236
# 2          480934  Ontario  Toronto     M2Z_4K1  Female  Bachelor     83236
# 3          480934  Ontario  Toronto     M2Z_4K1  Female  Bachelor     83236
# 4          480934  Ontario  Toronto     M2Z_4K1  Female  Bachelor     83236
#
#   Marital_Status Loyalty_Card      CLV Enrollment_Type Enrollment_Date  \
# 0        Married         Star  3839.14        Standard         2016-02
# 1        Married         Star  3839.14        Standard         2016-02
# 2        Married         Star  3839.14        Standard         2016-02
# 3        Married         Star  3839.14        Standard         2016-02
# 4        Married         Star  3839.14        Standard         2016-02
#
#    Flights_Booked  Flights_with_Companions  Total_Flights  Distance  \
# ...

# %%
df_aerolinea.shape
# Out:
# (405624, 20)

# %%
df_aerolinea.duplicated().sum()
# Out:
# 1864

# %%
df_aerolinea.isnull().sum()
# Out:
# Loyalty_Number                 0
# Province                       0
# City                           0
# Postal_Code                    0
# Gender                         0
# Education                      0
# Salary_$                       0
# Marital_Status                 0
# Loyalty_Card                   0
# CLV                            0
# Enrollment_Type                0
# Enrollment_Date                0
# Flights_Booked                 0
# Flights_with_Companions        0
# Total_Flights                  0
# Distance                       0
# Points_Accumulated             0
# Points_Redeemed                0
# Dollar_Cost_Points_Redeemed    0
# Date                           0
# dtype: int64

# %%
df_aerolinea.sort_values(['Loyalty_Number'])
# Out:
#         Loyalty_Number Province      City Postal_Code  Gender Education  \
# 56727           100018  Alberta  Edmonton     T9G_1W3  Female  Bachelor
# 56735           100018  Alberta  Edmonton     T9G_1W3  Female  Bachelor
# 56734           100018  Alberta  Edmonton     T9G_1W3  Female  Bachelor
# 56733           100018  Alberta  Edmonton     T9G_1W3  Female  Bachelor
# 56732           100018  Alberta  Edmonton     T9G_1W3  Female  Bachelor
# ...                ...      ...       ...         ...     ...       ...
# 243500          999986  Ontario    Ottawa     K1F_2R2  Female  Bachelor
# 243502          999986  Ontario    Ottawa     K1F_2R2  Female  Bachelor
# 243503          999986  Ontario    Ottawa     K1F_2R2  Female  Bachelor
# 243491          999986  Ontario    Ottawa     K1F_2R2  Female  Bachelor
# 243501          999986  Ontario    Ottawa     K1F_2R2  Female  Bachelor
#
#         Salary_$ Marital_Status Loyalty_Card      CLV Enrollment_Type  \
# ...

# %%
df_aerolinea.to_csv('aerolinea.csv')

# %% [markdown]
# ### Reviso por última vez los duplicados

# %%
df_aerolinea[df_aerolinea.duplicated(keep=False)]
# Out:
#         Loyalty_Number Province         City Postal_Code  Gender Education  \
# 120             193662    Yukon   Whitehorse     Y2K_6R0    Male  Bachelor
# 121             193662    Yukon   Whitehorse     Y2K_6R0    Male  Bachelor
# 159             193662    Yukon   Whitehorse     Y2K_6R0    Male  Bachelor
# 160             193662    Yukon   Whitehorse     Y2K_6R0    Male  Bachelor
# 164             193662    Yukon   Whitehorse     Y2K_6R0    Male  Bachelor
# ...                ...      ...          ...         ...     ...       ...
# 381803          373638  Ontario  Thunder_Bay     K8T_5M5  Female  Bachelor
# 381804          373638  Ontario  Thunder_Bay     K8T_5M5  Female  Bachelor
# 381805          373638  Ontario  Thunder_Bay     K8T_5M5  Female  Bachelor
# 381806          373638  Ontario  Thunder_Bay     K8T_5M5  Female  Bachelor
# 381807          373638  Ontario  Thunder_Bay     K8T_5M5  Female  Bachelor
#
# ...

# %% [markdown]
# #### No tengo ningún valor significativo y sé que las fechas están repetidas. Elimino registros duplicados, menos el primero.

# %%
df_aerolinea_limpio= df_aerolinea.drop_duplicates(keep='first')

# %% [markdown]
# #### Comprobamos

# %%
df_aerolinea_limpio.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Visualizamos

# %%
df_aerolinea_limpio.sort_values(['Loyalty_Number','Date'])
# Out:
#         Loyalty_Number Province      City Postal_Code  Gender Education  \
# 56712           100018  Alberta  Edmonton     T9G_1W3  Female  Bachelor
# 56713           100018  Alberta  Edmonton     T9G_1W3  Female  Bachelor
# 56725           100018  Alberta  Edmonton     T9G_1W3  Female  Bachelor
# 56715           100018  Alberta  Edmonton     T9G_1W3  Female  Bachelor
# 56716           100018  Alberta  Edmonton     T9G_1W3  Female  Bachelor
# ...                ...      ...       ...         ...     ...       ...
# 243487          999986  Ontario    Ottawa     K1F_2R2  Female  Bachelor
# 243500          999986  Ontario    Ottawa     K1F_2R2  Female  Bachelor
# 243501          999986  Ontario    Ottawa     K1F_2R2  Female  Bachelor
# 243502          999986  Ontario    Ottawa     K1F_2R2  Female  Bachelor
# 243503          999986  Ontario    Ottawa     K1F_2R2  Female  Bachelor
#
#         Salary_$ Marital_Status Loyalty_Card      CLV Enrollment_Type  \
# ...

# %% [markdown]
# #### Guardo en CSV para visaulizar mejor la comprobación y como documento final

# %%
df_aerolinea_limpio.to_csv('aerolinea_limpio.csv')
