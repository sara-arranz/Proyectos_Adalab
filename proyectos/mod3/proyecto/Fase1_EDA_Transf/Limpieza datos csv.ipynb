# %% [markdown]
# ## EDA

# %%
import pandas as pd
import numpy as np
from IPython.display import display

# %% [markdown]
# ## Cargamos CSV y realizamos visualización

# %%
df = pd.read_csv("files/data.csv", index_col=0)

# %%
display(df.sample(15))
# Out:
#      age attrition     businesstravel    dailyrate                department  \
# 956   53        No                NaN  1128.111111                       NaN
# 973   36        No      travel_rarely   290.035510   Research & Development
# 827   51       Yes  travel_frequently  1098.809524                       NaN
# 526   45        No                NaN   356.158730                       NaN
# 1407  29        No      travel_rarely   290.035510                       NaN
# 1117  27        No                NaN   355.436508                       NaN
# 629   52        No      travel_rarely   290.035510                       NaN
# 440   39        No                NaN   556.256661   Research & Development
# 181   30        No      travel_rarely   556.256661                       NaN
# 476   31        No                NaN  1032.487286                       NaN
# 1211  24        No                NaN   290.035510   Research & Development
# 1429  45        No      travel_rarely  1006.571429                       NaN
# 801   32        No      travel_rarely   290.035510                       NaN
# 1630  47       Yes         non-travel  1032.487286                       NaN
# 342   47        No                NaN   511.746032                       NaN
#
#       distancefromhome  education    educationfield  employeecount  \
# 956                  7          2               NaN              1
# 973                  7          4             Other              1
# 827                -16          4               NaN              1
# 526                 29          3               NaN              1
# 1407                 9          3               NaN              1
# 1117               -48          3               NaN              1
# 629                  8          4             Other              1
# 440                 10          5           Medical              1
# 181                  4          2               NaN              1
# 476                 10          3               NaN              1
# 1211               -24          2  Technical Degree              1
# 1429               -41          3     Life Sciences              1
# 801                  5          2               NaN              1
# 1630               -10          4     Life Sciences              1
# 342                -35          4         Marketing              1
#
#       employeenumber  ...  yearsatcompany  yearsincurrentrole  \
# 956              957  ...               5                 NaN
# 973              974  ...               6                 NaN
# 827              828  ...               4                 NaN
# 526              527  ...               6                 NaN
# 1407            1408  ...               1                 0,0
# 1117            1118  ...               6                 NaN
# 629              630  ...               5                 NaN
# 440              441  ...               7                 NaN
# 181              182  ...              11                 NaN
# 476              477  ...              11                 NaN
# 1211            1212  ...               1                 NaN
# 1429            1430  ...               5                 NaN
# 801              802  ...               6                 NaN
# 1630             300  ...              10                 NaN
# 342              343  ...               7                 NaN
#
#       yearssincelastpromotion  yearswithcurrmanager  sameasmonthlyincome  \
# 956                         0                     4             9111,67$
# 973                         0                     1             2342,59$
# 827                         0                     3                  NaN
# 526                         0                     3                  NaN
# 1407                        0                     0             2342,59$
# 1117                        1                     4             2870,83$
# 629                         0                     4                  NaN
# 440                         7                     7             4492,84$
# 181                         2                     7             4492,84$
# 476                         4                     8             8339,32$
# 1211                        0                     0                  NaN
# 1429                        0                     3                  NaN
# 801                         0                     5             2342,59$
# 1630                        9                     9             8339,32$
# 342                         1                     7             4133,33$
#
#      datebirth      salary                                    roledepartament  \
# 956       1970  109340,00$                                                NaN
# 973       1987   28111,13$     ReSEArcH sCIeNtist  -  Research & Development
# 827       1972  106500,00$                                                NaN
# 526       1978   34520,00$                                                NaN
# 1407      1994   28111,13$                                                NaN
# 1117      1996   34450,00$                                                NaN
# 629       1971   28111,13$                                                NaN
# 440       1984         NaN   maNuFAcTURInG DIReCtoR  -  Research & Develop...
# 181       1993   53914,11$                                                NaN
# 476       1992  100071,84$                                                NaN
# 1211      1999   28111,13$   LaBoratory TECHnICIAn  -  Research & Developm...
# 1429      1978   97560,00$                                                NaN
# 801       1991   28111,13$                                                NaN
# 1630      1976         NaN                                                NaN
# 342       1976         NaN                                                NaN
#
#      numberchildren remotework
# 956             NaN          0
# 973             NaN          1
# 827             NaN      False
# 526             NaN          1
# 1407            NaN          0
# 1117            NaN      False
# 629             NaN        Yes
# 440             NaN          0
# 181             NaN      False
# 476             NaN          1
# 1211            NaN      False
# 1429            NaN        Yes
# 801             NaN       True
# 1630            NaN       True
# 342             NaN      False
#
# [15 rows x 41 columns]

# %%
df.shape
print(f'Tenemos {df.shape[0]} filas y {df.shape[1]} columnas')
# Out:
# Tenemos 1678 filas y 41 columnas

# %%
df.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeecount',
#        'employeenumber', 'environmentsatisfaction', 'gender', 'hourlyrate',
#        'jobinvolvement', 'joblevel', 'jobrole', 'jobsatisfaction',
#        'maritalstatus', 'monthlyincome', 'monthlyrate', 'numcompaniesworked',
#        'over18', 'overtime', 'percentsalaryhike', 'performancerating',
#        'relationshipsatisfaction', 'standardhours', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'sameasmonthlyincome', 'datebirth', 'salary',
#        'roledepartament', 'numberchildren', 'remotework'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1678 entries, 0 to 1677
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1678 non-null   object
#  1   attrition                 1678 non-null   object
#  2   businesstravel            877 non-null    object
#  3   dailyrate                 1678 non-null   float64
#  4   department                312 non-null    object
#  5   distancefromhome          1678 non-null   int64
#  6   education                 1678 non-null   int64
#  7   educationfield            904 non-null    object
#  8   employeecount             1678 non-null   int64
#  9   employeenumber            1678 non-null   int64
#  10  environmentsatisfaction   1678 non-null   int64
#  11  gender                    1678 non-null   int64
#  12  hourlyrate                411 non-null    float64
#  13  jobinvolvement            1678 non-null   int64
#  14  joblevel                  1678 non-null   int64
#  15  jobrole                   1678 non-null   object
#  16  jobsatisfaction           1678 non-null   int64
#  17  maritalstatus             1003 non-null   object
#  18  monthlyincome             1189 non-null   object
#  19  monthlyrate               1678 non-null   object
#  20  numcompaniesworked        1678 non-null   int64
#  21  over18                    740 non-null    object
#  22  overtime                  982 non-null    object
#  23  percentsalaryhike         1678 non-null   int64
#  24  performancerating         1478 non-null   object
#  25  relationshipsatisfaction  1678 non-null   int64
#  26  standardhours             1327 non-null   object
#  27  stockoptionlevel          1678 non-null   int64
#  28  totalworkingyears         1129 non-null   object
#  29  trainingtimeslastyear     1678 non-null   int64
#  30  worklifebalance           1564 non-null   object
#  31  yearsatcompany            1678 non-null   int64
#  32  yearsincurrentrole        35 non-null     object
#  33  yearssincelastpromotion   1678 non-null   int64
#  34  yearswithcurrmanager      1678 non-null   int64
#  35  sameasmonthlyincome       1189 non-null   object
#  36  datebirth                 1678 non-null   int64
#  37  salary                    1393 non-null   object
#  38  roledepartament           312 non-null    object
#  39  numberchildren            0 non-null      float64
#  40  remotework                1678 non-null   object
# dtypes: float64(3), int64(18), object(20)
# memory usage: 550.6+ KB

# %% [markdown]
# ## Identificar valores nulos

# %%
df.isnull().sum()
# Out:
# age                            0
# attrition                      0
# businesstravel               801
# dailyrate                      0
# department                  1366
# distancefromhome               0
# education                      0
# educationfield               774
# employeecount                  0
# employeenumber                 0
# environmentsatisfaction        0
# gender                         0
# hourlyrate                  1267
# jobinvolvement                 0
# joblevel                       0
# jobrole                        0
# jobsatisfaction                0
# maritalstatus                675
# monthlyincome                489
# monthlyrate                    0
# numcompaniesworked             0
# over18                       938
# overtime                     696
# percentsalaryhike              0
# performancerating            200
# relationshipsatisfaction       0
# standardhours                351
# stockoptionlevel               0
# totalworkingyears            549
# trainingtimeslastyear          0
# worklifebalance              114
# yearsatcompany                 0
# yearsincurrentrole          1643
# yearssincelastpromotion        0
# yearswithcurrmanager           0
# sameasmonthlyincome          489
# datebirth                      0
# salary                       285
# roledepartament             1366
# numberchildren              1678
# remotework                     0
# dtype: int64

# %% [markdown]
# ## Porcentaje de valores nulos en cada columna

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# age                           0.000000
# attrition                     0.000000
# businesstravel               47.735399
# dailyrate                     0.000000
# department                   81.406436
# distancefromhome              0.000000
# education                     0.000000
# educationfield               46.126341
# employeecount                 0.000000
# employeenumber                0.000000
# environmentsatisfaction       0.000000
# gender                        0.000000
# hourlyrate                   75.506555
# jobinvolvement                0.000000
# joblevel                      0.000000
# jobrole                       0.000000
# jobsatisfaction               0.000000
# maritalstatus                40.226460
# monthlyincome                29.141836
# monthlyrate                   0.000000
# numcompaniesworked            0.000000
# over18                       55.899881
# overtime                     41.477950
# percentsalaryhike             0.000000
# performancerating            11.918951
# relationshipsatisfaction      0.000000
# standardhours                20.917759
# stockoptionlevel              0.000000
# totalworkingyears            32.717521
# trainingtimeslastyear         0.000000
# worklifebalance               6.793802
# yearsatcompany                0.000000
# yearsincurrentrole           97.914184
# yearssincelastpromotion       0.000000
# yearswithcurrmanager          0.000000
# sameasmonthlyincome          29.141836
# datebirth                     0.000000
# salary                       16.984505
# roledepartament              81.406436
# numberchildren              100.000000
# remotework                    0.000000
# dtype: float64

# %% [markdown]
# ## Toma de decisión con respecto a los datos nulos obtenidos:
#
# #### Eliminamos las columnas en las que elporcentaje de valores nulos sea superior al 80%.
#
# Columnas para  eliminar:
# - "department" (81.40%)
# - "roledepartament" (81.40%)
# - "numberchildren" (100%)
# - "yearsincurrentrole" (97.91%)

# %%
df.drop(columns=["department", "roledepartament", "numberchildren", "yearsincurrentrole"], inplace=True)

# %% [markdown]
# ### Visualización del dataframe tras la eliminación de columnas

# %%
df.head()
# Out:
#   age attrition businesstravel    dailyrate  distancefromhome  education  \
# 0  51        No            NaN  2015.722222                 6          3
# 1  52        No            NaN  2063.388889                 1          4
# 2  42        No  travel_rarely  1984.253968                 4          2
# 3  47        No  travel_rarely  1771.404762                 2          4
# 4  46        No            NaN  1582.771346                 3          3
#
#      educationfield  employeecount  employeenumber  environmentsatisfaction  \
# 0               NaN              1               1                        1
# 1     Life Sciences              1               2                        3
# 2  Technical Degree              1               3                        3
# 3           Medical              1               4                        1
# 4  Technical Degree              1               5                        1
#
#    ...  totalworkingyears  trainingtimeslastyear  worklifebalance  \
# 0  ...                NaN                      5              3,0
# 1  ...               34,0                      5              3,0
# 2  ...               22,0                      3              NaN
# 3  ...                NaN                      2              NaN
# 4  ...                NaN                      5              3,0
#
#    yearsatcompany yearssincelastpromotion  yearswithcurrmanager  \
# 0              20                      15                    15
# 1              33                      11                     9
# 2              22                      11                    15
# 3              20                       5                     6
# 4              19                       2                     8
#
#   sameasmonthlyincome datebirth      salary  remotework
# 0           16280,83$      1972  195370,00$         Yes
# 1                 NaN      1971  199990,00$           1
# 2                 NaN      1981  192320,00$           1
# 3           14307,50$      1976  171690,00$       False
# 4           12783,92$      1977         NaN           0
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Dividimos la limpieza y transformación de columnas según el tipo de dato (categóricas/numéricas).
# ### Comenzamos filtrando las columnas de tipo categóricas

# %%
columns_object = df.select_dtypes(include = object)

# %%
columns_object.shape
# Out:
# (1678, 17)

# %%
columns_object.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'educationfield', 'jobrole',
#        'maritalstatus', 'monthlyincome', 'monthlyrate', 'over18', 'overtime',
#        'performancerating', 'standardhours', 'totalworkingyears',
#        'worklifebalance', 'sameasmonthlyincome', 'salary', 'remotework'],
#       dtype='object')

# %%
columnas = ['age','attrition', 'businesstravel', 'educationfield', 'jobrole',
    'maritalstatus', 'monthlyincome', 'monthlyrate', 'over18', 'overtime',
    'performancerating', 'standardhours', 'totalworkingyears',
    'worklifebalance', 'sameasmonthlyincome', 'salary', 'remotework']

# %% [markdown]
# Visualizamos los valores en cada columna para visualizar en mayor medida qué transformaciones requieren los datos

# %%
for col in columnas:
    print(f"Valores únicos en '{col}':")
    print(df[col].unique(), "\n")
# Out:
# Valores únicos en 'age':
# ['51' '52' '42' '47' '46' '48' '59' '41' '56' '38' '55' '40' '58' '35'
#  '45' '33' '36' '34' 'forty-seven' '53' '43' '60' '32' '37' '49' '39' '50'
#  '44' '30' 'fifty-eight' '29' '31' '54' '57' '27' 'thirty-six' '28' '26'
#  'fifty-five' '25' 'fifty-two' 'thirty-one' '24' 'thirty' '23' '22' '21'
#  '20' 'twenty-six' '19' 'thirty-seven' '18' 'thirty-two' 'twenty-four']
#
# Valores únicos en 'attrition':
# ['No' 'Yes']
#
# Valores únicos en 'businesstravel':
# [nan 'travel_rarely' 'travel_frequently' 'non-travel']
#
# Valores únicos en 'educationfield':
# [nan 'Life Sciences' 'Technical Degree' 'Medical' 'Other' 'Marketing'
#  'Human Resources']
#
# Valores únicos en 'jobrole':
# [' resEArch DIREcToR ' ' ManAGeR ' ' ManaGER ' ... ' sAlES ExECUTivE '
#  ' SaLes ExecUtIVe ' ' mAnUfactURInG DiRECTOr ']
#  '4467,67$' '11931,83$' '17556,50$' '8619,00$' '11697,83$' '22637,33$'
#  '9620,00$' '5763,33$' '7312,50$' '4916,17$' '10371,83$' '6086,17$'
#  '23517,00$' '5570,50$' '13307,67$' '5408,00$' '7407,83$' '5418,83$'
#  '5559,67$' '8493,33$' '30255,33$' '14170,00$' '4862,00$' '35065,33$'
#  '9171,50$' '32097,00$' '37177,83$' '5022,33$' '7836,83$' '5815,33$'
#  '41680,17$' '9581,00$' '5529,33$' '5802,33$' '11203,83$' '25818,00$'
#  '20323,33$' '12735,67$' '5347,33$' '8941,83$' '4654,00$' '8419,67$'
#  '14445,17$' '4528,33$' '4519,67$' '4227,17$' '6547,67$' '21068,67$'
#  '7340,67$' '6582,33$' '5031,00$' '6339,67$' '9760,83$' '6142,50$'
#  '14198,17$' '14458,17$' '29447,17$' '4716,83$' '42286,83$' '41604,33$'
#  '21770,67$' '5899,83$' '14395,33$' '6848,83$' '3076,67$' '2600,00$'
#  '11349,00$' '21634,17$' '34649,33$' '5135,00$' '14692,17$' '14414,83$'
#  '6177,17$' '11392,33$' '5364,67$' '4950,83$' '7470,67$' '9875,67$'
#  '3687,67$' '5555,33$' '10985,00$' '8190,00$' '21285,33$' '4069,00$'
#  '5070,00$' '4608,50$' '4404,83$' '20804,33$' '36025,17$' '4513,17$'
#  '2186,17$' '17032,17$' '5724,33$' '11095,50$' '5837,00$' '11037,00$'
#  '4927,00$' '5013,67$' '5156,67$' '4350,67$' '22862,67$' '4894,50$'
#  '5228,17$' '4595,50$' '5371,17$' '28587,00$' '9019,83$' '5633,33$'
#  '39656,50$' '10350,17$' '2279,33$' '5332,17$' '5624,67$' '10244,00$'
#  '15927,17$' '10326,33$' '6125,17$' '6181,50$' '4961,67$' '4565,17$'
#  '4788,33$' '28580,50$' '39574,17$' '2422,33$' '5139,33$' '6149,00$'
#  '39132,17$' '3490,50$' '10330,67$' '2760,33$' '5548,83$' '3386,50$'
#  '13840,67$' '18148,00$' '10488,83$' '4493,67$' '6439,33$' '14765,83$'
#  '5828,33$' '38061,83$' '3399,50$' '9071,83$' '7163,00$' '3018,17$'
#  '23579,83$' '6201,00$' '14592,50$' '21138,00$' '11470,33$' '5280,17$'
#  '8820,50$' '6404,67$' '10070,67$' '6075,33$' '5284,50$' '6188,00$'
#  '6354,83$' '2363,83$' '11160,50$' '6203,17$' '6192,33$' '2446,17$'
#  '42100,50$']
#
# Valores únicos en 'over18':
# ['Y' nan]
#
# Valores únicos en 'overtime':
# ['No' nan 'Yes']
#
# Valores únicos en 'performancerating':
# ['3,0' '4,0' nan]
#
# Valores únicos en 'standardhours':
# ['Full Time' nan 'Part Time']
#
# Valores únicos en 'totalworkingyears':
# [nan '34,0' '22,0' '28,0' '20,0' '21,0' '33,0' '40,0' '18,0' '25,0' '15,0'
#  '17,0' '26,0' '16,0' '24,0' '14,0' '23,0' '27,0' '19,0' '11,0' '38,0'
#  '37,0' '13,0' '12,0' '29,0' '10,0' '36,0' '35,0' '9,0' '31,0' '32,0'
#  '21270,00$' '20330,00$' '96020,00$' '166270,00$' '20830,00$' '10090,00$'
#  '78610,00$' '26420,00$' '51210,00$' '26940,00$' '50940,00$' '22740,00$'
#  '23140,00$' '23800,00$' '20080,00$' '105520,00$' '22590,00$' '24130,00$'
#  '21210,00$' '24790,00$' '131940,00$' '26000,00$' '183030,00$' '47770,00$'
#  '10520,00$' '24610,00$' '25960,00$' '47280,00$' '73510,00$' '47660,00$'
#  '22580,00$' '28270,00$' '28530,00$' '22900,00$' '21070,00$' '22100,00$'
#  '131910,00$' '182650,00$' '23720,00$' '28380,00$' '180610,00$'
#  '16110,00$' '47680,00$' '12740,00$' '25610,00$' '15630,00$' '83760,00$'
#  '48410,00$' '29720,00$' '68150,00$' '175670,00$' '15690,00$' '41870,00$'
#  '33060,00$' '13930,00$' '108830,00$' '67350,00$' '97560,00$' '52940,00$'
#  '24370,00$' '40710,00$' '29560,00$' '46480,00$' '28040,00$' '24390,00$'
#  '29330,00$' '10910,00$' '51510,00$' '28630,00$' '11290,00$' '194310,00$'
#  '21440,00$' '160150,00$' '43060,00$' '28210,00$' '35390,00$' '58130,00$'
#  '26960,00$' '67550,00$' '58280,00$' '132120,00$' '27410,00$' '49600,00$'
#  '42440,00$']
#
# Valores únicos en 'remotework':
# ['Yes' '1' 'False' '0' 'True']

# %%
columns_sara = ['overtime', 'performancerating', 'standardhours', 'totalworkingyears',
    'worklifebalance','sameasmonthlyincome',
    'salary', 'remotework']

# %%
df[columns_sara].sample(10)
# Out:
#      overtime performancerating standardhours totalworkingyears  \
# 335       NaN               3,0     Part Time              10,0
# 1528       No               3,0     Part Time               5,0
# 504        No               3,0     Full Time               NaN
# 274        No               4,0     Part Time               NaN
# 1293      NaN               3,0     Part Time              18,0
# 1118      NaN               3,0     Part Time               2,0
# 1113       No               3,0     Part Time               3,0
# 1467      NaN               3,0     Full Time               NaN
# 548       NaN               3,0           NaN               6,0
# 715       NaN               3,0     Full Time               8,0
#
#      worklifebalance sameasmonthlyincome      salary remotework
# 335              3,0            2342,59$   28111,13$        Yes
# 1528             3,0                 NaN   28111,13$       True
# 504              3,0                 NaN   33760,00$      False
# 274              2,0            2342,59$   28111,13$      False
# 1293             2,0            3497,50$   41970,00$       True
# 1118             3,0            2300,00$   27600,00$          1
# 1113             1,0            2342,59$   28111,13$          0
# 1467             2,0           16192,50$  194310,00$      False
# 548              3,0            2663,33$   31960,00$          0
# 715              3,0                 NaN   60620,00$          0

# %%
df[columns_sara].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1678 entries, 0 to 1677
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   overtime             982 non-null    object
#  1   performancerating    1478 non-null   object
#  2   standardhours        1327 non-null   object
#  3   totalworkingyears    1129 non-null   object
#  4   worklifebalance      1564 non-null   object
#  5   sameasmonthlyincome  1189 non-null   object
#  6   salary               1393 non-null   object
#  7   remotework           1678 non-null   object
# dtypes: object(8)
# memory usage: 118.0+ KB

# %% [markdown]
# #### CREACIÓN DE FUNCIÓN PARA QUE ELIMINE LOS ESPACIOS DE TODAS LAS COLUMNAS, TRANSFORME LAS (,) EN (.), LETRAS EN MINÚSCULAS Y ELIMINE SÍMBOLO $

# %%
def limpieza(columna):
    
    try: 
        columna = columna.str.strip()
        columna = columna.str.lower()
        columna= columna.str.replace(',','.', regex = False)
        columna = columna.str.replace('$','', regex = False)
    
        return columna
    
    except:
        print(f'Error en la columna{columna}')
        return columna

# %%
df[columns_sara] = df[columns_sara].apply(limpieza)

# %%
for col in columns_sara:
    print(f"Valores únicos en '{col}':")
    print(df[col].unique(), "\n")
# Out:
# Valores únicos en 'overtime':
# ['no' nan 'yes']
#
# Valores únicos en 'performancerating':
# ['3.0' '4.0' nan]
#
# Valores únicos en 'standardhours':
# ['full time' nan 'part time']
#
# Valores únicos en 'totalworkingyears':
# [nan '34.0' '22.0' '28.0' '20.0' '21.0' '33.0' '40.0' '18.0' '25.0' '15.0'
#  '17.0' '26.0' '16.0' '24.0' '14.0' '23.0' '27.0' '19.0' '11.0' '38.0'
#  '37.0' '13.0' '12.0' '29.0' '10.0' '36.0' '35.0' '9.0' '31.0' '32.0'
#  '8.0' '7.0' '30.0' '6.0' '5.0' '4.0' '3.0' '2.0' '1.0' '0.0']
#
# Valores únicos en 'worklifebalance':
# ['3.0' nan '2.0' '4.0' '1.0']
#
# Valores únicos en 'sameasmonthlyincome':
# ['16280.83' nan '14307.50' '12783.92' '14311.67' '8339.32' '13829.17'
#  '15943.72' '16644.17' '15034.17' '16038.33' '4492.84' '8956.67' '5167.50'
#  '3334.17' '8705.83' '2675.00' '8555.00' '8729.17' '3934.17' '3845.83'
#  '14132.50' '8588.33' '4505.00' '4918.33' '4928.33' '5538.33' '11100.00'
#  '5572.50' '11560.00' '15870.83' '13345.83' '8010.83' '3588.33' '14205.00'
#  '4222.50' '3076.67' '2342.59' '4789.17' '8685.00' '5289.17' '1956.67'
#  '10408.33' '6683.33' '7452.50' '16060.00' '4647.50' '2242.50' '6169.17'
#  '7352.50' '2982.50' '14815.83' '15177.50' '15991.67' '15989.17' '8340.00'
#  '6656.67' '5902.50' '3935.83' '2839.17' '2440.83' '10025.83' '12855.83'
#  '5135.00' '4271.67' '8015.83' '4175.00' '15860.83' '8666.67' '2327.50'
#  '4728.33' '7010.00' '2790.00' '4424.17' '6378.33' '10673.33' '5488.33'
#  '2099.17' '10933.33' '2609.17' '5561.67' '14884.17' '6205.00' '11464.17'
#  '13831.67' '2557.50' '7700.83' '5393.33' '6934.17' '7148.33' '3497.50'
#  '8240.00' '4730.83' '7938.33' '5687.50' '3686.67' '4534.17' '5061.67'
#  '5143.33' '4670.83' '3599.17' '2970.00' '5217.50' '5670.00' '16196.67'
#  '4856.67' '3901.67' '1765.83' '4978.33' '11010.00' '3375.83' '4004.17'
#  '2284.17' '7861.67' '4496.67' '9299.17' '4133.33' '7327.50' '1846.67'
#  '9760.83' '4420.00' '9252.50' '5526.67' '6322.50' '3612.50' '4983.33'
#  '3536.67' '4356.67' '2250.00' '1971.67' '1940.83' '8604.17' '9037.50'
#  '5320.83' '3050.00' '7283.33' '11249.17' '2909.17' '4350.00' '8543.33'
#
# Valores únicos en 'remotework':
# ['yes' '1' 'false' '0' 'true']

# %% [markdown]
# ### Amplío las transformaciones a realizar según cada output de la columna específca tras la transformación general

# %% [markdown]
# ### Valores únicos en 'overtime':
# ['no' nan 'yes']

# %%
df['overtime'].isnull().sum()
# Out:
# np.int64(696)

# %%
df['overtime'] = df['overtime'].fillna('none')

# %%
df['overtime'].value_counts()
# Out:
# overtime
# no      714
# none    696
# yes     268
# Name: count, dtype: int64

# %% [markdown]
# ### Valores únicos en 'performancerating':
# [ 3.  4. nan]

# %%
df['performancerating'].isnull().sum()
# Out:
# np.int64(200)

# %%
df['performancerating'].value_counts()
# Out:
# performancerating
# 3.0    1257
# 4.0     221
# Name: count, dtype: int64

# %%
df['performancerating'] = pd.to_numeric(df['performancerating'], errors='coerce').astype('Int64')

# %%
df['performancerating'] .dtypes
# Out:
# Int64Dtype()

# %%
df['performancerating'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1678 entries, 0 to 1677
# Series name: performancerating
# Non-Null Count  Dtype
# --------------  -----
# 1478 non-null   Int64
# dtypes: Int64(1)
# memory usage: 27.9 KB

# %% [markdown]
# ### Valores únicos en 'standardhours':
# ['full time' None 'part time']

# %%
df['standardhours']= df['standardhours'].str.replace(' ','_')

# %%
df['standardhours']= df['standardhours'].fillna('none')

# %%
df['standardhours'].sample(15)
# Out:
# 1320    part_time
# 1508    part_time
# 669     full_time
# 1627    part_time
# 1573    part_time
# 161          none
# 630     full_time
# 1181         none
# 489          none
# 1246         none
# 1639    part_time
# 117     part_time
# 832     part_time
# 258     full_time
# 989          none
# Name: standardhours, dtype: object

# %% [markdown]
# ### Valores únicos en 'totalworkingyears':

# %%
df['totalworkingyears'].isnull().sum()
# Out:
# np.int64(549)

# %%
df['totalworkingyears'].value_counts()
# Out:
# totalworkingyears
# 10.0    151
# 6.0      88
# 8.0      86
# 9.0      71
# 5.0      68
# 7.0      59
# 4.0      57
# 1.0      55
# 3.0      34
# 12.0     34
# 13.0     31
# 11.0     31
# 14.0     31
# 20.0     30
# 16.0     30
# 15.0     28
# 18.0     28
# 21.0     23
# 17.0     23
# 2.0      21
# 22.0     19
# 19.0     17
# 24.0     14
# 28.0     14
# 23.0     13
# 26.0      8
# 0.0       8
# 37.0      7
# 36.0      6
# 29.0      6
# 27.0      6
# 25.0      6
# 33.0      6
# 31.0      4
# 40.0      4
# 32.0      3
# 35.0      3
# 30.0      3
# 34.0      2
# 38.0      1
# Name: count, dtype: int64

# %%
df['totalworkingyears'].sample(15)
# Out:
# 1661     NaN
# 456      NaN
# 1551     NaN
# 1170     NaN
# 1280    12.0
# 1114     3.0
# 774     12.0
# 1157     6.0
# 1107     NaN
# 638      NaN
# 1366     6.0
# 542     17.0
# 1420    21.0
# 796      NaN
# 548      6.0
# Name: totalworkingyears, dtype: object

# %%
df['totalworkingyears']= pd.to_numeric(df['totalworkingyears'], errors='coerce').astype('Int64')

# %%
df['totalworkingyears'].sample(15)
# Out:
# 1554       8
# 1227      12
# 1290       1
# 1382    <NA>
# 290        7
# 89        13
# 184        9
# 1387      18
# 1273      10
# 978     <NA>
# 275     <NA>
# 970        6
# 1105       8
# 668       20
# 22        17
# Name: totalworkingyears, dtype: Int64

# %%
df['totalworkingyears'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1678 entries, 0 to 1677
# Series name: totalworkingyears
# Non-Null Count  Dtype
# --------------  -----
# 1129 non-null   Int64
# dtypes: Int64(1)
# memory usage: 27.9 KB

# %% [markdown]
# ### Valores únicos en 'worklifebalance':
# ['3,0' nan '2,0' '4,0' '1,0']

# %%
df['worklifebalance'].value_counts()
# Out:
# worklifebalance
# 3.0    946
# 2.0    374
# 4.0    162
# 1.0     82
# Name: count, dtype: int64

# %%
df['worklifebalance'].isnull().sum()
# Out:
# np.int64(114)

# %%
df['worklifebalance'].sample(15)
# Out:
# 300     2.0
# 1377    1.0
# 1325    3.0
# 998     3.0
# 1185    3.0
# 1270    2.0
# 414     3.0
# 1605    4.0
# 269     2.0
# 575     3.0
# 1673    3.0
# 1347    3.0
# 499     3.0
# 399     3.0
# 1017    1.0
# Name: worklifebalance, dtype: object

# %%
df['worklifebalance']=pd.to_numeric(df['worklifebalance'],errors='coerce').astype('Int64')

# %%
df['worklifebalance'].sample(10)
# Out:
# 329       4
# 587       3
# 563       2
# 336       4
# 356       3
# 276       2
# 476       4
# 764       3
# 749    <NA>
# 928       3
# Name: worklifebalance, dtype: Int64

# %%
df['worklifebalance'].value_counts()
# Out:
# worklifebalance
# 3    946
# 2    374
# 4    162
# 1     82
# Name: count, dtype: Int64

# %%
df['worklifebalance'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1678 entries, 0 to 1677
# Series name: worklifebalance
# Non-Null Count  Dtype
# --------------  -----
# 1564 non-null   Int64
# dtypes: Int64(1)
# memory usage: 27.9 KB

# %% [markdown]
# ### Valores únicos en 'sameasmonthlyincome':
# ['16280.83' None '14307.50' '12783.92' '14311.67' '8339.32' '13829.17'
#  '15943.72' '16644.17' '15034.17' '16038.33' '4492.84' '8956.67' '5167.50'
#  '3334.17' '8705.83' '2675.00' '8555.00'

# %%
df['sameasmonthlyincome'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1678 entries, 0 to 1677
# Series name: sameasmonthlyincome
# Non-Null Count  Dtype
# --------------  -----
# 1189 non-null   object
# dtypes: object(1)
# memory usage: 26.2+ KB

# %%
df['sameasmonthlyincome'].isnull().sum()
# Out:
# np.int64(489)

# %%
df['sameasmonthlyincome'] = pd.to_numeric(df['sameasmonthlyincome'], errors='coerce')

# %%
df['sameasmonthlyincome'].sample(15)
# Out:
# 854      2342.59
# 1015     8339.32
# 210      5488.33
# 305          NaN
# 212      2099.17
# 1036     4492.84
# 1033     2342.59
# 382          NaN
# 297     12783.92
# 565      4492.84
# 640      7377.50
# 682          NaN
# 1235     2342.59
# 1468     2342.59
# 756      4492.84
# Name: sameasmonthlyincome, dtype: float64

# %%
df['sameasmonthlyincome']=df['sameasmonthlyincome'].astype(float)

# %%
df['sameasmonthlyincome'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1678 entries, 0 to 1677
# Series name: sameasmonthlyincome
# Non-Null Count  Dtype
# --------------  -----
# 1189 non-null   float64
# dtypes: float64(1)
# memory usage: 26.2 KB

# %% [markdown]
# ### Valores únicos en 'salary':
# ['195370.00' '199990.00' '192320.00' '171690.00' None '100071.84'
#  '53914.11' '165950.00' '199730.00'

# %%
df['salary'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1678 entries, 0 to 1677
# Series name: salary
# Non-Null Count  Dtype
# --------------  -----
# 1393 non-null   object
# dtypes: object(1)
# memory usage: 26.2+ KB

# %%
df['salary'].isnull().sum()
# Out:
# np.int64(285)

# %%
df['salary'] = pd.to_numeric(df['salary'], errors='coerce')

# %%
df['salary'].sample(15)
# Out:
# 1193     28111.13
# 863      28111.13
# 1158     22690.00
# 1264    135910.00
# 910      38940.00
# 567      28111.13
# 88      153407.07
# 1290          NaN
# 892      28111.13
# 1270     27230.00
# 1677     53914.11
# 683      23890.00
# 954      59330.00
# 1083          NaN
# 1597    191324.62
# Name: salary, dtype: float64

# %%
df['salary']=df['salary'].astype(float)

# %%
df['salary'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1678 entries, 0 to 1677
# Series name: salary
# Non-Null Count  Dtype
# --------------  -----
# 1393 non-null   float64
# dtypes: float64(1)
# memory usage: 26.2 KB

# %% [markdown]
# 📌 ¿Por qué NaN aparece en float, pero <NA> en int?
#
# 1️⃣ En columnas float64, Pandas usa NaN, que es un valor especial de numpy (np.nan).
#
# 2️⃣ En columnas int64, no pueden existir nulos (los enteros clásicos no admiten NaN).
#
# 3️⃣ En columnas Int64 (nullable), Pandas usa <NA>, que es su propia representación de valores

# %% [markdown]
# ### Valores únicos en 'remotework':
# ['yes' '1' 'false' '0' 'true']

# %%
df['remotework'] = df['remotework'].str.replace('1','yes')
df['remotework'] = df['remotework'].str.replace('true','yes')
df['remotework'] = df['remotework'].str.replace('0','no')
df['remotework'] = df['remotework'].str.replace('false','no')

# %%
df['remotework'].value_counts()
# Out:
# remotework
# yes    1042
# no      636
# Name: count, dtype: int64

# %%
df['remotework'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Columnas finales tras limpieza realizada

# %%
df[columns_sara].sample(15)
# Out:
#      overtime  performancerating standardhours  totalworkingyears  \
# 4          no                  3          none               <NA>
# 1347     none                  3     part_time                  6
# 1556     none                  3     full_time                 13
# 1098     none                  3     part_time                  4
# 165       yes                  3     part_time                 10
# 80       none                  3          none                 14
# 32       none                  3     full_time                 26
# 24       none                  3     full_time                 18
# 1584     none                  3     full_time                 10
# 1078       no                  3          none                  4
# 547      none                  4     part_time               <NA>
# 1204       no                  3     part_time                  7
# 422       yes                  3     part_time               <NA>
# 1512     none                  3     part_time               <NA>
# 878        no                  3          none                  8
#
#       worklifebalance  sameasmonthlyincome     salary remotework
# 4                   3             12783.92        NaN         no
# 1347                3              4492.84   53914.11        yes
# 1556                3                  NaN   59740.00        yes
# 1098                3              3645.00   43740.00        yes
# 165                 3              4492.84   53914.11         no
# 80                  3              8339.32        NaN         no
# 32                  2             15943.72  191324.62        yes
# 24               <NA>              5167.50   62010.00        yes
# 1584                3                  NaN  111590.00         no
# 1078                3              2342.59        NaN        yes
# 547                 2              4492.84   53914.11         no
# 1204                4                  NaN   53914.11         no
# 422                 3              8339.32  100071.84        yes
# 1512                3                  NaN   28111.13        yes
# 878                 2              5289.17        NaN        yes

# %%
df_transf_sara = df[columns_sara]
df_transf_sara
# Out:
#      overtime  performancerating standardhours  totalworkingyears  \
# 0          no                  3     full_time               <NA>
# 1        none                  3          none                 34
# 2          no                  3          none                 22
# 3        none                  3     full_time               <NA>
# 4          no                  3          none               <NA>
# ...       ...                ...           ...                ...
# 1673     none                  3          none               <NA>
# 1674       no                  3     full_time                 27
# 1675       no                  3     part_time                  6
# 1676      yes               <NA>     part_time               <NA>
# 1677      yes                  3     part_time                 10
#
#       worklifebalance  sameasmonthlyincome     salary remotework
# 0                   3             16280.83  195370.00        yes
# 1                   3                  NaN  199990.00        yes
# 2                <NA>                  NaN  192320.00        yes
# 3                <NA>             14307.50  171690.00         no
# 4                   3             12783.92        NaN         no
# ...               ...                  ...        ...        ...
# 1673                3              3949.17        NaN        yes
# 1674                3             15943.72  191324.62         no
# 1675                3                  NaN   28111.13         no
# 1676                3              8339.32  100071.84        yes
# 1677                3                  NaN   53914.11         no
#
# [1678 rows x 8 columns]

# %% [markdown]
# ### CONTINUAMOS CON TRANSFORMACIÓN DEL RESTO DE COLUMNAS CATEGÓRICAS

# %%
# FUNCION PARA LIMPIAR COLUMNAS OBJECT Y CONVERTIR A NUMERICAS:

def clean_numeric_column(df, column):  # df:dataframe, column: el nombre de la columna a limpiar.
    # Paso 1: convierto a texto y limpio símbolo
    df[column] = df[column].astype(str) # Convierto toda la columna a str, porque .str.replace() solo funciona con texto.
    df[column] = df[column].str.replace('$', '')
    df[column] = df[column].str.replace(',', '.')

    # Paso 2: convertir a float
    # errors = coerce -> Estoy forzando ->“Intenta convertir todo a número. Si encuentras algo que no se puede convertir (como texto raro o vacío), en vez de dar error, pon un NaN”.
    df[column] = pd.to_numeric(df[column], errors='coerce') # pd.to_numerics es una funcion de Pandas que  convierte strings en numeros int/float

    # Paso 3: convertir NaN a None para SQL
    df[column] = df[column].where(pd.notnull(df[column]), None) # si el valor es NaN, cambialo a None, sino dejalo tal cual.

    return df  # devuelvo el df modificado.

# %%
# creo lista con las columnas a las que le voy a aplicar la funcion que he creado.

columnas_a_limpiar = ['monthlyincome', 'monthlyrate']

# %%
# hago un bucle for para aplicar la funcion a la lista de columnas que he definido.

for col in columnas_a_limpiar:
    clean_numeric_column(df, col)

# %%
df[columnas_a_limpiar].head()
# Out:
#    monthlyincome  monthlyrate
# 0       16280.83     42330.17
# 1            NaN     43331.17
# 2            NaN     41669.33
# 3       14307.50     37199.50
# 4       12783.92     33238.20

# %%
df[columnas_a_limpiar].dtypes
# Out:
# monthlyincome    float64
# monthlyrate      float64
# dtype: object

# %%
# analizo columna AGE: son edades pero aparece como objetc, hay que pasarlo a INT.

df['age'].sample(15)

# vemos que hay algunos valores escritos en letra.
# Out:
# 929     24
# 1615    59
# 909     42
# 1131    29
# 83      29
# 1187    43
# 637     40
# 1536    43
# 1035    27
# 1454    44
# 1153    25
# 1362    51
# 1632    29
# 123     31
# 112     30
# Name: age, dtype: object

# %%
df["age"] = df["age"].str.strip() # primero quito los posibles espacios que puedan haber antes o despues del numero.

# %% [markdown]
# #### Importación de librería necesaria para transformar palabras en inglés que se refieren a números a integers

# %%
#!pip install word2number

# %%
from word2number import w2n
print(w2n.word_to_num("forty two"))
# Out:
# 42

# %%
# ya he importado la libreria, hago una funcion para limpiar la columna age:
# necesito pasarlo todo a texto/string primero.

def convertir_edad(valor):  # Definimos la función. Le pasaremos una edad, que puede ser: un numero ("42"), un string o un Nulo (NaN)
    if pd.isnull(valor):    # Si el valor es nulo (NaN), lo dejamos como None. 
        return None
    valor = str(valor).strip().lower() # str(valor) lo convierte a texto/string por si viene como numero, con .strip() elimino posibles espacios y .lower()lo paso todo a minusculas.
    try:
        return int(valor) if valor.isdigit() else w2n.word_to_num(valor)  # si el valor es .isdigit() significa que es un numero tipo "42" y uso INT para convertirlo, si no es numero sino letra (forty-two) uso w2n para traducirlo.
    except:
        return None  # Por si hay algún texto no válido


#con el try me aseguro de cambiar a INT si es un "35" y me de 35 y si esta escrito "twenty" uso w2n para que me de 20 en INT

# %%
df["age"] = df["age"].apply(convertir_edad)

# con apply aplico la funcion que acabo de hacer a cada fila de la columna AGE para que realice los cambios a INT. 
# El resultado se guarda en la misma columna.

# %%
df["age"].sample(5)

# ya aparece como INT.
# Out:
# 1656    41
# 1453    26
# 540     34
# 1660    36
# 1363    37
# Name: age, dtype: int64

# %%
columnas_binarias = ['attrition', 'over18']

# %%
def clean_binary_column(df, column):
    # Paso 1: convertir a texto, quitar espacios y pasar a minúsculas
    df[column] = df[column].astype(str).str.strip().str.lower()

    # Paso 2: estandarizar valores (sí/no)
    def estandarizar(valor):
        if valor in ['yes', '1', 'true']:
            return 'yes'
        elif valor in ['no', '0', 'false']:
            return 'no'
        else:
            return None  # Valor inesperado

    # Aplicamos la estandarización
    df[column] = df[column].apply(estandarizar)
    
    return df

# %%
for col in columnas_binarias:
    clean_binary_column(df, col)

# %%
# ME ASEGURO QUE SOLO HAY "YES", "NO" O "NONE"

for col in columnas_binarias:
    print(f"Valores únicos en '{col}':")
    print(df[col].unique())
    print("-----------------------------")
# Out:
# Valores únicos en 'attrition':
# ['no' 'yes']
# -----------------------------
# Valores únicos en 'over18':
# [None]
# -----------------------------

# %%
columnas_categoricas = ['businesstravel','educationfield','jobrole','maritalstatus']

# %%
def clean_text_column(df, column):
    df[column] = df[column].astype(str).str.strip().str.lower()
    df[column] = df[column].str.replace('-','_')
    df[column] = df[column].str.replace(' ','_')
    df[column] = df[column].str.replace('marreid','married')
    df[column] = df[column].where(pd.notnull(df[column]), None)
    return df # devuelve el dataframe modificado.

# pd.notnull(df[column]) -> Devuelve True para los valores que NO son nulos, y False para los NaN.
# .where(condición, valor_si_no_se_cumple)
# Si la condición es True, deja el valor como está.
# Si la condición es False (es decir, si hay un NaN), lo reemplaza por None.

# %%
# aplico la funcion a las columnas:

for col in columnas_categoricas:
    clean_text_column(df, col)

# %%
# ahora compruebo como han quedado las columnas:

for col in columnas_categoricas:
    print(f"Valores únicos en '{col}':")
    print(df[col].unique())
    print("------------------------------")
# Out:
# Valores únicos en 'businesstravel':
# ['nan' 'travel_rarely' 'travel_frequently' 'non_travel']
# ------------------------------
# Valores únicos en 'educationfield':
# ['nan' 'life_sciences' 'technical_degree' 'medical' 'other' 'marketing'
#  'human_resources']
# ------------------------------
# Valores únicos en 'jobrole':
# ['research_director' 'manager' 'sales_executive' 'manufacturing_director'
#  'research_scientist' 'healthcare_representative' 'laboratory_technician'
#  'sales_representative' 'human_resources']
# ------------------------------
# Valores únicos en 'maritalstatus':
# ['nan' 'married' 'divorced' 'single']
# ------------------------------

# %%
df[columnas_categoricas].dtypes
# Out:
# businesstravel    object
# educationfield    object
# jobrole           object
# maritalstatus     object
# dtype: object

# %% [markdown]
# ### COMENZAMOS LIMPIEZA DE COLUMNAS NUMÉRICAS

# %%
# Solo columnas numéricas (int y float)
df_num = df.select_dtypes(exclude="object")
display(df_num.head())
# Out:
#    age    dailyrate  distancefromhome  education  employeecount  \
# 0   51  2015.722222                 6          3              1
# 1   52  2063.388889                 1          4              1
# 2   42  1984.253968                 4          2              1
# 3   47  1771.404762                 2          4              1
# 4   46  1582.771346                 3          3              1
#
#    employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0               1                        1       0         NaN
# 1               2                        3       0         NaN
# 2               3                        3       0         NaN
# 3               4                        1       1         NaN
# 4               5                        1       1         NaN
#
#    jobinvolvement  ...  stockoptionlevel  totalworkingyears  \
# 0               3  ...                 0               <NA>
# 1               2  ...                 1                 34
# 2               3  ...                 0                 22
# 3               3  ...                 2               <NA>
# 4               4  ...                 1               <NA>
#
#    trainingtimeslastyear  worklifebalance  yearsatcompany  \
# 0                      5                3              20
# 1                      5                3              33
# 2                      3             <NA>              22
# 3                      2             <NA>              20
# 4                      5                3              19
#
#    yearssincelastpromotion  yearswithcurrmanager  sameasmonthlyincome  \
# 0                       15                    15             16280.83
# 1                       11                     9                  NaN
# 2                       11                    15                  NaN
# 3                        5                     6             14307.50
# 4                        2                     8             12783.92
#
#    datebirth    salary
# 0       1972  195370.0
# 1       1971  199990.0
# 2       1981  192320.0
# 3       1976  171690.0
# 4       1977       NaN
#
# [5 rows x 28 columns]

# %%
df_num["gender"].value_counts()
# Out:
# gender
# 0    1009
# 1     669
# Name: count, dtype: int64

# %%
df_num.shape
# Out:
# (1678, 28)

# %%
(df_num.isnull().sum() / len(df)) * 100
# Out:
# age                          0.000000
# dailyrate                    0.000000
# distancefromhome             0.000000
# education                    0.000000
# employeecount                0.000000
# employeenumber               0.000000
# environmentsatisfaction      0.000000
# gender                       0.000000
# hourlyrate                  75.506555
# jobinvolvement               0.000000
# joblevel                     0.000000
# jobsatisfaction              0.000000
# monthlyincome               29.141836
# monthlyrate                  0.000000
# numcompaniesworked           0.000000
# percentsalaryhike            0.000000
# performancerating           11.918951
# relationshipsatisfaction     0.000000
# stockoptionlevel             0.000000
# totalworkingyears           32.717521
# trainingtimeslastyear        0.000000
# worklifebalance              6.793802
# yearsatcompany               0.000000
# yearssincelastpromotion      0.000000
# yearswithcurrmanager         0.000000
# sameasmonthlyincome         29.141836
# datebirth                    0.000000
# salary                      16.984505
# dtype: float64

# %%
df_num.dtypes
# Out:
# age                           int64
# dailyrate                   float64
# distancefromhome              int64
# education                     int64
# employeecount                 int64
# employeenumber                int64
# environmentsatisfaction       int64
# gender                        int64
# hourlyrate                  float64
# jobinvolvement                int64
# joblevel                      int64
# jobsatisfaction               int64
# monthlyincome               float64
# monthlyrate                 float64
# numcompaniesworked            int64
# percentsalaryhike             int64
# performancerating             Int64
# relationshipsatisfaction      int64
# stockoptionlevel              int64
# totalworkingyears             Int64
# trainingtimeslastyear         int64
# worklifebalance               Int64
# yearsatcompany                int64
# yearssincelastpromotion       int64
# yearswithcurrmanager          int64
# sameasmonthlyincome         float64
# datebirth                     int64
# salary                      float64
# dtype: object

# %%
df_num.describe().T
# Out:
#                            count          mean           std         min  \
# age                       1678.0      36.94994      9.155706        18.0
# dailyrate                 1678.0    668.079714    470.787298  104.103175
# distancefromhome          1678.0      4.504172     14.652066       -49.0
# education                 1678.0      2.932658       1.02427         1.0
# employeecount             1678.0           1.0           0.0         1.0
# employeenumber            1678.0    809.859952    467.084867         1.0
# environmentsatisfaction   1678.0      4.264005      6.912695         1.0
# gender                    1678.0      0.398689      0.489774         0.0
# hourlyrate                 411.0     83.140768     57.272101   13.012897
# jobinvolvement            1678.0      2.740763      0.710359         1.0
# joblevel                  1678.0      2.064362      1.099425         1.0
# jobsatisfaction           1678.0      2.743147      1.105172         1.0
# monthlyincome             1189.0   5676.787065   6157.859086      1000.0
# monthlyrate               1678.0  14029.674648   9886.532728     2186.17
# numcompaniesworked        1678.0      2.670441      2.501133         0.0
# percentsalaryhike         1678.0      15.15435      3.649607        11.0
# performancerating         1478.0      3.149526      0.356727         3.0
# relationshipsatisfaction  1678.0      2.700238      1.079494         1.0
# stockoptionlevel          1678.0      0.787843      0.843252         0.0
# totalworkingyears         1129.0      11.35961      7.807298         0.0
# trainingtimeslastyear     1678.0       2.79559      1.288657         0.0
# worklifebalance           1564.0      2.759591      0.703527         1.0
# yearsatcompany            1678.0      7.124553      6.173837         0.0
# yearssincelastpromotion   1678.0      2.241955      3.246554         0.0
# yearswithcurrmanager      1678.0      4.200238      3.554224         0.0
# sameasmonthlyincome       1189.0   5676.787065   6157.859086      1000.0
# datebirth                 1678.0    1986.04708      9.154908      1963.0
# salary                    1393.0  65070.911587  45849.510802     10090.0
#
#                                 25%         50%         75%          max
# age                            30.0        36.0        43.0         60.0
# dailyrate                 290.03551  556.256661  971.956349  2063.388889
# distancefromhome                2.0         5.0        11.0         29.0
# education                       2.0         3.0         4.0          5.0
# employeecount                   1.0         1.0         1.0          1.0
# employeenumber               403.25       813.5     1215.75       1614.0
# environmentsatisfaction         2.0         3.0         4.0         49.0
# gender                          0.0         0.0         1.0          1.0
# hourlyrate                36.254439   69.532083  116.987103   255.963294
# jobinvolvement                  2.0         3.0         3.0          4.0
# joblevel                        1.0         2.0         3.0          5.0
# jobsatisfaction                 2.0         3.0         4.0          4.0
# monthlyincome               2342.59     4492.84     7861.67      94083.0
# monthlyrate                 6090.75    11681.39    20411.08     43331.17
# numcompaniesworked              1.0         2.0         4.0          9.0
# percentsalaryhike              12.0        14.0        18.0         25.0
# performancerating               3.0         3.0         3.0          4.0
# relationshipsatisfaction        2.0         3.0         4.0          4.0
# stockoptionlevel                0.0         1.0         1.0          3.0
# totalworkingyears               6.0        10.0        15.0         40.0
# trainingtimeslastyear           2.0         3.0         3.0          6.0
# worklifebalance                 2.0         3.0         3.0          4.0
# yearsatcompany                  3.0         5.0         9.0         40.0
# yearssincelastpromotion         0.0         1.0         3.0         15.0
# yearswithcurrmanager            2.0         3.0         7.0         17.0
# sameasmonthlyincome         2342.59     4492.84     7861.67      94083.0
# datebirth                    1980.0      1987.0      1993.0       2005.0
# salary                     28111.13    53914.11     94390.0     199990.0

# %%
columnas_numericas = ['dailyrate','distancefromhome','education','employeecount','employeenumber','environmentsatisfaction','gender','hourlyrate','jobinvolvement','joblevel', 
                    'jobsatisfaction','numcompaniesworked','percentsalaryhike','relationshipsatisfaction','stockoptionlevel','trainingtimeslastyear','yearsatcompany',
                    'yearssincelastpromotion','yearswithcurrmanager','datebirth']

# %%
# COLUMNA DISTANCEFROMHOME: TIENE VALORES NEGATIVOS

# Recorre y reemplaza valores negativos
# creo nueva lista con los valores corregidos.
nueva_distance = []

for valor in df["distancefromhome"]:
    if valor >= 0:
        nueva_distance.append(valor)
    else:
        nueva_distance.append(None)

# Asignamos la nueva columna al DataFrame
df['distancefromhome'] = nueva_distance

# %%
# VERIFICO LA LIMPIEZA:

df['distancefromhome'].min()  # Para asegurarme de que no quedan valores negativos
# Out:
# np.float64(1.0)

# %%
df['distancefromhome'].isnull().sum()  # Para ver cuántos None hay ahora
# Out:
# np.int64(202)

# %% [markdown]
# #### REALIZAMOS ESTUDIO DE OTRAS VARIABLES PARA PODER DETERMINAR EL VALOR DE 0 Y 1 DE MANERA AJUSTADA

# %%
lista_gender = ["gender"]

# %%
for columna in lista_gender:
    valores_unicos = df[columna].unique()
    print(f"La columna {columna} tiene {valores_unicos} valores unicos")
    # Recuento de respuestas por valores de la columna gender
    try:
        valores = df[columna].value_counts()
        print(f"La columna {columna} tiene {valores} valores")
    except Exception as e:
        print(f"Error processing column {columna}: {e}")

        # Nulos de la columna 
    nulos = df[columna].isnull().sum()
    print(f"La columna {columna} tiene {nulos} valores nulos")
# Out:
# La columna gender tiene [0 1] valores unicos
# La columna gender tiene gender
# 0    1009
# 1     669
# Name: count, dtype: int64 valores
# La columna gender tiene 0 valores nulos

# %%
df["gender"].info()
# tipo integer cambiar a object
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1678 entries, 0 to 1677
# Series name: gender
# Non-Null Count  Dtype
# --------------  -----
# 1678 non-null   int64
# dtypes: int64(1)
# memory usage: 26.2 KB

# %% [markdown]
# #### Agrupamos géneros y vemos relación con otras columnas

# %%
# ¿cuál es el género que corresponde a las mujeres y cuál al de los hombres empleados?
# en este caso tendremos que agrupar por el integer 0 y 1 '
df.groupby("gender").mean(numeric_only = True).T
# Out:
# gender                               0             1
# age                          36.778989     37.207773
# dailyrate                    660.38112    679.690898
# distancefromhome              8.822999      9.061121
# education                     2.918731      2.953662
# employeecount                      1.0           1.0
# employeenumber              822.691774    790.506726
# environmentsatisfaction       4.180377      4.390135
# hourlyrate                   80.907195     86.539088
# jobinvolvement                2.745292      2.733931
# joblevel                      2.034688      2.109118
# jobsatisfaction               2.777998      2.690583
# monthlyincome              5620.713908   5762.567064
# monthlyrate               13868.004182  14273.509477
# numcompaniesworked            2.581764      2.804185
# percentsalaryhike            15.176412     15.121076
# performancerating             3.143982      3.157895
# relationshipsatisfaction      2.729435      2.656203
# stockoptionlevel               0.79782      0.772795
# totalworkingyears            11.298938     11.444681
# trainingtimeslastyear          2.76115      2.847534
# worklifebalance               2.751073      2.772152
# yearsatcompany                6.957384      7.376682
# yearssincelastpromotion       2.142716      2.391629
# yearswithcurrmanager          4.107037      4.340807
# sameasmonthlyincome        5620.713908   5762.567064
# datebirth                  1986.216056   1985.792227
# salary                    64006.877515  66653.662268

# %%
columnas_genero = df.columns

# %%
grupo_generos = df.groupby("gender")[columnas_genero].apply(lambda x: x.reset_index(drop=True))
grupo_generos
# Out:
#             age attrition     businesstravel    dailyrate  distancefromhome  \
# gender
# 0      0     51        no                nan  2015.722222               6.0
#        1     52        no                nan  2063.388889               1.0
#        2     42        no      travel_rarely  1984.253968               4.0
#        3     42        no      travel_rarely   556.256661               1.0
#        4     41        no  travel_frequently  1973.984127               9.0
# ...         ...       ...                ...          ...               ...
# 1      664   31        no                nan   556.256661              12.0
#        665   43        no                nan   488.944444               NaN
#        666   47        no                nan  1973.984127              26.0
#        667   47        no      travel_rarely  1032.487286               4.0
#        668   32        no                nan   556.256661               2.0
#
#             education    educationfield  employeecount  employeenumber  \
# gender
# 0      0            3               nan              1               1
#        1            4     life_sciences              1               2
#        2            2  technical_degree              1               3
#        3            1               nan              1               8
#        4            3               nan              1              10
# ...               ...               ...            ...             ...
# 1      664          3           medical              1            1608
#        665          3           medical              1             824
#        666          4               nan              1            1087
#        667          3     life_sciences              1              76
#        668          2     life_sciences              1             401
#
#             environmentsatisfaction  ...  totalworkingyears  \
# gender                               ...
# 0      0                          1  ...               <NA>
#        1                          3  ...                 34
#        2                          3  ...                 22
#        3                          2  ...                 20
#        4                          1  ...                 21
# ...                             ...  ...                ...
# 1      664                        4  ...                 10
#        665                        2  ...               <NA>
#        666                        4  ...                 27
#        667                        3  ...               <NA>
#        668                        4  ...                 10
#
#             trainingtimeslastyear  worklifebalance  yearsatcompany  \
# gender
# 0      0                        5                3              20
#        1                        5                3              33
#        2                        3             <NA>              22
#        3                        3                3              20
#        4                        2                4              18
# ...                           ...              ...             ...
# 1      664                      2                1               9
#        665                      2                3               3
#        666                      2                3               5
#        667                      4                3              22
#        668                      2                3               8
#
#            yearssincelastpromotion  yearswithcurrmanager sameasmonthlyincome  \
# gender
# 0      0                        15                    15            16280.83
#        1                        11                     9                 NaN
#        2                        11                    15                 NaN
#        3                        11                     6                 NaN
#        4                         0                    11            15943.72
# ...                            ...                   ...                 ...
# 1      664                       8                     5                 NaN
#        665                       1                     2             3949.17
#        666                       1                     0            15943.72
#        667                      14                    10             8339.32
#        668                       0                     7                 NaN
#
#             datebirth     salary  remotework
# gender
# 0      0         1972  195370.00         yes
#        1         1971  199990.00         yes
#        2         1981  192320.00         yes
#        3         1981   53914.11          no
#        4         1982        NaN          no
# ...               ...        ...         ...
# 1      664       1992   53914.11         yes
#        665       1980        NaN         yes
#        666       1976  191324.62          no
#        667       1976  100071.84         yes
#        668       1991   53914.11          no
#
# [1678 rows x 37 columns]

# %%
df_salarios = grupo_generos["salary"].reset_index()
df_salarios
# Out:
#       gender  level_1     salary
# 0          0        0  195370.00
# 1          0        1  199990.00
# 2          0        2  192320.00
# 3          0        3   53914.11
# 4          0        4        NaN
# ...      ...      ...        ...
# 1673       1      664   53914.11
# 1674       1      665        NaN
# 1675       1      666  191324.62
# 1676       1      667  100071.84
# 1677       1      668   53914.11
#
# [1678 rows x 3 columns]

# %%
df_1 = df_salarios[df_salarios['gender'] == 1]
df_0 = df_salarios[df_salarios['gender'] == 0]

# %%
df_g1 =df_1.assign(gender1="1")
df_1
# Out:
#       gender  level_1     salary
# 1009       1        0  171690.00
# 1010       1        1        NaN
# 1011       1        2        NaN
# 1012       1        3  100071.84
# 1013       1        4  165950.00
# ...      ...      ...        ...
# 1673       1      664   53914.11
# 1674       1      665        NaN
# 1675       1      666  191324.62
# 1676       1      667  100071.84
# 1677       1      668   53914.11
#
# [669 rows x 3 columns]

# %%
df_g0 =df_0.assign(gender0="0")
df_g0
# Out:
#       gender  level_1     salary gender0
# 0          0        0  195370.00       0
# 1          0        1  199990.00       0
# 2          0        2  192320.00       0
# 3          0        3   53914.11       0
# 4          0        4        NaN       0
# ...      ...      ...        ...     ...
# 1004       0     1004   53914.11       0
# 1005       0     1005   53914.11       0
# 1006       0     1006   22590.00       0
# 1007       0     1007  100071.84       0
# 1008       0     1008   28111.13       0
#
# [1009 rows x 4 columns]

# %%
genero_salario = df.groupby("gender")["salary"].mean()
genero_salario
# Out:
# gender
# 0    64006.877515
# 1    66653.662268
# Name: salary, dtype: float64

# %% [markdown]
# ##### Existen numerosos estudios que confirman que, por lo general, los hombres tienen salarios superiores a las mujeres
#
# Asignamos por lo tanto el valor 1 a male y 0 a female
#
# https://www.rtve.es/noticias/20250206/mujeres-espanolas-ganan-media-casi-5000-euros-menos-ano-hombres/16437790.shtml

# %%
# COLUMNA GENDER VAMOS A PASAR 0 -> MALE Y 1 -> FEMALE

# CreO una nueva lista con los valores convertidos a texto
nueva_gender = []

for valor in df['gender']:
    if valor == 0:
        nueva_gender.append("male")
    elif valor == 1:
        nueva_gender.append("female")
    else:
        nueva_gender.append(None)  # Por si hay algo inesperado

# Asignamos la lista transformada a la columna original
df['gender'] = nueva_gender

# %%
df["gender"].sample(5)
# Out:
# 33       male
# 279      male
# 150    female
# 967    female
# 24       male
# Name: gender, dtype: object

# %%
# COLUMNA ENVOIREMENTSATISFACTION.
# ESTA COLUMNA VA DE 1 A 5, PERO APARECE UN VALOR MAXIMO DE 49

valores_validos = [1, 2, 3, 4, 5] # creo una lista con valores validos (escala de 1 a 5)

nueva_satisfaccion = [] # creo una lista vacia 
for valor in df['environmentsatisfaction']:
    if valor in valores_validos:  # por cada valor de la columna, verifica si el valor esta en la lista de validos
        nueva_satisfaccion.append(valor)  # si el valor es valido lo apendeo a la lista vacia
    else:
        nueva_satisfaccion.append(None) # sino dame None.

df['environmentsatisfaction'] = nueva_satisfaccion  # reemplaxzo la columna original por la mnueva

# %%
df['environmentsatisfaction'].sample(5)
# Out:
# 922     1.0
# 639     1.0
# 1541    3.0
# 1128    3.0
# 146     4.0
# Name: environmentsatisfaction, dtype: float64

# %% [markdown]
# ### LIMPIEZA FINALIZADA.

# %% [markdown]
# #### UNIMOS LOS DOS DATA FRAMES EN LOS QUE HEMOS TRABAJADO

# %% [markdown]
# USAMOS EL MÉTODO CONCAT YA QUE SOLO TENEMOS QUE UNIR DE MANERA PARALELA LAS COLUMNAS Y AXIS = 1 PORQUE LOS UNIMOS POR EL ÍNDICE (DE MANERA PARALELA)

# %% [markdown]
# Primero elimino las columnas trabajadas en el segundo DataFrame del df original.

# %%
df_transf_sara.columns
# Out:
# Index(['overtime', 'performancerating', 'standardhours', 'totalworkingyears',
#        'worklifebalance', 'sameasmonthlyincome', 'salary', 'remotework'],
#       dtype='object')

# %%
# Identificar las columnas comunes entre df y df_transf_sara
columnas_comunes = df.columns.intersection(df_transf_sara.columns)
columnas_comunes
# Out:
# Index(['overtime', 'performancerating', 'standardhours', 'totalworkingyears',
#        'worklifebalance', 'sameasmonthlyincome', 'salary', 'remotework'],
#       dtype='object')

# %%
# Eliminar las columnas comunes de df
df = df.drop(columns=columnas_comunes)

# %%
# realizamos la unión paralela
df_final = pd.concat([df, df_transf_sara], axis = 1)

# %%
display(df_final)
# Out:
#       age attrition businesstravel    dailyrate  distancefromhome  education  \
# 0      51        no            nan  2015.722222               6.0          3
# 1      52        no            nan  2063.388889               1.0          4
# 2      42        no  travel_rarely  1984.253968               4.0          2
# 3      47        no  travel_rarely  1771.404762               2.0          4
# 4      46        no            nan  1582.771346               3.0          3
# ...   ...       ...            ...          ...               ...        ...
# 1673   43        no            nan   488.944444               NaN          3
# 1674   47        no            nan  1973.984127              26.0          4
# 1675   29        no  travel_rarely   290.035510              15.0          3
# 1676   47        no  travel_rarely  1032.487286               4.0          3
# 1677   32        no            nan   556.256661               2.0          2
#
#         educationfield  employeecount  employeenumber  \
# 0                  nan              1               1
# 1        life_sciences              1               2
# 2     technical_degree              1               3
# 3              medical              1               4
# 4     technical_degree              1               5
# ...                ...            ...             ...
# 1673           medical              1             824
# 1674               nan              1            1087
# 1675               nan              1             528
# 1676     life_sciences              1              76
# 1677     life_sciences              1             401
#
#       environmentsatisfaction  ... yearswithcurrmanager  datebirth  overtime  \
# 0                         1.0  ...                   15       1972        no
# 1                         3.0  ...                    9       1971      none
# 2                         3.0  ...                   15       1981        no
# 3                         1.0  ...                    6       1976      none
# 4                         1.0  ...                    8       1977        no
# ...                       ...  ...                  ...        ...       ...
# 1673                      2.0  ...                    2       1980      none
# 1674                      4.0  ...                    0       1976        no
# 1675                      3.0  ...                    5       1994        no
# 1676                      3.0  ...                   10       1976       yes
# 1677                      4.0  ...                    7       1991       yes
#
#       performancerating standardhours  totalworkingyears worklifebalance  \
# 0                     3     full_time               <NA>               3
# 1                     3          none                 34               3
# 2                     3          none                 22            <NA>
# 3                     3     full_time               <NA>            <NA>
# 4                     3          none               <NA>               3
# ...                 ...           ...                ...             ...
# 1673                  3          none               <NA>               3
# 1674                  3     full_time                 27               3
# 1675                  3     part_time                  6               3
# 1676               <NA>     part_time               <NA>               3
# 1677                  3     part_time                 10               3
#
#       sameasmonthlyincome     salary  remotework
# 0                16280.83  195370.00         yes
# 1                     NaN  199990.00         yes
# 2                     NaN  192320.00         yes
# 3                14307.50  171690.00          no
# 4                12783.92        NaN          no
# ...                   ...        ...         ...
# 1673              3949.17        NaN         yes
# 1674             15943.72  191324.62          no
# 1675                  NaN   28111.13          no
# 1676              8339.32  100071.84         yes
# 1677                  NaN   53914.11          no
#
# [1678 rows x 37 columns]

# %%
df_final.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'distancefromhome',
#        'education', 'educationfield', 'employeecount', 'employeenumber',
#        'environmentsatisfaction', 'gender', 'hourlyrate', 'jobinvolvement',
#        'joblevel', 'jobrole', 'jobsatisfaction', 'maritalstatus',
#        'monthlyincome', 'monthlyrate', 'numcompaniesworked', 'over18',
#        'percentsalaryhike', 'relationshipsatisfaction', 'stockoptionlevel',
#        'trainingtimeslastyear', 'yearsatcompany', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'datebirth', 'overtime', 'performancerating',
#        'standardhours', 'totalworkingyears', 'worklifebalance',
#        'sameasmonthlyincome', 'salary', 'remotework'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)

# %%
df_final.sample(10)
# Out:
#       age attrition businesstravel    dailyrate  distancefromhome  education  \
# 1074   48        no  travel_rarely   290.035510              15.0          4
# 610    54        no            nan  1032.487286               2.0          4
# 1000   21        no            nan   213.571429               1.0          1
# 1109   31        no            nan   358.738095               2.0          4
# 366    36       yes  travel_rarely  1065.277778               3.0          1
# 346    36        no            nan  1208.484127               8.0          3
# 1239   48       yes            nan  1032.487286               1.0          2
# 103    38        no            nan   290.035510               2.0          3
# 1421   38        no  travel_rarely   341.095238               4.0          2
# 353    40        no            nan   437.873016               NaN          2
#
#      educationfield  employeecount  employeenumber  environmentsatisfaction  \
# 1074            nan              1            1075                      3.0
# 610   life_sciences              1             611                      3.0
# 1000            nan              1            1001                      4.0
# 1109  life_sciences              1            1110                      2.0
# 366   life_sciences              1             367                      3.0
# 346             nan              1             347                      1.0
# 1239            nan              1            1240                      1.0
# 103             nan              1             104                      1.0
# 1421            nan              1            1422                      4.0
# 353         medical              1             354                      NaN
#
#       gender  hourlyrate  jobinvolvement  joblevel                    jobrole  \
# 1074  female         NaN               3         1         research_scientist
# 610   female         NaN               2         3            sales_executive
# 1000  female         NaN               2         1         research_scientist
# 1109    male         NaN               3         1      laboratory_technician
# 366     male         NaN               2         3            sales_executive
# 346   female         NaN               4         3          research_director
# 1239    male         NaN               2         3      laboratory_technician
# 103     male         NaN               3         1            human_resources
# 1421  female         NaN               3         1      laboratory_technician
# 353   female         NaN               4         2  healthcare_representative
#
#       jobsatisfaction maritalstatus  monthlyincome  monthlyrate  \
# 1074                1       married        2342.59      6090.75
# 610                 3       married        8339.32     21682.23
# 1000                2        single            NaN      4485.00
# 1109                3       married        2897.50      7533.50
# 366                 4       married        8604.17     22370.83
# 346                 1       married        9760.83     25378.17
# 1239                3           nan        8339.32     21682.23
# 103                 2      divorced        2342.59      6090.75
# 1421                3           nan            NaN      7163.00
# 353                 2           nan        3536.67      9195.33
#
#       numcompaniesworked over18  percentsalaryhike  relationshipsatisfaction  \
# 1074                   8   None                 12                         4
# 610                    6   None                 11                         2
# 1000                   1   None                 11                         3
# 1109                   1   None                 14                         4
# 366                    1   None                 11                         1
# 346                    9   None                 14                         1
# 1239                   9   None                 13                         4
# 103                    5   None                 13                         4
# 1421                   7   None                 19                         4
# 353                    1   None                 24                         4
#
#       stockoptionlevel  trainingtimeslastyear  yearsatcompany  \
# 1074                 1                      3               8
# 610                  1                      4               9
# 1000                 0                      6               2
# 1109                 1                      2               5
# 366                  1                      6              16
# 346                  1                      2               8
# 1239                 0                      2               1
# 103                  3                      3              11
# 1421                 1                      5               0
# 353                  1                      2               8
#
#       yearssincelastpromotion  yearswithcurrmanager  datebirth overtime  \
# 1074                        7                     6       1975     none
# 610                         7                     0       1969       no
# 1000                        2                     2       2002      yes
# 1109                        0                     3       1992     none
# 366                         3                     7       1987     none
# 346                         0                     5       1987     none
# 1239                        0                     0       1975     none
# 103                         3                     8       1985       no
# 1421                        0                     0       1985     none
# 353                         3                     7       1983       no
#
#       performancerating standardhours  totalworkingyears  worklifebalance  \
# 1074                  3     part_time               <NA>                2
# 610                   3     part_time                 13                3
# 1000                  3     part_time                  2                4
# 1109                  3     full_time                  6                4
# 366                <NA>     full_time               <NA>                3
# 346                   3     full_time                 10                3
# 1239                  3     part_time               <NA>                3
# 103                   3     part_time                 13                3
# 1421                  3     full_time                  7             <NA>
# 353                   4          none                  8                3
#
#       sameasmonthlyincome     salary remotework
# 1074              2342.59   28111.13        yes
# 610               8339.32  100071.84        yes
# 1000                  NaN   20700.00        yes
# 1109              2897.50   34770.00         no
# 366               8604.17  103250.00         no
# 346               9760.83  117130.00         no
# 1239              8339.32  100071.84         no
# 103               2342.59   28111.13        yes
# 1421                  NaN   33060.00        yes
# 353               3536.67        NaN        yes

# %%
# Redondear las columnas numéricas especificadas a 2 decimales
df_final[['dailyrate', 'hourlyrate', 'percentsalaryhike']] = df[['dailyrate', 'hourlyrate', 'percentsalaryhike']].round(2)

# Verificamos que el redondeo se haya aplicado
df_final[['dailyrate', 'hourlyrate', 'percentsalaryhike']].head()
# Out:
#    dailyrate  hourlyrate  percentsalaryhike
# 0    2015.72         NaN                 13
# 1    2063.39         NaN                 14
# 2    1984.25         NaN                 11
# 3    1771.40         NaN                 19
# 4    1582.77         NaN                 12

# %% [markdown]
# #### RENOMBRAMOS LAS COLUMNAS PARA HOMOGENIZAR Y HACER MÁS VISIBLES SUS NOMBRES

# %%
df_final.columns.tolist()
# Out:
# ['age',
#  'attrition',
#  'businesstravel',
#  'dailyrate',
#  'distancefromhome',
#  'education',
#  'educationfield',
#  'employeecount',
#  'employeenumber',
#  'environmentsatisfaction',
#  'gender',
#  'hourlyrate',
#  'jobinvolvement',
#  'joblevel',
#  'jobrole',
#  'jobsatisfaction',
#  'maritalstatus',
#  'monthlyincome',
#  'monthlyrate',
#  'numcompaniesworked',
#  'over18',
#  'percentsalaryhike',
#  'relationshipsatisfaction',
#  'stockoptionlevel',
#  'trainingtimeslastyear',
#  'yearsatcompany',
#  'yearssincelastpromotion',
#  'yearswithcurrmanager',
#  'datebirth',
#  'overtime',
#  'performancerating',
#  'standardhours',
#  'totalworkingyears',
#  'worklifebalance',
#  'sameasmonthlyincome',
#  'salary',
#  'remotework']

# %%
# primero renombro una columna y luego hago una funcion

# Renombro la columna 'jobinvolvement' a 'job_involvement_level'
df_final.rename(columns={'jobinvolvement': 'job_involvement_level'}, inplace=True)

# Verifico que se ha renombrado correctamente
print(df_final.columns)
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'distancefromhome',
#        'education', 'educationfield', 'employeecount', 'employeenumber',
#        'environmentsatisfaction', 'gender', 'hourlyrate',
#        'job_involvement_level', 'joblevel', 'jobrole', 'jobsatisfaction',
#        'maritalstatus', 'monthlyincome', 'monthlyrate', 'numcompaniesworked',
#        'over18', 'percentsalaryhike', 'relationshipsatisfaction',
#        'stockoptionlevel', 'trainingtimeslastyear', 'yearsatcompany',
#        'yearssincelastpromotion', 'yearswithcurrmanager', 'datebirth',
#        'overtime', 'performancerating', 'standardhours', 'totalworkingyears',
#        'worklifebalance', 'sameasmonthlyincome', 'salary', 'remotework'],
#       dtype='object')

# %%
#AHORA HAGO LA FUNCION

# primero defino una lista de tuplas con los nombres originales y los nuevos.
# Definimos una lista de tuplas con los nombres originales y los nuevos
columnas_renombrar = [
    ('attrition', 'employee_turnover'),
    ('businesstravel', 'business_travel_frequency'),
    ('dailyrate', 'daily_rate'),
    ('distancefromhome', 'distance_from_home_km'),
    ('education', 'education_level'),
    ('educationfield', 'education_field'),
    ('employeecount', 'remove_column'),  # Esta se elimina?
    ('employeenumber', 'employee_id'),
    ('environmentsatisfaction', 'environmental_satisfaction_level'),
    ('gender', 'gender'),
    ('hourlyrate', 'hourly_rate'),
    ('jobinvolvement', 'job_involvement_level'),
    ('joblevel', 'job_level'),
    ('jobrole', 'job_role'),
    ('jobsatisfaction', 'job_satisfaction_level'),
    ('maritalstatus', 'marital_status'),
    ('monthlyincome', 'monthly_income'),
    ('monthlyrate', 'monthly_rate'),
    ('numcompaniesworked', 'num_companies_worked'),
    ('over18', 'over_18'),
    ('overtime', 'overtime_hours'),
    ('percentsalaryhike', 'percent_salary_hike'),
    ('performancerating', 'performance_rating'),
    ('relationshipsatisfaction', 'relationship_satisfaction_level'),
    ('standardhours', 'standard_work_hours'),
    ('stockoptionlevel', 'stock_option_level'),
    ('totalworkingyears', 'total_years_worked'),
    ('trainingtimeslastyear', 'training_sessions_last_year'),
    ('worklifebalance', 'work_life_balance'),
    ('yearsatcompany', 'years_at_company'),
    ('yearssincelastpromotion', 'years_since_last_promotion'),
    ('yearswithcurrmanager', 'years_with_current_manager'),
    ('sameasmonthlyincome', 'same_as_monthly_income'),
    ('datebirth', 'birth_year'),
    ('salary', 'annual_salary'),
    ('remotework', 'remote_work')
]

# %%
# Convierto la lista de tuplas en un diccionario
columnas_dict = dict(columnas_renombrar)

# Uso el diccionario para renombrar las columnas del DataFrame
df_final.rename(columns=columnas_dict, inplace=True)

# Verifico que se han renombrado correctamente
print(df_final.columns)
# Out:
# Index(['age', 'employee_turnover', 'business_travel_frequency', 'daily_rate',
#        'distance_from_home_km', 'education_level', 'education_field',
#        'remove_column', 'employee_id', 'environmental_satisfaction_level',
#        'gender', 'hourly_rate', 'job_involvement_level', 'job_level',
#        'job_role', 'job_satisfaction_level', 'marital_status',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'over_18',
#        'percent_salary_hike', 'relationship_satisfaction_level',
#        'stock_option_level', 'training_sessions_last_year', 'years_at_company',
#        'years_since_last_promotion', 'years_with_current_manager',
#        'birth_year', 'overtime_hours', 'performance_rating',
#        'standard_work_hours', 'total_years_worked', 'work_life_balance',
#        'same_as_monthly_income', 'annual_salary', 'remote_work'],
#       dtype='object')

# %%
# verifico el df
df_final.sample(10)
# Out:
#       age employee_turnover business_travel_frequency  daily_rate  \
# 1233   24               yes             travel_rarely      290.04
# 291    45                no                       nan     1032.49
# 577    31               yes                       nan      290.04
# 1539   25               yes             travel_rarely      290.04
# 691    27                no             travel_rarely      290.04
# 645    37                no             travel_rarely      406.10
# 1468   23               yes                       nan      290.04
# 860    29                no                       nan      715.10
# 741    27                no                       nan      259.69
# 1365   50               yes                       nan      487.81
#
#       distance_from_home_km  education_level education_field  remove_column  \
# 1233                    1.0                3             nan              1
# 291                     6.0                3         medical              1
# 577                    29.0                2             nan              1
# 1539                    3.0                3         medical              1
# 691                     5.0                3             nan              1
# 645                    10.0                3             nan              1
# 1468                    9.0                3             nan              1
# 860                     NaN                2       marketing              1
# 741                     4.0                2             nan              1
# 1365                    1.0                4             nan              1
#
#       employee_id  environmental_satisfaction_level  gender  hourly_rate  \
# 1233         1234                               2.0    male        36.25
# 291           292                               4.0  female       129.06
# 577           578                               3.0    male          NaN
# 1539         1540                               1.0    male        36.25
# 691           692                               3.0  female          NaN
# 645           646                               2.0  female        50.76
# 1468         1469                               4.0    male          NaN
# 860           861                               4.0    male        89.39
# 741           742                               1.0    male          NaN
# 1365         1366                               4.0    male          NaN
#
#       job_involvement_level  job_level               job_role  \
# 1233                      3          1     research_scientist
# 291                       2          3        sales_executive
# 577                       2          1  laboratory_technician
# 1539                      3          1  laboratory_technician
# 691                       3          1     research_scientist
# 645                       3          1     research_scientist
# 1468                      3          1   sales_representative
# 860                       3          2        sales_executive
# 741                       3          1     research_scientist
# 1365                      3          2        sales_executive
#
#       job_satisfaction_level marital_status  monthly_income  monthly_rate  \
# 1233                       4            nan             NaN       6090.75
# 291                        4         single         8339.32      21682.23
# 577                        2            nan         2342.59       6090.75
# 1539                       1        married             NaN       6090.75
# 691                        2         single             NaN       6090.75
# 645                        2        married             NaN       8528.00
# 1468                       1        married         2342.59       6090.75
# 860                        4       divorced             NaN      15017.17
# 741                        3       divorced             NaN       5453.50
# 1365                       3         single             NaN      10244.00
#
#       num_companies_worked over_18  percent_salary_hike  \
# 1233                     2    None                   16
# 291                      6    None                   12
# 577                      0    None                   11
# 1539                     5    None                   13
# 691                      1    None                   12
# 645                      1    None                   11
# 1468                     1    None                   19
# 860                      2    None                   14
# 741                      1    None                   11
# 1365                     3    None                   14
#
#       relationship_satisfaction_level  stock_option_level  \
# 1233                                1                   1
# 291                                 4                   0
# 577                                 2                   0
# 1539                                3                   1
# 691                                 2                   0
# 645                                 1                   1
# 1468                                1                   1
# 860                                 4                   1
# 741                                 2                   3
# 1365                                4                   0
#
#       training_sessions_last_year  years_at_company  \
# 1233                            2                 2
# 291                             2                19
# 577                             2                 5
# 1539                            5                 2
# 691                             2                 4
# 645                             2                 8
# 1468                            3                 1
# 860                             2                 3
# 741                             2                 5
# 1365                            4                 0
#
#       years_since_last_promotion  years_with_current_manager  birth_year  \
# 1233                           2                           0        1999
# 291                           12                           8        1978
# 577                            1                           4        1992
# 1539                           0                           2        1998
# 691                            1                           2        1996
# 645                            7                           7        1986
# 1468                           1                           0        2000
# 860                            0                           2        1994
# 741                            0                           3        1996
# 1365                           0                           0        1973
#
#      overtime_hours  performance_rating standard_work_hours  \
# 1233            yes                   3           part_time
# 291            none                   3           part_time
# 577              no                   3           part_time
# 1539             no                   3           part_time
# 691            none                   3           part_time
# 645            none                   3           full_time
# 1468             no                   3                none
# 860              no                   3           full_time
# 741            none                   3           part_time
# 1365            yes                   3           part_time
#
#       total_years_worked  work_life_balance  same_as_monthly_income  \
# 1233                   6               <NA>                     NaN
# 291                   23                  3                 8339.32
# 577                 <NA>                  4                 2342.59
# 1539                   6               <NA>                     NaN
# 691                    4               <NA>                     NaN
# 645                    8                  1                     NaN
# 1468                <NA>               <NA>                 2342.59
# 860                 <NA>                  3                     NaN
# 741                 <NA>               <NA>                     NaN
# 1365                   5                  3                     NaN
#
#       annual_salary remote_work
# 1233       28111.13          no
# 291       100071.84         yes
# 577        28111.13         yes
# 1539       28111.13         yes
# 691        28111.13         yes
# 645        39360.00          no
# 1468            NaN          no
# 860        69310.00          no
# 741        25170.00         yes
# 1365       47280.00         yes

# %% [markdown]
# GUARDAMOS EL DATAFRAME FINAL

# %%
# Guardamos el DataFrame limpio en un archivo CSV
df_final.to_csv('cleaned_data.csv', index=False)
