# %%
#Directorio actual de trabajo

import os
import pandas as pd

# Muestra el directorio de trabajo actual
print("Directorio actual de trabajo:", os.getcwd())
# Out:
# Directorio actual de trabajo: /home/sara-arranz/ADALAB/MÓDULO 2. APIs + SQL/PROYECTO/da-project-promo-49-modulo-2-team-4/FASE 2. CONVERSIÓN CSV/Archivos CSV SPOTIPY/2022

# %%
df1=pd.read_csv("/home/sara-arranz/ADALAB/MÓDULO 2. APIs + SQL/PROYECTO/da-project-promo-49-modulo-2-team-4/FASE 2. CONVERSIÓN CSV/Archivos CSV SPOTIPY/2022/indie2022.csv")

# %%
df1
# Out:
#      Unnamed: 0                             track_name  \
# 0             0                          Sin Vergüenza
# 1             1  Que nada nos pare (lo más importante)
# 2             2                                El Bien
# 3             3                No Hemos Aprendido Nada
# 4             4                       End of Beginning
# ..          ...                                    ...
# 495         495                               Tumblin'
# 496         496                              Halloween
# 497         497                            Underground
# 498         498                         Out of My Head
# 499         499                                Greener
#
#                      artist_name release_date                id_track  \
# 0    Arde Bogotá, Dani Fernández   2022-07-07  0mJ2qmDI2X4wrSIIBrvvpN
# 1        ELYELLA, La La Love You   2022-06-30  1FG7ZjnuT0O9CsDKOxND0E
# 2                    Viva Suecia   2022-10-06  6IuZFiKCeyQINqL0Id3xF2
# 3                    Viva Suecia   2022-10-06  23EYaP0VXowC6oT9DiY3QR
# 4                            Djo   2022-09-16  3qhlB30KknSejmIvZZLjOD
# ..                           ...          ...                     ...
# 495    The California Honeydrops   2022-10-07  53XMmw6emHn2NLt4YPPgPi
# 496                   Noah Kahan   2022-10-14  5aeQMQDWe64gVnVYSOqW6A
# 497                     Cody Fry   2022-01-21  6bU3RDOTuXynFSx3xWSdKq
# 498                First Aid Kit   2022-11-04  5LgguaX9k42ruNIHNZA6Re
# 499          FKJ, Carlos Santana   2022-06-10  1PZQtsLX6FKzqJ0jtFt7oO
#
#      popularity genero
# 0            59  indie
# 1            58  indie
# 2            58  indie
# 3            56  indie
# 4            85  indie
# ..          ...    ...
# 495          46  indie
# 496          54  indie
# 497          51  indie
# 498          48  indie
# 499          42  indie
#
# [500 rows x 7 columns]

# %%
df2=pd.read_csv("/home/sara-arranz/ADALAB/MÓDULO 2. APIs + SQL/PROYECTO/da-project-promo-49-modulo-2-team-4/FASE 2. CONVERSIÓN CSV/Archivos CSV SPOTIPY/2022/pop2022.csv")

# %%
df2
# Out:
#      Unnamed: 0                             track_name  \
# 0             0  Quevedo: Bzrp Music Sessions, Vol. 52
# 1             1                             La Bachata
# 2             2                            Quién Diría
# 3             3                   Las Cosas Pequeñitas
# 4             4                          Sin Vergüenza
# ..          ...                                    ...
# 495         495         Alleluia (feat. Sfera Ebbasta)
# 496         496                        Please Don't Go
# 497         497                               5 Foot 9
# 498         498                              Ochii Tai
# 499         499                          L'anima balla
#
#                      artist_name release_date                id_track  \
# 0              Bizarrap, Quevedo   2022-07-06  2tTmW7RDtMQtBk7m2rYeSw
# 1                  Manuel Turizo   2022-05-26  5ww2BF9slyYgNOk37BlC4u
# 2                          DePol   2022-04-08  0Fd3900xH77g0ARXQjtYvV
# 3                   Marta Santos   2022-04-22  5LU8Lk8uSCdMgBaqcTujmi
# 4    Arde Bogotá, Dani Fernández   2022-07-07  0mJ2qmDI2X4wrSIIBrvvpN
# ..                           ...          ...                     ...
# 495         Shiva, Sfera Ebbasta   2022-11-25  1MboxS3hV7Wr8UVO59uRth
# 496                 Wyatt Flores   2022-07-15  7fb4Qp5YoT4BKFdbj1Xu8r
# 497                Tyler Hubbard   2022-05-20  6AqwH2Y9FJwhUE2dCSkw1u
# 498                 Luis Gabriel   2022-04-05  0frrqHWRsmuM1f6T02VkoY
# 499                   Olly, JVLI   2022-12-16  0cLOSiqHFDQHbQbJnwpP7z
#
#      popularity genero
# 0            76    pop
# 1            74    pop
# 2            61    pop
# 3            61    pop
# 4            59    pop
# ..          ...    ...
# 495          53    pop
# 496          70    pop
# 497          61    pop
# 498          39    pop
# 499          55    pop
#
# [500 rows x 7 columns]

# %%
df3=pd.read_csv("/home/sara-arranz/ADALAB/MÓDULO 2. APIs + SQL/PROYECTO/da-project-promo-49-modulo-2-team-4/FASE 2. CONVERSIÓN CSV/Archivos CSV SPOTIPY/2022/rap2022.csv")

# %%
df3
# Out:
#      Unnamed: 0                                         track_name  \
# 0             0                                  Flow 2000 - Remix
# 1             1  Cayó La Noche (feat. Cruz Cafuné, Abhir Hathi,...
# 2             2                                            Lo Real
# 3             3                                   Barquito de Vela
# 4             4                                 7 Lágrimas - Remix
# ..          ...                                                ...
# 495         495                    Never Hating (feat. Young Thug)
# 496         496                                         Complicado
# 497         497                            You Wouldn't Understand
# 498         498                                              Marie
# 499         499                                        Knock Knock
#
#                                            artist_name release_date  \
# 0                                    Bad Gyal, Beny Jr   2022-03-17
# 1    La Pantera, Quevedo, Juseph, ABHIR, BEJO, Cruz...   2022-01-14
# 2                               Hard GZ, Nikone, Dualy   2022-03-24
# 3                                    Hard GZ, Antony Z   2022-05-06
# 4                        Soge Culebra, Mora, GARABATTO   2022-02-18
# ..                                                 ...          ...
# 495                               Lil Baby, Young Thug   2022-10-14
# 496                      Gera MX, Jayrick, Ervin River   2022-08-24
# 497                                         Juice WRLD   2022-03-18
# 498                                      Sleepy Hallow   2022-11-02
# 499                                    Tion Wayne, M24   2022-02-17
#
#                    id_track  popularity genero
# 0    7fRtruULHGuwC0wNRx1HSa          62    rap
# 1    0Bv7O6fmZk3GrNQFYJaXPn          62    rap
# 2    6ei0W4T1vFScCTM3UuLrIr          55    rap
# 3    09p2nomOAPyylPjRg1gzH0          55    rap
# 4    3wlX0yg6NRMDPwOvdPmuLn          62    rap
# ..                      ...         ...    ...
# 495  1Py8c3dkLF0YczcAyBFBEM          57    rap
# 496  3eGpyKNSwZH2E738CjK9w1          57    rap
# 497  0veO6y9anwdVTaRuW7y8NJ          56    rap
# 498  1pnwc4c5qjgxr2tVdSU4C5          56    rap
# 499  4EmzSqaqpv663TP3VvqCa9          46    rap
#
# [500 rows x 7 columns]

# %%
df4=pd.read_csv("/home/sara-arranz/ADALAB/MÓDULO 2. APIs + SQL/PROYECTO/da-project-promo-49-modulo-2-team-4/FASE 2. CONVERSIÓN CSV/Archivos CSV SPOTIPY/2022/reggaeton2022.csv")

# %%
df4
# Out:
#      Unnamed: 0               track_name                   artist_name  \
# 0             0               La Bachata                 Manuel Turizo
# 1             1            Ojitos Lindos      Bad Bunny, Bomba Estéreo
# 2             2  Feliz Cumpleaños Ferxxo                          Feid
# 3             3                  Hey Mor                   Ozuna, Feid
# 4             4              Moscow Mule                     Bad Bunny
# ..          ...                      ...                           ...
# 495         495    Los Hombres No Lloran                         Cazzu
# 496         496                  Armería                         Alejo
# 497         497            Tacones Rojos  Sebastian Yatra, John Legend
# 498         498                Exclusive                        Blessd
# 499         499                  Un Reel                   Ozuna, TINI
#
#     release_date                id_track  popularity     genero
# 0     2022-05-26  5ww2BF9slyYgNOk37BlC4u          73  reggaeton
# 1     2022-05-06  3k3NWokhRRkEPhCzPmV8TW          78  reggaeton
# 2     2022-09-14  2CeKVsFFXG4QzA415QygGb          77  reggaeton
# 3     2022-10-07  1zsPaEkglFvxjAhrM8yhpr          73  reggaeton
# 4     2022-05-06  6Xom58OOXk2SoU711L2IXO          76  reggaeton
# ..           ...                     ...         ...        ...
# 495   2022-05-30  7jzMyl5FmJWNnYsoRn4Sg5          44  reggaeton
# 496   2022-06-22  6BOQweIUz2y3RSzhNs311H          25  reggaeton
# 497   2022-07-29  4slJBQR5P1JjEH9HFkB1Tg          34  reggaeton
# 498   2022-11-03  73lC7gD1EKomxcuXRn7qRR          42  reggaeton
# 499   2022-10-07  5br09BQU134gRX5M6HMnmr          34  reggaeton
#
# [500 rows x 7 columns]

# %%
result = pd.concat([df1, df2, df3,df4], ignore_index=False)

# %%
result
# Out:
#      Unnamed: 0                             track_name  \
# 0             0                          Sin Vergüenza
# 1             1  Que nada nos pare (lo más importante)
# 2             2                                El Bien
# 3             3                No Hemos Aprendido Nada
# 4             4                       End of Beginning
# ..          ...                                    ...
# 495         495                  Los Hombres No Lloran
# 496         496                                Armería
# 497         497                          Tacones Rojos
# 498         498                              Exclusive
# 499         499                                Un Reel
#
#                       artist_name release_date                id_track  \
# 0     Arde Bogotá, Dani Fernández   2022-07-07  0mJ2qmDI2X4wrSIIBrvvpN
# 1         ELYELLA, La La Love You   2022-06-30  1FG7ZjnuT0O9CsDKOxND0E
# 2                     Viva Suecia   2022-10-06  6IuZFiKCeyQINqL0Id3xF2
# 3                     Viva Suecia   2022-10-06  23EYaP0VXowC6oT9DiY3QR
# 4                             Djo   2022-09-16  3qhlB30KknSejmIvZZLjOD
# ..                            ...          ...                     ...
# 495                         Cazzu   2022-05-30  7jzMyl5FmJWNnYsoRn4Sg5
# 496                         Alejo   2022-06-22  6BOQweIUz2y3RSzhNs311H
# 497  Sebastian Yatra, John Legend   2022-07-29  4slJBQR5P1JjEH9HFkB1Tg
# 498                        Blessd   2022-11-03  73lC7gD1EKomxcuXRn7qRR
# 499                   Ozuna, TINI   2022-10-07  5br09BQU134gRX5M6HMnmr
#
#      popularity     genero
# 0            59      indie
# 1            58      indie
# 2            58      indie
# 3            56      indie
# 4            85      indie
# ..          ...        ...
# 495          44  reggaeton
# 496          25  reggaeton
# 497          34  reggaeton
# 498          42  reggaeton
# 499          34  reggaeton
#
# [2000 rows x 7 columns]

# %%
result.to_csv("total_2022_Spotipy.csv")
