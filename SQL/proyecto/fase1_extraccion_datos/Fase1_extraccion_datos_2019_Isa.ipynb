# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import requests
import re
import pandas as pd

# %%
# Coloca tus credenciales aquí
CLIENT_ID = '00b3c07cbf3b41fe80275bf332b3ca96'
CLIENT_SECRET = '10e9e68a55f341c292dbd38c6349f314'

# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)
try:
    sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET))
    print("✅ Autenticación correcta")
except Exception as e:
    print(f"❌ Error de autenticación: {e}")
# Out:
# ✅ Autenticación correcta

# %%
def rastreo_global(year, limit=50, market='ES', max_results=500):
    
    generos = ['reggaeton', 'pop', 'rap', 'indie']
    resultados_por_genero = {}

    # Iterar por los géneros
    for genero in generos:
        print(f"Buscando canciones del género {genero}...")

        datos = []  # Lista donde almacenaremos los resultados
        offset = 0  # Para la paginación
        
        while len(datos) < max_results:
            # Realizar la búsqueda en Spotify por género y año
            query = f"genre:{genero} year:{year}"
            busqueda = sp.search(q=query, limit=limit, offset=offset, type='track', market=market)
            
            # Obtener los resultados
            items = busqueda['tracks']['items']
            
            # Si no hay más resultados, salir del bucle
            if not items:
                break

            # Procesar los resultados
            for item in items:
                track_info = {
                    'track_name': item['name'],
                    'artist_name': ', '.join([artist['name'] for artist in item['artists']]),  # Todos los artistas
                    'release_date': item['album']['release_date'],
                    'id_track': item['id'],
                    'popularity': item['popularity'],
                    'genero': genero  # Añadimos el género
                }
                datos.append(track_info)

                # Si alcanzamos el máximo de resultados, detenemos la búsqueda
                if len(datos) >= max_results:
                    break

            # Aumentamos el offset para la siguiente paginación
            offset += limit
        
        # Almacenamos los resultados de este género en el diccionario
        resultados_por_genero[genero] = datos

    return resultados_por_genero

# %%
resultados = rastreo_global (year = 2019)
# Out:
# Buscando canciones del género reggaeton...
# Buscando canciones del género pop...
# Buscando canciones del género rap...
# Buscando canciones del género indie...

# %%
df_resultados_reggaeton = pd.DataFrame (resultados ['reggaeton'])
df_resultados_reggaeton
# Out:
#                    track_name  \
# 0        No Me Conoce - Remix
# 1                  LA CANCIÓN
# 2           El Efecto - Remix
# 3                        Loco
# 4                   Me Rehúso
# ..                        ...
# 495                   Es Poco
# 496  badwine - Extended Remix
# 497         Malas Intenciones
# 498           Ven Pa Casa_RGT
# 499           Vamos a Prender
#
#                                            artist_name release_date  \
# 0                          JHAYCO, J Balvin, Bad Bunny   2019-05-24
# 1                                  J Balvin, Bad Bunny   2019-06-28
# 2    Rauw Alejandro, Chencho Corleone, KEVVO, Bryan...   2019-12-13
# 3                                                Beéle   2019-08-08
# 4                                          Danny Ocean   2019-03-22
# ..                                                 ...          ...
# 495                      Simon la Letra, Pablo Chill-E   2019-11-23
# 496              Feid, Farruko, El Alfa, Lenny Tavárez   2019-10-18
# 497                                              Lunay   2019-10-25
# 498                                               Feid   2019-05-17
# 499                                         Marvel Boy   2019-07-26
#
#                    id_track  popularity     genero
# 0    2beS6dD5rovBxSA1zYoSHR          78  reggaeton
# 1    0fea68AdmYNygeTGI4RC18          81  reggaeton
# 2    74j34STf8L6uADnTN69ohv          68  reggaeton
# 3    2J9B63FawlTaPdg4eH5X03          73  reggaeton
# 4    6ifUES3keWjwXgae8pXI3o          76  reggaeton
# ..                      ...         ...        ...
# 495  3GUegYmafTYS8azWF7s5Uq          56  reggaeton
# 496  44DCGBt8P6iZPd0RRsZiMw          37  reggaeton
# 497  4FWhPJjc9FMRCCFc038uEz          31  reggaeton
# 498  35dra2TxXnhMdDQaAkXs6S          37  reggaeton
# 499  1Xl8nku7yxv2ewWhHgvxbZ          35  reggaeton
#
# [500 rows x 6 columns]

# %%
df_resultados_pop = pd.DataFrame (resultados ['pop'])
df_resultados_pop
# Out:
#                            track_name  \
# 0                   El Efecto - Remix
# 1       Como Si Fueras a Morir Mañana
# 2                            Bailemos
# 3                           Me Rehúso
# 4                           El Efecto
# ..                                ...
# 495                   Moi, je prouve.
# 496  Song Request (feat. SUGA of BTS)
# 497                         Same Beef
# 498                            Simple
# 499                CRUDELIA - I nervi
#
#                                            artist_name release_date  \
# 0    Rauw Alejandro, Chencho Corleone, KEVVO, Bryan...   2019-12-13
# 1                                                Leiva   2019-03-22
# 2                                       Dani Fernández   2019-05-24
# 3                                          Danny Ocean   2019-03-22
# 4                     Rauw Alejandro, Chencho Corleone   2019-03-15
# ..                                                 ...          ...
# 495                                 Tayc, Barack Adama   2019-12-13
# 496                                    Lee So Ra, SUGA   2019-01-22
# 497                          Bohemia, Sidhu Moose Wala   2019-09-18
# 498                               Florida Georgia Line   2019-02-15
# 499                                          Marracash   2019-10-31
#
#                    id_track  popularity genero
# 0    74j34STf8L6uADnTN69ohv          68    pop
# 1    4aAfLSx9IthpC3Pw5pNk3E          59    pop
# 2    5EnaxC9amhXY55ezw87SL8          58    pop
# 3    6ifUES3keWjwXgae8pXI3o          76    pop
# 4    4SJHHpKhcuXwDsCsPqshXj          74    pop
# ..                      ...         ...    ...
# 495  3EF6LVr4vCyxu66HBe8pGO          53    pop
# 496  6Au7CCNN2wXgCNxdavgxDM          50    pop
# 497  65c6VCikt7f5sAS1heoYQC          66    pop
# 498  4L9Ds4mpD3SuYoWwFUlv16          64    pop
# 499  0xEgDBXYO9gGzmxCFWKxNg          61    pop
#
# [500 rows x 6 columns]

# %%
df_resultados_rap = pd.DataFrame (resultados ['rap'])
df_resultados_rap
# Out:
#                                track_name                   artist_name  \
# 0    Contando Lunares (feat. Cruz Cafuné)     Don Patricio, Cruz Cafuné
# 1                     HIGHEST IN THE ROOM                  Travis Scott
# 2                                  Ransom                     Lil Tecca
# 3                      Dembow y Reggaeton  El Alfa, Yandel, Myke Towers
# 4                              La Placita    Delaossa, EAZYBOI, J.Moods
# ..                                    ...                           ...
# 495                          La Luna Sabe                La Santa Grifa
# 496                      MADAME - L'anima             Marracash, Madame
# 497                        Ne reviens pas       Gradur, Heuss L'enfoiré
# 498                   Stick to the Models                        Future
# 499                            The Motion                         Drake
#
#     release_date                id_track  popularity genero
# 0     2019-01-27  6uW0PIRcyZLvkoonm763xD          61    rap
# 1     2019-10-04  3eekarcy7kvN4yt5ZFzltW          81    rap
# 2     2019-08-30  1lOe9qE0vR9zwWQAOk6CoO          82    rap
# 3     2019-08-02  3OB01aM0Nf7tWds1TLEL3j          61    rap
# 4     2019-07-19  5ZmmNBKHKLDureKMGrRHCJ          53    rap
# ..           ...                     ...         ...    ...
# 495   2019-12-03  09qJ4Mg46EmCp3P7w7YFEz          57    rap
# 496   2019-10-31  0uAnrNNITY7KwmOqdVEsIK          57    rap
# 497   2019-11-21  0kp0ovTvyYUdoexEt7AcoL          47    rap
# 498   2019-01-18  0F7FlaQBiyNkV8iakTocsW          53    rap
# 499   2019-08-02  0Tacxc5lDJ8LwiO1pWNSl8          57    rap
#
# [500 rows x 6 columns]

# %%
df_resultados_indie = pd.DataFrame (resultados ['indie'])
df_resultados_indie
# Out:
#                           track_name                 artist_name release_date  \
# 0      Como Si Fueras a Morir Mañana                       Leiva   2019-03-22
# 1                  Lo Que Te Mereces                 Viva Suecia   2019-10-04
# 2             No Te Preocupes por Mi                       Leiva   2019-03-22
# 3                       Serem Ocells               Oques Grasses   2019-02-08
# 4                                Cry        Cigarettes After Sex   2019-10-25
# ..                               ...                         ...          ...
# 495  Freefall (feat. Durand Bernarr)  KAYTRANADA, Durand Bernarr   2019-12-13
# 496                Prefiero No Saber               Los Mesoneros   2019-09-27
# 497                         Orbitron                      Duster   2019-03-22
# 498                            small                     sundots   2019-12-06
# 499                            Naeem                    Bon Iver   2019-08-09
#
#                    id_track  popularity genero
# 0    4aAfLSx9IthpC3Pw5pNk3E          59  indie
# 1    1m64wK0vr8OaviUWuIfncH          54  indie
# 2    7hv7synVPhVu30Ex2amJQc          52  indie
# 3    1OhTU9Vr08VrEAa0kJ98u8          51  indie
# 4    3p4hRhMcb6ch8OLtATMaLw          83  indie
# ..                      ...         ...    ...
# 495  2flqiTbuPeDZXxgEW67rxw          55  indie
# 496  1ihvIJGtSCKytYPWlzzDV4          40  indie
# 497  5uGI2hG03LVWU0rrBirOw6          55  indie
# 498  7cEUiQ4Wc2JpU9tkzrYqfv          58  indie
# 499  0XOsqpvDLx0FhizUCqwSNf          44  indie
#
# [500 rows x 6 columns]

# %%
df_resultados_indie.to_csv("indie2019.csv")

# %%
df_resultados_pop.to_csv("pop2019.csv")

# %%
df_resultados_rap.to_csv("rap2019.csv")

# %%
df_resultados_reggaeton.to_csv("reggaeton2019.csv")
