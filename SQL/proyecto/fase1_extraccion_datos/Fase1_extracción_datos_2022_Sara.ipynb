# %%
import requests
import re
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Coloca tus credenciales aquí
CLIENT_ID = "9af49838e1b74e169724be1ab629e364"
CLIENT_SECRET = "33372bda1f89408abd8a1c9cfcc7804f"

# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
def rastreo_global(year, limit=50, market='ES', max_results=500):
    """
    Realiza una búsqueda global de canciones de un género en Spotify.
    
    :param year: Año de lanzamiento de las canciones.
    :param limit: Número de canciones por solicitud (máx. 50).
    :param market: Mercado (por defecto 'ES').
    :param max_results: Número total de resultados deseados.
    :return: Lista de canciones con información relevante.
    """
    
    generos = ['reggaeton', 'pop', 'rap', 'indie']
    resultados_por_genero = {}

    # Iterar sobre los géneros
    for genero in generos:
        print(f"Buscando canciones del género {genero}...")

        datos = []  # Lista donde almacenaremos los resultados
        offset = 0  # Para la paginación
        
        while len(datos) < max_results:
            # Realizar la búsqueda en Spotify por género y año
            query = f"genre:{genero} year:{year}"
            busqueda = sp.search(q=query, limit=limit, offset=offset, type='track', market=market)
            
            # Obtener los resultados
            items = busqueda['tracks']['items']
            
            # Si no hay más resultados, salir del bucle
            if not items:
                break

            # Procesar los resultados
            for item in items:
                track_info = {
                    'track_name': item['name'],
                    'artist_name': ', '.join([artist['name'] for artist in item['artists']]),  # Todos los artistas
                    'release_date': item['album']['release_date'],
                    'id_track': item['id'],
                    'popularity': item['popularity'],
                    'genero': genero  # Añadimos el género
                }
                datos.append(track_info)

                # Si alcanzamos el máximo de resultados, detenemos la búsqueda
                if len(datos) >= max_results:
                    break

            # Aumentamos el offset para la siguiente paginación
            offset += limit
        
        # Almacenamos los resultados de este género en el diccionario
        resultados_por_genero[genero] = datos

    return resultados_por_genero

# %%
resultados = rastreo_global (year = 2022)
# Out:
# Buscando canciones del género reggaeton...
# Buscando canciones del género pop...
# Buscando canciones del género rap...
# Buscando canciones del género indie...

# %%
resultados
# Out:
# {'reggaeton': [{'track_name': 'La Bachata',
#    'artist_name': 'Manuel Turizo',
#    'release_date': '2022-05-26',
#    'id_track': '5ww2BF9slyYgNOk37BlC4u',
#    'popularity': 73,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ojitos Lindos',
#    'artist_name': 'Bad Bunny, Bomba Estéreo',
#    'release_date': '2022-05-06',
#    'id_track': '3k3NWokhRRkEPhCzPmV8TW',
#    'popularity': 78,
#    'genero': 'reggaeton'},
#   {'track_name': 'Feliz Cumpleaños Ferxxo',
#    'artist_name': 'Feid',
#    'release_date': '2022-09-14',
#    'id_track': '2CeKVsFFXG4QzA415QygGb',
#    'popularity': 77,
#    'genero': 'reggaeton'},
#   {'track_name': 'Hey Mor',
#    'artist_name': 'Ozuna, Feid',
#    'release_date': '2022-10-07',
#    'id_track': '1zsPaEkglFvxjAhrM8yhpr',
#    'popularity': 73,
#    'genero': 'reggaeton'},
#   {'track_name': 'Moscow Mule',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2022-05-06',
#    'id_track': '6Xom58OOXk2SoU711L2IXO',
#    'popularity': 76,
#    'genero': 'reggaeton'},
#   {'track_name': 'Normal',
#    'artist_name': 'Feid',
#    'release_date': '2022-09-14',
#    'id_track': '0T2pB7P1VdXPhLdQZ488uH',
#    'popularity': 75,
#    'genero': 'reggaeton'},
#   {'track_name': 'Enséñame a Bailar',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2022-05-06',
#    'id_track': '2NMjggapJcXXM7WccGEBUO',
#    'popularity': 72,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tarot',
#    'artist_name': 'Bad Bunny, JHAYCO',
#    'release_date': '2022-05-06',
#    'id_track': '41oY4WCTj5kccfesTVFnvN',
#    'popularity': 73,
#    'genero': 'reggaeton'},
#   {'track_name': 'Me Porto Bonito',
#    'artist_name': 'Bad Bunny, Chencho Corleone',
#    'release_date': '2022-05-06',
#    'id_track': '6Sq7ltF9Qa7SNFBsV5Cogx',
#    'popularity': 77,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tití Me Preguntó',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2022-05-06',
#    'id_track': '1IHWl5LamUGEuP4ozKQSXZ',
#    'popularity': 77,
#    'genero': 'reggaeton'},
#   {'track_name': '¿Qué Nos Pasó?',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-05-26',
#    'id_track': '7k3qWn8D43a5ISa3x8lJux',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'CHORRITO PA LAS ANIMAS',
#    'artist_name': 'Feid',
#    'release_date': '2022-12-02',
#    'id_track': '0CYTGMBYkwUxrj1MWDLrC5',
#    'popularity': 72,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ferxxo 100',
#    'artist_name': 'Feid',
#    'release_date': '2022-09-14',
#    'id_track': '1sbNEFiURUYfy024cJX8JG',
#    'popularity': 72,
#    'genero': 'reggaeton'},
#   {'track_name': 'Pareja Del Año',
#    'artist_name': 'Sebastian Yatra, Myke Towers',
#    'release_date': '2022-01-28',
#    'id_track': '655JkvIwu2rDCaD1hPf04g',
#    'popularity': 70,
#    'genero': 'reggaeton'},
#   {'track_name': 'Volare',
#    'artist_name': 'Danny Ocean',
#    'release_date': '2022-11-10',
#    'id_track': '7nE9H4e4uPOis5sJY39fOc',
#    'popularity': 72,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tacones Rojos',
#    'artist_name': 'Sebastian Yatra',
#    'release_date': '2022-01-28',
#    'id_track': '6ylDpki1VpIsc525KC1ojF',
#    'popularity': 69,
#    'genero': 'reggaeton'},
#   {'track_name': 'Efecto',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2022-05-06',
#    'id_track': '5Eax0qFko2dh7Rl2lYs3bx',
#    'popularity': 75,
#    'genero': 'reggaeton'},
#   {'track_name': 'Quiero Decirte',
#    'artist_name': 'Abraham Mateo, Ana Mena',
#    'release_date': '2022-05-12',
#    'id_track': '7dT6ccDqmMHvz5C0d8iUND',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Jumpa',
#    'artist_name': 'Arcángel, Bad Bunny',
#    'release_date': '2022-11-30',
#    'id_track': '5MxFWjuqQIsbNWbMdMdbli',
#    'popularity': 67,
#    'genero': 'reggaeton'},
#   {'track_name': 'Besos Moja2',
#    'artist_name': 'Wisin & Yandel, ROSALÍA',
#    'release_date': '2022-12-01',
#    'id_track': '6OzUIp8KjuwxJnCWkXp1uL',
#    'popularity': 65,
#    'genero': 'reggaeton'},
#   {'track_name': 'Un Coco',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2022-05-06',
#    'id_track': '6VrQTLzzuyGIYjUDe4kAZk',
#    'popularity': 73,
#    'genero': 'reggaeton'},
#   {'track_name': 'Dharma',
#    'artist_name': 'Sebastian Yatra, Jorge Celedón, Rosario',
#    'release_date': '2022-01-28',
#    'id_track': '5tpAcJ47UgF4udM5YXcDd2',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'Neverita',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2022-05-06',
#    'id_track': '31i56LZnwE6uSu3exoHjtB',
#    'popularity': 72,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Llevo Al Cielo (Ft. Ñengo Flow)',
#    'artist_name': 'Chris Jedi, Anuel AA, Chencho Corleone, Ñengo Flow',
#    'release_date': '2022-05-20',
#    'id_track': '6DoL1yYIwEW7VZMRaJhoJI',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': 'Callaita',
#    'artist_name': 'Bad Bunny, Tainy',
#    'release_date': '2022-05-06',
#    'id_track': '71wFwRo8xGc4lrcyKwsvba',
#    'popularity': 71,
#    'genero': 'reggaeton'},
#   {'track_name': 'Yandel 150',
#    'artist_name': 'Yandel, Feid',
#    'release_date': '2022-12-20',
#    'id_track': '2oiixB9QMIzhWaHGVlQx4g',
#    'popularity': 65,
#    'genero': 'reggaeton'},
#   {'track_name': 'MAMIII',
#    'artist_name': 'Becky G, KAROL G',
#    'release_date': '2022-05-13',
#    'id_track': '7FlQk2gJ6TBrHHiidvdR2O',
#    'popularity': 69,
#    'genero': 'reggaeton'},
#   {'track_name': 'Otro Atardecer',
#    'artist_name': 'Bad Bunny, The Marías',
#    'release_date': '2022-05-06',
#    'id_track': '0E0DRHf5PfMeor0ZCwB3oT',
#    'popularity': 74,
#    'genero': 'reggaeton'},
#   {'track_name': 'Pantysito',
#    'artist_name': 'Alejo, Feid, ROBI',
#    'release_date': '2022-03-18',
#    'id_track': '4srcMdbm2qzVG98tJajHxp',
#    'popularity': 64,
#    'genero': 'reggaeton'},
#   {'track_name': 'Dos Mil 16',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2022-05-06',
#    'id_track': '4d4ZXH4dr5bYfgErHiZCX2',
#    'popularity': 70,
#    'genero': 'reggaeton'},
#   {'track_name': 'PROVENZA',
#    'artist_name': 'KAROL G',
#    'release_date': '2022-04-22',
#    'id_track': '7dSZ6zGTQx66c2GF91xCrb',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'Si Te La Encuentras Por Ahí',
#    'artist_name': 'Feid',
#    'release_date': '2022-09-14',
#    'id_track': '2vsoD8S1OyrWSVIA43hjaU',
#    'popularity': 64,
#    'genero': 'reggaeton'},
#   {'track_name': 'Hola - Remix',
#    'artist_name': 'Dalex, Lenny Tavárez, Chencho Corleone, Juhn, Dímelo Flow',
#    'release_date': '2022-02-09',
#    'id_track': '17I27VXKtqXJHL6ReaG0eS',
#    'popularity': 69,
#    'genero': 'reggaeton'},
#   {'track_name': 'Andrea',
#    'artist_name': 'Bad Bunny, Buscabulla',
#    'release_date': '2022-05-06',
#    'id_track': '44XjoNvtwevktFKjvVe1vH',
#    'popularity': 72,
#    'genero': 'reggaeton'},
#   {'track_name': 'Chica Ideal',
#    'artist_name': 'Sebastian Yatra, Guaynaa',
#    'release_date': '2022-01-28',
#    'id_track': '4lCpamtFAIUga83gTKP8RY',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': 'MAMIII',
#    'artist_name': 'Becky G, KAROL G',
#    'release_date': '2022-02-10',
#    'id_track': '1ri9ZUkBJVFUdgwzCnfcYs',
#    'popularity': 65,
#    'genero': 'reggaeton'},
#   {'track_name': 'Me Fui de Vacaciones',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2022-05-06',
#    'id_track': '28GCbKgjlVD9eDmasGbe0T',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Corriente',
#    'artist_name': 'Bad Bunny, Tony Dize',
#    'release_date': '2022-05-06',
#    'id_track': '1797zYiX4cKosMH836X9Gt',
#    'popularity': 70,
#    'genero': 'reggaeton'},
#   {'track_name': 'Suelta',
#    'artist_name': 'Jay Wheeler, Mora',
#    'release_date': '2022-08-19',
#    'id_track': '5LitdykQszEnuzIrtGhwPs',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Un Ratito',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2022-05-06',
#    'id_track': '5CzixCxDkRXX9mScCmah8O',
#    'popularity': 70,
#    'genero': 'reggaeton'},
#   {'track_name': 'Prohibidox',
#    'artist_name': 'Feid',
#    'release_date': '2022-09-14',
#    'id_track': '3PpWCS95gDUDRPko3u1MZ9',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'Aguacero',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2022-05-06',
#    'id_track': '2uflssWlCaJ6CbTMOsUpNI',
#    'popularity': 69,
#    'genero': 'reggaeton'},
#   {'track_name': 'Yo No Soy Celoso',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2022-05-06',
#    'id_track': '5kVZxyMY1gfdCLiChsfjn1',
#    'popularity': 69,
#    'genero': 'reggaeton'},
#   {'track_name': 'Agosto',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2022-05-06',
#    'id_track': '0wihfILRNOwE2156Shezc8',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Jumpa',
#    'artist_name': 'Arcángel, Bad Bunny',
#    'release_date': '2022-12-01',
#    'id_track': '2mnXxnrX5vCGolNkaFvVeM',
#    'popularity': 64,
#    'genero': 'reggaeton'},
#   {'track_name': 'Monstruo',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '7eDVXAFMt2EERfXy9i63T1',
#    'popularity': 61,
#    'genero': 'reggaeton'},
#   {'track_name': 'Le Pido a DIOS',
#    'artist_name': 'Feid, DJ Premier',
#    'release_date': '2022-12-02',
#    'id_track': '4TFNKnMWjcMWzpkSwQrrcu',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': 'Party',
#    'artist_name': 'Bad Bunny, Rauw Alejandro',
#    'release_date': '2022-05-06',
#    'id_track': '4tYFy8ALRjIZvnvSLw5lxN',
#    'popularity': 70,
#    'genero': 'reggaeton'},
#   {'track_name': 'Toda - Remix',
#    'artist_name': 'Alex Rose, Rauw Alejandro, Lenny Tavárez, Cazzu, Lyanno',
#    'release_date': '2022-06-09',
#    'id_track': '5kCoykriGdZhWMlm9vrtQI',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': 'Instagram',
#    'artist_name': 'Blessd',
#    'release_date': '2022-04-07',
#    'id_track': '0EFxJw34fK8DWlTxx9qYeW',
#    'popularity': 69,
#    'genero': 'reggaeton'},
#   {'track_name': 'Si Te La Encuentras Por Ahí',
#    'artist_name': 'Feid',
#    'release_date': '2022-08-05',
#    'id_track': '02jLfqc9gMo8PkHEGHY3OT',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'RUMBATÓN',
#    'artist_name': 'Daddy Yankee',
#    'release_date': '2022-03-25',
#    'id_track': '3XjN0mvFkQp1FMVM9Ro5hm',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'Normal',
#    'artist_name': 'Feid',
#    'release_date': '2022-07-08',
#    'id_track': '2z9YkcLojiOE7Eu2p9lPZR',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'GATÚBELA',
#    'artist_name': 'KAROL G, Maldy',
#    'release_date': '2022-08-26',
#    'id_track': '1ga4PztXOIw1yBbdUt2X8v',
#    'popularity': 64,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tendencia Global',
#    'artist_name': 'Blessd, Myke Towers, Ovy On The Drums',
#    'release_date': '2022-11-03',
#    'id_track': '2TCklWS3S4Zg6e2m2MBoYm',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': 'Brother',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '7wT8mK7zq2pcvOXzqGfT3Z',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Gato de Noche',
#    'artist_name': 'Ñengo Flow, Bad Bunny',
#    'release_date': '2022-12-22',
#    'id_track': '54ELExv56KCAB4UP9cOCzC',
#    'popularity': 64,
#    'genero': 'reggaeton'},
#   {'track_name': 'En La De Ella',
#    'artist_name': 'JHAYCO, Feid, Sech',
#    'release_date': '2022-10-21',
#    'id_track': '5NxhMcHSVY3Z7ykWxZf3aj',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'CAIRO',
#    'artist_name': 'KAROL G, Ovy On The Drums',
#    'release_date': '2022-11-13',
#    'id_track': '6WbAhuwE6fCOriBu5786X1',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'EL NENE',
#    'artist_name': 'Anuel AA, Foreign Teck',
#    'release_date': '2022-12-09',
#    'id_track': '5erXVUirf9qivKY5sJOanE',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Punto G - (Remix)',
#    'artist_name': 'Brytiago, Farruko, Darell, Arcángel, De La Ghetto, Ñengo Flow',
#    'release_date': '2022-12-16',
#    'id_track': '2AoKiaQylcQaUwsJNKdJOo',
#    'popularity': 61,
#    'genero': 'reggaeton'},
#   {'track_name': 'Feliz Cumpleaños Ferxxo',
#    'artist_name': 'Feid',
#    'release_date': '2022-08-19',
#    'id_track': '3kUq4sBcmxhnOtNysZ9yrp',
#    'popularity': 62,
#    'genero': 'reggaeton'},
#   {'track_name': 'Pegao',
#    'artist_name': 'Camilo',
#    'release_date': '2022-05-19',
#    'id_track': '7Dk8r4VR5NoveUvTiCKEXC',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Del Kilo',
#    'artist_name': 'Anuel AA, Treintisiete, Yailin la Mas Viral',
#    'release_date': '2022-12-09',
#    'id_track': '7qgovmYLU3BUltCBdYUPKg',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Nuevo',
#    'artist_name': 'Lunay, YOVNGCHIMI',
#    'release_date': '2022-12-08',
#    'id_track': '5OAUEIwUw1TsoeCkoI1hbo',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'LOKERA',
#    'artist_name': 'Rauw Alejandro, Lyanno, Brray',
#    'release_date': '2022-07-25',
#    'id_track': '79HZAZNnOE97rb2hnI0XQr',
#    'popularity': 61,
#    'genero': 'reggaeton'},
#   {'track_name': 'DURO',
#    'artist_name': 'Chris Jedi, Anuel AA, Gaby Music, Jenny "La Sexy Voz"',
#    'release_date': '2022-11-04',
#    'id_track': '6Bix1x2zJnlvuLr2Xb6CXf',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ferxxo 100',
#    'artist_name': 'Feid',
#    'release_date': '2022-06-03',
#    'id_track': '6ipzb1kHhWIxp1tS0vwqPl',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'PUNTO 40',
#    'artist_name': 'Rauw Alejandro, Baby Rasta',
#    'release_date': '2022-09-22',
#    'id_track': '2TDyyEBasw10wu5Uh94bR1',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'Las Jordan',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '3dTfFNVkfGUAAsWa3ne3Ig',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'AMANTES',
#    'artist_name': 'Becky G, Daviles de Novelda',
#    'release_date': '2022-09-16',
#    'id_track': '3Q7o2zzvXj7QiSCumjBpvu',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'El Apagón',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2022-05-06',
#    'id_track': '0UvZcEfpzVyx47QsRbjyBz',
#    'popularity': 64,
#    'genero': 'reggaeton'},
#   {'track_name': 'Barranquilla Bajo Cero',
#    'artist_name': 'Beéle, Myke Towers, Feid',
#    'release_date': '2022-05-27',
#    'id_track': '02mhtclidb7Jpf1gwEasJh',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'Vibra',
#    'artist_name': 'Anuel AA, David Guetta',
#    'release_date': '2022-12-09',
#    'id_track': '0DU150UuvrIsqOzAoeB2Zv',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Luces De Neón',
#    'artist_name': 'Myke Towers',
#    'release_date': '2022-09-08',
#    'id_track': '5B60XFKzm8WsJTdVyt4u4I',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'BRRR',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '029cuB69yYCgVHND32hjcT',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Brother',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-09-14',
#    'id_track': '3M23T72K5eqHI2GzdFMMHE',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Los Cachos',
#    'artist_name': 'Piso 21, Manuel Turizo',
#    'release_date': '2022-10-13',
#    'id_track': '3eUR4NZa2hc8ZulyFYdCv8',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'BOMBÓN',
#    'artist_name': 'Daddy Yankee, El Alfa, Lil Jon',
#    'release_date': '2022-03-25',
#    'id_track': '4OAPnWJ3J5w4c4IBLh2chn',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'ULALA (OOH LA LA)',
#    'artist_name': 'Myke Towers, Daddy Yankee',
#    'release_date': '2022-11-24',
#    'id_track': '4EQOGfssbSpTlV6EZRtrSv',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ambulancia',
#    'artist_name': 'Camilo, Camila Cabello',
#    'release_date': '2022-09-06',
#    'id_track': '5OPte07J5hRK1pTn0f7ldr',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Belixe',
#    'artist_name': 'Feid',
#    'release_date': '2022-09-14',
#    'id_track': '0S4w5ZBEbxYxiygvz9wWdK',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Castigo',
#    'artist_name': 'Feid',
#    'release_date': '2022-09-14',
#    'id_track': '18pWcEUcUJpBFs7eNBsBht',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'X ÚLTIMA VEZ',
#    'artist_name': 'Daddy Yankee, Bad Bunny',
#    'release_date': '2022-03-25',
#    'id_track': '48AJSd42lXpicsGqcgopof',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Vida Es Una (From Puss in Boots: The Last Wish)',
#    'artist_name': 'KAROL G',
#    'release_date': '2022-12-08',
#    'id_track': '35HgzqAoEZ28Ovq7kb9nDz',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Se Enamoró de un Reggaetonero',
#    'artist_name': 'Alejo',
#    'release_date': '2022-06-22',
#    'id_track': '0dlEA0Yhxsd09QWncDvaXF',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ziploc (Blessd Version)',
#    'artist_name': 'Blessd, Pirlo',
#    'release_date': '2022-11-03',
#    'id_track': '3JYw9n3rJTVQryVz1rwlH4',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Los Besos',
#    'artist_name': 'Greeicy',
#    'release_date': '2022-03-04',
#    'id_track': '50SFVefoyzWnJy1oQWfRtr',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'California',
#    'artist_name': 'Feid',
#    'release_date': '2022-12-02',
#    'id_track': '19iUrnYyBAG5LaxT72ajsM',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mojando Asientos (feat. Feid)',
#    'artist_name': 'Maluma, Feid',
#    'release_date': '2022-03-24',
#    'id_track': '0LKu09Iq053CEUZ5ktQEWc',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ahora Te Puedes Marchar',
#    'artist_name': 'Abraham Mateo',
#    'release_date': '2022-08-25',
#    'id_track': '4aWuoE57P5KteX0L57OrJs',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Teteo',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '5qLTlf9mCA8JHeLt3tmlId',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'AEIOU',
#    'artist_name': 'Justin Quiles, Robin Schulz',
#    'release_date': '2022-06-23',
#    'id_track': '1c2vVx6knoiZHXbJJ9Mk8L',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Índigo',
#    'artist_name': 'Camilo, Evaluna Montaner',
#    'release_date': '2022-09-06',
#    'id_track': '6i28Cxd4CUiHmcowzQW38w',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'Bebiendo Sola',
#    'artist_name': 'Camilo, Myke Towers',
#    'release_date': '2022-09-06',
#    'id_track': '0wIIVkpeRLjoGAYkeYXevR',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Hey Mor',
#    'artist_name': 'Ozuna, Feid',
#    'release_date': '2022-10-06',
#    'id_track': '6Rpbzk2LC8xWZI93RyodAq',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mujeriego',
#    'artist_name': 'Ryan Castro',
#    'release_date': '2022-08-05',
#    'id_track': '4jiYaQVHzMfKhEeLypWpNO',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'Junio',
#    'artist_name': 'Maluma',
#    'release_date': '2022-09-29',
#    'id_track': '4XqXNU8MwPHwbgZmNXmAdc',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'No Confío',
#    'artist_name': 'Jay Wheeler, El Alfa, DJ Nelson',
#    'release_date': '2022-08-19',
#    'id_track': '2UieOcTk0Kl4bzLVBW4oVj',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'NASA',
#    'artist_name': 'Camilo, Alejandro Sanz',
#    'release_date': '2022-09-06',
#    'id_track': '7mCC2SBkb5uwmQ4Ozewtbc',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'FULANITO',
#    'artist_name': 'Becky G, El Alfa',
#    'release_date': '2022-05-13',
#    'id_track': '3CIl8hlnMcULSIIhUMmB1Z',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Suelta',
#    'artist_name': 'Jay Wheeler, Mora',
#    'release_date': '2022-07-08',
#    'id_track': '7kN7u1ZDOrNBKcEEGwGeDY',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Me Fije',
#    'artist_name': 'Alex Rose, Rauw Alejandro',
#    'release_date': '2022-06-09',
#    'id_track': '73ye5sXrSxSt9aMeXz5eG7',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'Si Tu Me Busca',
#    'artist_name': 'Anuel AA, Yailin la Mas Viral',
#    'release_date': '2022-04-01',
#    'id_track': '7krngwvy6pL3EVgOhDe7zE',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Buenos Días',
#    'artist_name': 'Wisin, Camilo, Los Legendarios',
#    'release_date': '2022-01-14',
#    'id_track': '2MxHuZWC99rsELX9SrCW7K',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Pasamos CXBRXN',
#    'artist_name': 'Feid, Zion & Lennox',
#    'release_date': '2022-12-02',
#    'id_track': '672zDo2nzWSoIIQ7zD5kuj',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'Bottas',
#    'artist_name': 'Arcángel, Duki, Bizarrap',
#    'release_date': '2022-12-01',
#    'id_track': '5G5Xl4HHGJM6MrMAUIb538',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Aguante',
#    'artist_name': 'Feid',
#    'release_date': '2022-09-14',
#    'id_track': '2dWGQ975YrNma4SdfmJRDg',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Ruta',
#    'artist_name': 'Arcángel, YOVNGCHIMI',
#    'release_date': '2022-12-01',
#    'id_track': '7D8tKs61tdzzDdG9w6kdu4',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Quemando Calorías',
#    'artist_name': 'Feid, Sky Rompiendo',
#    'release_date': '2022-09-14',
#    'id_track': '3ss6y0Id5Iwk2L5MIZp4xF',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'Éxtasis',
#    'artist_name': 'Manuel Turizo, Maria Becerra',
#    'release_date': '2022-10-27',
#    'id_track': '2X8AGLwb9F0JzJ9zT27a22',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Nada',
#    'artist_name': 'Cali Y El Dandee, Danna Paola',
#    'release_date': '2022-02-25',
#    'id_track': '1U7QlWG6O98xgsJtVjYREj',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'Si Yo Me Muero',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '4jr6VdPZUWtC7FQZ6kn21M',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'XQ Te Pones Así',
#    'artist_name': 'Feid, Yandel',
#    'release_date': '2022-09-14',
#    'id_track': '6JUMswocQ7Hp46kj9kyljT',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Guarida',
#    'artist_name': 'Bryant Myers',
#    'release_date': '2022-06-17',
#    'id_track': '19FjaZwowlzROovPliZty2',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Fundota',
#    'artist_name': 'Bryant Myers',
#    'release_date': '2022-11-25',
#    'id_track': '5MZIwnOllAg7HCrWpjSIXu',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Lejos Conmigo',
#    'artist_name': 'Greeicy, Alejandro Sanz',
#    'release_date': '2022-03-04',
#    'id_track': '4c1gXSj2oEYywSfN6iOwGu',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Loco Por Perrearte - Remix',
#    'artist_name': 'De La Ghetto, Rauw Alejandro',
#    'release_date': '2022-06-03',
#    'id_track': '0vHfVsEe6Ps0d8cZ9PGzSw',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Nosotros',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-09-08',
#    'id_track': '4o5kWgO8DVkEXO54fdXR3l',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'TBT',
#    'artist_name': 'Sebastian Yatra, Rauw Alejandro, Manuel Turizo',
#    'release_date': '2022-01-28',
#    'id_track': '0G6DFeq9ofdney54wryu8o',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'Nieve',
#    'artist_name': 'Feid',
#    'release_date': '2022-09-14',
#    'id_track': '2gLDm4AjVnHlsik9sK87vj',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mojando Asientos (feat. Feid)',
#    'artist_name': 'Maluma, Feid',
#    'release_date': '2022-06-10',
#    'id_track': '6lV9cTvioGWqRXSgfjAUGL',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'Llorar y Llorar - con Carin Leon',
#    'artist_name': 'Mau y Ricky, Carin Leon',
#    'release_date': '2022-05-31',
#    'id_track': '4YF13O2n16dcTyGgVmiGvN',
#    'popularity': 64,
#    'genero': 'reggaeton'},
#   {'track_name': 'Coroné',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '6BYeLJmIGlsSpaaTKTTZ2S',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Presidentes Muertos',
#    'artist_name': 'Casper Magico, Anuel AA, Bryant Myers, YOVNGCHIMI',
#    'release_date': '2022-11-17',
#    'id_track': '6KbONqnIUnp6dBJzqj2ChY',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Te Perdí',
#    'artist_name': 'Andy Rivera, Beéle',
#    'release_date': '2022-09-15',
#    'id_track': '3ODWjPcN2heqjInFGpH2KU',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'De La Nada',
#    'artist_name': 'Los G4, Rokero, De La Rose',
#    'release_date': '2022-06-17',
#    'id_track': '5TQfaKF3g6RRPWeNkTQ0bA',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Aeropuerto',
#    'artist_name': 'Camilo',
#    'release_date': '2022-09-06',
#    'id_track': '4v7riPZWyAclrOfUSwD0zp',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'Volare',
#    'artist_name': 'Danny Ocean',
#    'release_date': '2022-07-07',
#    'id_track': '6TCnhziFkBPhOTqvh8zVDU',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Malibu',
#    'artist_name': 'Feid, Ak4:20, Taiko',
#    'release_date': '2022-11-11',
#    'id_track': '4TRlBMj8wXsIfEDgWOPyE2',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'Nosotros',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '4eeUoNSCPLXuFtZoDxdCz2',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'JS4E',
#    'artist_name': 'Arcángel',
#    'release_date': '2022-12-01',
#    'id_track': '68e9XUS28xQRV9jghSx0NX',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'HOT',
#    'artist_name': 'Daddy Yankee, Pitbull',
#    'release_date': '2022-03-25',
#    'id_track': '5Pg4qYTcvCUBBq3jBhKq0t',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'Un Poquito',
#    'artist_name': 'Alejo, Young Miko',
#    'release_date': '2022-06-10',
#    'id_track': '1nU4sOQqqhFUqS0TiRlD0V',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Lady Mi Amor',
#    'artist_name': 'Feid',
#    'release_date': '2022-09-14',
#    'id_track': '30Xh83fw03PZ2Wfm36H4EZ',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Berlin',
#    'artist_name': 'Zion & Lennox, Maria Becerra',
#    'release_date': '2022-06-30',
#    'id_track': '2IzV2SPZQLadtA46ni3ICq',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Los Consejos',
#    'artist_name': 'Greeicy',
#    'release_date': '2022-03-04',
#    'id_track': '54KqP2AoCRcEMTfooOI5nK',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'Anfetamina',
#    'artist_name': 'Almighty, Luar La L',
#    'release_date': '2022-12-09',
#    'id_track': '30gIEtWe6BawlVKlsgllKa',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Viendo El Techo',
#    'artist_name': 'Jay Wheeler',
#    'release_date': '2022-01-12',
#    'id_track': '1KVkcUbK8rJpDyO6n0H5t2',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Los Cachos',
#    'artist_name': 'Piso 21, Manuel Turizo',
#    'release_date': '2022-07-08',
#    'id_track': '5fhcuVxuBWfgNXGuyAtLmr',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Enchule',
#    'artist_name': 'ICON, Beéle, Rios',
#    'release_date': '2022-09-23',
#    'id_track': '6NQQJRKTJeCuSnvNZ4J7xA',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Llamada',
#    'artist_name': 'Pusho, Myke Towers',
#    'release_date': '2022-07-15',
#    'id_track': '2pljRepUcPRQ27fZXWqBez',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Contra la Corriente',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '1dVqCgOJk2ViU6uQ25OzLh',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mintiendo',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '1T1YzsWr4iH6xJKTe0zZEs',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Location',
#    'artist_name': 'Alejo, Caleb Calloway',
#    'release_date': '2022-05-27',
#    'id_track': '0tvrucEjmw7aNS9qBSHO4l',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Sensual Bebé',
#    'artist_name': 'JHAYCO',
#    'release_date': '2022-03-11',
#    'id_track': '1xqbfjRuUw0ot43wgBuVkt',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Quien TV Remix',
#    'artist_name': 'Blessd, Ryan Castro',
#    'release_date': '2022-01-27',
#    'id_track': '58h5RuCMWCkstuXckWuRpp',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'De Adentro Pa Afuera',
#    'artist_name': 'Camilo',
#    'release_date': '2022-09-06',
#    'id_track': '6D5lH4GFCFLJAUlkUOUBUt',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Melancólicos Anónimos',
#    'artist_name': 'Sebastian Yatra',
#    'release_date': '2022-01-28',
#    'id_track': '1s4jVre4ZgBm3sVJP1NTrl',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Qué Prefieres?',
#    'artist_name': 'Boza, Beéle',
#    'release_date': '2022-09-22',
#    'id_track': '1YEQ5CvZVK9P4PsZY76GK5',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Vapor',
#    'artist_name': 'Wisin & Yandel, Rauw Alejandro',
#    'release_date': '2022-12-01',
#    'id_track': '7it0u6IGJQLRX9Q9q7vgOj',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Me Siento HP',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '2rS1JQegPDJe3evTvnRqMA',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ella - Remix',
#    'artist_name': 'Boza, Lunay, Lenny Tavárez, Juhn, Beéle',
#    'release_date': '2022-03-11',
#    'id_track': '7cx9L3i88euMfx1oNCqDAD',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'Roto',
#    'artist_name': 'Corina Smith, Eladio Carrion',
#    'release_date': '2022-03-10',
#    'id_track': '3Xn2pi2HBV46PNuGMG8kSq',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mercedes Tintia',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-08-25',
#    'id_track': '6e9Ew4AECYwY5Xgs2ZKMgp',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mercedes Tintia',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '5rvlNvyN5GkQxAI0GuBeXX',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ande Con Quien Ande',
#    'artist_name': 'Myke Towers, JHAYCO',
#    'release_date': '2022-08-18',
#    'id_track': '6AizmGCrFRQHru1Qf8WKoJ',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Hoodie',
#    'artist_name': 'Anuel AA, Bryant Myers',
#    'release_date': '2022-12-09',
#    'id_track': '6wpZ6aUZxirJyTshhuUhkR',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Rulay',
#    'artist_name': 'Amenazzy, Beny Jr',
#    'release_date': '2022-02-16',
#    'id_track': '7mLJiuLlh6v8Hz5PfYfOTh',
#    'popularity': 39,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Máquina',
#    'artist_name': 'Anuel AA, Jowell & Randy, De La Ghetto, Yailin la Mas Viral',
#    'release_date': '2022-12-09',
#    'id_track': '35ns1WEurw3MVlHJjHwNWQ',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'PASATIEMPO',
#    'artist_name': 'Daddy Yankee, Myke Towers',
#    'release_date': '2022-03-25',
#    'id_track': '3qUdysxsu5FDvOl7nR5vln',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Diamantes en Mis Dientes',
#    'artist_name': 'Anuel AA, YOVNGCHIMI',
#    'release_date': '2022-12-09',
#    'id_track': '5c3idBIe2HEX04QkMyfmTY',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mayor Que Usted',
#    'artist_name': 'NATTI NATASHA, Daddy Yankee, Wisin & Yandel',
#    'release_date': '2022-06-17',
#    'id_track': '7d7aPD2oxuzjhOZnu4Dj23',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'JS4E',
#    'artist_name': 'Arcángel',
#    'release_date': '2022-11-21',
#    'id_track': '5iaFGC7XdmWmfwxV9JUPY6',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'La 2blea',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-09-30',
#    'id_track': '3gOVQmGQcg8djqU044liT1',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': '5:24',
#    'artist_name': 'Camilo',
#    'release_date': '2022-09-06',
#    'id_track': '1ZymB4keoWbIgKYZ0RaO9b',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Hookiao',
#    'artist_name': 'Lil Silvio & El Vega',
#    'release_date': '2022-11-25',
#    'id_track': '68Air6MRHclUb0t6rQk4GE',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tiene Novio',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '6zbzhXVv52BUEi8rGolhCF',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Esquina del Mall',
#    'artist_name': 'Justin Quiles, Carin Leon',
#    'release_date': '2022-10-06',
#    'id_track': '3WtymOJb6mGqTzU9wlRzck',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'La 2blea',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '1UUit3l9f16ndc4ke8A1Eq',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mvrda Cartel',
#    'artist_name': 'Yampi, YOVNGCHIMI',
#    'release_date': '2022-05-13',
#    'id_track': '2E6Pm6YLlo4DF2F7lBkRwx',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': '1ro',
#    'artist_name': 'Anuel AA, Lil Durk',
#    'release_date': '2022-12-09',
#    'id_track': '67kjola5ELgfVclZuik6ZL',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Pegao',
#    'artist_name': 'Camilo',
#    'release_date': '2022-09-06',
#    'id_track': '0j3ULEzS14shcTGdiYwsOI',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ella',
#    'artist_name': 'Boza',
#    'release_date': '2022-03-11',
#    'id_track': '4177FNDorJz54RrGDbftxU',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Buena Fai',
#    'artist_name': 'Feid',
#    'release_date': '2022-09-14',
#    'id_track': '188Iohmux4LrDaj6e6eeEx',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Enchulao',
#    'artist_name': 'Beéle, Blessd',
#    'release_date': '2022-02-04',
#    'id_track': '3HaTdgWD41zkYPHZMNuQ0V',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'En Tu Cuerpo - Remix',
#    'artist_name': 'Lyanno, Rauw Alejandro, Lenny Tavárez, Maria Becerra',
#    'release_date': '2022-04-21',
#    'id_track': '1DASr37nq7l0ZZ91CSus6J',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mientes',
#    'artist_name': 'Anuel AA, Nicky Jam',
#    'release_date': '2022-12-09',
#    'id_track': '7l7Y0vqJvN0CHEVywKPEp6',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Sufro',
#    'artist_name': 'Anuel AA, Kodak Black, Ñengo Flow',
#    'release_date': '2022-12-09',
#    'id_track': '5KaOhT7vF4XdVtJ4eY3QF4',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'LEJOS DEL CIELO',
#    'artist_name': 'Rauw Alejandro',
#    'release_date': '2022-11-10',
#    'id_track': '39qtjJ454r2fgyXaenq8Wv',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tendencia Global',
#    'artist_name': 'Blessd, Myke Towers, Ovy On The Drums',
#    'release_date': '2022-03-18',
#    'id_track': '2iLegn1UOmpNpQAxcQoGJW',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tu Lo Sabes',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '0fZlFiYSCcYIpouuzjHaQr',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mala Eligiendo',
#    'artist_name': 'Amenazzy',
#    'release_date': '2022-10-18',
#    'id_track': '2dtQLhWPtBfzrGT5ynTUym',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'Anuel & Emmanuel',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '4CX7VV8m2V0k05FmjOUq7a',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mar Chiquita',
#    'artist_name': 'Ozuna, Pedro Capó',
#    'release_date': '2022-10-07',
#    'id_track': '52AHKfP6qQ3feLjPCDTiRI',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Castigo',
#    'artist_name': 'Feid',
#    'release_date': '2022-05-13',
#    'id_track': '7INDea2qgB7TlUgpux3hsg',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'HOOKIA',
#    'artist_name': 'Feid, Jory Boy',
#    'release_date': '2022-12-02',
#    'id_track': '1WgyA7SYEzPRZkig3q1b0j',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Soltera',
#    'artist_name': 'Cali Y El Dandee, Omar Montes',
#    'release_date': '2022-09-16',
#    'id_track': '41ffIDkb10CvzGNBYXm498',
#    'popularity': 38,
#    'genero': 'reggaeton'},
#   {'track_name': 'Nos Comemos Vivos',
#    'artist_name': 'Maluma, Chencho Corleone',
#    'release_date': '2022-06-10',
#    'id_track': '0bI5WRiDfU5BY38ufOJtGu',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Felices Perdidos',
#    'artist_name': 'Piso 21, Danny Ocean',
#    'release_date': '2022-10-13',
#    'id_track': '5XJWVLhYE2tsa5vXlcgT3N',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Sigue',
#    'artist_name': 'J Balvin, Ed Sheeran',
#    'release_date': '2022-03-25',
#    'id_track': '0bBd6K5X4W7t9GyXcaVOA7',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'WUEPA',
#    'artist_name': 'Rauw Alejandro, Ankhal',
#    'release_date': '2022-02-25',
#    'id_track': '0KYmzY7oFojlPb84tJeHhp',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ojos Rojos',
#    'artist_name': 'Nicky Jam',
#    'release_date': '2022-01-27',
#    'id_track': '5hYRabCQuFZN8yVCQsSeyF',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'Borracha & Loca',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '3M2Uxu8sbTwgznw6anIxB9',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Brisa',
#    'artist_name': 'Zion & Lennox, Danny Ocean',
#    'release_date': '2022-04-28',
#    'id_track': '5xhFO6kaUjGcSezSp5hIhG',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'WOW BB',
#    'artist_name': 'NATTI NATASHA, El Alfa, Chimbala',
#    'release_date': '2022-02-22',
#    'id_track': '4fQAjk5sPe6ay04m5slBlU',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Noche de Teteo',
#    'artist_name': 'Sech',
#    'release_date': '2022-05-19',
#    'id_track': '5YBvKoQDMAd7IjonxPQYFN',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Nieve',
#    'artist_name': 'Feid',
#    'release_date': '2022-03-04',
#    'id_track': '66uR26h9WTxwKhJCWnz5J9',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Wakanda',
#    'artist_name': 'Anuel AA, DaBaby',
#    'release_date': '2022-12-09',
#    'id_track': '14uatjtUxCp76wlN5qtWEj',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'Un Tiempo',
#    'artist_name': 'Cali Y El Dandee',
#    'release_date': '2022-02-25',
#    'id_track': '4hXUWmtVNjNz8dglR5iILz',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Melancólicos Anónimos',
#    'artist_name': 'Sebastian Yatra',
#    'release_date': '2022-01-21',
#    'id_track': '1xFwkEGGB6BDhHFzcpsuf8',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Sci-Fi',
#    'artist_name': 'Tainy, Rauw Alejandro',
#    'release_date': '2022-07-21',
#    'id_track': '5hF1rSgXQ4EPdWdYb8E6q0',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Sin Ti',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '06SVpxUS3JlL2g2p6QdbBl',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'BAILÉ CON MI EX',
#    'artist_name': 'Becky G',
#    'release_date': '2022-05-10',
#    'id_track': '0Yc0ziTsyjahYqlWXVXlTU',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'Malo',
#    'artist_name': 'Anuel AA, Zion, Randy',
#    'release_date': '2022-12-09',
#    'id_track': '1VTFzMagdw9UizqXYXhv0B',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'REMIX',
#    'artist_name': 'Daddy Yankee',
#    'release_date': '2022-03-25',
#    'id_track': '65MqlYPOWReasKWcuCaOCW',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'After Party',
#    'artist_name': 'Alex Sensation, Farruko, Prince Royce, Mariah Angeliq, Kevin Lyttle',
#    'release_date': '2022-02-04',
#    'id_track': '5px2CcFnmRJecJMNPYz4Io',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Sicaria',
#    'artist_name': 'Brytiago, Ankhal, Luar La L',
#    'release_date': '2022-01-14',
#    'id_track': '2h5kMJFJeZghxhPF3TTsrj',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'Aroma',
#    'artist_name': 'Brytiago, Lenny Tavárez, Beéle',
#    'release_date': '2022-11-17',
#    'id_track': '448oAggap8XbTa6TIOH6Kb',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'Nos Comemos Vivos',
#    'artist_name': 'Maluma, Chencho Corleone',
#    'release_date': '2022-06-09',
#    'id_track': '3SlKme42qm1vWrkl3BrZmm',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Airbnb',
#    'artist_name': 'Anuel AA, RobGz',
#    'release_date': '2022-12-09',
#    'id_track': '2IaAYf9m4Kw9C5Lf3eIbiD',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'TV',
#    'artist_name': 'Sebastian Yatra',
#    'release_date': '2022-06-10',
#    'id_track': '7umNRgkjLJEnGF8Iq8f2rI',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'De Qué Manera',
#    'artist_name': 'Mike Bahía',
#    'release_date': '2022-12-22',
#    'id_track': '3HMlb6Dh9OGr3CjV6IwjEP',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Si Yo Me Muero',
#    'artist_name': 'Anuel AA, MVSIS',
#    'release_date': '2022-11-23',
#    'id_track': '4qpTCXnBSPtkMEmdE4Dzi8',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Me Encantaría',
#    'artist_name': 'Abraham Mateo, Belinda',
#    'release_date': '2022-10-20',
#    'id_track': '1APLK79zZo67ny370NLO4F',
#    'popularity': 40,
#    'genero': 'reggaeton'},
#   {'track_name': 'Monumento - Remix',
#    'artist_name': 'Andy Rivera, Ñejo, Ryan Castro',
#    'release_date': '2022-05-12',
#    'id_track': '1bUTLkxM3nMUngIGP0M8ws',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Espejismo',
#    'artist_name': 'Javiielo, Nekxum',
#    'release_date': '2022-11-16',
#    'id_track': '3sd4gjbHSTzIhEyOmoQstz',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ascensor',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '0C4UEONd2UXucUZM1r821G',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'Miami',
#    'artist_name': 'CNCO, Beéle',
#    'release_date': '2022-08-24',
#    'id_track': '0969BXUHWVqlmZa7zhuuRV',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Anda Sola',
#    'artist_name': 'Jay Wheeler',
#    'release_date': '2022-01-12',
#    'id_track': '2wyw4eQ2SfIYfm1vxCgYI0',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Buenos Días',
#    'artist_name': 'Wisin, Camilo, Los Legendarios',
#    'release_date': '2022-07-01',
#    'id_track': '79NdVoSxUC2XC48eg0ifMy',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Somo Así',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '1Rz0mraGNPNTIyhRD4YZbi',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Diamantes en Mis Dientes',
#    'artist_name': 'Anuel AA, YOVNGCHIMI',
#    'release_date': '2022-11-01',
#    'id_track': '4bJ6YKzyVTnhOrSpccGQeN',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Pentagrama',
#    'artist_name': 'Alex Zurdo',
#    'release_date': '2022-01-07',
#    'id_track': '1DofNh9ulHsQkybB81XMPj',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'NASA',
#    'artist_name': 'Camilo, Alejandro Sanz',
#    'release_date': '2022-06-16',
#    'id_track': '7pt5VZBKEsd4JIQ67DZcnd',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'Foto En Panty',
#    'artist_name': 'Sech',
#    'release_date': '2022-10-28',
#    'id_track': '4HehbhlVK81hZT5Yg7QmiR',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'Jordan',
#    'artist_name': 'Ryan Castro',
#    'release_date': '2022-05-24',
#    'id_track': '7EF0R9lnsb7S81Q7xt5JzO',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Que Duro',
#    'artist_name': 'Blessd',
#    'release_date': '2022-11-03',
#    'id_track': '12RaiccXZ5yIDrHt4c5ngZ',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Maléfica',
#    'artist_name': 'Cazzu, Maria Becerra',
#    'release_date': '2022-05-30',
#    'id_track': '0U9OZFbn82oICL2jNbpNHy',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'PortoBello',
#    'artist_name': 'Arcángel',
#    'release_date': '2022-12-01',
#    'id_track': '4HXcnBfKuqGC2fIYXquurs',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Spicy Crab',
#    'artist_name': 'Arcángel, Bryant Myers',
#    'release_date': '2022-12-01',
#    'id_track': '2o4dhiZvbfttXqcwhToPaz',
#    'popularity': 39,
#    'genero': 'reggaeton'},
#   {'track_name': 'Adentro',
#    'artist_name': 'Amenazzy, Noriel',
#    'release_date': '2022-11-29',
#    'id_track': '4kG3m7rHjUJUJjhphH2m99',
#    'popularity': 41,
#    'genero': 'reggaeton'},
#   {'track_name': 'Dígitos',
#    'artist_name': 'Arcángel, Myke Towers',
#    'release_date': '2022-12-01',
#    'id_track': '6EGcTqLZZ7gkuhOIcyCp0k',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'Amor Pasajero',
#    'artist_name': 'Sebastian Yatra',
#    'release_date': '2022-01-28',
#    'id_track': '16P9pLDu8FdhiWLFPwlweZ',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'TV',
#    'artist_name': 'Sebastian Yatra',
#    'release_date': '2022-07-29',
#    'id_track': '6NIqCQW067X2AEHlz19TEc',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'Alaska',
#    'artist_name': 'Camilo, Grupo Firme',
#    'release_date': '2022-08-18',
#    'id_track': '607ZGkxOxHJUVDEU3MZl86',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Carro Nuevo',
#    'artist_name': 'Jay Wheeler, JHAYCO',
#    'release_date': '2022-08-19',
#    'id_track': '0OLLQD6ujaoOWnO6AbjV9W',
#    'popularity': 41,
#    'genero': 'reggaeton'},
#   {'track_name': 'Hoodie',
#    'artist_name': 'Anuel AA, Bryant Myers',
#    'release_date': '2022-12-01',
#    'id_track': '7DtsTnAn320fWxiw6bdAHe',
#    'popularity': 39,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Bruja',
#    'artist_name': 'Darell, Omar Montes',
#    'release_date': '2022-09-23',
#    'id_track': '1jYmFEVdOkPfhxuYF5fE7S',
#    'popularity': 32,
#    'genero': 'reggaeton'},
#   {'track_name': '40',
#    'artist_name': 'Anuel AA',
#    'release_date': '2022-12-09',
#    'id_track': '6wTBeNBpysAYa7NthlapSy',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Por Fin',
#    'artist_name': 'Dímelo Flow, Arcángel, Nicky Jam, Jay Wheeler',
#    'release_date': '2022-06-09',
#    'id_track': '3bd1snLjdM5iTO9S8s5jtI',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'Borracho',
#    'artist_name': 'Jay Wheeler, Reik, Chris Lebron',
#    'release_date': '2022-08-19',
#    'id_track': '36YVCCPC3oagSaOJSgUCEC',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'CAPRICHOSO',
#    'artist_name': 'Rauw Alejandro',
#    'release_date': '2022-02-25',
#    'id_track': '3Fm7EFSuLlW8KqWTPIYLZH',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'Amor Pasajero',
#    'artist_name': 'Sebastian Yatra',
#    'release_date': '2022-01-07',
#    'id_track': '2AQrDkF3XiC3xCkAM4OkJx',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Al Taller del Maestro',
#    'artist_name': 'Alex Campos, Jesús Adrián Romero, Lilly Goodman',
#    'release_date': '2022-09-30',
#    'id_track': '7Eyk7Fpn04yhOYppojynnA',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'AGUA',
#    'artist_name': 'Daddy Yankee, Rauw Alejandro, Nile Rodgers',
#    'release_date': '2022-03-25',
#    'id_track': '4e4t1qNN47CzmCxFffzs4U',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'NO MIENTEN',
#    'artist_name': 'Becky G',
#    'release_date': '2022-04-20',
#    'id_track': '3zUtuSPwyqKElkqfnJj3X2',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Te Creí',
#    'artist_name': 'Greeicy, Cultura Profética',
#    'release_date': '2022-03-04',
#    'id_track': '60c5SSCLMt13B27d6Df4dP',
#    'popularity': 53,
#    'genero': 'reggaeton'},
# ...
#    'release_date': '2022-03-10',
#    'id_track': '35b0iM96Uid8KI5s83IEHM',
#    'popularity': 36,
#    'genero': 'indie'},
#   {'track_name': 'The Funeral',
#    'artist_name': 'YUNGBLUD',
#    'release_date': '2022-09-02',
#    'id_track': '3t4zZ2SxXgQRIhc5N6a6oZ',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'Thérèse',
#    'artist_name': 'Maya Hawke',
#    'release_date': '2022-06-29',
#    'id_track': '1LklAGxyeK07JYRzw3Vzx9',
#    'popularity': 50,
#    'genero': 'indie'},
#   {'track_name': 'SKATE',
#    'artist_name': 'Bawo',
#    'release_date': '2022-06-06',
#    'id_track': '2rBm4JoA7r0CHlDADG526H',
#    'popularity': 48,
#    'genero': 'indie'},
#   {'track_name': 'Devil I Know',
#    'artist_name': 'Suki Waterhouse',
#    'release_date': '2022-05-06',
#    'id_track': '6R0v4lA69KxsAUYDskYwgs',
#    'popularity': 50,
#    'genero': 'indie'},
#   {'track_name': 'erase me',
#    'artist_name': 'Lizzy McAlpine, Jacob Collier',
#    'release_date': '2022-04-08',
#    'id_track': '4R2DDseYW2tsmMhvdQQ2Po',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'sunburn',
#    'artist_name': 'almost monday',
#    'release_date': '2022-04-08',
#    'id_track': '4gBkCqlITvat2A3aYPtMqS',
#    'popularity': 45,
#    'genero': 'indie'},
#   {'track_name': 'Healing',
#    'artist_name': 'The Blue Stones',
#    'release_date': '2022-11-04',
#    'id_track': '4tssgbtfbWp18TFKJLOZJP',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'Ur Mum',
#    'artist_name': 'Wet Leg',
#    'release_date': '2022-04-08',
#    'id_track': '4ug5wsIcbAPBun8TCKn2t6',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Fourth of July',
#    'artist_name': 'Sufjan Stevens',
#    'release_date': '2022-07-01',
#    'id_track': '1LjVNoqN5YsWf9vGu2JzhF',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'Talk to You',
#    'artist_name': 'Ricky Montgomery',
#    'release_date': '2022-12-16',
#    'id_track': '6suxUONtPxkEPL3JHGX9SX',
#    'popularity': 54,
#    'genero': 'indie'},
#   {'track_name': 'On My Knees - Adriatique Remix',
#    'artist_name': 'RÜFÜS DU SOL, Adriatique',
#    'release_date': '2022-08-12',
#    'id_track': '6cNxZMmp08PYnzoHd4f3ly',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'Another Night',
#    'artist_name': 'Sons Of The East',
#    'release_date': '2022-09-23',
#    'id_track': '5zvo5IHhdyHXTBSdO8H4ZI',
#    'popularity': 45,
#    'genero': 'indie'},
#   {'track_name': 'Goodbye Mr Blue',
#    'artist_name': 'Father John Misty',
#    'release_date': '2022-04-08',
#    'id_track': '4PxDBIYPRDoBROF7fh6Pkr',
#    'popularity': 41,
#    'genero': 'indie'},
#   {'track_name': 'Black and White',
#    'artist_name': 'Σtella, Redinho',
#    'release_date': '2022-06-17',
#    'id_track': '54eiaf9abJLL5981ZFOQ7C',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'I Got It',
#    'artist_name': 'Ogi',
#    'release_date': '2022-05-05',
#    'id_track': '4O9OqRpTCXz6fB3BDEAbKz',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Dark Room',
#    'artist_name': 'Foreign Figures, Jonny T',
#    'release_date': '2022-04-08',
#    'id_track': '6A2f2zK7E808HMHbygl9gD',
#    'popularity': 50,
#    'genero': 'indie'},
#   {'track_name': 'Philadelphia',
#    'artist_name': 'alt-J',
#    'release_date': '2022-02-11',
#    'id_track': '7lA8vA8CZsOdB8w0HjlIpy',
#    'popularity': 41,
#    'genero': 'indie'},
#   {'track_name': 'Scars leave beautiful trace',
#    'artist_name': 'Car, the garden',
#    'release_date': '2022-06-26',
#    'id_track': '1y6dEjheBdnopNo0xDXJ9P',
#    'popularity': 48,
#    'genero': 'indie'},
#   {'track_name': 'FAST LAND',
#    'artist_name': 'Moderat',
#    'release_date': '2022-05-13',
#    'id_track': '7g6zG8DhkZoqhbTk5j0lbB',
#    'popularity': 41,
#    'genero': 'indie'},
#   {'track_name': 'Valentine, Texas',
#    'artist_name': 'Mitski',
#    'release_date': '2022-02-04',
#    'id_track': '21r4kosHuDosz3AIdXqUGk',
#    'popularity': 50,
#    'genero': 'indie'},
#   {'track_name': 'Steady as Stones',
#    'artist_name': 'Woodlock',
#    'release_date': '2022-08-05',
#    'id_track': '3I12wCc8EaVTzE1rESoCyE',
#    'popularity': 45,
#    'genero': 'indie'},
#   {'track_name': 'The Truth Is',
#    'artist_name': 'Σtella, Redinho',
#    'release_date': '2022-06-17',
#    'id_track': '2XgKnKhbOOeA0WPFapu8ly',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Ripples',
#    'artist_name': 'beabadoobee',
#    'release_date': '2022-07-15',
#    'id_track': '0SIrEgMzTSWzFoT272mk2X',
#    'popularity': 57,
#    'genero': 'indie'},
#   {'track_name': 'Wish on an Eyelash, Pt. 2',
#    'artist_name': 'Mallrat, The Chainsmokers',
#    'release_date': '2022-12-09',
#    'id_track': '10yYDp1Lnac8zEIYiCk1sp',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Xtasy (Remix) [feat. Doechii]',
#    'artist_name': 'Ravyn Lenae, Doechii',
#    'release_date': '2022-09-14',
#    'id_track': '610faOY46uYOBi3KXazpSj',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'On My Knees - Adriatique Remix',
#    'artist_name': 'RÜFÜS DU SOL, Adriatique',
#    'release_date': '2022-07-29',
#    'id_track': '7MbfrPIsgFDVJifA7p7Evk',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'Ghost - Fejká Remix',
#    'artist_name': 'Mogli, Fejká',
#    'release_date': '2022-08-05',
#    'id_track': '2I78O9gyeZXS9b0VnWTU7Q',
#    'popularity': 45,
#    'genero': 'indie'},
#   {'track_name': 'all my ghosts',
#    'artist_name': 'Lizzy McAlpine',
#    'release_date': '2022-04-08',
#    'id_track': '46BHP7nFOrGQPLW8mCxzZr',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'Mona Ki Ngi Xica',
#    'artist_name': 'Synapson, Bonga',
#    'release_date': '2022-11-18',
#    'id_track': '1tVRRl2K6fHPIhowgx7CMB',
#    'popularity': 42,
#    'genero': 'indie'},
#   {'track_name': 'Rule #27 - Drunk on Pride',
#    'artist_name': 'Fish in a Birdcage, Philip Bowen',
#    'release_date': '2022-03-15',
#    'id_track': '2hhk7nZsDBQe4UlBR6o2PY',
#    'popularity': 50,
#    'genero': 'indie'},
#   {'track_name': 'What, Me Worry?',
#    'artist_name': 'Portugal. The Man',
#    'release_date': '2022-02-09',
#    'id_track': '0ePX6rVjeql7Bt1KurTbAG',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Give Up Baby Go',
#    'artist_name': 'Peach Pit',
#    'release_date': '2022-03-04',
#    'id_track': '6DIMM15oo3kxnCuVypaYGy',
#    'popularity': 55,
#    'genero': 'indie'},
#   {'track_name': 'Why Do I (with Hatsune Miku)',
#    'artist_name': 'Set It Off, Hatsune Miku',
#    'release_date': '2022-10-21',
#    'id_track': '5FH2ZZZDxuaDV4IoVlmjzX',
#    'popularity': 50,
#    'genero': 'indie'},
#   {'track_name': 'Psychic City - Classixx Remix',
#    'artist_name': 'YACHT, Classixx',
#    'release_date': '2022-07-15',
#    'id_track': '4NWpGwfkWMlA7G2ZpFKDXZ',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'See you Soon',
#    'artist_name': 'beabadoobee',
#    'release_date': '2022-07-15',
#    'id_track': '4Gy8ZglxsvsIX04R5PWY7U',
#    'popularity': 56,
#    'genero': 'indie'},
#   {'track_name': 'Age Of Ascent',
#    'artist_name': 'Kokoroko',
#    'release_date': '2022-08-05',
#    'id_track': '5BOkALb3jw3m6SONNtBYRR',
#    'popularity': 45,
#    'genero': 'indie'},
#   {'track_name': 'Fire In My Head',
#    'artist_name': 'Two Feet',
#    'release_date': '2022-05-13',
#    'id_track': '0O0l3h1tIwwec328IXT8NI',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'Falling Asleep At The Wheel',
#    'artist_name': 'Holly Humberstone',
#    'release_date': '2022-10-24',
#    'id_track': '6WP61cbYBHtyXMQZ5zaxY0',
#    'popularity': 48,
#    'genero': 'indie'},
#   {'track_name': 'Haldern',
#    'artist_name': 'Black Country, New Road',
#    'release_date': '2022-02-04',
#    'id_track': '4EVwKp8hDRmxrT6Dzu6aBc',
#    'popularity': 48,
#    'genero': 'indie'},
#   {'track_name': 'Forget About You (Intimate)',
#    'artist_name': 'Devin Kennedy',
#    'release_date': '2022-08-19',
#    'id_track': '16BMKSNU69eW0y1Q0vWvwa',
#    'popularity': 54,
#    'genero': 'indie'},
#   {'track_name': 'Little Bull Of Blithe',
#    'artist_name': 'Sam Fender',
#    'release_date': '2022-12-09',
#    'id_track': '3BWlCKFFCDuiQoY4sKLKyI',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Them Changes - Sped Up',
#    'artist_name': 'Thundercat',
#    'release_date': '2022-10-06',
#    'id_track': '6pod2VRHVTven17Da0uZHi',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'Giovani Wannabe',
#    'artist_name': 'Pinguini Tattici Nucleari',
#    'release_date': '2022-05-27',
#    'id_track': '7iLuBTHJSXM2HalKHFqEEy',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'Wondrous Place',
#    'artist_name': 'Drug Store Romeos',
#    'release_date': '2022-06-10',
#    'id_track': '0oXJQ8CyDcQJXASZiCSNGa',
#    'popularity': 43,
#    'genero': 'indie'},
#   {'track_name': 'POLTERGEIST!',
#    'artist_name': 'CORPSE, OmenXIII',
#    'release_date': '2022-04-08',
#    'id_track': '041sluNZwBxTCOuu766eNi',
#    'popularity': 53,
#    'genero': 'indie'},
#   {'track_name': 'Occhi rossi',
#    'artist_name': 'Coez',
#    'release_date': '2022-05-18',
#    'id_track': '5bvsNn7f4m0MTCuUQkMZGY',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'For You - Many Selves Version',
#    'artist_name': 'Kadhja Bonet',
#    'release_date': '2022-02-09',
#    'id_track': '1ZomkKbXsQoycnKzGV6NIZ',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'Northern Attitude',
#    'artist_name': 'Noah Kahan',
#    'release_date': '2022-09-16',
#    'id_track': '5hAFKx1IMhvx73JA6MSkIP',
#    'popularity': 53,
#    'genero': 'indie'},
#   {'track_name': 'Boyhood',
#    'artist_name': 'Birth Day',
#    'release_date': '2022-06-10',
#    'id_track': '490lRD7SCOhDbPcmcgQF9s',
#    'popularity': 53,
#    'genero': 'indie'},
#   {'track_name': 'Love Is Complicated (The Angels Sing)',
#    'artist_name': 'Labrinth',
#    'release_date': '2022-04-22',
#    'id_track': '5mbLTFP3GSGp1NH1ah2KG9',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'ACORDA PEDRINHO',
#    'artist_name': 'Jovem Dionisio',
#    'release_date': '2022-03-21',
#    'id_track': '2sUhjzuc6w4SRFwoC3LvXZ',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'Nosebleed Seats',
#    'artist_name': 'Vansire',
#    'release_date': '2022-05-12',
#    'id_track': '3zREOGri6ic2vk6Dt2NJWk',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': '(Pick Me Up) Euphoria - From "Euphoria" An HBO Original Series',
#    'artist_name': 'James Blake, Labrinth',
#    'release_date': '2022-01-28',
#    'id_track': '6QFCgioM2ZDxCEadWUes2b',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'Warm Ocean',
#    'artist_name': 'Salt Tree',
#    'release_date': '2022-02-11',
#    'id_track': '1x8yFhcdS5NgTceVdjT24m',
#    'popularity': 41,
#    'genero': 'indie'},
#   {'track_name': 'Bathroom Light',
#    'artist_name': 'Mt. Joy',
#    'release_date': '2022-06-03',
#    'id_track': '71glNHT4FultOqlau4zrFf',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'What It Is',
#    'artist_name': 'Amber Mark',
#    'release_date': '2022-01-28',
#    'id_track': '0w3A7y2EJ8awXWMUtftue5',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Chapstick',
#    'artist_name': 'COIN',
#    'release_date': '2022-03-25',
#    'id_track': '33E5u0qmzBlsHkhU1bTBWa',
#    'popularity': 54,
#    'genero': 'indie'},
#   {'track_name': 'Lift You Up',
#    'artist_name': 'LÉON',
#    'release_date': '2022-03-04',
#    'id_track': '4jGPk5J6GFrX1AzowueGoo',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'Just the Right Song',
#    'artist_name': 'Vansire',
#    'release_date': '2022-05-12',
#    'id_track': '4P3mcaMeif02CSqx6MAleZ',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'Ms. Poli Sci',
#    'artist_name': 'Paul Russell, Khary',
#    'release_date': '2022-11-11',
#    'id_track': '3imYkN34og7muZbkSZWLUW',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'Homerton',
#    'artist_name': 'Loyle Carner, JNR WILLIAMS, Olivia Dean',
#    'release_date': '2022-10-21',
#    'id_track': '1E8ZZzvgrMwm8qUi5IjOHt',
#    'popularity': 48,
#    'genero': 'indie'},
#   {'track_name': 'Bread Song',
#    'artist_name': 'Black Country, New Road',
#    'release_date': '2022-02-04',
#    'id_track': '7hxdkHpl8gNgx3NnoffkK4',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'Ain’t No Thief',
#    'artist_name': 'Viagra Boys',
#    'release_date': '2022-07-08',
#    'id_track': '1gPRoX2iVsbJnkWBGrW7Kg',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'wonder if she loves me',
#    'artist_name': 'JVKE',
#    'release_date': '2022-09-23',
#    'id_track': '5cceQYu8V7ZdFkMvdH6qPK',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'Line It Up (feat. LP)',
#    'artist_name': 'Palaye Royale, LP',
#    'release_date': '2022-10-28',
#    'id_track': '6pt3VzqcJ5jIUR5JyBtkmW',
#    'popularity': 42,
#    'genero': 'indie'},
#   {'track_name': 'cuéntame una historia de rencor',
#    'artist_name': 'Kevin Kaarl, El Guincho',
#    'release_date': '2022-08-25',
#    'id_track': '01g1VurJU8HG6B7vMel0hV',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': "Don't Miss",
#    'artist_name': 'The Blue Stones',
#    'release_date': '2022-11-04',
#    'id_track': '1ggbqc7jhg454UpFfSmdam',
#    'popularity': 45,
#    'genero': 'indie'},
#   {'track_name': 'Bull Breed',
#    'artist_name': 'Royel Otis',
#    'release_date': '2022-05-31',
#    'id_track': '0AJzVMzlFT03insWEIlrDz',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'My Mind',
#    'artist_name': 'Suki Waterhouse',
#    'release_date': '2022-05-06',
#    'id_track': '7fPSEiiNsZ5JybOoXLkaZN',
#    'popularity': 48,
#    'genero': 'indie'},
#   {'track_name': 'Higher',
#    'artist_name': 'SAULT',
#    'release_date': '2022-11-11',
#    'id_track': '0qnsUg7opCIpsBFHv0u7W1',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'Sunflower',
#    'artist_name': 'Tamino, Angèle',
#    'release_date': '2022-09-23',
#    'id_track': '6g7cJdDNjCDgqcpVGLzYhh',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': "Tumblin'",
#    'artist_name': 'The California Honeydrops',
#    'release_date': '2022-10-07',
#    'id_track': '53XMmw6emHn2NLt4YPPgPi',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'Vuelvo a Caer en un Túnel de Algodón',
#    'artist_name': 'El Plan De La Mariposa, Pedro Pastor',
#    'release_date': '2022-09-16',
#    'id_track': '3DIc5vKYOGk2NuRt38RW9L',
#    'popularity': 34,
#    'genero': 'indie'},
#   {'track_name': 'Stars at Noon',
#    'artist_name': 'Tindersticks',
#    'release_date': '2022-10-14',
#    'id_track': '026dJL0vYwCSfRYXzDKV4A',
#    'popularity': 37,
#    'genero': 'indie'},
#   {'track_name': 'Gilded Lily - Slowed + Reverb',
#    'artist_name': 'Cults',
#    'release_date': '2022-10-26',
#    'id_track': '1pmHy0UcUneFeyaMqQyh6V',
#    'popularity': 48,
#    'genero': 'indie'},
#   {'track_name': 'Your Stupid Face',
#    'artist_name': 'Kaden MacKay',
#    'release_date': '2022-06-11',
#    'id_track': '6f4HCP1JLS0ia5UdZ7hgJV',
#    'popularity': 50,
#    'genero': 'indie'},
#   {'track_name': 'Hot Mess',
#    'artist_name': 'Friday Pilots Club',
#    'release_date': '2022-06-23',
#    'id_track': '1mlVyUIqGTEkJy8sB5VchH',
#    'popularity': 48,
#    'genero': 'indie'},
#   {'track_name': 'Is It Over',
#    'artist_name': 'Σtella, Redinho',
#    'release_date': '2022-06-17',
#    'id_track': '5oR6jxK4RJzFPcb5beVff3',
#    'popularity': 45,
#    'genero': 'indie'},
#   {'track_name': "i like to think you're the leaves",
#    'artist_name': 'mage tears',
#    'release_date': '2022-08-17',
#    'id_track': '6OrfXVtcfifRxxebd9XG4L',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'AMOUR',
#    'artist_name': 'The Warning',
#    'release_date': '2022-06-24',
#    'id_track': '7tgH5rFMIMTfNaycKeMbDb',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'i haunt ur dreams',
#    'artist_name': 'hey, nothing',
#    'release_date': '2022-10-12',
#    'id_track': '7jBAskQhyfjmbYC0o3pXdW',
#    'popularity': 50,
#    'genero': 'indie'},
#   {'track_name': 'Bandido',
#    'artist_name': 'El Zar',
#    'release_date': '2022-11-04',
#    'id_track': '6vtx0XLuEsa0U8BcS8CoLc',
#    'popularity': 43,
#    'genero': 'indie'},
#   {'track_name': 'When Will It End',
#    'artist_name': 'Birth Day',
#    'release_date': '2022-06-10',
#    'id_track': '5F8RUGunSSBdu8Tn5qc63M',
#    'popularity': 52,
#    'genero': 'indie'}]}

# %%
len (resultados)
# Out:
# 4

# %%
type (resultados)
# Out:
# dict

# %%
resultados.keys ()
# Out:
# dict_keys(['reggaeton', 'pop', 'rap', 'indie'])

# %%
resultados.values ()
# Out:
# dict_values([[{'track_name': 'La Bachata', 'artist_name': 'Manuel Turizo', 'release_date': '2022-05-26', 'id_track': '5ww2BF9slyYgNOk37BlC4u', 'popularity': 73, 'genero': 'reggaeton'}, {'track_name': 'Ojitos Lindos', 'artist_name': 'Bad Bunny, Bomba Estéreo', 'release_date': '2022-05-06', 'id_track': '3k3NWokhRRkEPhCzPmV8TW', 'popularity': 78, 'genero': 'reggaeton'}, {'track_name': 'Feliz Cumpleaños Ferxxo', 'artist_name': 'Feid', 'release_date': '2022-09-14', 'id_track': '2CeKVsFFXG4QzA415QygGb', 'popularity': 77, 'genero': 'reggaeton'}, {'track_name': 'Hey Mor', 'artist_name': 'Ozuna, Feid', 'release_date': '2022-10-07', 'id_track': '1zsPaEkglFvxjAhrM8yhpr', 'popularity': 73, 'genero': 'reggaeton'}, {'track_name': 'Moscow Mule', 'artist_name': 'Bad Bunny', 'release_date': '2022-05-06', 'id_track': '6Xom58OOXk2SoU711L2IXO', 'popularity': 76, 'genero': 'reggaeton'}, {'track_name': 'Normal', 'artist_name': 'Feid', 'release_date': '2022-09-14', 'id_track': '0T2pB7P1VdXPhLdQZ488uH', 'popularity': 75, 'genero': 'reggaeton'}, {'track_name': 'Enséñame a Bailar', 'artist_name': 'Bad Bunny', 'release_date': '2022-05-06', 'id_track': '2NMjggapJcXXM7WccGEBUO', 'popularity': 72, 'genero': 'reggaeton'}, {'track_name': 'Tarot', 'artist_name': 'Bad Bunny, JHAYCO', 'release_date': '2022-05-06', 'id_track': '41oY4WCTj5kccfesTVFnvN', 'popularity': 73, 'genero': 'reggaeton'}, {'track_name': 'Me Porto Bonito', 'artist_name': 'Bad Bunny, Chencho Corleone', 'release_date': '2022-05-06', 'id_track': '6Sq7ltF9Qa7SNFBsV5Cogx', 'popularity': 77, 'genero': 'reggaeton'}, {'track_name': 'Tití Me Preguntó', 'artist_name': 'Bad Bunny', 'release_date': '2022-05-06', 'id_track': '1IHWl5LamUGEuP4ozKQSXZ', 'popularity': 77, 'genero': 'reggaeton'}, {'track_name': '¿Qué Nos Pasó?', 'artist_name': 'Anuel AA', 'release_date': '2022-05-26', 'id_track': '7k3qWn8D43a5ISa3x8lJux', 'popularity': 68, 'genero': 'reggaeton'}, {'track_name': 'CHORRITO PA LAS ANIMAS', 'artist_name': 'Feid', 'release_date': '2022-12-02', 'id_track': '0CYTGMBYkwUxrj1MWDLrC5', 'popularity': 72, 'genero': 'reggaeton'}, {'track_name': 'Ferxxo 100', 'artist_name': 'Feid', 'release_date': '2022-09-14', 'id_track': '1sbNEFiURUYfy024cJX8JG', 'popularity': 72, 'genero': 'reggaeton'}, {'track_name': 'Pareja Del Año', 'artist_name': 'Sebastian Yatra, Myke Towers', 'release_date': '2022-01-28', 'id_track': '655JkvIwu2rDCaD1hPf04g', 'popularity': 70, 'genero': 'reggaeton'}, {'track_name': 'Volare', 'artist_name': 'Danny Ocean', 'release_date': '2022-11-10', 'id_track': '7nE9H4e4uPOis5sJY39fOc', 'popularity': 72, 'genero': 'reggaeton'}, {'track_name': 'Tacones Rojos', 'artist_name': 'Sebastian Yatra', 'release_date': '2022-01-28', 'id_track': '6ylDpki1VpIsc525KC1ojF', 'popularity': 69, 'genero': 'reggaeton'}, {'track_name': 'Efecto', 'artist_name': 'Bad Bunny', 'release_date': '2022-05-06', 'id_track': '5Eax0qFko2dh7Rl2lYs3bx', 'popularity': 75, 'genero': 'reggaeton'}, {'track_name': 'Quiero Decirte', 'artist_name': 'Abraham Mateo, Ana Mena', 'release_date': '2022-05-12', 'id_track': '7dT6ccDqmMHvz5C0d8iUND', 'popularity': 55, 'genero': 'reggaeton'}, {'track_name': 'La Jumpa', 'artist_name': 'Arcángel, Bad Bunny', 'release_date': '2022-11-30', 'id_track': '5MxFWjuqQIsbNWbMdMdbli', 'popularity': 67, 'genero': 'reggaeton'}, {'track_name': 'Besos Moja2', 'artist_name': 'Wisin & Yandel, ROSALÍA', 'release_date': '2022-12-01', 'id_track': '6OzUIp8KjuwxJnCWkXp1uL', 'popularity': 65, 'genero': 'reggaeton'}, {'track_name': 'Un Coco', 'artist_name': 'Bad Bunny', 'release_date': '2022-05-06', 'id_track': '6VrQTLzzuyGIYjUDe4kAZk', 'popularity': 73, 'genero': 'reggaeton'}, {'track_name': 'Dharma', 'artist_name': 'Sebastian Yatra, Jorge Celedón, Rosario', 'release_date': '2022-01-28', 'id_track': '5tpAcJ47UgF4udM5YXcDd2', 'popularity': 57, 'genero': 'reggaeton'}, {'track_name': 'Neverita', 'artist_name': 'Bad Bunny', 'release_date': '2022-05-06', 'id_track': '31i56LZnwE6uSu3exoHjtB', 'popularity': 72, 'genero': 'regga ...

# %%
resultados ['pop']
# Out:
# [{'track_name': 'Quevedo: Bzrp Music Sessions, Vol. 52',
#   'artist_name': 'Bizarrap, Quevedo',
#   'release_date': '2022-07-06',
#   'id_track': '2tTmW7RDtMQtBk7m2rYeSw',
#   'popularity': 76,
#   'genero': 'pop'},
#  {'track_name': 'La Bachata',
#   'artist_name': 'Manuel Turizo',
#   'release_date': '2022-05-26',
#   'id_track': '5ww2BF9slyYgNOk37BlC4u',
#   'popularity': 73,
#   'genero': 'pop'},
#  {'track_name': 'Quién Diría',
#   'artist_name': 'DePol',
#   'release_date': '2022-04-08',
#   'id_track': '0Fd3900xH77g0ARXQjtYvV',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': 'Las Cosas Pequeñitas',
#   'artist_name': 'Marta Santos',
#   'release_date': '2022-04-22',
#   'id_track': '5LU8Lk8uSCdMgBaqcTujmi',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': 'Sin Vergüenza',
#   'artist_name': 'Arde Bogotá, Dani Fernández',
#   'release_date': '2022-07-07',
#   'id_track': '0mJ2qmDI2X4wrSIIBrvvpN',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'Feliz Cumpleaños Ferxxo',
#   'artist_name': 'Feid',
#   'release_date': '2022-09-14',
#   'id_track': '2CeKVsFFXG4QzA415QygGb',
#   'popularity': 77,
#   'genero': 'pop'},
#  {'track_name': 'Hey Mor',
#   'artist_name': 'Ozuna, Feid',
#   'release_date': '2022-10-07',
#   'id_track': '1zsPaEkglFvxjAhrM8yhpr',
#   'popularity': 73,
#   'genero': 'pop'},
#  {'track_name': 'El Bien',
#   'artist_name': 'Viva Suecia',
#   'release_date': '2022-10-06',
#   'id_track': '6IuZFiKCeyQINqL0Id3xF2',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'Que nada nos pare (lo más importante)',
#   'artist_name': 'ELYELLA, La La Love You',
#   'release_date': '2022-06-30',
#   'id_track': '1FG7ZjnuT0O9CsDKOxND0E',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'Normal',
#   'artist_name': 'Feid',
#   'release_date': '2022-09-14',
#   'id_track': '0T2pB7P1VdXPhLdQZ488uH',
#   'popularity': 75,
#   'genero': 'pop'},
#  {'track_name': 'Qué Bonita',
#   'artist_name': 'DePol',
#   'release_date': '2022-11-25',
#   'id_track': '31TmMW92lP0UoxtAaF89hU',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': "I'm Good (Blue)",
#   'artist_name': 'David Guetta, Bebe Rexha',
#   'release_date': '2022-08-26',
#   'id_track': '4uUG5RXrOk84mYEfFvj3cK',
#   'popularity': 81,
#   'genero': 'pop'},
#  {'track_name': 'As It Was',
#   'artist_name': 'Harry Styles',
#   'release_date': '2022-05-20',
#   'id_track': '4Dvkj6JhhA12EX05fT7y2e',
#   'popularity': 83,
#   'genero': 'pop'},
#  {'track_name': 'Fuera del mercado',
#   'artist_name': 'Danny Ocean',
#   'release_date': '2022-02-17',
#   'id_track': '1UdzJEpgJxtuXAlCOvD4S0',
#   'popularity': 73,
#   'genero': 'pop'},
#  {'track_name': 'mariposas',
#   'artist_name': 'sangiovanni, Aitana',
#   'release_date': '2022-06-02',
#   'id_track': '5R2hNuiiwnKVAUNktF9j2Y',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'No Hemos Aprendido Nada',
#   'artist_name': 'Viva Suecia',
#   'release_date': '2022-10-06',
#   'id_track': '23EYaP0VXowC6oT9DiY3QR',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'SI ELLA SUPIERA',
#   'artist_name': 'India Martinez, Melendi',
#   'release_date': '2022-12-02',
#   'id_track': '0quM3iWAOKw9OGIMBsppSC',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'CHORRITO PA LAS ANIMAS',
#   'artist_name': 'Feid',
#   'release_date': '2022-12-02',
#   'id_track': '0CYTGMBYkwUxrj1MWDLrC5',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'Ferxxo 100',
#   'artist_name': 'Feid',
#   'release_date': '2022-09-14',
#   'id_track': '1sbNEFiURUYfy024cJX8JG',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'Pareja Del Año',
#   'artist_name': 'Sebastian Yatra, Myke Towers',
#   'release_date': '2022-01-28',
#   'id_track': '655JkvIwu2rDCaD1hPf04g',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'La Bachata',
#   'artist_name': 'Marta Santos',
#   'release_date': '2022-09-22',
#   'id_track': '46dmazd1o2QIs1DfjyyTx5',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Diablo',
#   'artist_name': 'Beret, Estopa',
#   'release_date': '2022-11-11',
#   'id_track': '0CLVh9I8uHfuyorOdLFim7',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Volare',
#   'artist_name': 'Danny Ocean',
#   'release_date': '2022-11-10',
#   'id_track': '7nE9H4e4uPOis5sJY39fOc',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'End of Beginning',
#   'artist_name': 'Djo',
#   'release_date': '2022-09-16',
#   'id_track': '3qhlB30KknSejmIvZZLjOD',
#   'popularity': 84,
#   'genero': 'pop'},
#  {'track_name': 'Tacones Rojos',
#   'artist_name': 'Sebastian Yatra',
#   'release_date': '2022-01-28',
#   'id_track': '6ylDpki1VpIsc525KC1ojF',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Hablar De Nada',
#   'artist_name': 'Viva Suecia',
#   'release_date': '2022-10-06',
#   'id_track': '6PLIfuZYh2IrRNqJIEH26S',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'DESPECHÁ',
#   'artist_name': 'ROSALÍA',
#   'release_date': '2022-07-28',
#   'id_track': '5ildQOEKmJuWGl2vRkFdYc',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Y te voy a querer',
#   'artist_name': 'Antoñito Molina',
#   'release_date': '2022-02-04',
#   'id_track': '6ejDR4zHUdTUuzdnwuCrHK',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'FUE',
#   'artist_name': 'Manuel Carrasco',
#   'release_date': '2022-11-24',
#   'id_track': '69billX7itLzkgWjqWSFFn',
#   'popularity': 54,
#   'genero': 'pop'},
#  {'track_name': 'Camiseta de Rokanrol',
#   'artist_name': 'Estopa, Fito y Fitipaldis',
#   'release_date': '2022-02-24',
#   'id_track': '1eHr7GbGrNMIb01YUwLdku',
#   'popularity': 54,
#   'genero': 'pop'},
#  {'track_name': 'Envuelto en llamas',
#   'artist_name': 'Marta Santos',
#   'release_date': '2022-06-03',
#   'id_track': '2AQ5hqdrS6qS81R6nHgLw4',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Quiero Decirte',
#   'artist_name': 'Abraham Mateo, Ana Mena',
#   'release_date': '2022-05-12',
#   'id_track': '7dT6ccDqmMHvz5C0d8iUND',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Quieres',
#   'artist_name': 'Aitana, Emilia, Ptazeta',
#   'release_date': '2022-07-21',
#   'id_track': '4iGnpp1h0i33lpoP42Y8Jt',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'Clima Tropical',
#   'artist_name': 'Dani Fernández',
#   'release_date': '2022-02-18',
#   'id_track': '7JFa80j5Cw6DMf8RISgd0t',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Lo Siento',
#   'artist_name': 'Viva Suecia, Dani Fernández',
#   'release_date': '2022-10-06',
#   'id_track': '6RM3IZHeEwhvTXxfquDbZN',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Dile a los demás',
#   'artist_name': 'Dani Fernández',
#   'release_date': '2022-02-18',
#   'id_track': '71J4vM6OnOl9Bs99CaS2dq',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Me estoy volviendo loco',
#   'artist_name': 'Antoñito Molina',
#   'release_date': '2022-02-04',
#   'id_track': '2BwrXqrvawHTSUjncMivxP',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Dharma',
#   'artist_name': 'Sebastian Yatra, Jorge Celedón, Rosario',
#   'release_date': '2022-01-28',
#   'id_track': '5tpAcJ47UgF4udM5YXcDd2',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Justo Cuando El Mundo Apriete',
#   'artist_name': 'Viva Suecia, Leiva',
#   'release_date': '2022-10-06',
#   'id_track': '1C2aofmIOndmXAtrHeJ3YC',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Si tus piernas',
#   'artist_name': 'Dani Fernández',
#   'release_date': '2022-02-18',
#   'id_track': '5wqwUPr7DbRT6FogXVmWWj',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'Amigos (con Maria Becerra)',
#   'artist_name': 'Pablo Alborán, Maria Becerra',
#   'release_date': '2022-12-01',
#   'id_track': '20NeR3CwuyGfRktTncKRU7',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'LAS 12',
#   'artist_name': 'Ana Mena, Belinda',
#   'release_date': '2022-06-17',
#   'id_track': '0EpdLuptraYGFZ6J7HNSLc',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'DESPECHÁ',
#   'artist_name': 'ROSALÍA',
#   'release_date': '2022-09-09',
#   'id_track': '53tfEupEzQRtVFOeZvk7xq',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Porfa no te vayas',
#   'artist_name': 'Beret, Morat',
#   'release_date': '2022-11-11',
#   'id_track': '2XA5q5FBwqrlkGBzzOOVeK',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'MAMIII',
#   'artist_name': 'Becky G, KAROL G',
#   'release_date': '2022-05-13',
#   'id_track': '7FlQk2gJ6TBrHHiidvdR2O',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Cerquita de Mí',
#   'artist_name': 'Marta Santos',
#   'release_date': '2022-07-15',
#   'id_track': '661LWfw9LjFUFtrNDhgekb',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'Si Te La Encuentras Por Ahí',
#   'artist_name': 'Feid',
#   'release_date': '2022-09-14',
#   'id_track': '2vsoD8S1OyrWSVIA43hjaU',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'LA FAMA',
#   'artist_name': 'ROSALÍA, The Weeknd',
#   'release_date': '2022-03-18',
#   'id_track': '6Y46tOTRhkBamosyuWa6YX',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Te Felicito',
#   'artist_name': 'Shakira, Rauw Alejandro',
#   'release_date': '2022-04-21',
#   'id_track': '2rurDawMfoKP4uHyb2kJBt',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Bones',
#   'artist_name': 'Imagine Dragons',
#   'release_date': '2022-07-01',
#   'id_track': '54ipXppHLA8U4yqpOFTUhr',
#   'popularity': 76,
#   'genero': 'pop'},
#  {'track_name': 'Debí Suponerlo',
#   'artist_name': 'Morat',
#   'release_date': '2022-11-04',
#   'id_track': '2pIIRKRwWSi1Sb29VYLOOa',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Villano Antillano: Bzrp Music Sessions, Vol. 51',
#   'artist_name': 'Bizarrap, Villano Antillano',
#   'release_date': '2022-06-08',
#   'id_track': '4hceSKjrkDTO0nMKFcb3sj',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Ya no me muero por nadie',
#   'artist_name': 'Antoñito Molina',
#   'release_date': '2022-02-04',
#   'id_track': '6McW3rivyQPC2tBFwL7O43',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Duki: Bzrp Music Sessions, Vol. 50',
#   'artist_name': 'Bizarrap, Duki',
#   'release_date': '2022-11-16',
#   'id_track': '7MkylDYvKTSuWgrsBhHlsG',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'El día menos pensado',
#   'artist_name': 'Beret',
#   'release_date': '2022-11-11',
#   'id_track': '5tQ0WNliZPouHDIzP66l9I',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Salir Con Vida',
#   'artist_name': 'Morat, Feid',
#   'release_date': '2022-11-04',
#   'id_track': '0cubEBmB9wjsdBwXNFmzFy',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Chica Ideal',
#   'artist_name': 'Sebastian Yatra, Guaynaa',
#   'release_date': '2022-01-28',
#   'id_track': '4lCpamtFAIUga83gTKP8RY',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'MAMIII',
#   'artist_name': 'Becky G, KAROL G',
#   'release_date': '2022-02-10',
#   'id_track': '1ri9ZUkBJVFUdgwzCnfcYs',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Enemy (with JID) - from the series Arcane League of Legends',
#   'artist_name': 'Imagine Dragons, JID, Arcane, League of Legends',
#   'release_date': '2022-07-01',
#   'id_track': '3CIyK1V4JEJkg02E4EJnDl',
#   'popularity': 75,
#   'genero': 'pop'},
#  {'track_name': 'MUSEO',
#   'artist_name': 'Rauw Alejandro',
#   'release_date': '2022-02-25',
#   'id_track': '6WfxIJKmYRSpsBJv0tEAKX',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'como si no importara',
#   'artist_name': 'Emilia, Duki',
#   'release_date': '2022-05-31',
#   'id_track': '7M0mBls29IohQIPGqegcyE',
#   'popularity': 62,
#   'genero': 'pop'},
#  {'track_name': 'TV',
#   'artist_name': 'Billie Eilish',
#   'release_date': '2022-07-21',
#   'id_track': '3GYlZ7tbxLOxe6ewMNVTkw',
#   'popularity': 80,
#   'genero': 'pop'},
#  {'track_name': 'Monotonía',
#   'artist_name': 'Shakira, Ozuna',
#   'release_date': '2022-10-19',
#   'id_track': '6G12ZafqofSq7YtrMqUm76',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Prohibidox',
#   'artist_name': 'Feid',
#   'release_date': '2022-09-14',
#   'id_track': '3PpWCS95gDUDRPko3u1MZ9',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Moth To A Flame (with The Weeknd)',
#   'artist_name': 'Swedish House Mafia, The Weeknd',
#   'release_date': '2022-04-15',
#   'id_track': '0VO8gYVDSwM1Qdd2GsMoYK',
#   'popularity': 76,
#   'genero': 'pop'},
#  {'track_name': "I Ain't Worried",
#   'artist_name': 'OneRepublic',
#   'release_date': '2022-05-13',
#   'id_track': '4h9wh7iOZ0GGn8QVp4RAOB',
#   'popularity': 77,
#   'genero': 'pop'},
#  {'track_name': 'Solo Conmigo',
#   'artist_name': 'Romeo Santos',
#   'release_date': '2022-09-01',
#   'id_track': '22iCMlT0xYryKNnz4X5Vwn',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Made You Look',
#   'artist_name': 'Meghan Trainor',
#   'release_date': '2022-10-21',
#   'id_track': '0QHEIqNKsMoOY5urbzN48u',
#   'popularity': 74,
#   'genero': 'pop'},
#  {'track_name': '506',
#   'artist_name': 'Morat, Juanes',
#   'release_date': '2022-11-04',
#   'id_track': '4Q1oBLFPK9R4eUHkNlihlF',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Calm Down (with Selena Gomez)',
#   'artist_name': 'Rema, Selena Gomez',
#   'release_date': '2022-08-25',
#   'id_track': '0WtM2NBVQNNJLh6scP13H8',
#   'popularity': 76,
#   'genero': 'pop'},
#  {'track_name': 'Segundos Platos',
#   'artist_name': 'Morat',
#   'release_date': '2022-11-04',
#   'id_track': '1pHZf30WYm6CQukt7TvNPM',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Kill Bill',
#   'artist_name': 'SZA',
#   'release_date': '2022-12-08',
#   'id_track': '1Qrg8KqiBpW07V7PNxwwwL',
#   'popularity': 82,
#   'genero': 'pop'},
#  {'track_name': 'Nonsense',
#   'artist_name': 'Sabrina Carpenter',
#   'release_date': '2022-07-15',
#   'id_track': '6dgUya35uo964z7GZXM07g',
#   'popularity': 81,
#   'genero': 'pop'},
#  {'track_name': 'NIGHTS LIKE THESE',
#   'artist_name': 'Benson Boone',
#   'release_date': '2022-07-29',
#   'id_track': '33vZRjxJScapmRShRJq8I0',
#   'popularity': 76,
#   'genero': 'pop'},
#  {'track_name': 'Stick Season',
#   'artist_name': 'Noah Kahan',
#   'release_date': '2022-10-14',
#   'id_track': '0mflMxspEfB0VbI1kyLiAv',
#   'popularity': 82,
#   'genero': 'pop'},
#  {'track_name': 'Anti-Hero',
#   'artist_name': 'Taylor Swift',
#   'release_date': '2022-10-21',
#   'id_track': '0V3wPSX9ygBnCm8psDIegu',
#   'popularity': 77,
#   'genero': 'pop'},
#  {'track_name': 'Bam Bam (feat. Ed Sheeran)',
#   'artist_name': 'Camila Cabello, Ed Sheeran',
#   'release_date': '2022-03-04',
#   'id_track': '0QBzMgT7NIeoCYy3sJCof1',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Le Pido a DIOS',
#   'artist_name': 'Feid, DJ Premier',
#   'release_date': '2022-12-02',
#   'id_track': '4TFNKnMWjcMWzpkSwQrrcu',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'AUTOMÁTICO',
#   'artist_name': 'Maria Becerra',
#   'release_date': '2022-12-08',
#   'id_track': '0poQY3RMThmIiutOGv3yH3',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'Romantic Homicide',
#   'artist_name': 'd4vd',
#   'release_date': '2022-07-20',
#   'id_track': '1xK59OXxi2TAAAbmZK0kBL',
#   'popularity': 81,
#   'genero': 'pop'},
#  {'track_name': 'SIRI',
#   'artist_name': 'Romeo Santos, Chris Lebron',
#   'release_date': '2022-09-01',
#   'id_track': '5S4aEL1BMsgLvCSt4BijHd',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'Normal',
#   'artist_name': 'Feid',
#   'release_date': '2022-07-08',
#   'id_track': '2z9YkcLojiOE7Eu2p9lPZR',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'Belly Dancer',
#   'artist_name': 'Imanbek, BYOR',
#   'release_date': '2022-02-18',
#   'id_track': '7fZBQnc0zXwVybgCIrQQil',
#   'popularity': 73,
#   'genero': 'pop'},
#  {'track_name': 'Snooze',
#   'artist_name': 'SZA',
#   'release_date': '2022-12-09',
#   'id_track': '4iZ4pt7kvcaH6Yo8UoZ4s2',
#   'popularity': 84,
#   'genero': 'pop'},
#  {'track_name': 'Ferrari',
#   'artist_name': 'James Hype, Miggy Dela Rosa',
#   'release_date': '2022-04-01',
#   'id_track': '4zN21mbAuaD0WqtmaTZZeP',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'Heaven Takes You Home (feat. Connie Constance)',
#   'artist_name': 'Swedish House Mafia, Connie Constance',
#   'release_date': '2022-04-15',
#   'id_track': '3nEHrvNNtgLv9rneTAYVr4',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'Deep Down (feat. Never Dull)',
#   'artist_name': 'Alok, Ella Eyre, Kenny Dope, Never Dull',
#   'release_date': '2022-06-17',
#   'id_track': '7MIhUdNJtaOnDmC5nBC1fb',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': "she's all i wanna be",
#   'artist_name': 'Tate McRae',
#   'release_date': '2022-05-27',
#   'id_track': '7l9IqDtVWJurTvkQHq1BGh',
#   'popularity': 76,
#   'genero': 'pop'},
#  {'track_name': 'Late Night Talking',
#   'artist_name': 'Harry Styles',
#   'release_date': '2022-05-20',
#   'id_track': '1qEmFfgcLObUfQm0j1W2CK',
#   'popularity': 73,
#   'genero': 'pop'},
#  {'track_name': 'Is There Someone Else?',
#   'artist_name': 'The Weeknd',
#   'release_date': '2022-01-06',
#   'id_track': '0mL82sxCRjrs3br407IdJh',
#   'popularity': 77,
#   'genero': 'pop'},
#  {'track_name': 'Unholy (feat. Kim Petras)',
#   'artist_name': 'Sam Smith, Kim Petras',
#   'release_date': '2022-09-22',
#   'id_track': '3nqQXoyQOWXiESFLlDF1hG',
#   'popularity': 73,
#   'genero': 'pop'},
#  {'track_name': 'because i liked a boy',
#   'artist_name': 'Sabrina Carpenter',
#   'release_date': '2022-07-15',
#   'id_track': '32FhTAAjKZaBein150o3Px',
#   'popularity': 76,
#   'genero': 'pop'},
#  {'track_name': 'ADIÓS',
#   'artist_name': 'Maria Becerra',
#   'release_date': '2022-12-08',
#   'id_track': '2bNCiY24Eh4saMcc23bvUN',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'Sharks',
#   'artist_name': 'Imagine Dragons',
#   'release_date': '2022-07-01',
#   'id_track': '7sA2SKTo1QbTSSYn5YvJC4',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Feliz Cumpleaños Ferxxo',
#   'artist_name': 'Feid',
#   'release_date': '2022-08-19',
#   'id_track': '3kUq4sBcmxhnOtNysZ9yrp',
#   'popularity': 62,
#   'genero': 'pop'},
#  {'track_name': 'Bones',
#   'artist_name': 'Imagine Dragons',
#   'release_date': '2022-03-11',
#   'id_track': '0HqZX76SFLDz2aW8aiqi7G',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'DPM (De Pxta Madre)',
#   'artist_name': 'Kany García',
#   'release_date': '2022-05-27',
#   'id_track': '4wJXlFV0oh88ktxE54uqKE',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'CUFF IT',
#   'artist_name': 'Beyoncé',
#   'release_date': '2022-07-29',
#   'id_track': '1xzi1Jcr7mEi9K2RfzLOqS',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'Where Did You Go? (feat. MNEK)',
#   'artist_name': 'Jax Jones, MNEK',
#   'release_date': '2022-02-04',
#   'id_track': '3sa06xVNmLLYIxdNNmVQN8',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Jimmy Cooks (feat. 21 Savage)',
#   'artist_name': 'Drake, 21 Savage',
#   'release_date': '2022-06-17',
#   'id_track': '3F5CgOj3wFlRv51JsHbxhe',
#   'popularity': 76,
#   'genero': 'pop'},
#  {'track_name': 'the perfect pair',
#   'artist_name': 'beabadoobee',
#   'release_date': '2022-07-15',
#   'id_track': '41P6Tnd8KIHqON0QIydx6a',
#   'popularity': 80,
#   'genero': 'pop'},
#  {'track_name': 'Good Looking',
#   'artist_name': 'Suki Waterhouse',
#   'release_date': '2022-08-18',
#   'id_track': '0j3mqDTK4Z6lvrLzFCUUz6',
#   'popularity': 78,
#   'genero': 'pop'},
#  {'track_name': 'Crazy What Love Can Do',
#   'artist_name': 'David Guetta, Becky Hill, Ella Henderson',
#   'release_date': '2022-04-08',
#   'id_track': '1WCEAGGRD066z2Q89ObXTq',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'ceilings',
#   'artist_name': 'Lizzy McAlpine',
#   'release_date': '2022-04-08',
#   'id_track': '2L9N0zZnd37dwF0clgxMGI',
#   'popularity': 76,
#   'genero': 'pop'},
#  {'track_name': 'Open Arms (feat. Travis Scott)',
#   'artist_name': 'SZA, Travis Scott',
#   'release_date': '2022-12-08',
#   'id_track': '6koKhrBBcExADvWuOgceNZ',
#   'popularity': 79,
#   'genero': 'pop'},
#  {'track_name': 'Moth To A Flame (with The Weeknd)',
#   'artist_name': 'Swedish House Mafia, The Weeknd',
#   'release_date': '2022-01-03',
#   'id_track': '7kfOEMJBJwdCYqyJeEnNhr',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Ferxxo 100',
#   'artist_name': 'Feid',
#   'release_date': '2022-06-03',
#   'id_track': '6ipzb1kHhWIxp1tS0vwqPl',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': 'Call It Love',
#   'artist_name': 'Felix Jaehn, Ray Dalton',
#   'release_date': '2022-09-16',
#   'id_track': '5YdnOm5990Kfq1Jodws98B',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'Another Love - Tiësto Remix',
#   'artist_name': 'Tom Odell, Tiësto',
#   'release_date': '2022-05-13',
#   'id_track': '4Et6tUEO7biKxZEfJXpNj1',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'In The Stars',
#   'artist_name': 'Benson Boone',
#   'release_date': '2022-04-29',
#   'id_track': '1ei3hzQmrgealgRKFxIcWn',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'DESAFIANDO EL DESTINO',
#   'artist_name': 'Maria Becerra',
#   'release_date': '2022-12-09',
#   'id_track': '4rBQxFVwTnf99p818azSon',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'How Do I Say Goodbye',
#   'artist_name': 'Dean Lewis',
#   'release_date': '2022-11-04',
#   'id_track': '1aOl53hkZGHkl2Snhr7opL',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': '21 Reasons (feat. Ella Henderson)',
#   'artist_name': 'Nathan Dawe, Ella Henderson',
#   'release_date': '2022-04-29',
#   'id_track': '1RF02Cf80mTaeNXG2P2boR',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Get Busy',
#   'artist_name': 'Sean Paul',
#   'release_date': '2022-11-11',
#   'id_track': '6bK9BH9Ts8Gj5JFvnQkzak',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'How Do I Say Goodbye',
#   'artist_name': 'Dean Lewis',
#   'release_date': '2022-08-31',
#   'id_track': '5hnGrTBaEsdukpDF6aZg8a',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': "You're On Your Own, Kid",
#   'artist_name': 'Taylor Swift',
#   'release_date': '2022-10-21',
#   'id_track': '4D7BCuvgdJlYvlX5WlN54t',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': '10:35',
#   'artist_name': 'Tiësto, Tate McRae',
#   'release_date': '2022-11-03',
#   'id_track': '6BePGk3eCan4FqaW2X8Qy3',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Follow You',
#   'artist_name': 'Imagine Dragons',
#   'release_date': '2022-07-01',
#   'id_track': '0LtkAAEpEp1lkLX1ZvjHZb',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Satisfaction',
#   'artist_name': 'David Guetta, Benny Benassi',
#   'release_date': '2022-08-12',
#   'id_track': '0lwyzp7GppQxv0Eu6wRkUo',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Memories',
#   'artist_name': 'Conan Gray',
#   'release_date': '2022-06-24',
#   'id_track': '5UXJzLFdBn6u9FJTCnoHrH',
#   'popularity': 74,
#   'genero': 'pop'},
#  {'track_name': 'Bad Memories (feat. Elley Duhé & FAST BOY)',
#   'artist_name': 'MEDUZA, James Carter, Elley Duhé, FAST BOY',
#   'release_date': '2022-07-22',
#   'id_track': '3rb0tMq42WfggucPm0HHkA',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'golden hour',
#   'artist_name': 'JVKE',
#   'release_date': '2022-09-23',
#   'id_track': '5odlY52u43F5BjByhxg7wg',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'Before You',
#   'artist_name': 'Benson Boone',
#   'release_date': '2022-10-28',
#   'id_track': '523f4oSjrZx83XDtRLnsIw',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Bebo',
#   'artist_name': 'Romeo Santos',
#   'release_date': '2022-09-01',
#   'id_track': '7HsebNHZDGj8UhWIrZaMx6',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'KU LO SA - A COLORS SHOW',
#   'artist_name': 'Oxlade',
#   'release_date': '2022-06-10',
#   'id_track': '2WigMwGJysIh9fRnSJvpjn',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Calm Down',
#   'artist_name': 'Rema',
#   'release_date': '2022-02-10',
#   'id_track': '6hgoYQDUcPyCz7LcTUHKxa',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Heaven Is A Place On Earth',
#   'artist_name': 'W&W, AXMO',
#   'release_date': '2022-12-16',
#   'id_track': '6FAmtZoa7jq6bH9GBjCRkM',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Bolide allemand',
#   'artist_name': 'SDM',
#   'release_date': '2022-12-02',
#   'id_track': '0EzNyXyU7gHzj2TN8qYThj',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'cuatro veinte',
#   'artist_name': 'Emilia',
#   'release_date': '2022-05-31',
#   'id_track': '3ushwCdjpWNdSnZgRFU6Oc',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Belixe',
#   'artist_name': 'Feid',
#   'release_date': '2022-09-14',
#   'id_track': '0S4w5ZBEbxYxiygvz9wWdK',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'About Damn Time',
#   'artist_name': 'Lizzo',
#   'release_date': '2022-07-15',
#   'id_track': '6HMtHNpW6YPi1hrw9tgF8P',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'Shut up My Moms Calling (Sped up)',
#   'artist_name': 'Hotel Ugly',
#   'release_date': '2022-09-14',
#   'id_track': '31mzt4ZV8C0f52pIz1NSwd',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'Marte',
#   'artist_name': 'Sofía Reyes, Maria Becerra',
#   'release_date': '2022-02-10',
#   'id_track': '1uK5rDY3BnikyG0sl3tPpc',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': 'Castigo',
#   'artist_name': 'Feid',
#   'release_date': '2022-09-14',
#   'id_track': '18pWcEUcUJpBFs7eNBsBht',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'Words (feat. Zara Larsson)',
#   'artist_name': 'Alesso, Zara Larsson',
#   'release_date': '2022-04-22',
#   'id_track': '1bgKMxPQU7JIZEhNsM1vFs',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Little Freak',
#   'artist_name': 'Harry Styles',
#   'release_date': '2022-05-20',
#   'id_track': '3i058E8uxTsYqJ5NWZzqSj',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Los Besos',
#   'artist_name': 'Greeicy',
#   'release_date': '2022-03-04',
#   'id_track': '50SFVefoyzWnJy1oQWfRtr',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': 'California',
#   'artist_name': 'Feid',
#   'release_date': '2022-12-02',
#   'id_track': '19iUrnYyBAG5LaxT72ajsM',
#   'popularity': 59,
#   'genero': 'pop'},
#  {'track_name': 'Mojando Asientos (feat. Feid)',
#   'artist_name': 'Maluma, Feid',
#   'release_date': '2022-03-24',
#   'id_track': '0LKu09Iq053CEUZ5ktQEWc',
#   'popularity': 59,
#   'genero': 'pop'},
#  {'track_name': 'Karma',
#   'artist_name': 'Taylor Swift',
#   'release_date': '2022-10-21',
#   'id_track': '7KokYm8cMIXCsGVmUvKtqf',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'golden hour',
#   'artist_name': 'JVKE',
#   'release_date': '2022-10-03',
#   'id_track': '4yNk9iz9WVJikRFle3XEvn',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'Kill Bill',
#   'artist_name': 'SZA',
#   'release_date': '2022-12-09',
#   'id_track': '3OHfY25tqY28d16oZczHc8',
#   'popularity': 75,
#   'genero': 'pop'},
#  {'track_name': 'Hold My Hand',
#   'artist_name': 'Lady Gaga',
#   'release_date': '2022-05-03',
#   'id_track': '0oWraSo5ASJ0h1BEagTyEw',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Wrecked',
#   'artist_name': 'Imagine Dragons',
#   'release_date': '2022-07-01',
#   'id_track': '6TEftSkmWdTm1EpThnwqh6',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'this is what falling in love feels like',
#   'artist_name': 'JVKE',
#   'release_date': '2022-09-23',
#   'id_track': '2PWTZV5znjLtZC5T1EVJvL',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'Run BTS',
#   'artist_name': 'BTS',
#   'release_date': '2022-06-10',
#   'id_track': '69xohKu8C1fsflYAiSNbwM',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'Gilded Lily',
#   'artist_name': 'Cults',
#   'release_date': '2022-10-26',
#   'id_track': '3Z0qLOS0cqWKPHXkbTXmNF',
#   'popularity': 74,
#   'genero': 'pop'},
#  {'track_name': 'MANIAC',
#   'artist_name': 'Stray Kids',
#   'release_date': '2022-03-18',
#   'id_track': '63irPUP3xB74fHdw1Aw9zR',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'In My Room',
#   'artist_name': 'Chance Peña',
#   'release_date': '2022-05-06',
#   'id_track': '7CiDwKE62N6ey3LyG6s7xc',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'Good Days',
#   'artist_name': 'SZA',
#   'release_date': '2022-12-09',
#   'id_track': '4PMqSO5qyjpvzhlLI5GnID',
#   'popularity': 78,
#   'genero': 'pop'},
#  {'track_name': 'Wasted Love (feat. Lagique)',
#   'artist_name': 'Ofenbach, Lagique',
#   'release_date': '2022-09-02',
#   'id_track': '1cYyZ1N98GyRS3cMcccFHd',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Numb',
#   'artist_name': 'Marshmello, Khalid',
#   'release_date': '2022-06-10',
#   'id_track': '10xV5l9nhLvFpR8mqzs0bL',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'FAKE LOVE',
#   'artist_name': 'BTS',
#   'release_date': '2022-06-10',
#   'id_track': '3YspylwDrs1LuzPONbKmAL',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'MORE',
#   'artist_name': 'j-hope',
#   'release_date': '2022-07-15',
#   'id_track': '7GARzfC1mwhDuk4t9WOACq',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Me Extraño',
#   'artist_name': 'Romeo Santos, Christian Nodal',
#   'release_date': '2022-09-01',
#   'id_track': '3qx4POjFiODHPwCBjq8IEW',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': 'Read your Mind',
#   'artist_name': 'Sabrina Carpenter',
#   'release_date': '2022-07-15',
#   'id_track': '4Wos0h9ECU2Z3oJMTQxpbc',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'Pink Venom',
#   'artist_name': 'BLACKPINK',
#   'release_date': '2022-09-15',
#   'id_track': '5zwwW9Oq7ubSxoCGyW1nbY',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Head Shoulders Knees & Toes (feat. Norma Jean Martine)',
#   'artist_name': 'Ofenbach, Quarterhead, Norma Jean Martine',
#   'release_date': '2022-09-02',
#   'id_track': '2RRpaU7jFVcwo23pthdnBv',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Satellite',
#   'artist_name': 'Harry Styles',
#   'release_date': '2022-05-20',
#   'id_track': '0rzaRSujxA0bKyjJl6vHYq',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Malas Decisiones',
#   'artist_name': 'Kenia OS',
#   'release_date': '2022-10-26',
#   'id_track': '6Xj014IHwbLVjiVT6H89on',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Low',
#   'artist_name': 'SZA',
#   'release_date': '2022-12-09',
#   'id_track': '2GAhgAjOhEmItWLfgisyOn',
#   'popularity': 75,
#   'genero': 'pop'},
#  {'track_name': 'The 30th',
#   'artist_name': 'Billie Eilish',
#   'release_date': '2022-07-21',
#   'id_track': '5SHpuW2qjkQtFRpE6P9Nks',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'KICK BACK',
#   'artist_name': 'Kenshi Yonezu',
#   'release_date': '2022-10-12',
#   'id_track': '3khEEPRyBeOUabbmOPJzAG',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': "Pa' la Selección",
#   'artist_name': 'La T y La M',
#   'release_date': '2022-11-21',
#   'id_track': '2l0hr2jYYXdkbF393AThLm',
#   'popularity': 62,
#   'genero': 'pop'},
#  {'track_name': 'Fake ID (Coke & Rum Remix)',
#   'artist_name': 'Riton, Kah-Lo, GEE LEE',
#   'release_date': '2022-12-15',
#   'id_track': '2VuzBUB5V9AlpniCUhaszP',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'La Pasamos CXBRXN',
#   'artist_name': 'Feid, Zion & Lennox',
#   'release_date': '2022-12-02',
#   'id_track': '672zDo2nzWSoIIQ7zD5kuj',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'THE LONELIEST',
#   'artist_name': 'Måneskin',
#   'release_date': '2022-10-07',
#   'id_track': '1Ame8XTX6QHY0l0ahqUhgv',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Surround Sound (feat. 21 Savage & Baby Tate)',
#   'artist_name': 'JID, 21 Savage, Baby Tate',
#   'release_date': '2022-10-31',
#   'id_track': '1udwFobQ1JoOdWPQrp2b6u',
#   'popularity': 74,
#   'genero': 'pop'},
#  {'track_name': 'The Astronaut',
#   'artist_name': 'Jin',
#   'release_date': '2022-10-28',
#   'id_track': '0h7QMc9ZRzA9QJrbEHytn2',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Supongo Que Lo Sabes',
#   'artist_name': 'Ha*Ash',
#   'release_date': '2022-09-02',
#   'id_track': '0poZ5t6JLsuxtUXfhPDLJI',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Boyfriend',
#   'artist_name': 'Dove Cameron',
#   'release_date': '2022-02-11',
#   'id_track': '59CfNbkERJ3NoTXDvoURjj',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Aguante',
#   'artist_name': 'Feid',
#   'release_date': '2022-09-14',
#   'id_track': '2dWGQ975YrNma4SdfmJRDg',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Out of Time',
#   'artist_name': 'The Weeknd',
#   'release_date': '2022-01-06',
#   'id_track': '2SLwbpExuoBDZBpjfefCtV',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'cielo en la mente',
#   'artist_name': 'Emilia',
#   'release_date': '2022-05-31',
#   'id_track': '0Q1NGtkEts8tjIC4eSWiya',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'I Like You (A Happier Song) (with Doja Cat)',
#   'artist_name': 'Post Malone, Doja Cat',
#   'release_date': '2022-06-03',
#   'id_track': '0O6u0VJ46W86TxN9wgyqDj',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'Quemando Calorías',
#   'artist_name': 'Feid, Sky Rompiendo',
#   'release_date': '2022-09-14',
#   'id_track': '3ss6y0Id5Iwk2L5MIZp4xF',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Bejeweled',
#   'artist_name': 'Taylor Swift',
#   'release_date': '2022-10-21',
#   'id_track': '3qoftcUZaUOncvIYjFSPdE',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'Butter',
#   'artist_name': 'BTS',
#   'release_date': '2022-06-10',
#   'id_track': '6jjYDGxVJsWS0a5wlVF5vS',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Devil Doesn’t Bargain',
#   'artist_name': 'Alec Benjamin',
#   'release_date': '2022-04-15',
#   'id_track': '1zu2GKHPJIsUu80SUJX4H4',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Cicuta - Remix',
#   'artist_name': 'Peces Raros, Trueno',
#   'release_date': '2022-04-01',
#   'id_track': '6qqeq1UoryAxgud2JfF76t',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Family Line',
#   'artist_name': 'Conan Gray',
#   'release_date': '2022-06-24',
#   'id_track': '0iNZGC211wst3VjtobNnC5',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'Keep Driving',
#   'artist_name': 'Harry Styles',
#   'release_date': '2022-05-20',
#   'id_track': '2NcQic8JxdjAlAHuNbOIRE',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Best Day Of My Life',
#   'artist_name': 'Tom Odell',
#   'release_date': '2022-10-28',
#   'id_track': '1GIsnE71uUtWvGpvnJCTXO',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'Kernkraft 400 (A Better Day)',
#   'artist_name': 'Topic, A7S',
#   'release_date': '2022-06-17',
#   'id_track': '3kcKlOkQQEPVwxwljbGJ5p',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'Massive',
#   'artist_name': 'Drake',
#   'release_date': '2022-06-17',
#   'id_track': '28JBD8p18xNuOfyV7Cotdn',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Lavender Haze',
#   'artist_name': 'Taylor Swift',
#   'release_date': '2022-10-21',
#   'id_track': '5jQI2r1RdgtuT8S3iG8zFC',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'OJALÁ',
#   'artist_name': 'Maria Becerra',
#   'release_date': '2022-12-08',
#   'id_track': '5RlibNUdsaN2oPX9MWl52K',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Midnight Rain',
#   'artist_name': 'Taylor Swift',
#   'release_date': '2022-10-21',
#   'id_track': '3rWDp9tBPQR9z6U5YyRSK4',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'Rich Flex',
#   'artist_name': 'Drake, 21 Savage',
#   'release_date': '2022-11-04',
#   'id_track': '1bDbXMyjaUIooNwFE9wn0N',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'Qué Agonía',
#   'artist_name': 'Yuridia, Ángela Aguilar',
#   'release_date': '2022-10-20',
#   'id_track': '4H6o1bxKRGzmsE0vzo968m',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Astronomy',
#   'artist_name': 'Conan Gray',
#   'release_date': '2022-06-24',
#   'id_track': '2JN3ugW1cEahbYw0I5mw5U',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'Brividi',
#   'artist_name': 'Mahmood, BLANCO',
#   'release_date': '2022-02-02',
#   'id_track': '1ZMGp9MTXbtAPvcKa0U3zS',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'SUPERMODEL',
#   'artist_name': 'Måneskin',
#   'release_date': '2022-05-13',
#   'id_track': '63WuQOXohQIxOxIFA2K7bR',
#   'popularity': 62,
#   'genero': 'pop'},
#  {'track_name': 'Ditto',
#   'artist_name': 'NewJeans',
#   'release_date': '2022-12-19',
#   'id_track': '3r8RuvgbX9s7ammBn07D3W',
#   'popularity': 74,
#   'genero': 'pop'},
#  {'track_name': 'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack]',
#   'artist_name': 'Jung Kook, BTS, FIFA Sound',
#   'release_date': '2022-11-20',
#   'id_track': '0jY618wuln0b5b8sCxFgjk',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Mojando Asientos (feat. Feid)',
#   'artist_name': 'Maluma, Feid',
#   'release_date': '2022-06-10',
#   'id_track': '6lV9cTvioGWqRXSgfjAUGL',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Underground',
#   'artist_name': 'Emilia',
#   'release_date': '2022-11-17',
#   'id_track': '3QWCxOv2YharMus6KbfiPJ',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Llorar y Llorar - con Carin Leon',
#   'artist_name': 'Mau y Ricky, Carin Leon',
#   'release_date': '2022-05-31',
#   'id_track': '4YF13O2n16dcTyGgVmiGvN',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Volare',
#   'artist_name': 'Danny Ocean',
#   'release_date': '2022-07-07',
#   'id_track': '6TCnhziFkBPhOTqvh8zVDU',
#   'popularity': 59,
#   'genero': 'pop'},
#  {'track_name': 'Malibu',
#   'artist_name': 'Feid, Ak4:20, Taiko',
#   'release_date': '2022-11-11',
#   'id_track': '4TRlBMj8wXsIfEDgWOPyE2',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'LOCO',
#   'artist_name': 'GIMS, Lossa',
#   'release_date': '2022-12-02',
#   'id_track': '0ksYW1iavv5SwGshxjpLvK',
#   'popularity': 59,
#   'genero': 'pop'},
#  {'track_name': 'DOBLE VIDA',
#   'artist_name': 'Maria Becerra',
#   'release_date': '2022-12-08',
#   'id_track': '0Dhks7VwA1F7baYPVEeo4S',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Monalisa',
#   'artist_name': 'Lojay, Sarz, Chris Brown',
#   'release_date': '2022-05-19',
#   'id_track': '3baPniPXS0iEII8rDUJdYP',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Los Consejos',
#   'artist_name': 'Greeicy',
#   'release_date': '2022-03-04',
#   'id_track': '54KqP2AoCRcEMTfooOI5nK',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Hype Boy',
#   'artist_name': 'NewJeans',
#   'release_date': '2022-08-01',
#   'id_track': '0a4MMyCrzT0En247IhqZbD',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'Santé',
#   'artist_name': 'Stromae',
#   'release_date': '2022-03-03',
#   'id_track': '3Mcxi78U3lCjt8DMKa6YY4',
#   'popularity': 59,
#   'genero': 'pop'},
#  {'track_name': 'Green Green Grass',
#   'artist_name': 'George Ezra',
#   'release_date': '2022-06-10',
#   'id_track': '4N5s8lPTsjI9EGP7K4SXzB',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'CASE 143',
#   'artist_name': 'Stray Kids',
#   'release_date': '2022-10-07',
#   'id_track': '3O8G8eVrhfXTGttyQ1xVuq',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Back To You',
#   'artist_name': 'Lost Frequencies, Elley Duhé, X Ambassadors',
#   'release_date': '2022-12-09',
#   'id_track': '3K00Ib1shkOEiAXU5pec6e',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'People Watching',
#   'artist_name': 'Conan Gray',
#   'release_date': '2022-06-24',
#   'id_track': '3TFoEJe5zNuHZStRboWPxg',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'die first',
#   'artist_name': 'Nessa Barrett',
#   'release_date': '2022-10-14',
#   'id_track': '3TfDUStpnEVIlsNlgcKQgJ',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Hurricane',
#   'artist_name': 'Ofenbach, Ella Henderson',
#   'release_date': '2022-09-02',
#   'id_track': '3P3i2ratUjex3HJEF8aAVi',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': 'Costumbres - Vivo',
#   'artist_name': 'Damas Gratis, Ke Personajes',
#   'release_date': '2022-10-27',
#   'id_track': '6HT88WDVwEJiHEbPuQ5XcB',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'Escapism.',
#   'artist_name': 'RAYE, 070 Shake',
#   'release_date': '2022-12-07',
#   'id_track': '2VOZniNxFIDl8ydLltrMNb',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'First Class',
#   'artist_name': 'Jack Harlow',
#   'release_date': '2022-05-06',
#   'id_track': '0wHFktze2PHC5jDt3B17DC',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'Usseewa',
#   'artist_name': 'Ado',
#   'release_date': '2022-01-26',
#   'id_track': '61KYsWS25JXUO4fGb1138X',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'feel like shit',
#   'artist_name': 'Tate McRae',
#   'release_date': '2022-05-27',
#   'id_track': '03zuGqxMwUFFmCwusq0WKE',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'La Chain',
#   'artist_name': 'Emilia',
#   'release_date': '2022-08-16',
#   'id_track': '5lkgHMBFyhk6P3jinwsYo0',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'Never Going Home',
#   'artist_name': 'Kungs',
#   'release_date': '2022-03-18',
#   'id_track': '6ju5Ntn5pYksvkKxVkjEPK',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'Attention',
#   'artist_name': 'NewJeans',
#   'release_date': '2022-08-01',
#   'id_track': '2pIUpMhHL6L9Z5lnKxJJr9',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'Locksmith',
#   'artist_name': 'Sadie Jean',
#   'release_date': '2022-10-07',
#   'id_track': '4HcARAxzsbIB3MqiEkejM6',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': '2 Be Loved (Am I Ready)',
#   'artist_name': 'Lizzo',
#   'release_date': '2022-07-15',
#   'id_track': '2rmwqU7yzTvzkiaRV53DpT',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Nxde',
#   'artist_name': '(G)I-DLE',
#   'release_date': '2022-10-17',
#   'id_track': '6NnCWIWV740gP7DQ8kqdIE',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'TOMBOY',
#   'artist_name': '(G)I-DLE',
#   'release_date': '2022-03-14',
#   'id_track': '0IGUXY4JbK18bu9oD4mPIm',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'maybe (feat. Bring Me The Horizon)',
#   'artist_name': 'mgk, Bring Me The Horizon',
#   'release_date': '2022-03-25',
#   'id_track': '25wdC7CJmCJPgnKw9rYquJ',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'better off without me',
#   'artist_name': 'Matt Hansen',
#   'release_date': '2022-03-04',
#   'id_track': '1Ip5p31SowqjJLo2ss1afJ',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Qué Prefieres?',
#   'artist_name': 'Boza, Beéle',
#   'release_date': '2022-09-22',
#   'id_track': '1YEQ5CvZVK9P4PsZY76GK5',
#   'popularity': 49,
#   'genero': 'pop'},
#  {'track_name': 'Burn',
#   'artist_name': 'David Kushner',
#   'release_date': '2022-09-16',
#   'id_track': '40dfo65kBJa1UgzkD652Gl',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Spin Bout U',
#   'artist_name': 'Drake, 21 Savage',
#   'release_date': '2022-11-04',
#   'id_track': '2ZL7WZcjuYKi1KUDtp4kCC',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'Left and Right (Feat. Jung Kook of BTS)',
#   'artist_name': 'Charlie Puth, Jung Kook, BTS',
#   'release_date': '2022-10-06',
#   'id_track': '5Odq8ohlgIbQKMZivbWkEo',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Ella - Remix',
#   'artist_name': 'Boza, Lunay, Lenny Tavárez, Juhn, Beéle',
#   'release_date': '2022-03-11',
#   'id_track': '7cx9L3i88euMfx1oNCqDAD',
#   'popularity': 51,
#   'genero': 'pop'},
#  {'track_name': 'Open Arms (feat. Travis Scott)',
#   'artist_name': 'SZA, Travis Scott',
#   'release_date': '2022-12-09',
#   'id_track': '0xaFw2zDYf1rIJWl2dXiSF',
#   'popularity': 72,
#   'genero': 'pop'},
#  {'track_name': 'MORE',
#   'artist_name': 'j-hope',
#   'release_date': '2022-07-01',
#   'id_track': '4XKXphKH76W4zNpkgFS5o2',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Stay Alive (Prod. SUGA of BTS)',
#   'artist_name': 'Jung Kook',
#   'release_date': '2022-02-11',
#   'id_track': '7CAdT0HdiQNlt1C7xk2hep',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': "Car's Outside - Sped Up Version",
#   'artist_name': 'James Arthur',
#   'release_date': '2022-08-26',
#   'id_track': '6OmKbLCskNWi1IcfpZbeJc',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Mr. Forgettable',
#   'artist_name': 'David Kushner',
#   'release_date': '2022-09-16',
#   'id_track': '0c8K5IUrmVlieC0Fc0d8tV',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'All My Love',
#   'artist_name': 'Noah Kahan',
#   'release_date': '2022-10-14',
#   'id_track': '7ByxizhA4GgEf7Sxomxhze',
#   'popularity': 74,
#   'genero': 'pop'},
#  {'track_name': 'Northern Attitude',
#   'artist_name': 'Noah Kahan',
#   'release_date': '2022-10-14',
#   'id_track': '4O2rRsoSPb5aN7N3tG6Y3v',
#   'popularity': 73,
#   'genero': 'pop'},
#  {'track_name': 'POP!',
#   'artist_name': 'NAYEON',
#   'release_date': '2022-06-24',
#   'id_track': '3lOMJTQTd6J34faYwASc33',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Suzume',
#   'artist_name': 'RADWIMPS, Toaka',
#   'release_date': '2022-11-10',
#   'id_track': '1n1y2kFPISpF9WGD3JaFo5',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Light Switch',
#   'artist_name': 'Charlie Puth',
#   'release_date': '2022-10-06',
#   'id_track': '1jEBSDN5vYViJQr78W7jr2',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Never Gonna Not Dance Again',
#   'artist_name': 'P!nk',
#   'release_date': '2022-11-04',
#   'id_track': '6sZo5nJIsFWXefRCCexpx0',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'Ojos Marrones',
#   'artist_name': 'Lasso',
#   'release_date': '2022-06-03',
#   'id_track': '7gwT3HGL84vF7bgtwL1N88',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'Evergreen (You Didn’t Deserve Me At All)',
#   'artist_name': 'Omar Apollo',
#   'release_date': '2022-04-08',
#   'id_track': '2TktkzfozZifbQhXjT6I33',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'dying on the inside',
#   'artist_name': 'Nessa Barrett',
#   'release_date': '2022-02-25',
#   'id_track': '6h1s7cKnUtsbRpE5bwnUTf',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Heavy Metal Love',
#   'artist_name': 'twocolors',
#   'release_date': '2022-07-08',
#   'id_track': '07VcTAooOBP8hIluuUS5xr',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': "I'm Still in Love with You (feat. Sasha)",
#   'artist_name': 'Sean Paul, Sasha, Jeremy Harding, Murray Elias',
#   'release_date': '2022-11-11',
#   'id_track': '5lJx5eiSahFfsqkMJVlkDN',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Vegas (From the Original Motion Picture Soundtrack ELVIS)',
#   'artist_name': 'Doja Cat',
#   'release_date': '2022-05-06',
#   'id_track': '0hquQWY3xvYqN4qtiquniF',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'New Genesis',
#   'artist_name': 'Ado',
#   'release_date': '2022-08-10',
#   'id_track': '6A8NfypDHuwiLWbo4a1yca',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'Como la Flor',
#   'artist_name': 'Ke Personajes',
#   'release_date': '2022-05-28',
#   'id_track': '52yp1caEYyP1w9qFINypd1',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': '堕天',
#   'artist_name': 'Creepy Nuts',
#   'release_date': '2022-09-07',
#   'id_track': '5HPsZwo40KA3GThqBFZFac',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'My You',
#   'artist_name': 'Jung Kook',
#   'release_date': '2022-06-13',
#   'id_track': '0pNFrM5L0te1EXGxveeYiR',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Fils de joie',
#   'artist_name': 'Stromae',
#   'release_date': '2022-03-03',
#   'id_track': '6w2jx3gzQAtoKP22czcANv',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'CALLEJERO FINO | DJ TAO Turreo Sessions #723',
#   'artist_name': 'DJ Tao, Callejero Fino',
#   'release_date': '2022-10-20',
#   'id_track': '3fUZbg31mIJKIxuv8nUcGg',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Pussy & Millions (feat. Travis Scott)',
#   'artist_name': 'Drake, 21 Savage, Travis Scott',
#   'release_date': '2022-11-04',
#   'id_track': '2KLwPaRDOB87XOYAT2fgxh',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Ella',
#   'artist_name': 'Boza',
#   'release_date': '2022-03-11',
#   'id_track': '4177FNDorJz54RrGDbftxU',
#   'popularity': 50,
#   'genero': 'pop'},
#  {'track_name': 'La Buena Fai',
#   'artist_name': 'Feid',
#   'release_date': '2022-09-14',
#   'id_track': '188Iohmux4LrDaj6e6eeEx',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Sleep Deprivation',
#   'artist_name': 'Chance Peña',
#   'release_date': '2022-04-01',
#   'id_track': '2A1FGotEDhN5UjBiLsUwnk',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'For My Hand (feat. Ed Sheeran)',
#   'artist_name': 'Burna Boy, Ed Sheeran',
#   'release_date': '2022-07-07',
#   'id_track': '0HaRLPnr887lcQM2YQzkff',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'Alone',
#   'artist_name': 'Burna Boy',
#   'release_date': '2022-11-11',
#   'id_track': '0AoBY2Y3qs6dtGgOD6c91N',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'After LIKE',
#   'artist_name': 'IVE',
#   'release_date': '2022-08-22',
#   'id_track': '2gYj9lubBorOPIVWsTXugG',
#   'popularity': 67,
#   'genero': 'pop'},
#  {'track_name': 'Solitaire',
#   'artist_name': 'Werenoi',
#   'release_date': '2022-10-28',
#   'id_track': '3kzXT2poHInDISrXOgT1PR',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': 'Shirt',
#   'artist_name': 'SZA',
#   'release_date': '2022-12-09',
#   'id_track': '2wSTnntOPRi7aQneobFtU4',
#   'popularity': 71,
#   'genero': 'pop'},
#  {'track_name': 'Teenage Dream',
#   'artist_name': 'Stephen Dawes',
# ...
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'TOUT VA BIEN (feat. Ninho & Naps)',
#   'artist_name': 'Alonzo, Ninho, Naps',
#   'release_date': '2022-05-20',
#   'id_track': '6OZwia8loN0aPS0vTvsBjR',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Zona De Perigo',
#   'artist_name': 'Léo Santana',
#   'release_date': '2022-12-08',
#   'id_track': '1jHgfC8T5KxUyC5Ldw6lk9',
#   'popularity': 62,
#   'genero': 'pop'},
#  {'track_name': 'PANICO (feat. Takagi & Ketra)',
#   'artist_name': 'Lazza, Takagi & Ketra',
#   'release_date': '2022-04-07',
#   'id_track': '0SsUOrXUM2gZxVLYizZfQZ',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': '小城夏天',
#   'artist_name': 'LBI利比',
#   'release_date': '2022-04-02',
#   'id_track': '4QZMBVrBLAvBryj8ZJIIY2',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'La nevedere',
#   'artist_name': 'Andia',
#   'release_date': '2022-11-04',
#   'id_track': '2Eh3mKeLBrmiyAQUOLI0bW',
#   'popularity': 43,
#   'genero': 'pop'},
#  {'track_name': 'Наверно, ты меня не помнишь',
#   'artist_name': 'JONY, HammAli',
#   'release_date': '2022-12-02',
#   'id_track': '2yJJSg7vCeZgJMY3xWJ2C2',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Ride the Lightning - 717 Tapes',
#   'artist_name': 'Warren Zeiders',
#   'release_date': '2022-09-30',
#   'id_track': '04YKO5t4AZrsqKfGhhUb2j',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Heart Like A Truck',
#   'artist_name': 'Lainey Wilson',
#   'release_date': '2022-11-28',
#   'id_track': '5DIBVDJOHh7djepAjKHWCO',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Good Parts (when the quality is bad but I am)',
#   'artist_name': 'LE SSERAFIM',
#   'release_date': '2022-10-17',
#   'id_track': '1sZBzYhrQG40zcSuKkI93c',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': 'Last Call',
#   'artist_name': 'Will Linley',
#   'release_date': '2022-12-09',
#   'id_track': '73QGVDmZWTLnQ6lG7rF1vd',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'ABISSALE',
#   'artist_name': 'Tananai',
#   'release_date': '2022-11-24',
#   'id_track': '3U8TFdchz8dK1nYYgZgd9f',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Ototo',
#   'artist_name': 'Asake',
#   'release_date': '2022-09-07',
#   'id_track': '0CUJV0Hh512Ns7U2yGflqt',
#   'popularity': 59,
#   'genero': 'pop'},
#  {'track_name': 'Rubami la Notte',
#   'artist_name': 'Pinguini Tattici Nucleari',
#   'release_date': '2022-12-02',
#   'id_track': '3mMjLv3IyxlEKmXg3JxCI5',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Tu le sais',
#   'artist_name': 'Kalash, Gazo',
#   'release_date': '2022-04-29',
#   'id_track': '1frmYvoVtyFlGypiapnkrX',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': '¿Con Qué Se Pega un Corazón?',
#   'artist_name': 'Yuridia',
#   'release_date': '2022-10-20',
#   'id_track': '2eSTnoRpEK2VXIccMbzXrE',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': 'Один',
#   'artist_name': 'Вектор А',
#   'release_date': '2022-09-30',
#   'id_track': '5BPINlBbMGpHu0S79efirq',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'Meuda',
#   'artist_name': 'Tiakola',
#   'release_date': '2022-05-27',
#   'id_track': '4wNyrbY6B2Okii8VeKo2B2',
#   'popularity': 62,
#   'genero': 'pop'},
#  {'track_name': 'Giovani Wannabe',
#   'artist_name': 'Pinguini Tattici Nucleari',
#   'release_date': '2022-12-02',
#   'id_track': '4ICCU06b8FkQIrMv0XTzlv',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Candy',
#   'artist_name': 'NCT DREAM',
#   'release_date': '2022-12-16',
#   'id_track': '27bIik73QCu8Xzt3xpG1bI',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': 'No Digas Nada',
#   'artist_name': 'El Blachy',
#   'release_date': '2022-09-09',
#   'id_track': '1X3ygwog1SLNAcoiZvjcgS',
#   'popularity': 43,
#   'genero': 'pop'},
#  {'track_name': 'DONA DE MIM',
#   'artist_name': 'Ana Castela',
#   'release_date': '2022-12-23',
#   'id_track': '7sopDXkuzXtHt8AQpdBxmT',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Jamal',
#   'artist_name': 'Werenoi',
#   'release_date': '2022-10-28',
#   'id_track': '3MNBUdX7zP4E0UhlfYenMf',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'INVU',
#   'artist_name': 'TAEYEON',
#   'release_date': '2022-02-14',
#   'id_track': '7rXcCpIAoOUCydkVDMcoPV',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Peace Be Unto You (PBUY)',
#   'artist_name': 'Asake',
#   'release_date': '2022-09-07',
#   'id_track': '6ewsOjbC1jWAZcjAhVxDs0',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'On Top',
#   'artist_name': 'Karan Aujla',
#   'release_date': '2022-11-25',
#   'id_track': '4SJMuaIYcBS8ke96lDYOsw',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'FLEURS (feat. Tiakola)',
#   'artist_name': 'Gazo, Tiakola',
#   'release_date': '2022-07-01',
#   'id_track': '0i9RysNKssk6syOrKDX3U2',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'SAINT-TROPEZ',
#   'artist_name': 'GIMS',
#   'release_date': '2022-12-02',
#   'id_track': '3Mbma25p8UwArob1tt5SPy',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': "Et même après je t'aimerai",
#   'artist_name': 'Hoshi',
#   'release_date': '2022-02-11',
#   'id_track': '5Pl4OxV9RGWNMO8MGmAoDP',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'USCITO DI GALERA',
#   'artist_name': 'Lazza',
#   'release_date': '2022-04-07',
#   'id_track': '01DXwNf1GzEJkYTbXgL0eb',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'Peg Patiala',
#   'artist_name': 'Cheema Y, Chinna',
#   'release_date': '2022-02-28',
#   'id_track': '1T2zltv44cifAqZIbG3D2N',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'По барам',
#   'artist_name': 'ANNA ASTI',
#   'release_date': '2022-06-24',
#   'id_track': '5rbKNd54ig1qtSUeK83OOo',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': 'AMAZING',
#   'artist_name': 'Rex Orange County',
#   'release_date': '2022-03-11',
#   'id_track': '3OM6qQmdFV6uy61GIqpRtf',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'Bine Asa',
#   'artist_name': 'Oana Radu',
#   'release_date': '2022-12-22',
#   'id_track': '1UY5xHX9Fpt0htxSQizfyO',
#   'popularity': 38,
#   'genero': 'pop'},
#  {'track_name': 'Still Life',
#   'artist_name': 'BIGBANG',
#   'release_date': '2022-04-05',
#   'id_track': '3TSLqZssCoCdDlMhCJ08XW',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'Pipoco',
#   'artist_name': 'Ana Castela, Melody, Dj Chris No Beat',
#   'release_date': '2022-06-01',
#   'id_track': '7AwVSKaQxpidrtYBerkHKk',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': '祝福',
#   'artist_name': 'YOASOBI',
#   'release_date': '2022-10-01',
#   'id_track': '7ajpbW6tBpqUI9foCtwlLw',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'Vamos',
#   'artist_name': 'Naps, Gazo',
#   'release_date': '2022-06-17',
#   'id_track': '5QowMIujytktMDC8pktNXH',
#   'popularity': 52,
#   'genero': 'pop'},
#  {'track_name': 'Overloading (OVERDOSE)',
#   'artist_name': 'Mavins, Crayon, Ayra Starr, LADIPOE, Magixx, Boy Spyce',
#   'release_date': '2022-12-02',
#   'id_track': '3ES1fBQACydIODlZmQS359',
#   'popularity': 51,
#   'genero': 'pop'},
#  {'track_name': 'اليوم الحلو ده',
#   'artist_name': 'Ahmed Saad',
#   'release_date': '2022-07-07',
#   'id_track': '2HbrI0oakRE7qNXoK74zNR',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Tati, vreau',
#   'artist_name': 'Alex Velea, George Talent',
#   'release_date': '2022-11-25',
#   'id_track': '7hoILhEoePHXh6qTw5H0Fe',
#   'popularity': 46,
#   'genero': 'pop'},
#  {'track_name': '說好不哭',
#   'artist_name': 'Jay Chou, Ashin Chen',
#   'release_date': '2022-07-15',
#   'id_track': '52yAKumXlqPjUsIBlmiMvo',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Ash',
#   'artist_name': 'SEVENTEEN',
#   'release_date': '2022-05-27',
#   'id_track': '5kc5p2mwO2GFq93zw5ZFWV',
#   'popularity': 59,
#   'genero': 'pop'},
#  {'track_name': 'Au Ce Mi-Ai Facut Tu Mie',
#   'artist_name': 'Oana Radu',
#   'release_date': '2022-04-20',
#   'id_track': '2qW6uphdqGZlHosQBacyfG',
#   'popularity': 37,
#   'genero': 'pop'},
#  {'track_name': 'Toata noaptea',
#   'artist_name': 'Juno, MIRA',
#   'release_date': '2022-05-19',
#   'id_track': '4lC2rmlMug4B4FeaeZ2Ya1',
#   'popularity': 41,
#   'genero': 'pop'},
#  {'track_name': 'ばかまじめ',
#   'artist_name': 'Creepy Nuts, Ayase, Lilas',
#   'release_date': '2022-09-07',
#   'id_track': '7FiTlLKW0Knj8rm7lMa9N7',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Le bruit du silence',
#   'artist_name': 'Mentissa',
#   'release_date': '2022-11-18',
#   'id_track': '063IwEdb1LaITJk0LOP0h9',
#   'popularity': 53,
#   'genero': 'pop'},
#  {'track_name': '3 singes',
#   'artist_name': 'Werenoi, Ninho',
#   'release_date': '2022-10-28',
#   'id_track': '57JhjU33uXlZtmr2Dsk8TX',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'VERMELHO',
#   'artist_name': 'Gloria Groove',
#   'release_date': '2022-02-10',
#   'id_track': '4EVzu5mYyigjyLrryKbZs7',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'White Brown Black',
#   'artist_name': 'Avvy Sra, Karan Aujla, Jaani',
#   'release_date': '2022-12-09',
#   'id_track': '3nKQrVVlwbAQSnFbgZWdN0',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Xtra Cool',
#   'artist_name': 'Young Jonn',
#   'release_date': '2022-09-23',
#   'id_track': '5F4OfeowSReF93KcH2eUcG',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'RAPPEL',
#   'artist_name': 'Gazo',
#   'release_date': '2022-07-01',
#   'id_track': '48BdA5qBxXVoe59xvu0bwc',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'When Im Gone',
#   'artist_name': 'LECADE',
#   'release_date': '2022-05-27',
#   'id_track': '4ObFZEXHQJcc8WQtqbCupZ',
#   'popularity': 66,
#   'genero': 'pop'},
#  {'track_name': 'Como Antes',
#   'artist_name': 'Matias Damásio',
#   'release_date': '2022-03-25',
#   'id_track': '0dAZ5dCofHy6rquqU6YG29',
#   'popularity': 51,
#   'genero': 'pop'},
#  {'track_name': 'What Happened To Virgil (feat. Gunna)',
#   'artist_name': 'Lil Durk, Gunna',
#   'release_date': '2022-03-11',
#   'id_track': '7ohROa13QK43JBRqfCmz4P',
#   'popularity': 59,
#   'genero': 'pop'},
#  {'track_name': 'Omo Ope (feat. Olamide)',
#   'artist_name': 'Asake, Olamide',
#   'release_date': '2022-01-18',
#   'id_track': '7d1aTQlsHMgWmkPywDi7h1',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Memory to Drown',
#   'artist_name': 'Bryan Martin',
#   'release_date': '2022-04-29',
#   'id_track': '6d3rOaVzZshI2YRBl7WjQb',
#   'popularity': 65,
#   'genero': 'pop'},
#  {'track_name': 'Fammi morire',
#   'artist_name': 'Olly, Juli',
#   'release_date': '2022-12-16',
#   'id_track': '6N61dCQlsQioiz5M2kDnnu',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Ai Papai',
#   'artist_name': 'Anitta, Mc Danny, HITMAKER',
#   'release_date': '2022-11-29',
#   'id_track': '4PQ5AInr4YoBauth9YPduL',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'go - goddard. Remix',
#   'artist_name': 'Cat Burns, goddard.',
#   'release_date': '2022-03-25',
#   'id_track': '6RZo8T7GY9EoWZXC5i2587',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': '是你',
#   'artist_name': '梦然',
#   'release_date': '2022-07-25',
#   'id_track': '7gYKASXibOLyet8JTBJOO2',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'Nzaza',
#   'artist_name': 'Asake',
#   'release_date': '2022-09-07',
#   'id_track': '0VjzaXw81JQJM61pzWwP8b',
#   'popularity': 61,
#   'genero': 'pop'},
#  {'track_name': 'Pentru totdeauna',
#   'artist_name': 'Irina Rimes, Grasu XXL',
#   'release_date': '2022-06-03',
#   'id_track': '03F6MEGpr7HVT6MpgO7v05',
#   'popularity': 47,
#   'genero': 'pop'},
#  {'track_name': '字字句句',
#   'artist_name': '卢卢快闭嘴',
#   'release_date': '2022-12-29',
#   'id_track': '7fAdinC2UTc0Y9GiKrkTtu',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': '爱怎么了',
#   'artist_name': '陈村长',
#   'release_date': '2022-04-27',
#   'id_track': '0c9gjnRGBRke9VmLaZWmhM',
#   'popularity': 58,
#   'genero': 'pop'},
#  {'track_name': 'Банкомат',
#   'artist_name': 'DEAD BLONDE',
#   'release_date': '2022-11-18',
#   'id_track': '3rGOoMEEIBonQBGOX48yjB',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Ricordi',
#   'artist_name': 'Pinguini Tattici Nucleari',
#   'release_date': '2022-12-02',
#   'id_track': '1AQqSrJYbCeRtzO7EApqYX',
#   'popularity': 54,
#   'genero': 'pop'},
#  {'track_name': 'Me Hace Tanto Bien',
#   'artist_name': 'Yuridia, Eden Muñoz',
#   'release_date': '2022-10-20',
#   'id_track': '0J87ieRdbGPItHA6qc3KCr',
#   'popularity': 62,
#   'genero': 'pop'},
#  {'track_name': 'Lemonade',
#   'artist_name': 'Diljit Dosanjh',
#   'release_date': '2022-07-15',
#   'id_track': '3ZGJhN4unVspOqpwGvUL2W',
#   'popularity': 68,
#   'genero': 'pop'},
#  {'track_name': 'Flower Shops (feat. Morgan Wallen)',
#   'artist_name': 'ERNEST, Morgan Wallen',
#   'release_date': '2022-03-11',
#   'id_track': '1DbZAffh8GGwW41Q3AU8iC',
#   'popularity': 69,
#   'genero': 'pop'},
#  {'track_name': 'Sfarsitul lumii',
#   'artist_name': 'Andia',
#   'release_date': '2022-03-25',
#   'id_track': '3ILu8nLtlFRhwnY38VyXSk',
#   'popularity': 40,
#   'genero': 'pop'},
#  {'track_name': "L'anima balla",
#   'artist_name': 'Olly, Juli',
#   'release_date': '2022-12-16',
#   'id_track': '0cLOSiqHFDQHbQbJnwpP7z',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'PIOVE (feat. Sfera Ebbasta)',
#   'artist_name': 'Lazza, Sfera Ebbasta',
#   'release_date': '2022-04-07',
#   'id_track': '6BUueuMQR4k7CuoMEsnGou',
#   'popularity': 55,
#   'genero': 'pop'},
#  {'track_name': 'Nous deux',
#   'artist_name': 'SDM',
#   'release_date': '2022-12-02',
#   'id_track': '42EApozzvP6H2RpNOh6dr1',
#   'popularity': 59,
#   'genero': 'pop'},
#  {'track_name': 'Le feu',
#   'artist_name': 'Kendji Girac, Vianney',
#   'release_date': '2022-11-11',
#   'id_track': '6dEysAhgnVJ9905XmZmwty',
#   'popularity': 54,
#   'genero': 'pop'},
#  {'track_name': 'Ykwim',
#   'artist_name': 'Karan Aujla, KR$NA, Mehar Vaani',
#   'release_date': '2022-01-18',
#   'id_track': '6qS40yL7kXVoChI8SSCQIQ',
#   'popularity': 63,
#   'genero': 'pop'},
#  {'track_name': 'портреты - Acoustic',
#   'artist_name': 'zhanulka',
#   'release_date': '2022-09-09',
#   'id_track': '7ojBwkKhmZzXDjrqwfLH26',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'March',
#   'artist_name': 'SEVENTEEN',
#   'release_date': '2022-05-27',
#   'id_track': '5Av3flFGhQPu960OvjeNhm',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Mimos Son Mimos',
#   'artist_name': 'Babasonicos',
#   'release_date': '2022-04-28',
#   'id_track': '0AK6oKtH1xi0y66ZkN6OGT',
#   'popularity': 50,
#   'genero': 'pop'},
#  {'track_name': 'Coup de vieux',
#   'artist_name': 'Bigflo & Oli, Julien Doré',
#   'release_date': '2022-06-23',
#   'id_track': '63siBeZzxXVaY0uASns1V2',
#   'popularity': 54,
#   'genero': 'pop'},
#  {'track_name': 'Кульбаби',
#   'artist_name': 'Тоня Матвієнко',
#   'release_date': '2022-12-09',
#   'id_track': '7CuxOoQMEaiSXIGwJJkQHW',
#   'popularity': 56,
#   'genero': 'pop'},
#  {'track_name': 'Gasolina (feat. Rsko)',
#   'artist_name': 'Tiakola, Rsko',
#   'release_date': '2022-05-27',
#   'id_track': '6kwmp0U8M1tPvgPHqvbwsr',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'Ochii Tai',
#   'artist_name': 'Luis Gabriel',
#   'release_date': '2022-04-05',
#   'id_track': '0frrqHWRsmuM1f6T02VkoY',
#   'popularity': 38,
#   'genero': 'pop'},
#  {'track_name': 'Never Fold',
#   'artist_name': 'Sidhu Moose Wala, Sunny Malton, SOE',
#   'release_date': '2022-04-25',
#   'id_track': '3JkVYvxNoGf2HCWJo61462',
#   'popularity': 64,
#   'genero': 'pop'},
#  {'track_name': 'DM',
#   'artist_name': 'fromis_9',
#   'release_date': '2022-01-17',
#   'id_track': '7B9W7Qsy5M2kyUNjQYIEG8',
#   'popularity': 57,
#   'genero': 'pop'},
#  {'track_name': 'PETETE',
#   'artist_name': 'Gambi',
#   'release_date': '2022-07-29',
#   'id_track': '0z3bi63SNZ5ylyHOzb81Uq',
#   'popularity': 51,
#   'genero': 'pop'},
#  {'track_name': "Please Don't Go",
#   'artist_name': 'Wyatt Flores',
#   'release_date': '2022-07-15',
#   'id_track': '7fb4Qp5YoT4BKFdbj1Xu8r',
#   'popularity': 70,
#   'genero': 'pop'},
#  {'track_name': 'Pas bête',
#   'artist_name': 'Beendo Z',
#   'release_date': '2022-06-17',
#   'id_track': '3TVUW7bJJWDOonkVCZxfLV',
#   'popularity': 60,
#   'genero': 'pop'},
#  {'track_name': 'La Bachata',
#   'artist_name': 'The La Planta, Valeria Gau, Pushi',
#   'release_date': '2022-09-01',
#   'id_track': '3AMr0QkBGjrAoTbst5uWCG',
#   'popularity': 46,
#   'genero': 'pop'},
#  {'track_name': 'Bi Saraha',
#   'artist_name': 'Abeer Nehme',
#   'release_date': '2022-11-15',
#   'id_track': '2TkmosdPkJXcjhvMzscrYP',
#   'popularity': 60,
#   'genero': 'pop'}]

# %%
df_resultados_pop = pd.DataFrame (resultados ['pop'])
df_resultados_pop
# Out:
#                                 track_name                        artist_name  \
# 0    Quevedo: Bzrp Music Sessions, Vol. 52                  Bizarrap, Quevedo
# 1                               La Bachata                      Manuel Turizo
# 2                              Quién Diría                              DePol
# 3                     Las Cosas Pequeñitas                       Marta Santos
# 4                            Sin Vergüenza        Arde Bogotá, Dani Fernández
# ..                                     ...                                ...
# 495                                 PETETE                              Gambi
# 496                        Please Don't Go                       Wyatt Flores
# 497                               Pas bête                           Beendo Z
# 498                             La Bachata  The La Planta, Valeria Gau, Pushi
# 499                              Bi Saraha                        Abeer Nehme
#
#     release_date                id_track  popularity genero
# 0     2022-07-06  2tTmW7RDtMQtBk7m2rYeSw          76    pop
# 1     2022-05-26  5ww2BF9slyYgNOk37BlC4u          73    pop
# 2     2022-04-08  0Fd3900xH77g0ARXQjtYvV          60    pop
# 3     2022-04-22  5LU8Lk8uSCdMgBaqcTujmi          60    pop
# 4     2022-07-07  0mJ2qmDI2X4wrSIIBrvvpN          58    pop
# ..           ...                     ...         ...    ...
# 495   2022-07-29  0z3bi63SNZ5ylyHOzb81Uq          51    pop
# 496   2022-07-15  7fb4Qp5YoT4BKFdbj1Xu8r          70    pop
# 497   2022-06-17  3TVUW7bJJWDOonkVCZxfLV          60    pop
# 498   2022-09-01  3AMr0QkBGjrAoTbst5uWCG          46    pop
# 499   2022-11-15  2TkmosdPkJXcjhvMzscrYP          60    pop
#
# [500 rows x 6 columns]

# %%
df_resultados_indie = pd.DataFrame (resultados ['indie'])
df_resultados_indie
# Out:
#                                 track_name                  artist_name  \
# 0                            Sin Vergüenza  Arde Bogotá, Dani Fernández
# 1                                  El Bien                  Viva Suecia
# 2    Que nada nos pare (lo más importante)      ELYELLA, La La Love You
# 3                  No Hemos Aprendido Nada                  Viva Suecia
# 4                         End of Beginning                          Djo
# ..                                     ...                          ...
# 495      i like to think you're the leaves                   mage tears
# 496                                  AMOUR                  The Warning
# 497                      i haunt ur dreams                 hey, nothing
# 498                                Bandido                       El Zar
# 499                       When Will It End                    Birth Day
#
#     release_date                id_track  popularity genero
# 0     2022-07-07  0mJ2qmDI2X4wrSIIBrvvpN          58  indie
# 1     2022-10-06  6IuZFiKCeyQINqL0Id3xF2          58  indie
# 2     2022-06-30  1FG7ZjnuT0O9CsDKOxND0E          58  indie
# 3     2022-10-06  23EYaP0VXowC6oT9DiY3QR          56  indie
# 4     2022-09-16  3qhlB30KknSejmIvZZLjOD          84  indie
# ..           ...                     ...         ...    ...
# 495   2022-08-17  6OrfXVtcfifRxxebd9XG4L          49  indie
# 496   2022-06-24  7tgH5rFMIMTfNaycKeMbDb          44  indie
# 497   2022-10-12  7jBAskQhyfjmbYC0o3pXdW          50  indie
# 498   2022-11-04  6vtx0XLuEsa0U8BcS8CoLc          43  indie
# 499   2022-06-10  5F8RUGunSSBdu8Tn5qc63M          52  indie
#
# [500 rows x 6 columns]

# %%
df_resultados_rap = pd.DataFrame (resultados ['rap'])
df_resultados_rap
# Out:
#                                             track_name  \
# 0                                    Flow 2000 - Remix
# 1    Cayó La Noche (feat. Cruz Cafuné, Abhir Hathi,...
# 2                                              Lo Real
# 3                                     Barquito de Vela
# 4                                   7 Lágrimas - Remix
# ..                                                 ...
# 495                                     Un'altra volta
# 496               Broadway Girls (feat. Morgan Wallen)
# 497                                           ruthless
# 498                                 Can′t Slow Me Down
# 499                                          Teen Bean
#
#                                            artist_name release_date  \
# 0                                    Bad Gyal, Beny Jr   2022-03-17
# 1    La Pantera, Quevedo, Juseph, ABHIR, BEJO, Cruz...   2022-01-14
# 2                               Hard GZ, Nikone, Dualy   2022-03-24
# 3                                    Hard GZ, Antony Z   2022-05-06
# 4                        Soge Culebra, Mora, GARABATTO   2022-02-18
# ..                                                 ...          ...
# 495                                         Olly, Juli   2022-12-16
# 496                            Lil Durk, Morgan Wallen   2022-03-10
# 497                                         Rich Amiri   2022-07-29
# 498               MIRANI, lIlBOI, GroovyRoom, VALORANT   2022-02-15
# 499                                         Ken Carson   2022-02-18
#
#                    id_track  popularity genero
# 0    7fRtruULHGuwC0wNRx1HSa          62    rap
# 1    0Bv7O6fmZk3GrNQFYJaXPn          62    rap
# 2    6ei0W4T1vFScCTM3UuLrIr          55    rap
# 3    09p2nomOAPyylPjRg1gzH0          54    rap
# 4    3wlX0yg6NRMDPwOvdPmuLn          62    rap
# ..                      ...         ...    ...
# 495  4q4q8ib0uKBGC7pF9mPFIJ          56    rap
# 496  7qTaDOcld0VmBWXnkbUj45          67    rap
# 497  7ijPT6fxP7xf8IdHVsuNwA          58    rap
# 498  66wSpvsxSBGBBnHax8VB9S          48    rap
# 499  4jx9GqqVMPacAOKHaFlsLb          61    rap
#
# [500 rows x 6 columns]

# %%
df_resultados_reggaeton = pd.DataFrame (resultados ['reggaeton'])
df_resultados_reggaeton
# Out:
#                   track_name                   artist_name release_date  \
# 0                 La Bachata                 Manuel Turizo   2022-05-26
# 1              Ojitos Lindos      Bad Bunny, Bomba Estéreo   2022-05-06
# 2    Feliz Cumpleaños Ferxxo                          Feid   2022-09-14
# 3                    Hey Mor                   Ozuna, Feid   2022-10-07
# 4                Moscow Mule                     Bad Bunny   2022-05-06
# ..                       ...                           ...          ...
# 495    Los Hombres No Lloran                         Cazzu   2022-05-30
# 496                  Armería                         Alejo   2022-06-22
# 497            Tacones Rojos  Sebastian Yatra, John Legend   2022-07-29
# 498                Exclusive                        Blessd   2022-11-03
# 499                  Un Reel                   Ozuna, TINI   2022-10-07
#
#                    id_track  popularity     genero
# 0    5ww2BF9slyYgNOk37BlC4u          73  reggaeton
# 1    3k3NWokhRRkEPhCzPmV8TW          78  reggaeton
# 2    2CeKVsFFXG4QzA415QygGb          77  reggaeton
# 3    1zsPaEkglFvxjAhrM8yhpr          73  reggaeton
# 4    6Xom58OOXk2SoU711L2IXO          76  reggaeton
# ..                      ...         ...        ...
# 495  7jzMyl5FmJWNnYsoRn4Sg5          44  reggaeton
# 496  6BOQweIUz2y3RSzhNs311H          25  reggaeton
# 497  4slJBQR5P1JjEH9HFkB1Tg          34  reggaeton
# 498  73lC7gD1EKomxcuXRn7qRR          42  reggaeton
# 499  5br09BQU134gRX5M6HMnmr          34  reggaeton
#
# [500 rows x 6 columns]

# %%
df_resultados_pop.to_csv("pop2022.csv")

# %%
df_resultados_indie.to_csv("indie2022.csv")

# %%
df_resultados_rap.to_csv("rap2022.csv")

# %%
df_resultados_reggaeton.to_csv("reggaeton2022.csv")
