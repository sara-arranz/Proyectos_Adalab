# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import requests
import re
import pandas as pd

# %%
# Coloca tus credenciales aquí
CLIENT_ID = '00b3c07cbf3b41fe80275bf332b3ca96'
CLIENT_SECRET = '10e9e68a55f341c292dbd38c6349f314'

# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)
try:
    sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET))
    print("✅ Autenticación correcta")
except Exception as e:
    print(f"❌ Error de autenticación: {e}")
# Out:
# ✅ Autenticación correcta

# %%
def rastreo_global(year, limit=50, market='ES', max_results=500):
    
    generos = ['reggaeton', 'pop', 'rap', 'indie']
    resultados_por_genero = {}

    # Iterar por los géneros
    for genero in generos:
        print(f"Buscando canciones del género {genero}...")

        datos = []  # Lista donde almacenaremos los resultados
        offset = 0  # Para la paginación
        
        while len(datos) < max_results:
            # Realizar la búsqueda en Spotify por género y año
            query = f"genre:{genero} year:{year}"
            busqueda = sp.search(q=query, limit=limit, offset=offset, type='track', market=market)
            
            # Obtener los resultados
            items = busqueda['tracks']['items']
            
            # Si no hay más resultados, salir del bucle
            if not items:
                break

            # Procesar los resultados
            for item in items:
                track_info = {
                    'track_name': item['name'],
                    'artist_name': ', '.join([artist['name'] for artist in item['artists']]),  # Todos los artistas
                    'release_date': item['album']['release_date'],
                    'id_track': item['id'],
                    'popularity': item['popularity'],
                    'genero': genero  # Añadimos el género
                }
                datos.append(track_info)

                # Si alcanzamos el máximo de resultados, detenemos la búsqueda
                if len(datos) >= max_results:
                    break

            # Aumentamos el offset para la siguiente paginación
            offset += limit
        
        # Almacenamos los resultados de este género en el diccionario
        resultados_por_genero[genero] = datos

    return resultados_por_genero

# %%
resultados = rastreo_global (year = 2018)
# Out:
# Buscando canciones del género reggaeton...
# Buscando canciones del género pop...
# Buscando canciones del género rap...
# Buscando canciones del género indie...

# %%
resultados
# Out:
# {'reggaeton': [{'track_name': 'Amanece',
#    'artist_name': 'Anuel AA, Haze',
#    'release_date': '2018-12-14',
#    'id_track': '1LiN0Z98FkR1t0m8KmLcAH',
#    'popularity': 76,
#    'genero': 'reggaeton'},
#   {'track_name': 'Madura',
#    'artist_name': 'Cosculluela, Bad Bunny',
#    'release_date': '2018-04-13',
#    'id_track': '5n2XTRsYFlZwNBp06KAjDX',
#    'popularity': 74,
#    'genero': 'reggaeton'},
#   {'track_name': 'X (feat. Maluma & Ozuna) - Remix',
#    'artist_name': 'Nicky Jam, J Balvin, Maluma, Ozuna',
#    'release_date': '2018-06-29',
#    'id_track': '6JjPBQfI2Y8nIjnm65X6Pw',
#    'popularity': 77,
#    'genero': 'reggaeton'},
#   {'track_name': 'Si Estuviésemos Juntos',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2018-12-23',
#    'id_track': '35wvL50xvKpCHEJPxLOLPI',
#    'popularity': 75,
#    'genero': 'reggaeton'},
#   {'track_name': 'Hipócrita',
#    'artist_name': 'Anuel AA, Zion',
#    'release_date': '2018-07-17',
#    'id_track': '4CbANooTL2aTHzJZqQ0Uvk',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'Triste',
#    'artist_name': 'Bryant Myers, Bad Bunny',
#    'release_date': '2018-07-27',
#    'id_track': '6pnzUCBMwMT5rvx6PyhusZ',
#    'popularity': 67,
#    'genero': 'reggaeton'},
#   {'track_name': 'Darte Remix',
#    'artist_name': 'Alex Rose, Casper Magico, Ñengo Flow, Bryant Myers, Noriel, Juhn, Miky Woodz, JHAYCO, Myke Towers',
#    'release_date': '2018-07-27',
#    'id_track': '6wxZq37sANWYDJiDN5khyL',
#    'popularity': 69,
#    'genero': 'reggaeton'},
#   {'track_name': 'Sigue Bailandome',
#    'artist_name': 'Yannc, Darkiel, Eladio Carrion, Brray, Myke Towers',
#    'release_date': '2018-10-19',
#    'id_track': '0GmiGIxXDNrePrHBpijYDp',
#    'popularity': 69,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tú No Lo Amas',
#    'artist_name': 'Anuel AA',
#    'release_date': '2018-07-17',
#    'id_track': '0fLOPPoyIaPTe8dm2Mrft3',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ponle Música',
#    'artist_name': 'Bryant Myers, Plan B',
#    'release_date': '2018-07-27',
#    'id_track': '6fMrYZH28LcWXYpmDxdXAS',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Quiere Beber',
#    'artist_name': 'Anuel AA',
#    'release_date': '2018-07-17',
#    'id_track': '0FDMH2ahuIVzCybwHJK9zh',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'De las 2 (feat. Bad Bunny & Arcángel)',
#    'artist_name': 'Trap Capos, Noriel, Bad Bunny, Arcángel',
#    'release_date': '2018-04-13',
#    'id_track': '4DS7HoqrKq1dDjeYOKBlu9',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'Bandolera',
#    'artist_name': 'Anuel AA',
#    'release_date': '2018-07-17',
#    'id_track': '6zw6EBrOdGTbKzC0djTOlD',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'Traicionera',
#    'artist_name': 'Sebastian Yatra',
#    'release_date': '2018-05-18',
#    'id_track': '4Ft0391aLVNtCPPseh98lp',
#    'popularity': 70,
#    'genero': 'reggaeton'},
#   {'track_name': 'Báilame - Remix',
#    'artist_name': 'Nacho, Yandel, Bad Bunny, Mambo Kingz, DJ Luian',
#    'release_date': '2018-05-11',
#    'id_track': '4l3xGFwoTinvYxsePytOOf',
#    'popularity': 67,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ella Quiere Beber - Remix',
#    'artist_name': 'Anuel AA, Romeo Santos',
#    'release_date': '2018-11-02',
#    'id_track': '3f5lA8nnc4YYF1qf78WpHw',
#    'popularity': 70,
#    'genero': 'reggaeton'},
#   {'track_name': 'Yeezy',
#    'artist_name': 'Anuel AA, Ñengo Flow',
#    'release_date': '2018-07-17',
#    'id_track': '54N6ILqlyNzADZNuGEfk9a',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'Brindemos',
#    'artist_name': 'Anuel AA, Ozuna',
#    'release_date': '2018-07-17',
#    'id_track': '5P8TXlZCMwru6DaMsIbbO3',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Forma en Que Me Miras',
#    'artist_name': 'Super Yei, Sammy Baby, Myke Towers, Lenny Tavárez, Rafa Pabön',
#    'release_date': '2018-08-04',
#    'id_track': '6t94PGXYAuo9GbJEnMpPcW',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': 'Explícale (feat. Cosculluela & Brytiago) - Remix',
#    'artist_name': 'Yandel, Bad Bunny, Noriel, Cosculluela, Brytiago',
#    'release_date': '2018-04-11',
#    'id_track': '65n40RsQ9SObH7hNvVTHp0',
#    'popularity': 67,
#    'genero': 'reggaeton'},
#   {'track_name': 'Solita',
#    'artist_name': 'Ozuna, Mambo Kingz, DJ Luian, Bad Bunny, Wisin, Almighty',
#    'release_date': '2018-01-19',
#    'id_track': '7rwX0O3RlxqqIjQM8evm5E',
#    'popularity': 69,
#    'genero': 'reggaeton'},
#   {'track_name': 'Momentos',
#    'artist_name': 'Bryant Myers, Cosculluela',
#    'release_date': '2018-07-27',
#    'id_track': '0YjWCWvFmC0yXW8aQrIlEF',
#    'popularity': 61,
#    'genero': 'reggaeton'},
#   {'track_name': 'Vaina Loca',
#    'artist_name': 'Ozuna, Manuel Turizo',
#    'release_date': '2018-08-24',
#    'id_track': '48zFZh27QU5qsrBjn4C2FA',
#    'popularity': 69,
#    'genero': 'reggaeton'},
#   {'track_name': 'Vacio',
#    'artist_name': 'Almighty',
#    'release_date': '2018-02-03',
#    'id_track': '3HoZTyT6zXnyDkiVUQRO9N',
#    'popularity': 65,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Ocasión',
#    'artist_name': 'DJ Luian, Mambo Kingz, De La Ghetto, Arcángel, Ozuna, Anuel AA',
#    'release_date': '2018-03-16',
#    'id_track': '20pJKlNIU3J1CrvhBr1kQ8',
#    'popularity': 69,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Romana',
#    'artist_name': 'Bad Bunny, El Alfa',
#    'release_date': '2018-12-23',
#    'id_track': '1khmgu0pveJbkbpbkyvcQv',
#    'popularity': 69,
#    'genero': 'reggaeton'},
#   {'track_name': 'Volvamos Hablar',
#    'artist_name': 'Bryant Myers',
#    'release_date': '2018-07-27',
#    'id_track': '04Sr9FYcAOLzxLtXF0GKV8',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'Asesina',
#    'artist_name': 'Brytiago, Darell',
#    'release_date': '2018-05-01',
#    'id_track': '5lZaM4985p0t3YfizlQWUz',
#    'popularity': 69,
#    'genero': 'reggaeton'},
#   {'track_name': 'Indiferente',
#    'artist_name': 'Almighty',
#    'release_date': '2018-02-03',
#    'id_track': '2LcZ4LPsVN1yXP7MEOnSgg',
#    'popularity': 62,
#    'genero': 'reggaeton'},
#   {'track_name': 'Toda (Remix)',
#    'artist_name': 'Alex Rose, Rauw Alejandro, Lenny Tavárez, Cazzu, Lyanno',
#    'release_date': '2018-06-01',
#    'id_track': '47ZS1OjnJpJVfGN9yHXfMn',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'Felices los 4',
#    'artist_name': 'Maluma',
#    'release_date': '2018-05-18',
#    'id_track': '1RouRzlg8OKFeqc6LvdxmB',
#    'popularity': 70,
#    'genero': 'reggaeton'},
#   {'track_name': 'Adictiva',
#    'artist_name': 'Daddy Yankee, Anuel AA',
#    'release_date': '2018-11-09',
#    'id_track': '6MJUCumnQsQEKbCy28tbCP',
#    'popularity': 64,
#    'genero': 'reggaeton'},
#   {'track_name': 'Te Boté - Remix',
#    'artist_name': 'Nio Garcia, Casper Magico, Bad Bunny, Darell, Ozuna, Nicky Jam',
#    'release_date': '2018-04-13',
#    'id_track': '3V8UKqhEK5zBkBb6d6ub8i',
#    'popularity': 68,
#    'genero': 'reggaeton'},
#   {'track_name': 'Dime Si Te Acuerdas',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2018-02-22',
#    'id_track': '3kG1jgWIDmjJkXhOiOmioO',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': 'Te Vi',
#    'artist_name': 'Piso 21, Micro TDH',
#    'release_date': '2018-12-14',
#    'id_track': '059bcIhyc2SBwm6sw2AZzd',
#    'popularity': 72,
#    'genero': 'reggaeton'},
#   {'track_name': 'No Pensarte',
#    'artist_name': 'Myke Towers, Juhn',
#    'release_date': '2018-10-19',
#    'id_track': '5hsWWWUEmfSmClsm0Wqy6X',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mi Gente',
#    'artist_name': 'J Balvin, Willy William',
#    'release_date': '2018-05-25',
#    'id_track': '7COfe3P7KgfwDwIRB8LIDw',
#    'popularity': 70,
#    'genero': 'reggaeton'},
#   {'track_name': 'MIA',
#    'artist_name': 'Bad Bunny, Drake',
#    'release_date': '2018-12-23',
#    'id_track': '3gE4eQH3K83Sght0ZLvuBK',
#    'popularity': 71,
#    'genero': 'reggaeton'},
#   {'track_name': '¿Cual Es Tu Plan?',
#    'artist_name': 'Bad Bunny, Ñejo, Pj Sin Suela, DJ Nelson',
#    'release_date': '2018-08-17',
#    'id_track': '45jM2fuCq0NHD9p7xn0ptd',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': 'Naturaleza',
#    'artist_name': 'Anuel AA',
#    'release_date': '2018-07-17',
#    'id_track': '7nusMe2WRMNH3szeIOaAWD',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'No Es Justo',
#    'artist_name': 'J Balvin, Zion & Lennox',
#    'release_date': '2018-05-25',
#    'id_track': '5qFeMRz4TvetPmzjre9Dq7',
#    'popularity': 67,
#    'genero': 'reggaeton'},
#   {'track_name': 'La player (Bandolera)',
#    'artist_name': 'Zion & Lennox',
#    'release_date': '2018-02-23',
#    'id_track': '0VKkyBKCXyR99navhVRqcP',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': 'Pensando en Ti',
#    'artist_name': 'Anuel AA, Wisin',
#    'release_date': '2018-07-17',
#    'id_track': '33Xd0gRmLMzStrrWccKwuH',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Darte',
#    'artist_name': 'Alex Rose, Myke Towers',
#    'release_date': '2018-03-27',
#    'id_track': '69NkJxpioPfy8rWe4l3EXr',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tanta Falta',
#    'artist_name': 'Bryant Myers',
#    'release_date': '2018-10-10',
#    'id_track': '6H8vwKQzKhw0oAgRPZsQge',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'Amantes de una Noche',
#    'artist_name': 'NATTI NATASHA, Bad Bunny',
#    'release_date': '2018-01-12',
#    'id_track': '2iCOdoyDmWG3hWkbtH1KB2',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'En Disney',
#    'artist_name': 'Jamby El Favo',
#    'release_date': '2018-03-22',
#    'id_track': '6T91msAA2LX33LDlfGZkkq',
#    'popularity': 61,
#    'genero': 'reggaeton'},
#   {'track_name': 'Devuelveme',
#    'artist_name': 'Ozuna',
#    'release_date': '2018-08-24',
#    'id_track': '5uvucCRBTkxv7VxIDLOqe7',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ojala',
#    'artist_name': 'Bryant Myers, Darell, Almighty, De La Ghetto',
#    'release_date': '2018-07-27',
#    'id_track': '63EJDEfcZwwRlPt5qEWPjV',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ibiza',
#    'artist_name': 'Ozuna, Romeo Santos',
#    'release_date': '2018-08-24',
#    'id_track': '1h9P5WJwyvK8OB7O2YiXgp',
#    'popularity': 61,
#    'genero': 'reggaeton'},
#   {'track_name': "Na' Personal",
#    'artist_name': 'Miky Woodz, Alex Rose',
#    'release_date': '2018-12-14',
#    'id_track': '16fZpc0Md2q1SGu8FMTo6x',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Subete',
#    'artist_name': 'Lary Over, Lirico En La Casa',
#    'release_date': '2018-09-06',
#    'id_track': '7IKPzIshm586JYCchDyfAc',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'NI BIEN NI MAL',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2018-12-23',
#    'id_track': '278kSqsZIiYp8p3QjYAqa8',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ya No Tiene Novio',
#    'artist_name': 'Sebastian Yatra, Mau y Ricky',
#    'release_date': '2018-08-10',
#    'id_track': '7uQmJ1jgNzBpATSoWKSPFu',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': 'T.T.I.',
#    'artist_name': 'Rauw Alejandro',
#    'release_date': '2018-09-21',
#    'id_track': '4gPpYLervKt4cXmhUjpYLj',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Déjala Que Vuelva (feat. Manuel Turizo)',
#    'artist_name': 'Piso 21, Manuel Turizo',
#    'release_date': '2018-05-11',
#    'id_track': '1j6xOGusnyXq3l6IryKF3G',
#    'popularity': 70,
#    'genero': 'reggaeton'},
#   {'track_name': 'Te Necesito',
#    'artist_name': 'Anuel AA',
#    'release_date': '2018-07-17',
#    'id_track': '5x5kN5Qx1zptllSZV42jfh',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'Bipolar',
#    'artist_name': 'Chris Jedi, Ozuna, Brytiago',
#    'release_date': '2018-03-09',
#    'id_track': '2ixygoa1o3CdZknv1PPjyj',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'Déjate Llevar',
#    'artist_name': 'Alex Rose, Lyanno',
#    'release_date': '2018-03-27',
#    'id_track': '1g4h47nGXrMyaRP7Za4Fuy',
#    'popularity': 61,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Modelo',
#    'artist_name': 'Ozuna, Cardi B',
#    'release_date': '2018-08-24',
#    'id_track': '2SbzdGpOKlH3HIAGTWTbwU',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'Me Han Hablau De Ti',
#    'artist_name': 'Bryant Myers, Miky Woodz',
#    'release_date': '2018-07-27',
#    'id_track': '6olXxxrQ2nvvBP3BppeCEy',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Devuélveme El Corazón',
#    'artist_name': 'Sebastian Yatra',
#    'release_date': '2018-05-18',
#    'id_track': '7etlF1zMxJbiaeQrXYh0PY',
#    'popularity': 64,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tu Peor Error',
#    'artist_name': 'Darell',
#    'release_date': '2018-06-22',
#    'id_track': '2cPSKVsKHsjCkztKkaekfS',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Corazón (feat. Nego do Borel)',
#    'artist_name': 'Maluma, Nego do Borel',
#    'release_date': '2018-05-18',
#    'id_track': '5cepAtqnEQ6yVG6088zMMu',
#    'popularity': 65,
#    'genero': 'reggaeton'},
#   {'track_name': 'Prende Un Phillie',
#    'artist_name': 'Bryant Myers, Farruko',
#    'release_date': '2018-07-27',
#    'id_track': '5f9vMvGrddN6mXbupOnJx6',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'El Farsante - Remix',
#    'artist_name': 'Ozuna, Romeo Santos',
#    'release_date': '2018-01-30',
#    'id_track': '7uYgVgRSgqluZclLS7wpp4',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'Solo de Mi',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2018-12-23',
#    'id_track': '4uP3pUP18ennmz0tb3GphR',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': "Na' Nuevo",
#    'artist_name': 'Anuel AA',
#    'release_date': '2018-07-17',
#    'id_track': '0jYLYhbDoceMWHWwwvYpVv',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'Dura',
#    'artist_name': 'Daddy Yankee',
#    'release_date': '2018-01-18',
#    'id_track': '6KuqAtoeVzxAYOaMveLNpH',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': 'Caro',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2018-12-23',
#    'id_track': '6it15CsDlkqB7N4lF0C1qM',
#    'popularity': 61,
#    'genero': 'reggaeton'},
#   {'track_name': 'Hey DJ',
#    'artist_name': 'CNCO, Yandel',
#    'release_date': '2018-04-06',
#    'id_track': '1XgpK29CGGjZnxPYkiRbh4',
#    'popularity': 61,
#    'genero': 'reggaeton'},
#   {'track_name': 'Vamos a Vernos',
#    'artist_name': 'Bryant Myers, Jon Z, Gigolo Y La Exce',
#    'release_date': '2018-07-27',
#    'id_track': '6Jwdh5gh23gmJQ6MFPS0go',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Espina',
#    'artist_name': 'Anuel AA',
#    'release_date': '2018-07-17',
#    'id_track': '1jsFnIYH6MnEjMyvJn7HF1',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Noche De Fantasia',
#    'artist_name': 'Bryant Myers',
#    'release_date': '2018-12-21',
#    'id_track': '0nvRdR944foe7KNNUhrNhb',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Vamos a Vernos',
#    'artist_name': 'Bryant Myers, Jon Z, Gigolo Y La Exce',
#    'release_date': '2018-04-27',
#    'id_track': '3h5rL4b4k10EyTc0qBymvi',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Sin Pijama',
#    'artist_name': 'Becky G, NATTI NATASHA',
#    'release_date': '2018-04-20',
#    'id_track': '2ijef6ni2amuunRoKTlgww',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'Aullando',
#    'artist_name': 'Wisin & Yandel, Romeo Santos',
#    'release_date': '2018-12-14',
#    'id_track': '7BuHdm4lQqcyG3qTwdkxus',
#    'popularity': 62,
#    'genero': 'reggaeton'},
#   {'track_name': 'Te Amo',
#    'artist_name': 'Piso 21, Paulo Londra',
#    'release_date': '2018-03-15',
#    'id_track': '2RVrdr062uLFxXwIxwdXPH',
#    'popularity': 67,
#    'genero': 'reggaeton'},
#   {'track_name': 'A Solas (Remix)',
#    'artist_name': 'Lunay, Lyanno, Anuel AA, Brytiago, Alex Rose',
#    'release_date': '2018-12-07',
#    'id_track': '77MsQNnI0Co0UZOkPyuid3',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Puntos Suspensivos',
#    'artist_name': 'Piso 21',
#    'release_date': '2018-05-11',
#    'id_track': '04cd1MHVq1D8v1nuTZoCdv',
#    'popularity': 66,
#    'genero': 'reggaeton'},
#   {'track_name': 'Modo de Avión',
#    'artist_name': 'Anuel AA',
#    'release_date': '2018-07-17',
#    'id_track': '2sR8ZcBWTUVxLVbbqMPmLD',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Unica',
#    'artist_name': 'Ozuna',
#    'release_date': '2018-08-24',
#    'id_track': '33b2wX9d0kxqxhi7lcsC1A',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Supuestamente',
#    'artist_name': 'Ozuna, Anuel AA',
#    'release_date': '2018-08-24',
#    'id_track': '1ZBU5DSoYQwaZVgep6pfn2',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Culpables',
#    'artist_name': 'KAROL G, Anuel AA',
#    'release_date': '2018-09-14',
#    'id_track': '6q8Lb50EtqNeeJXXe8mMAH',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Por Perro',
#    'artist_name': 'Sebastian Yatra, Luis Figueroa, Lary Over',
#    'release_date': '2018-05-18',
#    'id_track': '2alIsNw1mqEShbWyO1HXZZ',
#    'popularity': 65,
#    'genero': 'reggaeton'},
#   {'track_name': 'Loco Enamorado',
#    'artist_name': 'Abraham Mateo, Farruko, Christian Daniel',
#    'release_date': '2018-11-30',
#    'id_track': '0ftNNfxBAJJeN0E7iq27fZ',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ta To Gucci (Remix)',
#    'artist_name': 'Cauty, Brytiago, Darell, Cosculluela, Rafa Pabön, Chencho Corleone',
#    'release_date': '2018-12-07',
#    'id_track': '7kuRvjpeUcn6qNV9IBXC2C',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ahora Dice - Real Hasta La Muerte Remix',
#    'artist_name': 'Chris Jedi, J Balvin, Ozuna, Cardi B, Offset, Anuel, Arcángel',
#    'release_date': '2018-02-12',
#    'id_track': '2TQTZ2TSAO5eGgkCtjxjrt',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Dura - Remix',
#    'artist_name': 'Daddy Yankee, NATTI NATASHA, Becky G, Bad Bunny',
#    'release_date': '2018-04-27',
#    'id_track': '6U2NuJILEOEpW2tVCuqKHb',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': '200 Mph',
#    'artist_name': 'Bad Bunny, Diplo',
#    'release_date': '2018-12-23',
#    'id_track': '5jGUJXnELDaDTgiRjD9lsg',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Armao 100pre Andamos',
#    'artist_name': 'Anuel AA',
#    'release_date': '2018-05-04',
#    'id_track': '127Q567KlWtlo1pLsiXr3h',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'No Somos Ná (feat. Gigolo y La Exce, Bryant Myers, Alex Rose, Juhn & Amenazzy) - Remix',
#    'artist_name': 'Trap Capos, Noriel, Gigolo Y La Exce, Bryant Myers, Alex Rose, Juhn, Amenazzy',
#    'release_date': '2018-12-14',
#    'id_track': '68Rv2E7MiZwsuazbHttgEj',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mala Mía',
#    'artist_name': 'Maluma',
#    'release_date': '2018-08-10',
#    'id_track': '62o8KoI44JfN7aYxgTnPvh',
#    'popularity': 62,
#    'genero': 'reggaeton'},
#   {'track_name': 'Cuando Te Besé',
#    'artist_name': 'Becky G, Paulo Londra',
#    'release_date': '2018-08-02',
#    'id_track': '2XXMDz7SPZ4mSFN1PXfHUy',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'Que Somos',
#    'artist_name': 'Rauw Alejandro, Lyanno, Mathew',
#    'release_date': '2018-11-21',
#    'id_track': '5FXARQTlf6UwUVuIS60Vn2',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Me Frontió',
#    'artist_name': 'Dímelo Flow, Justin Quiles, Alex Rose, Gigolo Y La Exce',
#    'release_date': '2018-09-10',
#    'id_track': '68Mb6NjkX5hX6DuqHaYhHS',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Que Vuelvas',
#    'artist_name': 'Yannc, Ele A El Dominio',
#    'release_date': '2018-01-05',
#    'id_track': '5UWgZEGRVk6clK3ljzlXmx',
#    'popularity': 57,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tenemos Que Hablar',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2018-12-23',
#    'id_track': '5VQpJ2AY2iMzrRZKgcvNjh',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'Sirena',
#    'artist_name': 'Cali Y El Dandee',
#    'release_date': '2018-04-27',
#    'id_track': '1juHIWqgFiDFAKuEBP24Lt',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Bésame',
#    'artist_name': 'Revol, Jon Z',
#    'release_date': '2018-02-16',
#    'id_track': '6jqCYd3cReqHggswjqU1OR',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'No Podemos',
#    'artist_name': 'Ele A El Dominio',
#    'release_date': '2018-12-07',
#    'id_track': '2IdkC2Ez7RF1NswGllht41',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'PPP',
#    'artist_name': 'KEVIN ROLDAN',
#    'release_date': '2018-09-07',
#    'id_track': '1DcxnVNFAyVl2sDQ646pXS',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'Noche Loca',
#    'artist_name': 'Oken, Myke Towers, Mora',
#    'release_date': '2018-06-08',
#    'id_track': '1AhMFqSONo33DCeTazNF6y',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'MIA (feat. Drake)',
#    'artist_name': 'Bad Bunny, Drake',
#    'release_date': '2018-10-11',
#    'id_track': '3Ueq2zboxwAbsvHrOjdEqz',
#    'popularity': 62,
#    'genero': 'reggaeton'},
#   {'track_name': 'SUTRA',
#    'artist_name': 'Sebastian Yatra, Dalmata',
#    'release_date': '2018-05-18',
#    'id_track': '0lTYnxJdC68v0oXd5xolxY',
#    'popularity': 63,
#    'genero': 'reggaeton'},
#   {'track_name': 'El Préstamo',
#    'artist_name': 'Maluma',
#    'release_date': '2018-05-18',
#    'id_track': '2XVilv6s9GETnw9PG4T9Mz',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Rebota',
#    'artist_name': 'Guaynaa',
#    'release_date': '2018-12-14',
#    'id_track': '4THusowxdHxwt0HBh5pyRx',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'No Somos Ná (feat. Gigolo y La Exce & Bryant Myers)',
#    'artist_name': 'Trap Capos, Noriel, Gigolo Y La Exce, Bryant Myers',
#    'release_date': '2018-04-13',
#    'id_track': '4dtJ5SxwydFay6RTFUxjNu',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Créeme',
#    'artist_name': 'KAROL G, Maluma',
#    'release_date': '2018-11-02',
#    'id_track': '1mT47pKLXUwPYGwB91GcNz',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'Cuando Perriabas',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2018-12-23',
#    'id_track': '5mj8WVFcKdGA8p9HWGTSLc',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'Reggaeton',
#    'artist_name': 'J Balvin',
#    'release_date': '2018-11-17',
#    'id_track': '2D3z17LBMJ2HEHeBFFjTLi',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mocca',
#    'artist_name': 'Lalo Ebratt, Trapical',
#    'release_date': '2018-04-27',
#    'id_track': '0NKoPGc72yUKTIneVhFfg1',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Báilame',
#    'artist_name': 'Nacho',
#    'release_date': '2018-05-11',
#    'id_track': '3umCRVVIPZ72WnperWxLgL',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'Peligrosa',
#    'artist_name': 'J Balvin, Wisin & Yandel',
#    'release_date': '2018-05-25',
#    'id_track': '3Nkqp3NSGWMXVVO08zGpN7',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Pocas Horas',
#    'artist_name': 'Juhn',
#    'release_date': '2018-12-03',
#    'id_track': '3KkYrqGeoj7Eps5pq4gPCT',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'No Eres Mia',
#    'artist_name': 'Bryant Myers',
#    'release_date': '2018-07-27',
#    'id_track': '4GDWxKZCwBpeISD0unxWH6',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Diabla (Official Remix)',
#    'artist_name': 'Frank Miami, Farruko, Lary Over, Bad Bunny',
#    'release_date': '2018-12-21',
#    'id_track': '1OPVFxzEgHEdfvCTiB7nh2',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Yo Quisiera',
#    'artist_name': 'Alex Rose, Dalex',
#    'release_date': '2018-03-27',
#    'id_track': '1rQFjnZx88P7ORhkdDUPZw',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': "Pa' Pasar El Rato",
#    'artist_name': 'Bryant Myers',
#    'release_date': '2018-07-27',
#    'id_track': '4IeAihIO5X4koJjvtWJJfj',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Me Llamas',
#    'artist_name': 'Piso 21',
#    'release_date': '2018-05-11',
#    'id_track': '6tkMQQ5bJ6g0YF6d18iavC',
#    'popularity': 59,
#    'genero': 'reggaeton'},
#   {'track_name': 'Balenciaga',
#    'artist_name': 'Ozuna, Ele A El Dominio',
#    'release_date': '2018-04-05',
#    'id_track': '3iIZvct75tkk1CwbqVjsry',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': '¿Quien Tu Eres?',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2018-12-23',
#    'id_track': '6kN06eEOblRAuWI0xUUS91',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Unica - Remix',
#    'artist_name': 'Ozuna, Anuel AA, Wisin, Yandel',
#    'release_date': '2018-08-24',
#    'id_track': '5Sv1rKKMX1yl9kfJ2HTluk',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Fórmula (feat. Chris Jedi)',
#    'artist_name': 'De La Ghetto, Daddy Yankee, Ozuna, Chris Jedi',
#    'release_date': '2018-09-28',
#    'id_track': '55NwAn7bAl1edTEg1azLOW',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Felices los 4 (feat. Marc Anthony) - Salsa Version',
#    'artist_name': 'Maluma, Marc Anthony',
#    'release_date': '2018-05-18',
#    'id_track': '6PNG5G1v7pU74I13KkvAIo',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Original',
#    'artist_name': 'Arcángel, Bad Bunny',
#    'release_date': '2018-06-29',
#    'id_track': '7MjaU5iFujwT1gOyvJnqNp',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ser Bichote',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2018-12-23',
#    'id_track': '4UEuIEv9Wc3wtiWUplGJ7q',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'El Juego',
#    'artist_name': 'Ñengo Flow, Darell',
#    'release_date': '2018-03-02',
#    'id_track': '212Ot0W7Lofqf3jCgPGAW8',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Llegó la Navidad',
#    'artist_name': 'Ozuna, Generacion Escogida, Christian Nieves',
#    'release_date': '2018-12-12',
#    'id_track': '0Biqb9UJEsimAKNSxTuJYM',
#    'popularity': 41,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ponle',
#    'artist_name': 'Rvssian, Farruko, J Balvin',
#    'release_date': '2018-09-06',
#    'id_track': '28O1p0bQXH2F6Qn8jBZZR4',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Subete',
#    'artist_name': 'Frank Miami, Lary Over, Lirico En La Casa',
#    'release_date': '2018-12-21',
#    'id_track': '4OOlKNTQISagv0nsofvySZ',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Reggaetón en lo Oscuro',
#    'artist_name': 'Wisin & Yandel',
#    'release_date': '2018-12-14',
#    'id_track': '7LLXLd0pisbEAdIVK502VM',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Estamos Clear',
#    'artist_name': 'Miky Woodz, Bad Bunny',
#    'release_date': '2018-05-25',
#    'id_track': '6IlcjkEw26SeAKvjXSwsVb',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Baby',
#    'artist_name': 'Amenazzy, Nicky Jam, Farruko',
#    'release_date': '2018-12-21',
#    'id_track': '2IA8cFA46DkjgbsRG7kKbp',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'Nadie Sabe',
#    'artist_name': 'Juhn, Amenazzy',
#    'release_date': '2018-09-28',
#    'id_track': '2tZVSTEiHry79oI8Qs0W9l',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Luz Apaga',
#    'artist_name': 'Ozuna, Lunay, Rauw Alejandro, Lyanno',
#    'release_date': '2018-11-16',
#    'id_track': '5Q3e16qE1RE5oilN3ukasm',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Sigues Preguntando',
#    'artist_name': 'Alex Rose',
#    'release_date': '2018-03-27',
#    'id_track': '1BO09TcMR3Va5sILAyrWww',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ella Fuma',
#    'artist_name': 'Plan B, Chencho Corleone, Farruko, Darell, Brytiago',
#    'release_date': '2018-08-03',
#    'id_track': '4IYxcqhcFFJ025qfWJeulF',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'Momentos',
#    'artist_name': 'Bryant Myers, Cosculluela',
#    'release_date': '2018-06-15',
#    'id_track': '2HnW1RQQuF82U7nfnxaSkK',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Te Boté',
#    'artist_name': 'Darell, Casper Magico, Nio Garcia, Nicky Jam, Ozuna, Bad Bunny',
#    'release_date': '2018-04-20',
#    'id_track': '42FWqCxAw5aG1FvjyVjIlH',
#    'popularity': 61,
#    'genero': 'reggaeton'},
#   {'track_name': 'Deseos',
#    'artist_name': 'JHAYCO, Bryant Myers',
#    'release_date': '2018-05-18',
#    'id_track': '4XZYFGgAx1X2X6sKinaPvL',
#    'popularity': 41,
#    'genero': 'reggaeton'},
#   {'track_name': 'Pasado y Presente',
#    'artist_name': 'Ozuna, Anuel AA',
#    'release_date': '2018-08-24',
#    'id_track': '6NPjHwhEG7eQUQBoPFBrnz',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Qué Más Pues',
#    'artist_name': 'Sech, Justin Quiles',
#    'release_date': '2018-12-06',
#    'id_track': '5O3cRP4ZHC9vvVIHtET1f0',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Bella - Remix',
#    'artist_name': 'Wolfine, Maluma',
#    'release_date': '2018-04-23',
#    'id_track': '78nLeZtgvDeKygduWsgeUk',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Alguien Robo',
#    'artist_name': 'Sebastian Yatra, Nacho, Wisin',
#    'release_date': '2018-05-18',
#    'id_track': '0pQoNBSZeRFuhLVH8gCVDT',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Se Te Hizo Tarde',
#    'artist_name': 'Ñejo, Ele A, Jon Z, Jamby El Favo',
#    'release_date': '2018-01-19',
#    'id_track': '4ZtSifmVEda37YUYnnHz1y',
#    'popularity': 60,
#    'genero': 'reggaeton'},
#   {'track_name': 'Dame Algo',
#    'artist_name': 'Wisin & Yandel, Bad Bunny',
#    'release_date': '2018-12-14',
#    'id_track': '4ByaTrfoYbXrmlbsTG8MTD',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Secreto - Remix',
#    'artist_name': 'Amarion, Rauw Alejandro, Mora, Randy, Darkiel, Anonimus',
#    'release_date': '2018-12-06',
#    'id_track': '0pc1ydCVOqDfJrEsFUorBg',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ambiente',
#    'artist_name': 'J Balvin',
#    'release_date': '2018-05-25',
#    'id_track': '6VrBWh90BiwWmwKtvwWFcq',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Noche Loca Remix',
#    'artist_name': 'Oken, Myke Towers, Mora, De La Ghetto, Noriel, Juhn, Bryant Myers',
#    'release_date': '2018-12-21',
#    'id_track': '6EuWlqhvkWyJMW8HQxEfEA',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': "Pa' la Pared",
#    'artist_name': 'Myke Towers, Darell',
#    'release_date': '2018-12-21',
#    'id_track': '6QDFKeRwjrtWfecE08iMg9',
#    'popularity': 39,
#    'genero': 'reggaeton'},
#   {'track_name': 'Besándote',
#    'artist_name': 'Piso 21',
#    'release_date': '2018-05-11',
#    'id_track': '43jclIPKJv9iFiYWVyWqsb',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'Solo - Remix',
#    'artist_name': 'Lary Over, Amenazzy, Farruko',
#    'release_date': '2018-03-02',
#    'id_track': '56LZ6nyFFA1mUUZh1SCA3b',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Solo de Mi',
#    'artist_name': 'Bad Bunny',
#    'release_date': '2018-12-14',
#    'id_track': '5YOkA7qd2983FtBQnP8sYx',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Dime',
#    'artist_name': 'Revol, J Balvin, Bad Bunny, Arcángel, De La Ghetto',
#    'release_date': '2018-03-23',
#    'id_track': '08wJw4VdkKImX4t1vL6MsO',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'Original',
#    'artist_name': 'Arcángel, Bad Bunny',
#    'release_date': '2018-07-13',
#    'id_track': '1LBlcCtOrKITXpEp1hnNpj',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'Confia',
#    'artist_name': 'Juhn',
#    'release_date': '2018-01-12',
#    'id_track': '1cAi1LzSuFcGXK6juPWisy',
#    'popularity': 41,
#    'genero': 'reggaeton'},
#   {'track_name': 'Siempre Esta Conmigo',
#    'artist_name': 'Almighty',
#    'release_date': '2018-03-16',
#    'id_track': '1dmWiKgQGr3tWB984jZXnZ',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mi Cama',
#    'artist_name': 'KAROL G',
#    'release_date': '2018-05-11',
#    'id_track': '7sFYVcKSb24qg0dAkqLEFj',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Si Tú',
#    'artist_name': 'Justin Quiles, Magnifico, Plan B',
#    'release_date': '2018-11-08',
#    'id_track': '5FbQLB4JlxE1MMubQBdpfi',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'Una Noche Mas',
#    'artist_name': 'Ñengo Flow, Yannc, Andre TG',
#    'release_date': '2018-11-16',
#    'id_track': '6s4Fyxy3vnTwb33Q9IlLo4',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'No Es Justo',
#    'artist_name': 'J Balvin, Zion & Lennox',
#    'release_date': '2018-05-11',
#    'id_track': '1RTlTuLOdnmgbe11ynwR7c',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Solicitud',
#    'artist_name': 'Menor Menor, Mr. Perez, Myke Towers',
#    'release_date': '2018-12-07',
#    'id_track': '2ooAAsrXBYlwpcqgUBaQxx',
#    'popularity': 41,
#    'genero': 'reggaeton'},
#   {'track_name': 'Te Busco',
#    'artist_name': 'Sech, Alex Rose',
#    'release_date': '2018-12-06',
#    'id_track': '7AyXdBQAgRLJBK72gqq0Hz',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'Puedo Ser',
#    'artist_name': 'Cazzu, Maikel Delacalle',
#    'release_date': '2018-08-17',
#    'id_track': '5olxoiU59KJZTbqyzki5TW',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'Fantasía',
#    'artist_name': 'Alex Sensation, Bad Bunny',
#    'release_date': '2018-02-09',
#    'id_track': '72BQwM1wnBQCbjwjRu1rmF',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Abuso',
#    'artist_name': 'Brytiago, Farruko, Lary Over',
#    'release_date': '2018-02-16',
#    'id_track': '73jCuIwQZavaxgy7iCIIR3',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Confia - Remix',
#    'artist_name': 'Juhn, Ozuna',
#    'release_date': '2018-08-03',
#    'id_track': '0cObNe1tjeNMHNdp7DfLk5',
#    'popularity': 41,
#    'genero': 'reggaeton'},
#   {'track_name': 'Nanana',
#    'artist_name': 'Kendo Kaponi, Anuel AA',
#    'release_date': '2018-12-26',
#    'id_track': '3slH8q2QxyyZdp4MiXEyuO',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Chapiadora',
#    'artist_name': 'Cazzu, Omar Varela, MYKKA',
#    'release_date': '2018-03-30',
#    'id_track': '04QLFxiUzVVD6kFekO0FIZ',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'Porque Te Mientes (feat. Gadiel & Bryant Myers)',
#    'artist_name': 'Trap Capos, Noriel, Gadiel, Bryant Myers',
#    'release_date': '2018-04-13',
#    'id_track': '0Ks2NJH2PCxyWAFPlI4p9B',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mocca - Remix',
#    'artist_name': 'Lalo Ebratt, J Balvin, Trapical',
#    'release_date': '2018-10-05',
#    'id_track': '1usoXi4f0BnMART4uActEA',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Doble Personalidad',
#    'artist_name': 'Trap Capos, Noriel, Yandel',
#    'release_date': '2018-04-13',
#    'id_track': '63Sj8CfN6RtKBES7G7l5Bp',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Lucete',
#    'artist_name': 'Dalex, Dímelo Flow, Justin Quiles',
#    'release_date': '2018-10-04',
#    'id_track': '5yx43rnqectCMLHDdNgyyB',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'La Confusión',
#    'artist_name': 'Juhn',
#    'release_date': '2018-01-19',
#    'id_track': '7uDTfVnhvH0Yhdx6CGF7QJ',
#    'popularity': 36,
#    'genero': 'reggaeton'},
#   {'track_name': 'A Solas',
#    'artist_name': 'Lunay, Lyanno',
#    'release_date': '2018-08-17',
#    'id_track': '54LQVnoZMPN5gEBgvnYTem',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Traicionera - Remix',
#    'artist_name': 'Sebastian Yatra, Cosculluela, Cali Y El Dandee',
#    'release_date': '2018-05-18',
#    'id_track': '341wMisUIHkGCvq5e8ZcZv',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tu Sabes',
#    'artist_name': 'Bryant Myers, Tito "El Bambino"',
#    'release_date': '2018-07-27',
#    'id_track': '74mPFHG0wnJsKtEhAmuIBC',
#    'popularity': 41,
#    'genero': 'reggaeton'},
#   {'track_name': 'Sin Putas No Hay Paraiso',
#    'artist_name': 'Jon Z, Ele A El Dominio',
#    'release_date': '2018-03-09',
#    'id_track': '293XAZ5eXgAWPXb1N2eR47',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Se Supone - Remix',
#    'artist_name': 'JHAYCO, Darell, Ñengo Flow, Almighty, Miky Woodz, Myke Towers',
#    'release_date': '2018-05-18',
#    'id_track': '3EEnqlWxR1XX15grqw8lU1',
#    'popularity': 41,
#    'genero': 'reggaeton'},
#   {'track_name': 'Selfie',
#    'artist_name': 'Juhn, Benny Benni',
#    'release_date': '2018-06-08',
#    'id_track': '2dCSrMdcE6kP0OzpaS4ycJ',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Viajo Sin Ver (Remix) [feat. De La Ghetto, Almighty, Miky Woodz, El Alfa, Noriel, Ele A El Dominio, Lyan, Juanka El Problematik, Pusho, Jeycyn]',
#    'artist_name': 'Jon Z, De La Ghetto, Almighty, Miky Woodz, El Alfa, Noriel, Ele A El Dominio, Lyan, Juanka El Problematik, Pusho',
#    'release_date': '2018-08-31',
#    'id_track': '6InhAZgp7qVG2DGCPN9dCL',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Me Torturas 2.5',
#    'artist_name': 'Camiloskill, Cosculluela',
#    'release_date': '2018-01-17',
#    'id_track': '3AMfYy6eD7ptMUOgr5mTTa',
#    'popularity': 41,
#    'genero': 'reggaeton'},
#   {'track_name': 'No Love (feat. Bryant Myers)',
#    'artist_name': 'Trap Capos, Noriel, Prince Royce, Bryant Myers',
#    'release_date': '2018-04-13',
#    'id_track': '1cLz9rUh4Wpr2l3idSJqPw',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'Coméntale',
#    'artist_name': 'Ozuna, Akon',
#    'release_date': '2018-08-24',
#    'id_track': '7oCGD6Ccuw8JmYWw6IrI8z',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Satisfacción',
#    'artist_name': 'Nicky Jam, Bad Bunny, Arcángel',
#    'release_date': '2018-08-03',
#    'id_track': '21WvAGxPUNJARcZoSqswd7',
#    'popularity': 46,
#    'genero': 'reggaeton'},
#   {'track_name': 'Una Vuelta',
#    'artist_name': 'Pinto Picasso',
#    'release_date': '2018-03-02',
#    'id_track': '5zLHwFSoGvK5AUbma0pQDS',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'Prepago',
#    'artist_name': 'Lary Over, Ñejo',
#    'release_date': '2018-03-02',
#    'id_track': '4LPa3CFFan6WKAvl78dfMM',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'Me Dijeron',
#    'artist_name': 'Ozuna',
#    'release_date': '2018-08-24',
#    'id_track': '17UUYZ290omPaJY4wKeyHh',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mi Cama - Remix',
#    'artist_name': 'KAROL G, J Balvin, Nicky Jam',
#    'release_date': '2018-07-13',
#    'id_track': '38QmUDpkoYlNbMKvpvAsrE',
#    'popularity': 49,
#    'genero': 'reggaeton'},
#   {'track_name': 'Desconocidos',
#    'artist_name': 'Mau y Ricky, Manuel Turizo, Camilo',
#    'release_date': '2018-10-12',
#    'id_track': '0s5DNDV6LAKn2u2Ufa3VjQ',
#    'popularity': 54,
#    'genero': 'reggaeton'},
#   {'track_name': 'Fuego En el Fuego',
#    'artist_name': 'Darkiel, Myke Towers',
#    'release_date': '2018-09-07',
#    'id_track': '7GF9S8IHIuJXJpSjxdHegh',
#    'popularity': 40,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tonta',
#    'artist_name': 'R.K.M & Ken-Y, NATTI NATASHA',
#    'release_date': '2018-02-09',
#    'id_track': '5ZjJT7BB8OoVjyRZRYGen8',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Se Supone - Remix',
#    'artist_name': 'JHAYCO, Darell, Ñengo Flow, Almighty, Miky Woodz, Myke Towers',
#    'release_date': '2018-03-30',
#    'id_track': '2BUFK8XGHJQEeA4xxlu3iO',
#    'popularity': 36,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ahora',
#    'artist_name': 'J Balvin',
#    'release_date': '2018-05-25',
#    'id_track': '2yBWnRKj0Zx7AF1kufajvW',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ponle Música',
#    'artist_name': 'Bryant Myers, Plan B',
#    'release_date': '2018-07-13',
#    'id_track': '0kJ0YyW1liWJbK32TxKfQn',
#    'popularity': 32,
#    'genero': 'reggaeton'},
#   {'track_name': 'Como Soy',
#    'artist_name': 'Pacho El Antifeka, Daddy Yankee, Bad Bunny',
#    'release_date': '2018-08-30',
#    'id_track': '6l2UmWFHtPqgWq0hnqlfJT',
#    'popularity': 43,
#    'genero': 'reggaeton'},
#   {'track_name': 'KaRma',
#    'artist_name': 'Noriel',
#    'release_date': '2018-10-19',
#    'id_track': '6wvk09WzIyOYuDk5ycathk',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'Deseos - Remix',
#    'artist_name': 'JHAYCO, Nio Garcia, Casper Magico, Bryant Myers',
#    'release_date': '2018-07-27',
#    'id_track': '1kQ8PZqLkg3UdClArw42Uk',
#    'popularity': 40,
#    'genero': 'reggaeton'},
#   {'track_name': 'Soy un Puto (feat. Baby Rasta)',
#    'artist_name': 'Trap Capos, Noriel, Baby Rasta',
#    'release_date': '2018-04-13',
#    'id_track': '2frKlnaUycCPoAUAJwIXDL',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mi Medicina',
#    'artist_name': 'CNCO',
#    'release_date': '2018-04-06',
#    'id_track': '0CrcWtJQB7bQE6S1yEbxnP',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'No Te Enamores',
#    'artist_name': 'Paloma Mami',
#    'release_date': '2018-12-21',
#    'id_track': '0EJu1RBtxzldMG2peczuPv',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': "Vamos Pa' la Calle",
#    'artist_name': 'Bad Bunny, Héctor "El Father"',
#    'release_date': '2018-08-21',
#    'id_track': '23mxI8WrJJx5SF1M5HirFX',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'Quiero Mas',
#    'artist_name': 'Ozuna, Wisin, Yandel',
#    'release_date': '2018-08-24',
#    'id_track': '1aYcpI8hXtpAEdBq8fp1pH',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Amaneci',
#    'artist_name': 'Jon Z, Ele A El Dominio',
#    'release_date': '2018-03-09',
#    'id_track': '22BK9A6aL3yQC87edC8KX0',
#    'popularity': 48,
#    'genero': 'reggaeton'},
#   {'track_name': 'Sin Ti',
#    'artist_name': 'Alex Zurdo',
#    'release_date': '2018-08-17',
#    'id_track': '57ogj5vevbzdRtC8Ng2Rtx',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'Se Vuelve Loca',
#    'artist_name': 'CNCO',
#    'release_date': '2018-04-06',
#    'id_track': '2PYmyMAMlhX1eVevLo5A6n',
#    'popularity': 51,
#    'genero': 'reggaeton'},
#   {'track_name': 'Cambiaste Mi Corazón',
#    'artist_name': 'Alex Zurdo',
#    'release_date': '2018-08-17',
#    'id_track': '6wkcbqDurhYtPtZP5QxN5U',
#    'popularity': 56,
#    'genero': 'reggaeton'},
#   {'track_name': 'Machika',
#    'artist_name': 'J Balvin, Jeon, Anitta',
#    'release_date': '2018-05-25',
#    'id_track': '7FnHUsFRTMg8VYteFKj3xL',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Llegaste Tú',
#    'artist_name': 'CNCO, Prince Royce',
#    'release_date': '2018-10-26',
#    'id_track': '6tT4Ks1N04Ut0lSQ3xjSaZ',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'No Lo Parece',
#    'artist_name': 'Myke Towers, Casper Magico, Gotay "El Autentiko"',
#    'release_date': '2018-12-14',
#    'id_track': '25zbmcTZCBbkRlkNCNLNTU',
#    'popularity': 38,
#    'genero': 'reggaeton'},
#   {'track_name': 'Epa Wei',
#    'artist_name': 'Danny Ocean',
#    'release_date': '2018-08-10',
#    'id_track': '2QmsKag0YaqhAbpR9Nwmpn',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Amigo',
#    'artist_name': 'Miky Woodz, Darkiel',
#    'release_date': '2018-05-25',
#    'id_track': '62KpVg6lsf4kKNJ0RjGlXd',
#    'popularity': 50,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mamita',
#    'artist_name': 'CNCO',
#    'release_date': '2018-04-06',
#    'id_track': '71GAvRsilpo9pqd0vYn8Mo',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'A Todas Horas',
#    'artist_name': 'Miky Woodz, Marvel Boy',
#    'release_date': '2018-12-18',
#    'id_track': '11TBBqxLKUQBlyGKJXfvOe',
#    'popularity': 44,
#    'genero': 'reggaeton'},
#   {'track_name': 'Reggaetón Lento (Remix)',
#    'artist_name': 'CNCO, Little Mix',
#    'release_date': '2018-04-06',
#    'id_track': '58gqyeFXhOttZW3yetJGPN',
#    'popularity': 58,
#    'genero': 'reggaeton'},
#   {'track_name': 'My Only One (No Hay Nadie Más)',
#    'artist_name': 'Sebastian Yatra, Isabela Merced',
#    'release_date': '2018-07-27',
#    'id_track': '1gJA27xiMdENwoAVN7kMlo',
#    'popularity': 55,
#    'genero': 'reggaeton'},
#   {'track_name': 'Ambiente',
#    'artist_name': 'J Balvin',
#    'release_date': '2018-04-13',
#    'id_track': '4N9V7YYPoN4DoSnjjfHW1k',
#    'popularity': 47,
#    'genero': 'reggaeton'},
#   {'track_name': 'Entre Sabanas',
#    'artist_name': 'Anonimus, Jon Z, Myke Towers, Rowsy',
#    'release_date': '2018-11-16',
#    'id_track': '75MeklnIklLyjAqsi6MZk7',
#    'popularity': 34,
#    'genero': 'reggaeton'},
#   {'track_name': 'Quiero Decirte',
#    'artist_name': 'Sebastian Yatra',
#    'release_date': '2018-05-18',
#    'id_track': '6PZraXLVqn18HrwCf9fdzH',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Por Ti',
#    'artist_name': 'Ozuna, Almighty',
#    'release_date': '2018-12-06',
#    'id_track': '4e8UMYNboPs6q7yv3ZxD9p',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Deseos',
#    'artist_name': 'JHAYCO, Bryant Myers',
#    'release_date': '2018-02-09',
#    'id_track': '3YuvsuLVA1GHFzT2mIAfXm',
#    'popularity': 31,
#    'genero': 'reggaeton'},
#   {'track_name': 'Nunca Imagine',
#    'artist_name': 'Ryan Castro, Palma Productions, Maycol Riddim',
#    'release_date': '2018-12-27',
#    'id_track': '4nfLH2TfoWT161gMuhep45',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tú Y Yo (feat. Nicky Jam & Justin Quiles)',
#    'artist_name': 'Valentino, Nicky Jam, Justin Quiles',
#    'release_date': '2018-07-27',
#    'id_track': '58smOywZbVu8AjWutppiQA',
#    'popularity': 45,
#    'genero': 'reggaeton'},
#   {'track_name': 'Me Llama Todavia 2 (Remix)',
#    'artist_name': 'Super Yei, Agus Padilla, Juanka, Towy, Yomo, Gotay "El Autentiko", Darkiel, Osquel',
#    'release_date': '2018-05-19',
#    'id_track': '3lJ9fpbayaKDrFziV2UApI',
#    'popularity': 53,
#    'genero': 'reggaeton'},
#   {'track_name': 'Costear',
#    'artist_name': 'JHAYCO, Almighty',
#    'release_date': '2018-10-31',
#    'id_track': '5LtMCyV3rBlXZ31TrigFWU',
#    'popularity': 29,
#    'genero': 'reggaeton'},
#   {'track_name': 'Mi Forma de Ser (feat. Ala Jaza) - Mambo Version',
#    'artist_name': 'Farruko, Ala Jaza',
#    'release_date': '2018-07-20',
#    'id_track': '3eL5jJwutVux7277wM5qzV',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'Not Steady',
#    'artist_name': 'Paloma Mami',
#    'release_date': '2018-09-21',
#    'id_track': '42ArfZUgGo3k5btIHp08it',
#    'popularity': 52,
#    'genero': 'reggaeton'},
#   {'track_name': 'Me Han Hablau De Ti',
#    'artist_name': 'Bryant Myers, Miky Woodz',
#    'release_date': '2018-03-09',
#    'id_track': '6nlunviFw6TH94aRMrnAzz',
#    'popularity': 37,
#    'genero': 'reggaeton'},
#   {'track_name': 'Si Voy A Morir, Me Muero Contento',
#    'artist_name': 'Ele A El Dominio, Onyx Toca El Piano',
#    'release_date': '2018-06-08',
#    'id_track': '4PM1sDbmSOzjzal6bHCh8e',
#    'popularity': 37,
#    'genero': 'reggaeton'},
#   {'track_name': 'No Me Busques (Remix) [feat. Ñengo Flow & Cazzu]',
#    'artist_name': 'Jory Boy, Ñengo Flow',
#    'release_date': '2018-06-15',
#    'id_track': '4hPYUJXanNrTSqG0iTv0gK',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'Se Acabó el Amor - Urban Version',
#    'artist_name': 'Abraham Mateo, Yandel, Jennifer Lopez',
#    'release_date': '2018-03-09',
#    'id_track': '37ZbdPsSjAZjPTVKPi8Dii',
#    'popularity': 36,
#    'genero': 'reggaeton'},
#   {'track_name': 'Vuelve',
#    'artist_name': 'Sebastian Yatra, Beret',
#    'release_date': '2018-09-28',
#    'id_track': '6WSAPEkvEfcEUgSTAo1D3S',
#    'popularity': 42,
#    'genero': 'reggaeton'},
#   {'track_name': 'Tu Olor',
#    'artist_name': 'Ozuna',
#    'release_date': '2018-08-24',
#    'id_track': '48aHJHJyNBcuYIFGMrT5cQ',
#    'popularity': 41,
#    'genero': 'reggaeton'},
#   {'track_name': 'El Combo Me Llama 2',
#    'artist_name': 'Benny Benni, Daddy Yankee, Bad Bunny, Pusho, Farruko, Noriel, Miky Woodz',
#    'release_date': '2018-01-29',
#    'id_track': '4uuGltp3Z6d0IUxsSf4xFl',
#    'popularity': 40,
#    'genero': 'reggaeton'},
#   {'track_name': 'Estamos Clear',
#    'artist_name': 'Miky Woodz, Bad Bunny',
#    'release_date': '2018-04-20',
#    'id_track': '1sNl87MiEoEVXffVgzh44o',
#    'popularity': 42,
#    'genero': 'reggaeton'},
# ...
#   {'track_name': 'Birds',
#    'artist_name': 'Dominique Fils-Aimé',
#    'release_date': '2018-02-02',
#    'id_track': '08TmRNaaezzsowLSXk9zYO',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'Walk Away',
#    'artist_name': 'Xavier Rudd',
#    'release_date': '2018-05-25',
#    'id_track': '6Wq2sy2cIwYbqxs63ACPBd',
#    'popularity': 41,
#    'genero': 'indie'},
#   {'track_name': 'AYER TE VI (feat. Zoe Gotusso)',
#    'artist_name': 'LOUTA, Zoe Gotusso',
#    'release_date': '2018-10-12',
#    'id_track': '7gfyrnHMieXMjIW4n2p5wf',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': "I'll Be Around",
#    'artist_name': 'Garrett Kato',
#    'release_date': '2018-09-28',
#    'id_track': '3ccDb4UqLC54IoFJ8LmFoy',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'Saturdays (feat. HAIM)',
#    'artist_name': 'Twin Shadow, HAIM',
#    'release_date': '2018-04-27',
#    'id_track': '5ClqcvP4dYDDX6Zv3jPQD1',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'Lucy',
#    'artist_name': 'Still Woozy, ODIE',
#    'release_date': '2018-03-22',
#    'id_track': '5RxpYHVbGJPOvSEATQyg9P',
#    'popularity': 55,
#    'genero': 'indie'},
#   {'track_name': 'Kouzen',
#    'artist_name': 'Melissa Laveaux',
#    'release_date': '2018-03-23',
#    'id_track': '5xm25DdCRuMuUqb9cZTa4z',
#    'popularity': 43,
#    'genero': 'indie'},
#   {'track_name': 'The Joke',
#    'artist_name': 'Brandi Carlile',
#    'release_date': '2018-02-16',
#    'id_track': '18k8IlS52uxRWObykDUZFG',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'Ich geh heut nicht mehr tanzen',
#    'artist_name': 'AnnenMayKantereit',
#    'release_date': '2018-12-07',
#    'id_track': '13Fo5bvBmmDDaMGtLlAqB5',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'You Say',
#    'artist_name': 'Two Feet',
#    'release_date': '2018-10-05',
#    'id_track': '7ERD3wzsj1VGhORdxamue7',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'Cómo Te Quiero',
#    'artist_name': 'Khruangbin',
#    'release_date': '2018-01-26',
#    'id_track': '5lNCB8HiizT8ldhUjgSwtf',
#    'popularity': 43,
#    'genero': 'indie'},
#   {'track_name': "Why Can't We Be Friends?",
#    'artist_name': 'The Academic',
#    'release_date': '2018-01-12',
#    'id_track': '0qZXLvlsM5ELq3WfZXgnCi',
#    'popularity': 48,
#    'genero': 'indie'},
#   {'track_name': 'Blood // Water',
#    'artist_name': 'grandson',
#    'release_date': '2018-06-15',
#    'id_track': '7clyJIrLkEbXUDwj1tC9zz',
#    'popularity': 61,
#    'genero': 'indie'},
#   {'track_name': 'Sandman',
#    'artist_name': 'BRONCHO',
#    'release_date': '2018-10-12',
#    'id_track': '28I0KNqOmkvzzz7SghMhfu',
#    'popularity': 48,
#    'genero': 'indie'},
#   {'track_name': 'Cara Italia',
#    'artist_name': 'Ghali',
#    'release_date': '2018-05-02',
#    'id_track': '3atDsUhlUgDlQQrI0XFh7I',
#    'popularity': 51,
#    'genero': 'indie'},
#   {'track_name': 'crash',
#    'artist_name': 'EDEN',
#    'release_date': '2018-01-19',
#    'id_track': '7EkMIQ2PzEzwQroLl6dUvw',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'You and Me',
#    'artist_name': 'Shallou',
#    'release_date': '2018-04-27',
#    'id_track': '1Z6u99PTG9w2t4mcIGoqqS',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'Eyes',
#    'artist_name': 'RÜFÜS DU SOL',
#    'release_date': '2018-10-19',
#    'id_track': '6vkFCzPmJ3beYG0zeevdmX',
#    'popularity': 50,
#    'genero': 'indie'},
#   {'track_name': 'Love Is Blind',
#    'artist_name': 'Dustin Tebbutt',
#    'release_date': '2018-10-26',
#    'id_track': '7jcX70Kf48Lbo7TssexWeY',
#    'popularity': 39,
#    'genero': 'indie'},
#   {'track_name': 'No Going Back',
#    'artist_name': 'Yuno',
#    'release_date': '2018-06-15',
#    'id_track': '356aM3w6i5v1cltIzOnVTP',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'Quiero un Amor',
#    'artist_name': 'El Chacal & Los Alpes Floreados',
#    'release_date': '2018-09-30',
#    'id_track': '09MrbfVQQcG5qSyXp9fsL9',
#    'popularity': 43,
#    'genero': 'indie'},
#   {'track_name': "Questa nostra stupida canzone d'amore",
#    'artist_name': 'Thegiornalisti',
#    'release_date': '2018-09-21',
#    'id_track': '1Kw6V4wiZKTVwLZ5YcYJR3',
#    'popularity': 54,
#    'genero': 'indie'},
#   {'track_name': 'Home to You',
#    'artist_name': 'Jack Botts',
#    'release_date': '2018-10-19',
#    'id_track': '74Wc7GSHUsVZaFHUOj6TyC',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Sempre In Due',
#    'artist_name': 'Carl Brave x Franco126',
#    'release_date': '2018-02-16',
#    'id_track': '6ElWuGFrYbsf2mdHWUoGCk',
#    'popularity': 57,
#    'genero': 'indie'},
#   {'track_name': 'Goca Dünya',
#    'artist_name': 'Altin Gün',
#    'release_date': '2018-03-30',
#    'id_track': '5QO3UJc1gF1ummP75n2b3R',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'Be My Fire',
#    'artist_name': 'The Blue Stones',
#    'release_date': '2018-10-26',
#    'id_track': '1lctRlmXFqukXxW4Gjm5HJ',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Habibi',
#    'artist_name': 'Tamino',
#    'release_date': '2018-10-19',
#    'id_track': '5juBKIr7vbfAUgFpa34DuO',
#    'popularity': 51,
#    'genero': 'indie'},
#   {'track_name': 'God Only Knows',
#    'artist_name': 'for KING & COUNTRY',
#    'release_date': '2018-10-05',
#    'id_track': '4ElNxglBjcrASiGn58t9Jm',
#    'popularity': 63,
#    'genero': 'indie'},
#   {'track_name': 'Estábamos Tan Bien',
#    'artist_name': 'Daniela Spalla',
#    'release_date': '2018-09-21',
#    'id_track': '3uRSGfI30pIW4efbKh4age',
#    'popularity': 51,
#    'genero': 'indie'},
#   {'track_name': 'Turntable',
#    'artist_name': 'Dead Horses',
#    'release_date': '2018-04-06',
#    'id_track': '0Dp07EA5ybveKSUE27CuEd',
#    'popularity': 45,
#    'genero': 'indie'},
#   {'track_name': 'Temptation',
#    'artist_name': 'Raveena',
#    'release_date': '2018-10-23',
#    'id_track': '0ulct3cASnhGvaGhFIuIyZ',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'Sincerity Is Scary',
#    'artist_name': 'The 1975',
#    'release_date': '2018-11-30',
#    'id_track': '6HguG9HRb1Ke1bhihfE4m8',
#    'popularity': 55,
#    'genero': 'indie'},
#   {'track_name': 'Night Market',
#    'artist_name': 'ConcernedApe',
#    'release_date': '2018-08-08',
#    'id_track': '2J82xw91Tqk1RaF38zUn8w',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'Anarchist',
#    'artist_name': 'YUNGBLUD',
#    'release_date': '2018-07-06',
#    'id_track': '3vVkxjrTP4SM1Ogq68LoXW',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Dead Inside',
#    'artist_name': 'Younger Hunger',
#    'release_date': '2018-10-12',
#    'id_track': '2JqyquFrqaoKt0SRr91meT',
#    'popularity': 54,
#    'genero': 'indie'},
#   {'track_name': 'Drunk in L.A.',
#    'artist_name': 'Beach House',
#    'release_date': '2018-05-11',
#    'id_track': '579f7KQP5rpiiugsVuSuoQ',
#    'popularity': 40,
#    'genero': 'indie'},
#   {'track_name': 'Some Feeling',
#    'artist_name': 'Mild Orange',
#    'release_date': '2018-04-18',
#    'id_track': '0zWvxp7DQhbL3ZiqknVqBK',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'Birthday Suit',
#    'artist_name': 'Cosmo Sheldrake',
#    'release_date': '2018-04-06',
#    'id_track': '598B9RU1jZhObFSQJhisIa',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'Painkillers',
#    'artist_name': 'Rainbow Kitten Surprise',
#    'release_date': '2018-04-06',
#    'id_track': '6fc51JZVE0Yijdi6RuoLFv',
#    'popularity': 63,
#    'genero': 'indie'},
#   {'track_name': 'Paris',
#    'artist_name': "L'Impératrice",
#    'release_date': '2018-03-02',
#    'id_track': '6UTDgh5ezazezpAe4HmAos',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'Sunset Canyon',
#    'artist_name': 'Foxwarren, Andy Shauf, Darryl Kissick',
#    'release_date': '2018-11-30',
#    'id_track': '4YvOkz9IrldHkWiDZremSr',
#    'popularity': 48,
#    'genero': 'indie'},
#   {'track_name': 'At Home',
#    'artist_name': 'Slow Pulp',
#    'release_date': '2018-06-05',
#    'id_track': '4wDgL9CFL7ee8Z7gwQCXJW',
#    'popularity': 54,
#    'genero': 'indie'},
#   {'track_name': 'Say, Can You Hear',
#    'artist_name': 'Men I Trust',
#    'release_date': '2018-11-30',
#    'id_track': '16Ky4KZFBlAnFzsgQOn5MT',
#    'popularity': 51,
#    'genero': 'indie'},
#   {'track_name': 'Same Old Song (S.O.S. Part 1)',
#    'artist_name': 'Two Feet',
#    'release_date': '2018-10-05',
#    'id_track': '41VDk3CQ9viP55n40jCniL',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'Disco Sole',
#    'artist_name': 'Nu Genea',
#    'release_date': '2018-05-01',
#    'id_track': '4shVjgoOMa73JgBtZIDDz4',
#    'popularity': 45,
#    'genero': 'indie'},
#   {'track_name': 'カラカラカラのカラ',
#    'artist_name': 'Kikuo',
#    'release_date': '2018-01-24',
#    'id_track': '2LEe6g4jPbwHNDM3dJCyCF',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'Aline',
#    'artist_name': 'Therapie TAXI',
#    'release_date': '2018-06-20',
#    'id_track': '2GdQWH8tkjfX9V4Ay296PE',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'Rose Petals',
#    'artist_name': 'S. Carey',
#    'release_date': '2018-02-23',
#    'id_track': '2qWuegI1pmesQPRvzgnokk',
#    'popularity': 43,
#    'genero': 'indie'},
#   {'track_name': 'Geyser',
#    'artist_name': 'Mitski',
#    'release_date': '2018-08-17',
#    'id_track': '2fCdOF4nBAeQaXW84WjoiU',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'Rolling With the Punches',
#    'artist_name': 'The Blue Stones',
#    'release_date': '2018-10-26',
#    'id_track': '0v9RvGFYslguejByMf7zp1',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'Triciclo Perú',
#    'artist_name': 'Los Mojarras',
#    'release_date': '2018-02-15',
#    'id_track': '1Ahb1lGCvsRSlmThubFzsy',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'Talia',
#    'artist_name': 'King Princess',
#    'release_date': '2018-04-13',
#    'id_track': '53jbdPQBaH6WaQvW0zmGBs',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'Cold War',
#    'artist_name': 'Cautious Clay',
#    'release_date': '2018-02-21',
#    'id_track': '6DwiGVCgXGREeCyJZtX7S1',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'Espacio',
#    'artist_name': 'Sous-Sol',
#    'release_date': '2018-07-20',
#    'id_track': '36aUaCD7uFu2MH4W6VIjio',
#    'popularity': 48,
#    'genero': 'indie'},
#   {'track_name': 'La Vida la Vida',
#    'artist_name': 'Jósean Log',
#    'release_date': '2018-01-26',
#    'id_track': '3zmkTFvCLTIa6JfPr8F8QX',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'Nocturne',
#    'artist_name': 'Blanco White',
#    'release_date': '2018-10-29',
#    'id_track': '3wSrfFr3uqwz17l1iF5rvc',
#    'popularity': 45,
#    'genero': 'indie'},
#   {'track_name': 'Pictures of Girls',
#    'artist_name': 'Wallows',
#    'release_date': '2018-04-06',
#    'id_track': '415dK4glwDO7fXxYg3np8B',
#    'popularity': 54,
#    'genero': 'indie'},
#   {'track_name': 'Such A Simple Thing - Recorded at Sound Stage Studios Nashville',
#    'artist_name': 'Ray LaMontagne',
#    'release_date': '2018-06-13',
#    'id_track': '1xYMyM7MxFi4OuzDA2op9Q',
#    'popularity': 45,
#    'genero': 'indie'},
#   {'track_name': 'Heaven',
#    'artist_name': 'Clairo',
#    'release_date': '2018-09-07',
#    'id_track': '4XYo3W8U6IY42EbB01rnR4',
#    'popularity': 60,
#    'genero': 'indie'},
#   {'track_name': 'Karpe Diem',
#    'artist_name': 'Ed Maverick',
#    'release_date': '2018-03-02',
#    'id_track': '2Jpw6uRsDncpCYkvdrfTTk',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Ddoje Facce',
#    'artist_name': 'Nu Genea',
#    'release_date': '2018-05-01',
#    'id_track': '2eugKq2QsQ3TRJ4JgbdpzC',
#    'popularity': 45,
#    'genero': 'indie'},
#   {'track_name': 'Low Life (2018)',
#    'artist_name': 'The Reytons',
#    'release_date': '2018-08-03',
#    'id_track': '3smy3Bm9wW1YpBvxsm4Kxl',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'count on',
#    'artist_name': 'Shallou, Colin',
#    'release_date': '2018-11-29',
#    'id_track': '1A4tabNlyLKLOHQW2XpjaU',
#    'popularity': 44,
#    'genero': 'indie'},
#   {'track_name': 'Party of One (feat. Sam Smith)',
#    'artist_name': 'Brandi Carlile, Sam Smith',
#    'release_date': '2018-10-17',
#    'id_track': '25fcj6d2W1l8DQL11Czdzb',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'Tints (feat. Kendrick Lamar)',
#    'artist_name': 'Anderson .Paak, Kendrick Lamar',
#    'release_date': '2018-11-16',
#    'id_track': '7c3SbTuufigBWURcICnAWy',
#    'popularity': 51,
#    'genero': 'indie'},
#   {'track_name': 'Please',
#    'artist_name': 'Noah Kahan',
#    'release_date': '2018-02-02',
#    'id_track': '6ltDkBIvtG6cP5xhXMvFie',
#    'popularity': 49,
#    'genero': 'indie'},
#   {'track_name': 'King of Everything',
#    'artist_name': 'Dominic Fike',
#    'release_date': '2018-10-16',
#    'id_track': '0lO1yt6M1l1OAs80M3vEfM',
#    'popularity': 54,
#    'genero': 'indie'},
#   {'track_name': 'Policía',
#    'artist_name': '1915',
#    'release_date': '2018-10-05',
#    'id_track': '0pDooPTaMUaDQfnBdbPdYo',
#    'popularity': 45,
#    'genero': 'indie'},
#   {'track_name': 'Bakara',
#    'artist_name': 'Polo & Pan',
#    'release_date': '2018-07-13',
#    'id_track': '5Sl1RVQbD9PigheYMG7yAP',
#    'popularity': 42,
#    'genero': 'indie'},
#   {'track_name': "Tommy's Party",
#    'artist_name': 'Peach Pit',
#    'release_date': '2018-06-28',
#    'id_track': '5OuJTtNve7FxUX82eEBupN',
#    'popularity': 56,
#    'genero': 'indie'},
#   {'track_name': 'Better Not (with Wafia)',
#    'artist_name': 'Louis The Child, Wafia',
#    'release_date': '2018-10-26',
#    'id_track': '7n1940b6kHcaEewFSZXnXa',
#    'popularity': 56,
#    'genero': 'indie'},
#   {'track_name': 'Where Angels Fear To Tread',
#    'artist_name': 'Disclosure',
#    'release_date': '2018-08-20',
#    'id_track': '1ZqeykOaDmjkldzs7XGR4b',
#    'popularity': 48,
#    'genero': 'indie'},
#   {'track_name': 'Absinthe',
#    'artist_name': 'I DONT KNOW HOW BUT THEY FOUND ME',
#    'release_date': '2018-11-09',
#    'id_track': '4hs2FbesB8qo6H5Berbikd',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'Du bist anders',
#    'artist_name': 'AnnenMayKantereit',
#    'release_date': '2018-12-07',
#    'id_track': '1FuB3SlcjgU3KAyDwUwB6r',
#    'popularity': 54,
#    'genero': 'indie'},
#   {'track_name': 'Hurt Somebody (With Julia Michaels)',
#    'artist_name': 'Noah Kahan, Julia Michaels',
#    'release_date': '2018-02-02',
#    'id_track': '7vA2Y79Q4bBqdzBCfHeGEe',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Narcissist (feat. The 1975)',
#    'artist_name': 'No Rome, The 1975',
#    'release_date': '2018-08-28',
#    'id_track': '4qjLvvBh5ZeKEPyShKRf06',
#    'popularity': 56,
#    'genero': 'indie'},
#   {'track_name': 'Aura',
#    'artist_name': 'SG Lewis, J Warner',
#    'release_date': '2018-04-06',
#    'id_track': '4qEEERg5kM60N2vcna11oq',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Persephone',
#    'artist_name': 'Tamino',
#    'release_date': '2018-10-19',
#    'id_track': '4tIbyvltn6p8NNzuGOyJUH',
#    'popularity': 47,
#    'genero': 'indie'},
#   {'track_name': 'Groceries',
#    'artist_name': 'Mallrat',
#    'release_date': '2018-06-01',
#    'id_track': '3II5NhDhjzIessLfaSjPQn',
#    'popularity': 52,
#    'genero': 'indie'},
#   {'track_name': 'Know You Better',
#    'artist_name': 'LEISURE',
#    'release_date': '2018-10-05',
#    'id_track': '0iSSotaTG7XEd7x0vSwlUw',
#    'popularity': 43,
#    'genero': 'indie'},
#   {'track_name': 'Hielo',
#    'artist_name': 'Zoé',
#    'release_date': '2018-04-18',
#    'id_track': '2YiqBesMJpszYU6raDOG0R',
#    'popularity': 56,
#    'genero': 'indie'},
#   {'track_name': 'Make Out in My Car - Sufjan Stevens Version',
#    'artist_name': 'Moses Sumney, Sufjan Stevens',
#    'release_date': '2018-05-25',
#    'id_track': '099OI5KEJXIIj1GezRIWU0',
#    'popularity': 46,
#    'genero': 'indie'},
#   {'track_name': 'I Can Change',
#    'artist_name': 'Lake Street Dive',
#    'release_date': '2018-05-04',
#    'id_track': '0jCe45cYIc6NXedmbIKy0Q',
#    'popularity': 51,
#    'genero': 'indie'},
#   {'track_name': 'No Van a Parar',
#    'artist_name': 'Peces Raros',
#    'release_date': '2018-10-26',
#    'id_track': '1GLYsZMbHm72Uy2QvzdgDQ',
#    'popularity': 45,
#    'genero': 'indie'},
#   {'track_name': 'Dull Knives (Cut Better)',
#    'artist_name': 'The Warning',
#    'release_date': '2018-11-25',
#    'id_track': '17qrNfLq2XLWTlXO7jn4p7',
#    'popularity': 45,
#    'genero': 'indie'}]}

# %%
df_resultados_reggaeton = pd.DataFrame (resultados ['reggaeton'])
df_resultados_reggaeton
# Out:
#                                       track_name  \
# 0                                        Amanece
# 1                                         Madura
# 2               X (feat. Maluma & Ozuna) - Remix
# 3                         Si Estuviésemos Juntos
# 4                                      Hipócrita
# ..                                           ...
# 495                                          420
# 496                                  Cuando Fuma
# 497  Ay Mi Dios (feat. Pitbull, Yandel & Chacal)
# 498                          Sensual Inspiration
# 499                                        Hielo
#
#                               artist_name release_date  \
# 0                          Anuel AA, Haze   2018-12-14
# 1                  Cosculluela, Bad Bunny   2018-04-13
# 2      Nicky Jam, J Balvin, Maluma, Ozuna   2018-06-29
# 3                               Bad Bunny   2018-12-23
# 4                          Anuel AA, Zion   2018-07-17
# ..                                    ...          ...
# 495           Jon Z, Newtone, Myke Towers   2018-04-20
# 496                                  Lyan   2018-04-22
# 497  IAmChino, Pitbull, Yandel, El Chacal   2018-07-20
# 498               Jowell & Randy, Farruko   2018-02-01
# 499                          Daddy Yankee   2018-05-18
#
#                    id_track  popularity     genero
# 0    1LiN0Z98FkR1t0m8KmLcAH          76  reggaeton
# 1    5n2XTRsYFlZwNBp06KAjDX          74  reggaeton
# 2    6JjPBQfI2Y8nIjnm65X6Pw          77  reggaeton
# 3    35wvL50xvKpCHEJPxLOLPI          75  reggaeton
# 4    4CbANooTL2aTHzJZqQ0Uvk          68  reggaeton
# ..                      ...         ...        ...
# 495  1Qkurre1pgzwODbuprzjIf          26  reggaeton
# 496  4YKCzYZ4WzcqIYaqRRmpOE          43  reggaeton
# 497  3QAZw2aBp2NUGC7FzitaOK          14  reggaeton
# 498  5zFMNDK1AaiHko0sx6vWhC          40  reggaeton
# 499  2HBycDgM5FIOUZFewSTUgp          32  reggaeton
#
# [500 rows x 6 columns]

# %%
df_resultados_pop = pd.DataFrame (resultados ['pop'])
df_resultados_pop
# Out:
#                               track_name       artist_name release_date  \
# 0                        Cuando Nadie Ve             Morat   2018-10-25
# 1                        Besos En Guerra     Morat, Juanes   2018-10-25
# 2                   Qué Bonito Es Querer   Manuel Carrasco   2018-12-07
# 3                               No Se Va             Morat   2018-10-25
# 4            Always Remember Us This Way         Lady Gaga   2018-10-05
# ..                                   ...               ...          ...
# 495                     Jatt Da Muqabala  Sidhu Moose Wala   2018-10-18
# 496                             الكدابين           Sherine   2018-10-24
# 497  La stella più fragile dell'universo            Ultimo   2018-02-09
# 498                              REVIVER    MY FIRST STORY   2018-10-17
# 499          Our dawn is hotter than day         SEVENTEEN   2018-07-16
#
#                    id_track  popularity genero
# 0    71iAechwVKGu26pahzFL0k          74    pop
# 1    1mlGScrDQqHqmhdIqE8MmA          74    pop
# 2    6uzGmmQ4CuG9HvZktEy0LF          60    pop
# 3    4khWEpnaijN0G1x019Uzdr          74    pop
# 4    2rbDhOo9Fh61Bbu23T2qCk          80    pop
# ..                      ...         ...    ...
# 495  71Udwiv5GsZghU6XQ5LXQj          60    pop
# 496  6OvHZA4I4Nl1F0Brs8nPkR          52    pop
# 497  3iHqUSg0LBRxAF5CzjBK9y          51    pop
# 498  1p6WtbNY4bDjiFBmSZolJY          50    pop
# 499  2EGRE8lyfRRGuq7spra3eR          57    pop
#
# [500 rows x 6 columns]

# %%
df_resultados_rap = pd.DataFrame (resultados ['rap'])
df_resultados_rap
# Out:
#                                  track_name  \
# 0                  All The Stars (with SZA)
# 1                                      Love
# 2                                Cicatrices
# 3                     MALA (feat. Anuel AA)
# 4                     BEBE (feat. Anuel AA)
# ..                                      ...
# 495                    Bounce Out With That
# 496                      Hard Work Pays Off
# 497                    Rubbin off the Paint
# 498  I Am the Grinch (feat. Fletcher Jones)
# 499                      No Cuenten Conmigo
#
#                                       artist_name release_date  \
# 0                             Kendrick Lamar, SZA   2018-02-09
# 1    Hard GZ, Lupita's Friends, Lil GZ, Tee Amara   2018-11-23
# 2                                    Natos y Waor   2018-02-13
# 3                               6ix9ine, Anuel AA         2018
# 4                               6ix9ine, Anuel AA         2018
# ..                                            ...          ...
# 495                                    YBN Nahmir   2018-09-07
# 496                            Future, Juice WRLD   2018-10-19
# 497                                    YBN Nahmir   2018-09-07
# 498            Tyler, The Creator, Fletcher Jones   2018-11-09
# 499                                    Alex Zurdo   2018-08-17
#
#                    id_track  popularity genero
# 0    3GCdLUSnKSMJhs4Tj6CV3s          90    rap
# 1    3wm27SCXXbKtLVv1B6JLFN          57    rap
# 2    2zQvtkghOHiBG48Bj0oFR9          57    rap
# 3    5tYCl2bT9bDjMuTyn6OVb0          74    rap
# 4    4jCodMLVA5tV5MhPrspTfV          67    rap
# ..                      ...         ...    ...
# 495  5gQcxYXqnofyocKgEbGYKt          58    rap
# 496  6gzIcEUuswJQGfJNPYMjjv          58    rap
# 497  6V4KHt9xu4TPEnDFoBeacT          59    rap
# 498  5TVQdlY5H99BSAciKixBSt          53    rap
# 499  6HAV1VX6u6a3ewmZyUhshw          45    rap
#
# [500 rows x 6 columns]

# %%
df_resultados_indie = pd.DataFrame (resultados ['indie'])
df_resultados_indie
# Out:
#                                       track_name  \
# 0                      Perdona (Ahora Sí Que Sí)
# 1                                          Pausa
# 2                             Let Me Down Slowly
# 3                                        El Pozo
# 4        Amar el Conflicto (todo Lo Que Importa)
# ..                                           ...
# 495                                        Hielo
# 496  Make Out in My Car - Sufjan Stevens Version
# 497                                 I Can Change
# 498                               No Van a Parar
# 499                     Dull Knives (Cut Better)
#
#                       artist_name release_date                id_track  \
# 0         Carolina Durante, Amaia   2018-11-23  1AODZVWUeYlsKoFTo2iyEA
# 1                            IZAL   2018-03-09  2xVrFCODKe7cGjc8nkOINq
# 2                   Alec Benjamin   2018-11-16  2qxmye6gAegTMjLKEBoR3d
# 3                            IZAL   2018-03-09  23mLKL6hhER8DHc6PBIRE2
# 4                     Viva Suecia   2018-06-01  69WmxTgi8QNP45mKobRDpq
# ..                            ...          ...                     ...
# 495                           Zoé   2018-04-18  2YiqBesMJpszYU6raDOG0R
# 496  Moses Sumney, Sufjan Stevens   2018-05-25  099OI5KEJXIIj1GezRIWU0
# 497              Lake Street Dive   2018-05-04  0jCe45cYIc6NXedmbIKy0Q
# 498                   Peces Raros   2018-10-26  1GLYsZMbHm72Uy2QvzdgDQ
# 499                   The Warning   2018-11-25  17qrNfLq2XLWTlXO7jn4p7
#
#      popularity genero
# 0            55  indie
# 1            53  indie
# 2            80  indie
# 3            50  indie
# 4            49  indie
# ..          ...    ...
# 495          56  indie
# 496          46  indie
# 497          51  indie
# 498          45  indie
# 499          45  indie
#
# [500 rows x 6 columns]

# %%
df_resultados_indie.to_csv("indie2018.csv")

# %%
df_resultados_pop.to_csv("pop2018.csv")

# %%
df_resultados_rap.to_csv("rap2018.csv")

# %%
df_resultados_reggaeton.to_csv("reggaeton2018.csv")
