# %% [markdown]
# Nombre de la aplicación 	ProyectoAdalab-Sara
#
# Tección de API 	a0f04126345752a0660606089F98185ce20
#
# Secreto compartido 	9778d44899a2bed919320cdf95d59cc3
#
# Registrado a 	saraadalaber Sara2286!

# %%
import requests

# Define tu API key de Last.fm
API_KEY = 'a0f04126345752a0660606089F98185ce20'  # Usa tu API Key aquí
BASE_URL = 'http://ws.audioscrobbler.com/2.0/'  # Base URL correcta de la API de Last.fm

# %%
import requests
import pandas as pd

url = 'https://ws.audioscrobbler.com/2.0/?method=chart.gettoptracks&api_key=%20a0f04126345752a0660a9831f785ce20&format=json'

llamada = requests.get(url)

# %%
TopCanciones=llamada.json()

# %%
TopCanciones.keys()
# Out:
# dict_keys(['tracks'])

# %%
print(TopCanciones["tracks"])
# Out:
# {'track': [{'name': 'DENIAL IS A RIVER', 'duration': '0', 'playcount': '6797498', 'listeners': '808654', 'mbid': '', 'url': 'https://www.last.fm/music/Doechii/_/DENIAL+IS+A+RIVER', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'Doechii', 'mbid': '', 'url': 'https://www.last.fm/music/Doechii'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}]}, {'name': 'Not Like Us', 'duration': '0', 'playcount': '21204486', 'listeners': '1498716', 'mbid': '', 'url': 'https://www.last.fm/music/Kendrick+Lamar/_/Not+Like+Us', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'Kendrick Lamar', 'mbid': '381086ea-f511-4aba-bdf9-71c753dc5077', 'url': 'https://www.last.fm/music/Kendrick+Lamar'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}]}, {'name': 'luther (with SZA)', 'duration': '0', 'playcount': '11875902', 'listeners': '956217', 'mbid': '', 'url': 'https://www.last.fm/music/Kendrick+Lamar/_/luther+(with+SZA)', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'Kendrick Lamar', 'mbid': '381086ea-f511-4aba-bdf9-71c753dc5077', 'url': 'https://www.last.fm/music/Kendrick+Lamar'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}]}, {'name': 'Good Luck, Babe!', 'duration': '0', 'playcount': '39716254', 'listeners': '1542940', 'mbid': '', 'url': 'https://www.last.fm/music/Chappell+Roan/_/Good+Luck,+Babe%21', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'Chappell Roan', 'mbid': '', 'url': 'https://www.last.fm/music/Chappell+Roan'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}]}, {'name': 'BIRDS OF A FEATHER', 'duration': '0', 'playcount': '36478173', 'listeners': '1628334', 'mbid': '', 'url': 'https://www.last.fm/music/Billie+Eilish/_/BIRDS+OF+A+FEATHER', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'Billie Eilish', 'mbid': '', 'url': 'https://www.last.fm/music/Billie+Eilish'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}]}, {' ...

# %%
dict_canciones = {}

for dato, cancion in enumerate(TopCanciones["tracks"]['track']):

    if 'name' in cancion and 'artist' in cancion:
        
        dict_canciones[dato + 1] = {'name':cancion ['name'], "artist": cancion["artist"]["name"]}



print(dict_canciones)
# Out:
# {1: {'name': 'DENIAL IS A RIVER', 'artist': 'Doechii'}, 2: {'name': 'Not Like Us', 'artist': 'Kendrick Lamar'}, 3: {'name': 'luther (with SZA)', 'artist': 'Kendrick Lamar'}, 4: {'name': 'Good Luck, Babe!', 'artist': 'Chappell Roan'}, 5: {'name': 'BIRDS OF A FEATHER', 'artist': 'Billie Eilish'}, 6: {'name': 'Abracadabra', 'artist': 'Lady Gaga'}, 7: {'name': 'tv off (feat. Lefty Gunplay)', 'artist': 'Kendrick Lamar'}, 8: {'name': 'espresso', 'artist': 'Sabrina Carpenter'}, 9: {'name': 'All The Stars (with SZA)', 'artist': 'Kendrick Lamar'}, 10: {'name': 'Die With A Smile', 'artist': 'Lady Gaga'}, 11: {'name': 'squabble up', 'artist': 'Kendrick Lamar'}, 12: {'name': 'See You Again (feat. Kali Uchis)', 'artist': 'Tyler, the Creator'}, 13: {'name': 'Pink Pony Club', 'artist': 'Chappell Roan'}, 14: {'name': 'guess featuring billie eilish', 'artist': 'Charli XCX'}, 15: {'name': 'tAsTe', 'artist': 'Sabrina Carpenter'}, 16: {'name': 'Like Him (feat. Lola Young)', 'artist': 'Tyler, the Creator'}, 17: {'name': 'HOT TO GO!', 'artist': 'Chappell Roan'}, 18: {'name': 'Please Please Please', 'artist': 'Sabrina Carpenter'}, 19: {'name': 'NISSAN ALTIMA', 'artist': 'Doechii'}, 20: {'name': 'Wildflower', 'artist': 'Billie Eilish'}, 21: {'name': 'Cry For Me', 'artist': 'The Weeknd'}, 22: {'name': '360', 'artist': 'Charli XCX'}, 23: {'name': 'Red Wine Supernova', 'artist': 'Chappell Roan'}, 24: {'name': 'No One Noticed', 'artist': 'The Marías'}, 25: {'name': 'Money Trees', 'artist': 'Kendrick Lamar'}, 26: {'name': 'STICKY (feat. GloRilla, Sexyy Red & Lil Wayne)', 'artist': 'Tyler, the Creator'}, 27: {'name': 'Bed Chem', 'artist': 'Sabrina Carpenter'}, 28: {'name': 'APT.', 'artist': 'Rosé'}, 29: {'name': 'HUMBLE.', 'artist': 'Kendrick Lamar'}, 30: {'name': 'Pink + White', 'artist': 'Frank Ocean'}, 31: {'name': 'CHIHIRO', 'artist': 'Billie Eilish'}, 32: {'name': 'Headlock', 'artist': 'Imogen Heap'}, 33: {'name': 'Casual', 'artist': 'Chappell Roan'}, 34: {'name': 'Kill Bill', 'artist': 'SZA'}, 35: {'name': 'Juno', 'artist': 'Sabrina Carpenter'}, 36: {'name': 'Von Dutch', 'artist': 'Charli XCX'}, 37: {'name': 'that’s so true', 'artist': 'Gracie Abrams'}, 38: {'name': 'Lovers Rock', 'artist': 'TV Girl'}, 39: {'name': 'Alright', 'artist': 'Kendrick Lamar'}, 40: {'name': 'Earfquake', 'artist': 'Tyler, the Creator'}, 41: {'name': 'Apple', 'artist': 'Charli XCX'}, 42: {'name': '505', 'artist': 'Arctic Monkeys'}, 43: {'name': 'Sailor Song', 'artist': 'Gigi Perez'}, 44: {'name': 'Busy Woman', 'artist': 'Sabrina Carpenter'}, 45: {'name': 'CATFISH', 'artist': 'Doechii'}, 46: {'name': 'Juna', 'artist': 'Clairo'}, 47: {'name': 'Feel Good Inc.', 'artist': 'Gorillaz'}, 48: {'name': 'The Less I Know the Better', 'artist': 'Tame Impala'}, 49: {'name': 'Sweater Weather', 'artist': 'The Neighbourhood'}, 50: {'name': 'Lunch', 'artist': 'Billie Eilish'}}

# %%
lista_canciones = list(dict_canciones.values())

print(lista_canciones)
# Out:
# [{'name': 'DENIAL IS A RIVER', 'artist': 'Doechii'}, {'name': 'Not Like Us', 'artist': 'Kendrick Lamar'}, {'name': 'luther (with SZA)', 'artist': 'Kendrick Lamar'}, {'name': 'Good Luck, Babe!', 'artist': 'Chappell Roan'}, {'name': 'BIRDS OF A FEATHER', 'artist': 'Billie Eilish'}, {'name': 'Abracadabra', 'artist': 'Lady Gaga'}, {'name': 'tv off (feat. Lefty Gunplay)', 'artist': 'Kendrick Lamar'}, {'name': 'espresso', 'artist': 'Sabrina Carpenter'}, {'name': 'All The Stars (with SZA)', 'artist': 'Kendrick Lamar'}, {'name': 'Die With A Smile', 'artist': 'Lady Gaga'}, {'name': 'squabble up', 'artist': 'Kendrick Lamar'}, {'name': 'See You Again (feat. Kali Uchis)', 'artist': 'Tyler, the Creator'}, {'name': 'Pink Pony Club', 'artist': 'Chappell Roan'}, {'name': 'guess featuring billie eilish', 'artist': 'Charli XCX'}, {'name': 'tAsTe', 'artist': 'Sabrina Carpenter'}, {'name': 'Like Him (feat. Lola Young)', 'artist': 'Tyler, the Creator'}, {'name': 'HOT TO GO!', 'artist': 'Chappell Roan'}, {'name': 'Please Please Please', 'artist': 'Sabrina Carpenter'}, {'name': 'NISSAN ALTIMA', 'artist': 'Doechii'}, {'name': 'Wildflower', 'artist': 'Billie Eilish'}, {'name': 'Cry For Me', 'artist': 'The Weeknd'}, {'name': '360', 'artist': 'Charli XCX'}, {'name': 'Red Wine Supernova', 'artist': 'Chappell Roan'}, {'name': 'No One Noticed', 'artist': 'The Marías'}, {'name': 'Money Trees', 'artist': 'Kendrick Lamar'}, {'name': 'STICKY (feat. GloRilla, Sexyy Red & Lil Wayne)', 'artist': 'Tyler, the Creator'}, {'name': 'Bed Chem', 'artist': 'Sabrina Carpenter'}, {'name': 'APT.', 'artist': 'Rosé'}, {'name': 'HUMBLE.', 'artist': 'Kendrick Lamar'}, {'name': 'Pink + White', 'artist': 'Frank Ocean'}, {'name': 'CHIHIRO', 'artist': 'Billie Eilish'}, {'name': 'Headlock', 'artist': 'Imogen Heap'}, {'name': 'Casual', 'artist': 'Chappell Roan'}, {'name': 'Kill Bill', 'artist': 'SZA'}, {'name': 'Juno', 'artist': 'Sabrina Carpenter'}, {'name': 'Von Dutch', 'artist': 'Charli XCX'}, {'name': 'that’s so true', 'artist': 'Gracie Abrams'}, {'name': 'Lovers Rock', 'artist': 'TV Girl'}, {'name': 'Alright', 'artist': 'Kendrick Lamar'}, {'name': 'Earfquake', 'artist': 'Tyler, the Creator'}, {'name': 'Apple', 'artist': 'Charli XCX'}, {'name': '505', 'artist': 'Arctic Monkeys'}, {'name': 'Sailor Song', 'artist': 'Gigi Perez'}, {'name': 'Busy Woman', 'artist': 'Sabrina Carpenter'}, {'name': 'CATFISH', 'artist': 'Doechii'}, {'name': 'Juna', 'artist': 'Clairo'}, {'name': 'Feel Good Inc.', 'artist': 'Gorillaz'}, {'name': 'The Less I Know the Better', 'artist': 'Tame Impala'}, {'name': 'Sweater Weather', 'artist': 'The Neighbourhood'}, {'name': 'Lunch', 'artist': 'Billie Eilish'}]

# %%
df_lista_canciones = pd.DataFrame (lista_canciones)

# %%
df_lista_canciones
# Out:
#                                               name              artist
# 0                                DENIAL IS A RIVER             Doechii
# 1                                      Not Like Us      Kendrick Lamar
# 2                                luther (with SZA)      Kendrick Lamar
# 3                                 Good Luck, Babe!       Chappell Roan
# 4                               BIRDS OF A FEATHER       Billie Eilish
# 5                                      Abracadabra           Lady Gaga
# 6                     tv off (feat. Lefty Gunplay)      Kendrick Lamar
# 7                                         espresso   Sabrina Carpenter
# 8                         All The Stars (with SZA)      Kendrick Lamar
# 9                                 Die With A Smile           Lady Gaga
# 10                                     squabble up      Kendrick Lamar
# 11                See You Again (feat. Kali Uchis)  Tyler, the Creator
# 12                                  Pink Pony Club       Chappell Roan
# 13                   guess featuring billie eilish          Charli XCX
# 14                                           tAsTe   Sabrina Carpenter
# 15                     Like Him (feat. Lola Young)  Tyler, the Creator
# 16                                      HOT TO GO!       Chappell Roan
# 17                            Please Please Please   Sabrina Carpenter
# 18                                   NISSAN ALTIMA             Doechii
# 19                                      Wildflower       Billie Eilish
# 20                                      Cry For Me          The Weeknd
# 21                                             360          Charli XCX
# 22                              Red Wine Supernova       Chappell Roan
# 23                                  No One Noticed          The Marías
# 24                                     Money Trees      Kendrick Lamar
# 25  STICKY (feat. GloRilla, Sexyy Red & Lil Wayne)  Tyler, the Creator
# 26                                        Bed Chem   Sabrina Carpenter
# 27                                            APT.                Rosé
# 28                                         HUMBLE.      Kendrick Lamar
# 29                                    Pink + White         Frank Ocean
# 30                                         CHIHIRO       Billie Eilish
# 31                                        Headlock         Imogen Heap
# 32                                          Casual       Chappell Roan
# 33                                       Kill Bill                 SZA
# 34                                            Juno   Sabrina Carpenter
# 35                                       Von Dutch          Charli XCX
# 36                                  that’s so true       Gracie Abrams
# 37                                     Lovers Rock             TV Girl
# 38                                         Alright      Kendrick Lamar
# 39                                       Earfquake  Tyler, the Creator
# 40                                           Apple          Charli XCX
# 41                                             505      Arctic Monkeys
# 42                                     Sailor Song          Gigi Perez
# 43                                      Busy Woman   Sabrina Carpenter
# 44                                         CATFISH             Doechii
# 45                                            Juna              Clairo
# 46                                  Feel Good Inc.            Gorillaz
# 47                      The Less I Know the Better         Tame Impala
# 48                                 Sweater Weather   The Neighbourhood
# 49                                           Lunch       Billie Eilish

# %%
import requests
import pandas as pd

url = 'https://ws.audioscrobbler.com/2.0/?method=chart.gettoptracks&api_key=%20a0f04126345752a0660a9831f785ce20&format=json'


from_year = int(2018) 
to_year = int(2022) 
params = {'from':from_year, 'to':to_year}

max_resultados = 200
resultados_obtenidos = 0

while resultados_obtenidos < max_resultados:
    
    params.update({
        'from':from_year, 'to':to_year,
        'format': 'json', 
        'limit': 50, # Máximo número de resultados por solicitud (50 es el límite)
        'page': (resultados_obtenidos // 50) + 1 
    })
    
    top_canciones_fecha = llamada.json()

print (resultados_obtenidos)
print (top_canciones_fecha)

# %%
import requests
import pandas as pd

url = 'https://ws.audioscrobbler.com/2.0/?method=chart.gettoptracks&api_key=a0f04126345752a0660a9831f785ce20&format=json'

# Definimos los años de inicio y fin
from_year = int(2018) 
to_year = int(2022)

# Inicializamos los parámetros de la solicitud
params = {'from': from_year, 'to': to_year}

# Establecemos los límites de resultados
max_resultados = 200
resultados_obtenidos = 0

# Lista para almacenar los resultados de las canciones
canciones_lista = []

# Bucle para obtener los resultados paginados
while resultados_obtenidos < max_resultados:
    
    params.update({
        'format': 'json', 
        'limit': 50,  # Número máximo de resultados por solicitud
        'page': (resultados_obtenidos // 50) + 1  # Página que vamos a consultar
    })
    
    # Realizamos la solicitud a la API
    llamada = requests.get(url, params=params)
        
        # Verificamos si la respuesta contiene las canciones
    if 'tracks' in top_canciones_fecha:
        tracks = top_canciones_fecha['tracks']['track']
            
        # Añadimos las canciones a la lista
        for track in tracks:
            name = track.get('name', 'Sin nombre')
            artist_name = track.get('artist', {}).get('name', 'Desconocido')
                
            # Creamos un diccionario con los datos de la canción
            cancion_top= {
                'name': name,
                'artist': artist_name
                }
                
            # Añadimos la canción a la lista
            canciones_lista.append(cancion_top)
            
        # Actualizamos el número de resultados obtenidos
        resultados_obtenidos += len(tracks)

# %%
len (canciones_lista)
# Out:
# 200

# %%
canciones_lista
# Out:
# [{'name': 'DENIAL IS A RIVER', 'artist': 'Doechii'},
#  {'name': 'Not Like Us', 'artist': 'Kendrick Lamar'},
#  {'name': 'luther (with SZA)', 'artist': 'Kendrick Lamar'},
#  {'name': 'Good Luck, Babe!', 'artist': 'Chappell Roan'},
#  {'name': 'BIRDS OF A FEATHER', 'artist': 'Billie Eilish'},
#  {'name': 'Abracadabra', 'artist': 'Lady Gaga'},
#  {'name': 'tv off (feat. Lefty Gunplay)', 'artist': 'Kendrick Lamar'},
#  {'name': 'espresso', 'artist': 'Sabrina Carpenter'},
#  {'name': 'All The Stars (with SZA)', 'artist': 'Kendrick Lamar'},
#  {'name': 'Die With A Smile', 'artist': 'Lady Gaga'},
#  {'name': 'squabble up', 'artist': 'Kendrick Lamar'},
#  {'name': 'See You Again (feat. Kali Uchis)', 'artist': 'Tyler, the Creator'},
#  {'name': 'Pink Pony Club', 'artist': 'Chappell Roan'},
#  {'name': 'guess featuring billie eilish', 'artist': 'Charli XCX'},
#  {'name': 'tAsTe', 'artist': 'Sabrina Carpenter'},
#  {'name': 'Like Him (feat. Lola Young)', 'artist': 'Tyler, the Creator'},
#  {'name': 'HOT TO GO!', 'artist': 'Chappell Roan'},
#  {'name': 'Please Please Please', 'artist': 'Sabrina Carpenter'},
#  {'name': 'NISSAN ALTIMA', 'artist': 'Doechii'},
#  {'name': 'Wildflower', 'artist': 'Billie Eilish'},
#  {'name': 'Cry For Me', 'artist': 'The Weeknd'},
#  {'name': '360', 'artist': 'Charli XCX'},
#  {'name': 'Red Wine Supernova', 'artist': 'Chappell Roan'},
#  {'name': 'No One Noticed', 'artist': 'The Marías'},
#  {'name': 'Money Trees', 'artist': 'Kendrick Lamar'},
#  {'name': 'STICKY (feat. GloRilla, Sexyy Red & Lil Wayne)',
#   'artist': 'Tyler, the Creator'},
#  {'name': 'Bed Chem', 'artist': 'Sabrina Carpenter'},
#  {'name': 'APT.', 'artist': 'Rosé'},
#  {'name': 'HUMBLE.', 'artist': 'Kendrick Lamar'},
#  {'name': 'Pink + White', 'artist': 'Frank Ocean'},
#  {'name': 'CHIHIRO', 'artist': 'Billie Eilish'},
#  {'name': 'Headlock', 'artist': 'Imogen Heap'},
#  {'name': 'Casual', 'artist': 'Chappell Roan'},
#  {'name': 'Kill Bill', 'artist': 'SZA'},
#  {'name': 'Juno', 'artist': 'Sabrina Carpenter'},
#  {'name': 'Von Dutch', 'artist': 'Charli XCX'},
#  {'name': 'that’s so true', 'artist': 'Gracie Abrams'},
#  {'name': 'Lovers Rock', 'artist': 'TV Girl'},
#  {'name': 'Alright', 'artist': 'Kendrick Lamar'},
#  {'name': 'Earfquake', 'artist': 'Tyler, the Creator'},
#  {'name': 'Apple', 'artist': 'Charli XCX'},
#  {'name': '505', 'artist': 'Arctic Monkeys'},
#  {'name': 'Sailor Song', 'artist': 'Gigi Perez'},
#  {'name': 'Busy Woman', 'artist': 'Sabrina Carpenter'},
#  {'name': 'CATFISH', 'artist': 'Doechii'},
#  {'name': 'Juna', 'artist': 'Clairo'},
#  {'name': 'Feel Good Inc.', 'artist': 'Gorillaz'},
#  {'name': 'The Less I Know the Better', 'artist': 'Tame Impala'},
#  {'name': 'Sweater Weather', 'artist': 'The Neighbourhood'},
#  {'name': 'Lunch', 'artist': 'Billie Eilish'},
#  {'name': 'DENIAL IS A RIVER', 'artist': 'Doechii'},
#  {'name': 'Not Like Us', 'artist': 'Kendrick Lamar'},
#  {'name': 'luther (with SZA)', 'artist': 'Kendrick Lamar'},
#  {'name': 'Good Luck, Babe!', 'artist': 'Chappell Roan'},
#  {'name': 'BIRDS OF A FEATHER', 'artist': 'Billie Eilish'},
#  {'name': 'Abracadabra', 'artist': 'Lady Gaga'},
#  {'name': 'tv off (feat. Lefty Gunplay)', 'artist': 'Kendrick Lamar'},
#  {'name': 'espresso', 'artist': 'Sabrina Carpenter'},
#  {'name': 'All The Stars (with SZA)', 'artist': 'Kendrick Lamar'},
#  {'name': 'Die With A Smile', 'artist': 'Lady Gaga'},
#  {'name': 'squabble up', 'artist': 'Kendrick Lamar'},
#  {'name': 'See You Again (feat. Kali Uchis)', 'artist': 'Tyler, the Creator'},
#  {'name': 'Pink Pony Club', 'artist': 'Chappell Roan'},
#  {'name': 'guess featuring billie eilish', 'artist': 'Charli XCX'},
#  {'name': 'tAsTe', 'artist': 'Sabrina Carpenter'},
#  {'name': 'Like Him (feat. Lola Young)', 'artist': 'Tyler, the Creator'},
#  {'name': 'HOT TO GO!', 'artist': 'Chappell Roan'},
#  {'name': 'Please Please Please', 'artist': 'Sabrina Carpenter'},
#  {'name': 'NISSAN ALTIMA', 'artist': 'Doechii'},
#  {'name': 'Wildflower', 'artist': 'Billie Eilish'},
#  {'name': 'Cry For Me', 'artist': 'The Weeknd'},
#  {'name': '360', 'artist': 'Charli XCX'},
#  {'name': 'Red Wine Supernova', 'artist': 'Chappell Roan'},
#  {'name': 'No One Noticed', 'artist': 'The Marías'},
#  {'name': 'Money Trees', 'artist': 'Kendrick Lamar'},
#  {'name': 'STICKY (feat. GloRilla, Sexyy Red & Lil Wayne)',
#   'artist': 'Tyler, the Creator'},
#  {'name': 'Bed Chem', 'artist': 'Sabrina Carpenter'},
#  {'name': 'APT.', 'artist': 'Rosé'},
#  {'name': 'HUMBLE.', 'artist': 'Kendrick Lamar'},
#  {'name': 'Pink + White', 'artist': 'Frank Ocean'},
#  {'name': 'CHIHIRO', 'artist': 'Billie Eilish'},
#  {'name': 'Headlock', 'artist': 'Imogen Heap'},
#  {'name': 'Casual', 'artist': 'Chappell Roan'},
#  {'name': 'Kill Bill', 'artist': 'SZA'},
#  {'name': 'Juno', 'artist': 'Sabrina Carpenter'},
#  {'name': 'Von Dutch', 'artist': 'Charli XCX'},
#  {'name': 'that’s so true', 'artist': 'Gracie Abrams'},
#  {'name': 'Lovers Rock', 'artist': 'TV Girl'},
#  {'name': 'Alright', 'artist': 'Kendrick Lamar'},
#  {'name': 'Earfquake', 'artist': 'Tyler, the Creator'},
#  {'name': 'Apple', 'artist': 'Charli XCX'},
#  {'name': '505', 'artist': 'Arctic Monkeys'},
#  {'name': 'Sailor Song', 'artist': 'Gigi Perez'},
#  {'name': 'Busy Woman', 'artist': 'Sabrina Carpenter'},
#  {'name': 'CATFISH', 'artist': 'Doechii'},
#  {'name': 'Juna', 'artist': 'Clairo'},
#  {'name': 'Feel Good Inc.', 'artist': 'Gorillaz'},
#  {'name': 'The Less I Know the Better', 'artist': 'Tame Impala'},
#  {'name': 'Sweater Weather', 'artist': 'The Neighbourhood'},
#  {'name': 'Lunch', 'artist': 'Billie Eilish'},
#  {'name': 'DENIAL IS A RIVER', 'artist': 'Doechii'},
#  {'name': 'Not Like Us', 'artist': 'Kendrick Lamar'},
#  {'name': 'luther (with SZA)', 'artist': 'Kendrick Lamar'},
#  {'name': 'Good Luck, Babe!', 'artist': 'Chappell Roan'},
#  {'name': 'BIRDS OF A FEATHER', 'artist': 'Billie Eilish'},
#  {'name': 'Abracadabra', 'artist': 'Lady Gaga'},
#  {'name': 'tv off (feat. Lefty Gunplay)', 'artist': 'Kendrick Lamar'},
#  {'name': 'espresso', 'artist': 'Sabrina Carpenter'},
#  {'name': 'All The Stars (with SZA)', 'artist': 'Kendrick Lamar'},
#  {'name': 'Die With A Smile', 'artist': 'Lady Gaga'},
#  {'name': 'squabble up', 'artist': 'Kendrick Lamar'},
#  {'name': 'See You Again (feat. Kali Uchis)', 'artist': 'Tyler, the Creator'},
#  {'name': 'Pink Pony Club', 'artist': 'Chappell Roan'},
#  {'name': 'guess featuring billie eilish', 'artist': 'Charli XCX'},
#  {'name': 'tAsTe', 'artist': 'Sabrina Carpenter'},
#  {'name': 'Like Him (feat. Lola Young)', 'artist': 'Tyler, the Creator'},
#  {'name': 'HOT TO GO!', 'artist': 'Chappell Roan'},
#  {'name': 'Please Please Please', 'artist': 'Sabrina Carpenter'},
#  {'name': 'NISSAN ALTIMA', 'artist': 'Doechii'},
#  {'name': 'Wildflower', 'artist': 'Billie Eilish'},
#  {'name': 'Cry For Me', 'artist': 'The Weeknd'},
#  {'name': '360', 'artist': 'Charli XCX'},
#  {'name': 'Red Wine Supernova', 'artist': 'Chappell Roan'},
#  {'name': 'No One Noticed', 'artist': 'The Marías'},
#  {'name': 'Money Trees', 'artist': 'Kendrick Lamar'},
#  {'name': 'STICKY (feat. GloRilla, Sexyy Red & Lil Wayne)',
#   'artist': 'Tyler, the Creator'},
#  {'name': 'Bed Chem', 'artist': 'Sabrina Carpenter'},
#  {'name': 'APT.', 'artist': 'Rosé'},
#  {'name': 'HUMBLE.', 'artist': 'Kendrick Lamar'},
#  {'name': 'Pink + White', 'artist': 'Frank Ocean'},
#  {'name': 'CHIHIRO', 'artist': 'Billie Eilish'},
#  {'name': 'Headlock', 'artist': 'Imogen Heap'},
#  {'name': 'Casual', 'artist': 'Chappell Roan'},
#  {'name': 'Kill Bill', 'artist': 'SZA'},
#  {'name': 'Juno', 'artist': 'Sabrina Carpenter'},
#  {'name': 'Von Dutch', 'artist': 'Charli XCX'},
#  {'name': 'that’s so true', 'artist': 'Gracie Abrams'},
#  {'name': 'Lovers Rock', 'artist': 'TV Girl'},
#  {'name': 'Alright', 'artist': 'Kendrick Lamar'},
#  {'name': 'Earfquake', 'artist': 'Tyler, the Creator'},
#  {'name': 'Apple', 'artist': 'Charli XCX'},
#  {'name': '505', 'artist': 'Arctic Monkeys'},
#  {'name': 'Sailor Song', 'artist': 'Gigi Perez'},
#  {'name': 'Busy Woman', 'artist': 'Sabrina Carpenter'},
#  {'name': 'CATFISH', 'artist': 'Doechii'},
#  {'name': 'Juna', 'artist': 'Clairo'},
#  {'name': 'Feel Good Inc.', 'artist': 'Gorillaz'},
#  {'name': 'The Less I Know the Better', 'artist': 'Tame Impala'},
#  {'name': 'Sweater Weather', 'artist': 'The Neighbourhood'},
#  {'name': 'Lunch', 'artist': 'Billie Eilish'},
#  {'name': 'DENIAL IS A RIVER', 'artist': 'Doechii'},
#  {'name': 'Not Like Us', 'artist': 'Kendrick Lamar'},
#  {'name': 'luther (with SZA)', 'artist': 'Kendrick Lamar'},
#  {'name': 'Good Luck, Babe!', 'artist': 'Chappell Roan'},
#  {'name': 'BIRDS OF A FEATHER', 'artist': 'Billie Eilish'},
#  {'name': 'Abracadabra', 'artist': 'Lady Gaga'},
#  {'name': 'tv off (feat. Lefty Gunplay)', 'artist': 'Kendrick Lamar'},
#  {'name': 'espresso', 'artist': 'Sabrina Carpenter'},
#  {'name': 'All The Stars (with SZA)', 'artist': 'Kendrick Lamar'},
#  {'name': 'Die With A Smile', 'artist': 'Lady Gaga'},
#  {'name': 'squabble up', 'artist': 'Kendrick Lamar'},
#  {'name': 'See You Again (feat. Kali Uchis)', 'artist': 'Tyler, the Creator'},
#  {'name': 'Pink Pony Club', 'artist': 'Chappell Roan'},
#  {'name': 'guess featuring billie eilish', 'artist': 'Charli XCX'},
#  {'name': 'tAsTe', 'artist': 'Sabrina Carpenter'},
#  {'name': 'Like Him (feat. Lola Young)', 'artist': 'Tyler, the Creator'},
#  {'name': 'HOT TO GO!', 'artist': 'Chappell Roan'},
#  {'name': 'Please Please Please', 'artist': 'Sabrina Carpenter'},
#  {'name': 'NISSAN ALTIMA', 'artist': 'Doechii'},
#  {'name': 'Wildflower', 'artist': 'Billie Eilish'},
#  {'name': 'Cry For Me', 'artist': 'The Weeknd'},
#  {'name': '360', 'artist': 'Charli XCX'},
#  {'name': 'Red Wine Supernova', 'artist': 'Chappell Roan'},
#  {'name': 'No One Noticed', 'artist': 'The Marías'},
#  {'name': 'Money Trees', 'artist': 'Kendrick Lamar'},
#  {'name': 'STICKY (feat. GloRilla, Sexyy Red & Lil Wayne)',
#   'artist': 'Tyler, the Creator'},
#  {'name': 'Bed Chem', 'artist': 'Sabrina Carpenter'},
#  {'name': 'APT.', 'artist': 'Rosé'},
#  {'name': 'HUMBLE.', 'artist': 'Kendrick Lamar'},
#  {'name': 'Pink + White', 'artist': 'Frank Ocean'},
#  {'name': 'CHIHIRO', 'artist': 'Billie Eilish'},
#  {'name': 'Headlock', 'artist': 'Imogen Heap'},
#  {'name': 'Casual', 'artist': 'Chappell Roan'},
#  {'name': 'Kill Bill', 'artist': 'SZA'},
#  {'name': 'Juno', 'artist': 'Sabrina Carpenter'},
#  {'name': 'Von Dutch', 'artist': 'Charli XCX'},
#  {'name': 'that’s so true', 'artist': 'Gracie Abrams'},
#  {'name': 'Lovers Rock', 'artist': 'TV Girl'},
#  {'name': 'Alright', 'artist': 'Kendrick Lamar'},
#  {'name': 'Earfquake', 'artist': 'Tyler, the Creator'},
#  {'name': 'Apple', 'artist': 'Charli XCX'},
#  {'name': '505', 'artist': 'Arctic Monkeys'},
#  {'name': 'Sailor Song', 'artist': 'Gigi Perez'},
#  {'name': 'Busy Woman', 'artist': 'Sabrina Carpenter'},
#  {'name': 'CATFISH', 'artist': 'Doechii'},
#  {'name': 'Juna', 'artist': 'Clairo'},
#  {'name': 'Feel Good Inc.', 'artist': 'Gorillaz'},
#  {'name': 'The Less I Know the Better', 'artist': 'Tame Impala'},
#  {'name': 'Sweater Weather', 'artist': 'The Neighbourhood'},
#  {'name': 'Lunch', 'artist': 'Billie Eilish'}]
